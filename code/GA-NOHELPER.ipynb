# %% [markdown]
# ---
# # Import LiB

# %%
import pandas as pd
import random
from collections import defaultdict, Counter
import numpy as np
import csv
import os

# %% [markdown]
# ---
# # INIT GLOBAL CONST

# %%
POPULASI = 50
ITERATION = 3000
MUTATION_PROB = 0.8
CROSSOVER_PROB = 0.7 
TOURNAMENT_SIZE = 10
SLOT_PER_KELAS = 36
JUMLAH_KELAS = 27
FITNESS_EXPORT = "GA-NOHELPER3.csv" # input user
RECORD_EXPORT = "GA-NOHELPER3.csv" # input user

# %% [markdown]
# ---
# # IMPORT DATA

# %%
guru_df = pd.read_csv('../dataset/guru.csv')
kelas_df = pd.read_csv('../dataset/kelas.csv')
mapel_df = pd.read_csv('../dataset/mapel.csv')
relasi_guru_mapel_df = pd.read_csv('../dataset/relasi_guru_mapel.csv')
slot_df = pd.read_csv('../dataset/slot.csv')
wali_kelas_df = pd.read_csv('../dataset/wali_kelas.csv')

# %% [markdown]
# ---
# # DICT MAKER

# %%
# =========================================================
# Mapping hari -> id
# Digunakan agar proses komputasi lebih cepat dibanding
# menggunakan string nama hari secara langsung.
# =========================================================
hariId = {
    "Senin": 1,
    "Selasa": 2,
    "Rabu": 3,
    "Kamis": 4,
    "Jumat": 5,
}

# =========================================================
# Slot per hari
# Menghitung jumlah slot jam pelajaran untuk setiap hari
# berdasarkan data slot_df.
# Hasilnya akan digunakan saat evaluasi fitness dan
# pembentukan jadwal.
# =========================================================

# Hitung jumlah slot tiap hari dari dataframe slot
slotPerHariDict = slot_df['hari'].value_counts().to_dict()

# Ubah key dari nama hari menjadi id hari
slotPerHariDict = {hariId[k]: v for k, v in slotPerHariDict.items()}

# Disimpan dalam numpy array agar perhitungan evaluasi
# (loop, indexing) lebih cepat
slotPerHari = np.array([
    slotPerHariDict[1],
    slotPerHariDict[2],
    slotPerHariDict[3],
    slotPerHariDict[4],
    slotPerHariDict[5]
])

# =========================================================
# Kelas -> tingkatan
# Mapping setiap kelas dengan tingkatan (misal kelas X, XI, XII)
# Informasi ini penting karena beberapa guru hanya mengajar
# mapel pada tingkatan tertentu.
# =========================================================
kelasTingkatan = dict(
    zip(kelas_df['kelas_id'], kelas_df['tingkatan'])
)

# Ambil seluruh id kelas dan urutkan
kelasIds = np.array(sorted(kelasTingkatan.keys()))

# Jumlah total kelas dalam sistem
JUMLAH_KELAS = len(kelasIds)

# =========================================================
# Mapel -> jam per minggu
# Menyimpan jumlah jam pelajaran setiap mapel per minggu
# =========================================================
jamPerMingguMapel = dict(
    zip(mapel_df['mapel_id'], mapel_df['jam_per_minggu'])
)

# Array id mapel
mapelIds = np.array(list(jamPerMingguMapel.keys()))

# Array jumlah jam tiap mapel
jamMapel = np.array(list(jamPerMingguMapel.values()))

# =========================================================
# MGMP Mapel
# MGMP = waktu rapat guru mapel tertentu
# Mapel tidak boleh dijadwalkan pada hari MGMP tersebut
# =========================================================
mgmpMapel = dict(
    zip(mapel_df['mapel_id'], mapel_df['MGMP'])
)

# Konversi hari MGMP dari string menjadi id hari
mgmpMapel = {
    mapel_id: hariId[hari]
    for mapel_id, hari in mgmpMapel.items()
}

# =========================================================
# Batas slot siang
# Slot setelah batas ini dianggap slot siang.
# Beberapa mapel diusahakan tidak ditempatkan di slot siang.
# =========================================================
batasSiang = np.array([
    5,  # senin
    5,  # selasa
    4,  # rabu
    5,  # kamis
    4   # jumat
])

# =========================================================
# Batas MGMP per hari
# Jumlah maksimum mapel MGMP yang boleh muncul dalam
# satu hari tertentu.
# =========================================================
batasMGMP = np.array([
    2,
    2,
    2,
    2,
    1
])

# =========================================================
# Guru valid untuk mapel + tingkatan
# Membuat relasi guru yang boleh mengajar mapel tertentu
# pada tingkatan tertentu.
# key   = (mapel_id, tingkatan)
# value = list guru yang boleh mengajar
# =========================================================
guruValidMapel = defaultdict(list)

for row in relasi_guru_mapel_df.itertuples():

    # pasangan mapel dan tingkatan
    key = (row.mapel_id, row.tingkatan)

    # tambahkan guru yang memenuhi kriteria
    guruValidMapel[key].append(row.guru_id)

# ubah menjadi dictionary biasa
guruValidMapel = dict(guruValidMapel)

# =========================================================
# Guru mengajar durasi
# Menghitung total beban mengajar setiap guru
# digunakan untuk mengecek constraint durasi guru
# =========================================================
maxJamGuru = (
    relasi_guru_mapel_df
    .groupby("guru_id")["durasi"]
    .sum()
    .to_dict()
)

# =========================================================
# Wali kelas
# Mapping guru yang menjadi wali kelas untuk kelas tertentu.
# Digunakan sebagai constraint tambahan dalam penjadwalan.
# =========================================================
waliKelas = dict(
    zip(wali_kelas_df['guru_id'], wali_kelas_df['kelas_id'])
)

# =========================================================
# Slot -> hari
# Setiap slot memiliki informasi hari ke berapa.
# Digunakan untuk mengetahui posisi hari dari setiap gen
# dalam kromosom.
# =========================================================
slotHari = np.array([
    hariId[row.hari]
    for row in slot_df.itertuples()
])

# Jumlah slot untuk setiap kelas
SLOT_PER_KELAS = len(slotHari)

# =========================================================
# Total gen kromosom
# Dalam representasi GA:
# kromosom = jadwal seluruh kelas
# gen      = satu slot pelajaran
# =========================================================
TOTAL_SLOT = JUMLAH_KELAS * SLOT_PER_KELAS

# =========================================================
# Fitness weight
# Bobot penalti setiap constraint dalam evaluasi fitness.
# Semakin besar bobotnya, semakin penting constraint tersebut.
# =========================================================
fitnessWeight = {
    "guruBentrok": 100,          # guru mengajar di dua kelas pada waktu sama
    "distribusiMapel": 20,       # distribusi mapel tidak merata
    "konsistensiGuruMapel": 20,  # mapel diajar guru berbeda
    "durasiGuru": 10,            # jam mengajar melebihi batas
    "waktuMGMP": 5,              # melanggar jadwal MGMP
    "mapelSiang": 5,             # mapel muncul di slot siang
    "cekWaliKelas": 5            # wali kelas tidak sesuai
}

# =========================================================
# Blok jam mata pelajaran
# Beberapa mapel harus diajarkan secara berurutan
# (misalnya 2 jam berturut-turut).
# Fungsi ini menentukan pembagian blok jam tersebut.
# =========================================================
def blokDistribusi(jam):

    # mapel 2 jam -> 1 blok 2 jam
    if jam == 2:
        return [2]

    # mapel 3 jam -> 1 blok 3 jam
    if jam == 3:
        return [3]

    # mapel 4 jam -> 2 blok (2+2)
    if jam == 4:
        return [2,2]

    # mapel 5 jam -> 2 blok (2+3)
    if jam == 5:
        return [2,3]

    # default
    return [jam]


# ======================================
# slot awal dan akhir hari
# Digunakan untuk mengetahui batas indeks
# slot setiap hari dalam kromosom.
# ======================================

# indeks slot pertama tiap hari
slotAwalHari = np.concatenate(([0], np.cumsum(slotPerHari)[:-1]))

# indeks slot terakhir tiap hari
slotAkhirHari = np.cumsum(slotPerHari)


# ======================================
# blok mapel
# Menyimpan pembagian blok jam untuk
# setiap mata pelajaran.
# ======================================

blokMapel = {}

for mapel_id, jam in jamPerMingguMapel.items():

    # menentukan blok distribusi jam mapel
    blokMapel[mapel_id] = blokDistribusi(jam)

# %% [markdown]
# ---
# # INDIVIDU CONSTRUCT

# %% [markdown]
# ### Generate Per kelas

# %%
def generatePerKelas(tingkatan):

    # list sementara yang berisi blok-blok mapel
    # format: (mapel_id, guru_id, panjang_blok)
    blok_list = []

    # loop semua mata pelajaran yang ada di sistem
    for mapel_id, jam in jamPerMingguMapel.items():

        # ambil daftar guru yang valid untuk:
        # - mapel tersebut
        # - tingkatan kelas tertentu
        guruValid = guruValidMapel.get((mapel_id, tingkatan))

        # jika tidak ada guru yang bisa mengajar mapel ini
        # maka mapel tersebut dilewati
        if not guruValid:
            continue

        # pilih guru secara acak dari guru valid
        # randomisasi ini penting untuk membuat populasi awal GA bervariasi
        guru = random.choice(guruValid)

        # ambil distribusi blok jam mapel
        # contoh:
        # 4 jam -> [2,2]
        # 5 jam -> [2,3]
        blok = blokMapel[mapel_id]
    
        # setiap blok dimasukkan sebagai item dalam list
        for b in blok:
            blok_list.append((mapel_id, guru, b))

    # acak urutan blok mapel
    # agar posisi mapel dalam jadwal tidak selalu sama
    random.shuffle(blok_list)

    # array untuk menyimpan hasil jadwal
    mapel_arr = []
    guru_arr = []

    # konversi blok mapel menjadi slot-slot individu
    for mapel_id, guru, panjang in blok_list:

        # tambahkan mapel sebanyak panjang blok
        # misalnya blok = 2 -> [mapel,mapel]
        mapel_arr.extend([mapel_id]*panjang)

        # guru juga diulang sesuai panjang blok
        guru_arr.extend([guru]*panjang)

    # konversi ke numpy array agar operasi lebih cepat
    mapel_arr = np.array(mapel_arr, dtype=np.int16)
    guru_arr  = np.array(guru_arr, dtype=np.int16)

    # =====================================================
    # memastikan panjang jadwal sesuai jumlah slot kelas
    # =====================================================

    # jika jumlah slot melebihi slot tersedia
    if len(mapel_arr) > SLOT_PER_KELAS:

        # potong ke ukuran yang sesuai
        mapel_arr = mapel_arr[:SLOT_PER_KELAS]
        guru_arr  = guru_arr[:SLOT_PER_KELAS]

    # jika slot masih kurang
    while len(mapel_arr) < SLOT_PER_KELAS:

        # pilih mapel secara acak
        mapel = random.choice(mapelIds)

        # cek apakah ada guru yang bisa mengajar mapel tersebut
        guruValid = guruValidMapel.get((mapel, tingkatan))

        if guruValid:

            # pilih guru secara acak
            guru = random.choice(guruValid)

            # tambahkan ke slot jadwal
            mapel_arr = np.append(mapel_arr, mapel)
            guru_arr  = np.append(guru_arr, guru)

    # return jadwal untuk satu kelas
    return mapel_arr, guru_arr

# %% [markdown]
# ### Membuat individu (1 jadwal penuh)

# %%
def individuConstruct():

    # Membuat matriks kosong untuk menyimpan jadwal mapel dan guru
    # Dimensi:
    # baris  = jumlah kelas
    # kolom  = jumlah slot waktu per kelas
    #
    # mapel_matrix -> menyimpan ID mata pelajaran pada setiap slot
    # guru_matrix  -> menyimpan ID guru yang mengajar pada slot tersebut
    mapel_matrix = np.zeros((JUMLAH_KELAS, SLOT_PER_KELAS), dtype=np.int16)
    guru_matrix  = np.zeros((JUMLAH_KELAS, SLOT_PER_KELAS), dtype=np.int16)

    # Loop setiap kelas yang ada di sistem
    # enumerate digunakan agar kita mendapatkan:
    # i        -> index baris pada matrix
    # kelas_id -> id kelas sebenarnya
    for i, kelas_id in enumerate(kelasIds):

        # Ambil tingkatan kelas
        # Contoh: kelas 10A -> tingkatan 10
        # Tingkatan ini digunakan untuk menentukan
        # guru yang boleh mengajar mapel tertentu
        tingkatan = kelasTingkatan[kelas_id]

        # Generate jadwal untuk satu kelas
        # fungsi ini akan menghasilkan:
        # mapel_row -> array mapel sepanjang SLOT_PER_KELAS
        # guru_row  -> array guru sepanjang SLOT_PER_KELAS
        mapel_row, guru_row = generatePerKelas(tingkatan)

        # Masukkan hasil jadwal tersebut ke baris matrix
        # sehingga setiap baris mewakili satu kelas
        mapel_matrix[i] = mapel_row
        guru_matrix[i]  = guru_row

    # Return satu individu jadwal lengkap
    # yang terdiri dari:
    # - matrix mapel
    # - matrix guru
    return mapel_matrix, guru_matrix

# %% [markdown]
# ### Membuat Populasi

# %%
def generatePopulation(POPULASI):

    # Membuat array 3 dimensi untuk menyimpan populasi jadwal
    #
    # Dimensi:
    # POPULASI      -> jumlah individu dalam populasi GA
    # JUMLAH_KELAS  -> jumlah kelas dalam sistem
    # SLOT_PER_KELAS -> jumlah slot waktu per kelas
    #
    # pop_mapel menyimpan mata pelajaran
    # pop_guru menyimpan guru yang mengajar
    pop_mapel = np.zeros((POPULASI, JUMLAH_KELAS, SLOT_PER_KELAS), dtype=np.int16)
    pop_guru  = np.zeros((POPULASI, JUMLAH_KELAS, SLOT_PER_KELAS), dtype=np.int16)

    # Loop untuk membuat setiap individu dalam populasi
    for i in range(POPULASI):

        # Membuat satu individu jadwal lengkap
        # fungsi ini menghasilkan:
        # mapel_matrix -> jadwal mapel seluruh kelas
        # guru_matrix  -> jadwal guru seluruh kelas
        mapel_matrix, guru_matrix = individuConstruct()

        # Simpan individu ke dalam populasi
        # indeks i menunjukkan individu ke-i
        pop_mapel[i] = mapel_matrix
        pop_guru[i]  = guru_matrix

    # Return populasi awal
    # pop_mapel dan pop_guru berisi seluruh individu jadwal
    return pop_mapel, pop_guru

# %%
# Memanggil fungsi untuk membangkitkan populasi
pop_mapel, pop_guru = generatePopulation(POPULASI)

# %% [markdown]
# ### Debug

# %%
kelas = 0
ind = 0

print("Mapel kelas", kelas+1)
print(pop_mapel[ind, kelas])

print("Guru kelas", kelas+1)
print(pop_guru[ind, kelas])
# Out:
# Mapel kelas 1
# [12 12 12  7  7  7  9  9 11 11  1  1  3  3  2  2  6  6  6  8  8  3  3  3
#   5  5 10 10  4  4  5  5 13 13  4  4]
# Guru kelas 1
# [55 55 55 37 37 37 42 42 37 37 39 39 36 36 39 39  2  2  2 42 42 36 36 36
#  48 48 16 16 47 47 48 48 53 53 47 47]

# %% [markdown]
# ---
# # EVAL

# %% [markdown]
# ### Guru Bentrok

# %%
def guruBentrok(guru_matrix):

        # Variabel untuk menghitung total pelanggaran bentrok guru
        pelanggaran = 0

        # Loop setiap slot waktu
        # SLOT_PER_KELAS merepresentasikan jumlah slot waktu dalam satu hari/minggu
        # yang sama untuk semua kelas
        for slot in range(SLOT_PER_KELAS):

            # Ambil semua guru yang mengajar pada slot waktu yang sama
            # guru_matrix memiliki bentuk:
            # (JUMLAH_KELAS, SLOT_PER_KELAS)
            # guru_matrix[:, slot] berarti:
            # semua kelas pada slot waktu yang sama
            guruSlot = guru_matrix[:, slot]

            # Mengambil nilai guru yang unik
            # Jika tidak ada bentrok maka jumlah unik = jumlah kelas
            unik = np.unique(guruSlot)

            # Hitung jumlah bentrok
            # Contoh:
            # guruSlot = [3, 5, 3, 7]
            # artinya guru 3 mengajar di dua kelas pada waktu yang sama
            # unik = [3,5,7]
            # bentrok = 4 - 3 = 1
            pelanggaran += len(guruSlot) - len(unik)

        # Mengembalikan total jumlah konflik guru
        return pelanggaran

# %% [markdown]
# ### Durasi GUru mengajar

# %%
def durasiGuru(guru_matrix, maxJamGuru):

    # Variabel untuk menghitung total pelanggaran
    # Pelanggaran terjadi jika total jam mengajar guru
    # melebihi batas maksimal yang diperbolehkan
    pelanggaran = 0

    # Mengubah matrix guru menjadi array 1 dimensi
    # sehingga seluruh slot dari semua kelas digabung
    # contoh:
    # guru_matrix.shape = (10 kelas, 36 slot)
    # flatten() -> array 360 slot
    semuaGuru = guru_matrix.flatten()

    # Menghitung jumlah kemunculan setiap guru
    # guru_ids -> daftar guru unik
    # counts   -> jumlah slot yang diajar oleh guru tersebut
    # contoh:
    # guru_ids = [1,2,3]
    # counts   = [40,35,28]
    guru_ids, counts = np.unique(semuaGuru, return_counts=True)

    # Loop setiap guru yang muncul dalam jadwal
    for guru, jam in zip(guru_ids, counts):

        # Ambil batas maksimal jam mengajar guru
        # dari dictionary maxJamGuru
        # jika guru tidak ditemukan maka default = 0
        max_jam = maxJamGuru.get(guru, 0)

        # Jika jam mengajar melebihi batas
        if jam > max_jam:

            # Tambahkan selisihnya sebagai pelanggaran
            # contoh:
            # jam = 30
            # max_jam = 24
            # pelanggaran = 6
            pelanggaran += (jam - max_jam)

    # Return total pelanggaran durasi guru
    return pelanggaran

# %% [markdown]
# ### Distribusi Mapel

# %%
def hitungBlok(slots):

    # Mengurutkan slot agar mudah mendeteksi slot yang berurutan
    # contoh: [5,2,3] -> [2,3,5]
    slots = sorted(slots)

    # list untuk menyimpan panjang setiap blok berurutan
    blok = []

    # panjang blok saat ini
    panjang = 1

    # loop dari slot kedua sampai terakhir
    for i in range(1,len(slots)):

        # jika slot sekarang berurutan dengan slot sebelumnya
        # contoh: 3 setelah 2
        if slots[i] == slots[i-1] + 1:
            panjang += 1

        else:
            # jika tidak berurutan maka blok sebelumnya selesai
            blok.append(panjang)

            # mulai blok baru
            panjang = 1

    # masukkan blok terakhir
    blok.append(panjang)

    # contoh output:
    # slots = [2,3,5,6,7]
    # blok  = [2,3]
    return blok



def distribusiMapel(mapel_matrix):

    # menghitung total pelanggaran distribusi mapel
    pelanggaran = 0

    # loop setiap kelas
    for kelas in range(JUMLAH_KELAS):

        # ambil jadwal mapel untuk kelas tersebut
        jadwal = mapel_matrix[kelas]

        # dictionary untuk menyimpan slot setiap mapel
        # key   = mapel_id
        # value = daftar slot
        mapelSlot = defaultdict(list)

        # loop setiap slot pada jadwal
        for slot, mapel in enumerate(jadwal):

            # simpan slot kemunculan mapel
            mapelSlot[mapel].append(slot)

        # cek setiap mapel dalam kelas tersebut
        for mapel, slots in mapelSlot.items():

            # ambil distribusi blok yang diharapkan
            # contoh:
            # mapel 4 jam -> [2,2]
            blok_expected = blokMapel.get(mapel, [])

            # jika hanya 1 blok maka tidak perlu dicek distribusi
            # contoh: 2 jam -> [2]
            if len(blok_expected) <= 1:
                continue

            # hitung blok aktual dari jadwal
            # contoh:
            # slots = [1,2,5,6]
            # blok_real = [2,2]
            blok_real = hitungBlok(slots)

            # cek apakah distribusi blok sesuai
            # sorted digunakan agar urutan blok tidak masalah
            if sorted(blok_real) != sorted(blok_expected):

                # jika tidak sesuai maka pelanggaran bertambah
                pelanggaran += 1

            # cek distribusi hari
            # ambil hari dari setiap slot
            hariSet = set(slotHari[s] for s in slots)

            # jika jumlah hari kurang dari jumlah blok
            # berarti ada blok mapel yang berada di hari yang sama
            if len(hariSet) < len(blok_expected):

                # tambahkan pelanggaran
                pelanggaran += 1

    # return total pelanggaran distribusi mapel
    return pelanggaran

# %% [markdown]
# ### Mapel PJOK

# %%
def mapelSiang(mapel_matrix):

    # ID mata pelajaran yang tidak diinginkan berada di slot siang
    # contoh: mapel tertentu seperti olahraga
    # mapel berat sering dihindari di jam terakhir
    TARGET_MAPEL = 8

    # variabel untuk menghitung total pelanggaran
    pelanggaran = 0

    # loop semua slot waktu dalam satu minggu
    for slot in range(SLOT_PER_KELAS):

        # ambil hari dari slot tersebut
        # slotHari menyimpan mapping slot -> hari
        hari = slotHari[slot]

        # ambil batas slot siang untuk hari tersebut
        # contoh:
        # senin batas = 5
        batas = batasSiang[hari-1]

        # menghitung slot keberapa dalam hari tersebut
        #
        # contoh:
        # slot global = 14
        # slot awal hari = 12
        # slotHariKe = 2
        slotHariKe = slot - slotAwalHari[hari-1]

        # jika slot masih sebelum batas siang
        # maka tidak perlu dicek
        if slotHariKe < batas:
            continue

        # jika sudah melewati batas siang
        # maka hitung jumlah TARGET_MAPEL pada slot tersebut
        # mapel_matrix[:, slot] -> semua kelas pada slot yang sama
        # contoh:
        # [8,3,8,5]
        # berarti ada 2 pelanggaran
        pelanggaran += np.sum(mapel_matrix[:, slot] == TARGET_MAPEL)

    # return total pelanggaran mapel siang
    return pelanggaran

# %% [markdown]
# ### Waktu MGMP

# %%
def waktuMGMP(mapel_matrix):

    # Variabel untuk menghitung total pelanggaran
    pelanggaran = 0

    # Loop setiap kelas
    for kelas in range(JUMLAH_KELAS):

        # Ambil jadwal mapel untuk kelas tersebut
        jadwal = mapel_matrix[kelas]

        # Loop setiap mapel yang memiliki aturan MGMP
        # mgmpMapel berisi mapping:
        # mapel_id -> hari MGMP
        for mapel, hariMGMP in mgmpMapel.items():

            # Mengubah hari MGMP menjadi index array (0-based)
            hari_idx = hariMGMP - 1

            # Menentukan batas slot awal dan akhir hari tersebut
            # agar hanya slot di hari MGMP yang diperiksa
            start = slotAwalHari[hari_idx]
            end   = slotAkhirHari[hari_idx]

            # Menghitung berapa kali mapel tersebut muncul
            # pada hari MGMP untuk kelas ini
            jumlah = np.sum(jadwal[start:end] == mapel)

            # Jika jumlah kemunculan melebihi batas yang diperbolehkan
            if jumlah > batasMGMP[hari_idx]:

                # Tambahkan selisihnya sebagai pelanggaran
                pelanggaran += jumlah - batasMGMP[hari_idx]

    # Return total pelanggaran MGMP
    return pelanggaran

# %% [markdown]
# ### Wali Kelas

# %%
def cekWaliKelas(guru_matrix):

    # Variabel untuk menghitung total pelanggaran
    pelanggaran = 0

    # Loop setiap pasangan wali kelas
    # waliKelas berisi mapping:
    # guru_id -> kelas_id
    for guru, kelas in waliKelas.items():

        # Mengecek apakah guru tersebut mengajar di kelas yang menjadi wali-nya
        # guru_matrix[kelas-1] mengambil seluruh slot pada kelas tersebut
        # kelas-1 digunakan karena index array dimulai dari 0
        # contoh:
        # kelas = 3 -> index = 2
        if guru not in guru_matrix[kelas-1]:

            # Jika guru wali tidak mengajar di kelasnya sama sekali
            # maka dianggap pelanggaran
            pelanggaran += 1

    # Return total pelanggaran wali kelas
    return pelanggaran

# %% [markdown]
# ### Konsistensi GUru mapel

# %%
def konsistensiGuruMapel(mapel_matrix, guru_matrix):

    # Variabel untuk menghitung total pelanggaran
    pelanggaran = 0

    # Loop setiap kelas
    for kelas in range(JUMLAH_KELAS):

        # Ambil jadwal mapel dan guru untuk kelas tersebut
        jadwalMapel = mapel_matrix[kelas]
        jadwalGuru  = guru_matrix[kelas]

        # Ambil daftar mapel unik yang muncul di kelas tersebut
        # agar tidak mengecek mapel yang sama berulang kali
        for mapel in np.unique(jadwalMapel):

            # Ambil semua guru yang mengajar mapel tersebut
            # jadwalMapel == mapel -> menghasilkan mask boolean
            # kemudian digunakan untuk memilih guru yang mengajar mapel itu
            guruSet = np.unique(jadwalGuru[jadwalMapel == mapel])

            # Jika lebih dari satu guru mengajar mapel yang sama
            # maka terjadi pelanggaran konsistensi
            if len(guruSet) > 1:

                # Tambahkan selisih jumlah guru sebagai pelanggaran
                # contoh:
                # guruSet = [3,7]
                # pelanggaran = 1
                # guruSet = [3,7,8]
                # pelanggaran = 2
                pelanggaran += len(guruSet) - 1

    # Return total pelanggaran konsistensi guru-mapel
    return pelanggaran

# %% [markdown]
# ### main eval

# %%
def evaluasiIndividu(mapel_matrix, guru_matrix, maxJamGuru):

    # Fungsi ini mengevaluasi satu individu jadwal (satu solusi)
    # dengan menghitung jumlah pelanggaran untuk setiap constraint.

    # mapel_matrix : matriks mata pelajaran
    # baris = kelas
    # kolom = slot waktu

    # guru_matrix : matriks guru yang mengajar
    # strukturnya sama dengan mapel_matrix

    # maxJamGuru : dictionary yang berisi batas maksimal jam mengajar tiap guru

    # Fungsi mengembalikan dictionary yang berisi jumlah pelanggaran
    # untuk setiap jenis constraint

    return {

        # Mengecek apakah ada guru yang mengajar di lebih dari satu kelas
        # pada slot waktu yang sama
        "guruBentrok": guruBentrok(guru_matrix),

        # Mengecek apakah distribusi jam mata pelajaran sesuai dengan
        # blok yang seharusnya (misalnya 2+1 jam atau 3 jam)
        "distribusiMapel": distribusiMapel(mapel_matrix),

        # Mengecek apakah mata pelajaran tertentu muncul di jam siang
        # yang seharusnya dihindari
        "mapelSiang": mapelSiang(mapel_matrix),

        # Mengecek apakah total jam mengajar guru melebihi batas maksimum
        "durasiGuru": durasiGuru(guru_matrix, maxJamGuru),

        # Mengecek aturan MGMP, misalnya jumlah maksimal mapel tertentu
        # dalam satu hari
        "waktuMGMP": waktuMGMP(mapel_matrix),

        # Mengecek apakah wali kelas mengajar di kelasnya sendiri
        "cekWaliKelas": cekWaliKelas(guru_matrix),

        # Mengecek apakah satu mapel dalam satu kelas diajar oleh lebih
        # dari satu guru (harusnya konsisten satu guru)
        "konsistensiGuruMapel": konsistensiGuruMapel(mapel_matrix, guru_matrix)
    }

# %% [markdown]
# ### Looping setiap individu

# %%
def hitungFitness(hasilEvaluasi):

    # Variabel untuk menyimpan total nilai fitness
    # Fitness biasanya merepresentasikan total penalti dari semua pelanggaran
    fitness = 0

    # Melakukan iterasi pada setiap jenis constraint
    # hasilEvaluasi berupa dictionary seperti:
    # {
    #   "guruBentrok": 5,
    #   "distribusiMapel": 3,
    #   "mapelSiang": 1,
    #   ...
    # }

    for k, v in hasilEvaluasi.items():

        # k = nama constraint
        # v = jumlah pelanggaran constraint tersebut

        # fitnessWeight adalah dictionary berisi bobot tiap constraint
        # contoh:
        # fitnessWeight = {
        #     "guruBentrok": 100,
        #     "distribusiMapel": 20,
        #     "mapelSiang": 5,
        #     ...
        # }

        # Pelanggaran dikalikan dengan bobot constraint
        # lalu ditambahkan ke total fitness
        fitness += fitnessWeight[k] * v

    # Mengembalikan total fitness
    # Semakin kecil nilai fitness -> semakin baik solusi jadwal
    return fitness

# %% [markdown]
# ### Menyimpan hasil eval tiap individu

# %%
def evaluasiPopulasi(pop_mapel, pop_guru, maxJamGuru):

    # List untuk menyimpan hasil evaluasi setiap individu dalam populasi
    hasilPopulasi = []

    # pop_mapel.shape[0] = jumlah individu dalam populasi
    # setiap individu adalah satu kandidat solusi jadwal
    for i in range(pop_mapel.shape[0]):

        # Mengambil jadwal mapel dari individu ke-i
        # bentuknya matrix: kelas × slot
        mapel_matrix = pop_mapel[i]

        # Mengambil jadwal guru dari individu ke-i
        # strukturnya sama dengan mapel_matrix
        guru_matrix  = pop_guru[i]

        # Mengevaluasi individu menggunakan semua constraint
        # hasilnya berupa dictionary jumlah pelanggaran
        evaluasi = evaluasiIndividu(mapel_matrix, guru_matrix, maxJamGuru)

        # Menghitung nilai fitness berdasarkan jumlah pelanggaran
        # dan bobot masing-masing constraint
        fitness = hitungFitness(evaluasi)

        # Menyimpan hasil evaluasi individu dalam bentuk dictionary
        hasilPopulasi.append({
            "fitness": fitness,     # nilai fitness individu
            "evaluasi": evaluasi,   # detail pelanggaran constraint
            "index": i              # posisi individu dalam populasi
        })

    # Mengembalikan seluruh hasil evaluasi populasi
    return hasilPopulasi

# %%
hasil = evaluasiPopulasi(pop_mapel, pop_guru, maxJamGuru)

# %% [markdown]
# ### Output debug

# %%
# best = min(hasil, key=lambda x: x["fitness"])

# print("Best Fitness:", best["fitness"])
# print("Detail Evaluasi:")
# print(best["evaluasi"])

# %% [markdown]
# ---
# # GA

# %% [markdown]
# ### Tournament

# %%
def tournamentSelection(pop_mapel, pop_guru, hasilPopulasi):

    # Mengambil beberapa individu secara acak dari populasi
    # jumlah individu yang diambil ditentukan oleh TOURNAMENT_SIZE
    # contoh: jika TOURNAMENT_SIZE = 3 maka akan dipilih 3 kandidat secara acak
    kandidat = random.sample(hasilPopulasi, TOURNAMENT_SIZE)

    # Dari kandidat tersebut dipilih individu dengan fitness terbaik
    # min digunakan karena dalam timetabling fitness yang lebih kecil lebih baik
    terbaik = min(kandidat, key=lambda x: x["fitness"])

    # Mengambil index individu terbaik dalam populasi
    idx = terbaik["index"]

    # Mengembalikan jadwal mapel dan guru dari individu terpilih
    # .copy() digunakan agar perubahan pada offspring tidak mengubah parent asli
    return pop_mapel[idx].copy(), pop_guru[idx].copy()

# %% [markdown]
# ### Crossover

# %%
def crossover(parent1_mapel, parent1_guru, parent2_mapel, parent2_guru):

    # Menentukan titik pemotongan crossover berdasarkan jumlah kelas
    # split berada di antara 1 sampai JUMLAH_KELAS-1
    # artinya sebagian kelas diambil dari parent1 dan sisanya dari parent2
    split = random.randint(1, JUMLAH_KELAS - 1)

    # Membuat matriks anak dengan ukuran yang sama seperti parent
    # diinisialisasi dengan nilai 0
    child1_mapel = np.zeros_like(parent1_mapel)
    child1_guru  = np.zeros_like(parent1_guru)

    child2_mapel = np.zeros_like(parent1_mapel)
    child2_guru  = np.zeros_like(parent1_guru)

    # Membentuk child1:
    # kelas sebelum titik split diambil dari parent1
    child1_mapel[:split] = parent1_mapel[:split]

    # kelas setelah titik split diambil dari parent2
    child1_mapel[split:] = parent2_mapel[split:]

    # Guru mengikuti struktur yang sama dengan mapel
    child1_guru[:split] = parent1_guru[:split]
    child1_guru[split:] = parent2_guru[split:]

    # Membentuk child2:
    # kebalikan dari child1
    # kelas sebelum split dari parent2
    child2_mapel[:split] = parent2_mapel[:split]

    # kelas setelah split dari parent1
    child2_mapel[split:] = parent1_mapel[split:]

    # Guru mengikuti struktur yang sama dengan mapel
    child2_guru[:split] = parent2_guru[:split]
    child2_guru[split:] = parent1_guru[split:]

    # Mengembalikan dua anak hasil crossover
    return child1_mapel, child1_guru, child2_mapel, child2_guru

# %% [markdown]
# ### Mutasi

# %%
def mutasi(mapel_matrix, guru_matrix):

    # Mengevaluasi individu untuk mengetahui jumlah pelanggaran tiap constraint
    evaluasi = evaluasiIndividu(mapel_matrix, guru_matrix, maxJamGuru)

    # Menentukan constraint yang memiliki pelanggaran paling besar
    # constraint ini akan menjadi target mutasi
    constraint = max(evaluasi, key=evaluasi.get)

    # Memilih kelas secara acak yang akan dimodifikasi
    kelas = random.randint(0, JUMLAH_KELAS - 1)

    # Jika pelanggaran terbesar berasal dari distribusi mapel
    if constraint == "distribusiMapel":

        # Memilih dua slot berurutan untuk ditukar
        slot1 = random.randint(0, SLOT_PER_KELAS - 2)
        slot2 = slot1 + 1

        # Menukar posisi mapel pada dua slot tersebut
        mapel_matrix[kelas,slot1], mapel_matrix[kelas,slot2] = \
            mapel_matrix[kelas,slot2], mapel_matrix[kelas,slot1]

        # Menukar guru yang mengajar pada slot yang sama
        guru_matrix[kelas,slot1], guru_matrix[kelas,slot2] = \
            guru_matrix[kelas,slot2], guru_matrix[kelas,slot1]

    # Jika pelanggaran terbesar adalah guru bentrok
    elif constraint == "guruBentrok":

        # Memilih slot acak pada kelas tersebut
        slot = random.randint(0, SLOT_PER_KELAS-1)

        # Mengambil mapel pada slot tersebut
        mapel = mapel_matrix[kelas,slot]

        # Menentukan tingkatan kelas (misalnya kelas 10,11,12)
        tingkatan = kelasTingkatan[kelasIds[kelas]]

        # Mengambil daftar guru yang valid untuk mapel dan tingkatan tersebut
        guruValid = guruValidMapel.get((mapel, tingkatan))

        # Jika ada guru yang valid
        if guruValid:

            # Mengganti guru dengan salah satu guru valid secara acak
            guru_matrix[kelas,slot] = random.choice(guruValid)

    # Jika constraint lain yang dominan
    else:

        # Memilih dua slot acak dalam satu kelas
        slot1 = random.randint(0, SLOT_PER_KELAS - 1)
        slot2 = random.randint(0, SLOT_PER_KELAS - 1)

        # Menukar posisi mapel antara dua slot tersebut
        mapel_matrix[kelas,slot1], mapel_matrix[kelas,slot2] = \
            mapel_matrix[kelas,slot2], mapel_matrix[kelas,slot1]

        # Menukar guru pada slot yang sama
        guru_matrix[kelas,slot1], guru_matrix[kelas,slot2] = \
            guru_matrix[kelas,slot2], guru_matrix[kelas,slot1]

    # Mengembalikan individu yang telah dimutasi
    return mapel_matrix, guru_matrix

# %% [markdown]
# ### Repair

# %%
def repairOperator(mapel_matrix, guru_matrix):

    # Mengevaluasi individu untuk mengetahui jumlah pelanggaran constraint
    evaluasi = evaluasiIndividu(mapel_matrix, guru_matrix, maxJamGuru)

    # Repair hanya dilakukan jika terdapat pelanggaran guru bentrok
    if evaluasi["guruBentrok"] > 0:

        # Iterasi setiap slot waktu
        for slot in range(SLOT_PER_KELAS):

            # Mengambil semua guru yang mengajar pada slot tersebut
            # (dari semua kelas pada waktu yang sama)
            guruSlot = guru_matrix[:,slot]

            # Mengambil guru unik dan jumlah kemunculannya
            unik, counts = np.unique(guruSlot, return_counts=True)

            # Mendeteksi guru yang muncul lebih dari sekali pada slot yang sama
            # artinya guru tersebut mengajar di lebih dari satu kelas
            bentrok = unik[counts > 1]

            # Memproses setiap guru yang mengalami bentrok
            for g in bentrok:

                # Mencari kelas mana saja yang menggunakan guru tersebut
                kelasBentrok = np.where(guruSlot == g)[0]

                # Memilih salah satu kelas secara acak untuk diperbaiki
                kelas = random.choice(kelasBentrok)

                # Mengambil mapel pada kelas dan slot tersebut
                mapel = mapel_matrix[kelas,slot]

                # Menentukan tingkatan kelas (misal kelas 10, 11, 12)
                tingkatan = kelasTingkatan[kelasIds[kelas]]

                # Mengambil daftar guru yang valid untuk mapel dan tingkatan ini
                guruValid = guruValidMapel.get((mapel, tingkatan))

                # Jika ada guru yang valid
                if guruValid:

                    # Mengganti guru yang bentrok dengan guru valid lain secara acak
                    guru_matrix[kelas,slot] = random.choice(guruValid)

    # Mengembalikan jadwal yang telah diperbaiki
    return mapel_matrix, guru_matrix

# %% [markdown]
# ---
# # GWO

# %%
def runGWO(pop_mapel, pop_guru, hasilPop, iter_gwo=0, max_iter=20):

    hasilSorted = sorted(hasilPop, key=lambda x: x["fitness"])

    alpha = hasilSorted[0]["index"]
    beta  = hasilSorted[1]["index"]
    delta = hasilSorted[2]["index"]

    alpha_mapel = pop_mapel[alpha]
    alpha_guru  = pop_guru[alpha]

    beta_mapel = pop_mapel[beta]
    beta_guru  = pop_guru[beta]

    delta_mapel = pop_mapel[delta]
    delta_guru  = pop_guru[delta]

    # parameter convergence GWO
    a = 2 * (1 - (iter_gwo / max_iter))

    new_pop_mapel = []
    new_pop_guru  = []

    for i in range(len(pop_mapel)):

        mapel = pop_mapel[i].copy()
        guru  = pop_guru[i].copy()

        # elitism
        if i == alpha:
            new_pop_mapel.append(mapel)
            new_pop_guru.append(guru)
            continue

        # ===============================
        # pilih beberapa kelas sekaligus
        # ===============================
        kelas_list = random.sample(range(JUMLAH_KELAS), k=3)

        for kelas in kelas_list:

            # pilih hari random
            hari = random.randint(0,4)

            start = slotAwalHari[hari]
            end   = slotAkhirHari[hari]

            # ukuran segmen
            panjang = end-start
            size = random.randint(1, max(2, panjang//2))
            s = random.randint(start, end-size)

            for slot in range(s, s+size):

                # ===============================
                # GWO voting (alpha beta delta)
                # ===============================

                kandidat_mapel = [
                    alpha_mapel[kelas,slot],
                    beta_mapel[kelas,slot],
                    delta_mapel[kelas,slot]
                ]

                kandidat_guru = [
                    alpha_guru[kelas,slot],
                    beta_guru[kelas,slot],
                    delta_guru[kelas,slot]
                ]

                # majority vote
                mapel_vote = Counter(kandidat_mapel).most_common(1)[0][0]
                guru_vote  = Counter(kandidat_guru).most_common(1)[0][0]

                # eksplorasi jika a besar
                if random.random() < a/2:
                    mapel[kelas,slot] = mapel_vote
                    guru[kelas,slot]  = guru_vote

                # eksplorasi random
                else:
                    tingkatan = kelasTingkatan[kelasIds[kelas]]
                    guruValid = guruValidMapel.get((mapel_vote, tingkatan))

                    if guruValid:
                        mapel[kelas,slot] = mapel_vote
                        guru[kelas,slot]  = random.choice(guruValid)

        # ===============================
        # local improvement swap
        # ===============================

        if random.random() < 0.5:

            kelas = random.randint(0,JUMLAH_KELAS-1)
            slot1 = random.randint(0,SLOT_PER_KELAS-1)
            slot2 = random.randint(0,SLOT_PER_KELAS-1)

            mapel[kelas,slot1], mapel[kelas,slot2] = mapel[kelas,slot2], mapel[kelas,slot1]
            guru[kelas,slot1],  guru[kelas,slot2]  = guru[kelas,slot2],  guru[kelas,slot1]

        # repair constraint
        mapel, guru = repairOperator(mapel, guru)

        # ===============================
        # accept only if better
        # ===============================

        oldFitness = hasilPop[i]["fitness"]

        evaluasi = evaluasiIndividu(mapel, guru, maxJamGuru)
        newFitness = hitungFitness(evaluasi)

        if newFitness <= oldFitness:
            new_pop_mapel.append(mapel)
            new_pop_guru.append(guru)
        else:
            new_pop_mapel.append(pop_mapel[i])
            new_pop_guru.append(pop_guru[i])

    return np.array(new_pop_mapel), np.array(new_pop_guru)

# %% [markdown]
# # MAIN

# %%
def runGA():

    # Membuat populasi awal jadwal mapel dan guru
    pop_mapel, pop_guru = generatePopulation(POPULASI)

    # Mengevaluasi seluruh populasi awal
    hasilPop = evaluasiPopulasi(pop_mapel, pop_guru, maxJamGuru)

    # Menyimpan fitness terbaik global
    bestFitness = float("inf")

    # Menyimpan log perkembangan fitness
    log_data = []

    # Iterasi utama algoritma
    for gen in range(ITERATION):

        # laoding efffect nang kene

        # Menyimpan populasi baru hasil GA
        new_pop_mapel = []
        new_pop_guru  = []

        # ==========================
        # PROSES GA
        # ==========================

        # Membuat populasi baru sampai jumlah individu terpenuhi
        while len(new_pop_mapel) < POPULASI:

            # Memilih parent menggunakan tournament selection
            p1_mapel, p1_guru = tournamentSelection(pop_mapel, pop_guru, hasilPop)
            p2_mapel, p2_guru = tournamentSelection(pop_mapel, pop_guru, hasilPop)

            # Jika memenuhi probabilitas crossover
            if random.random() < CROSSOVER_PROB:

                # Melakukan class-based crossover
                c1_mapel, c1_guru, c2_mapel, c2_guru = crossover(
                    p1_mapel, p1_guru, p2_mapel, p2_guru
                )

            else:

                # Jika tidak crossover, anak adalah copy dari parent
                c1_mapel, c1_guru = p1_mapel.copy(), p1_guru.copy()
                c2_mapel, c2_guru = p2_mapel.copy(), p2_guru.copy()

            # Mutasi anak pertama jika memenuhi probabilitas mutasi
            if random.random() < MUTATION_PROB:
                c1_mapel, c1_guru = mutasi(c1_mapel, c1_guru)

            # Mutasi anak kedua
            if random.random() < MUTATION_PROB:
                c2_mapel, c2_guru = mutasi(c2_mapel, c2_guru)

            # Repair untuk memperbaiki pelanggaran constraint
            # c1_mapel, c1_guru = repairOperator(c1_mapel, c1_guru)
            # c2_mapel, c2_guru = repairOperator(c2_mapel, c2_guru)

            # Menambahkan anak pertama ke populasi baru
            new_pop_mapel.append(c1_mapel)
            new_pop_guru.append(c1_guru)

            # Menambahkan anak kedua jika populasi belum penuh
            if len(new_pop_mapel) < POPULASI:
                new_pop_mapel.append(c2_mapel)
                new_pop_guru.append(c2_guru)

        # Mengganti populasi lama dengan populasi baru
        pop_mapel = np.array(new_pop_mapel)
        pop_guru  = np.array(new_pop_guru)

        # Mengevaluasi populasi baru
        hasilPop = evaluasiPopulasi(pop_mapel, pop_guru, maxJamGuru)

        # ==========================
        # PROSESS GWO
        # ==========================

        # Setiap 20 generasi dilakukan fase optimasi GWO
        # if gen % 20 == 0 and gen != 0:

        #     print("----- GWO PHASE -----")

        #     # Melakukan iterasi GWO sebanyak 20 kali
        #     for iter_gwo in range(20):

        #         # Update posisi populasi menggunakan Grey Wolf Optimizer
        #         pop_mapel, pop_guru = runGWO(pop_mapel, pop_guru, hasilPop)

        #         # Evaluasi kembali populasi hasil GWO
        #         hasilPop = evaluasiPopulasi(pop_mapel, pop_guru, maxJamGuru)

        #         # Mengambil fitness terbaik dalam populasi
        #         best_gwo = min(x["fitness"] for x in hasilPop)

        #         # Menghitung rata-rata fitness populasi
        #         avg_gwo  = sum(x["fitness"] for x in hasilPop) / len(hasilPop)

        #         # Menyimpan log GWO
        #         log_data.append([gen, "GWO", best_gwo, avg_gwo])

        #         print("GWO Iter", iter_gwo,"Best:", best_gwo,"Avg:", round(avg_gwo))

        # ==========================
        # BEST FITNESS
        # ==========================

        # Mengambil individu terbaik dalam populasi
        best = min(hasilPop, key=lambda x: x["fitness"])

        # Menghitung rata-rata fitness populasi
        avg = np.mean([x['fitness'] for x in hasilPop])

        # Update best global fitness jika ditemukan yang lebih baik
        if best["fitness"] < bestFitness:
            bestFitness = best["fitness"]

        # Menyimpan log GA
        log_data.append([gen,"GA", bestFitness, avg])

        # Menampilkan progress generasi
        print("Generasi", gen, "| Best Fitness:", bestFitness, "| avg:", avg)

    # ==========================
    # OUTPUT
    # ==========================

    # Menentukan path file untuk menyimpan log
    path_file = os.path.join("../hasil/record", RECORD_EXPORT)

    # Menyimpan log fitness ke file CSV
    with open(path_file, mode="w", newline="") as file:

        writer = csv.writer(file)

        # Header kolom
        writer.writerow(["iterasi", "method","best", "avg"])

        # Data log
        writer.writerows(log_data)

    # Mengembalikan individu terbaik
    return best

# %% [markdown]
# ### Main Call

# %%
best = runGA()

print("Best Fitness:", best["fitness"])
print("Detail Evaluasi:")
print(best["evaluasi"])
# Out:
# Generasi 0 | Best Fitness: 19430 | avg: 21087.3
# Generasi 1 | Best Fitness: 18780 | avg: 20180.0
# Generasi 2 | Best Fitness: 18215 | avg: 19614.4
# Generasi 3 | Best Fitness: 17775 | avg: 18766.9
# Generasi 4 | Best Fitness: 17665 | avg: 18149.8
# Generasi 5 | Best Fitness: 17575 | avg: 17787.7
# Generasi 6 | Best Fitness: 17525 | avg: 17644.9
# Generasi 7 | Best Fitness: 17405 | avg: 17582.7
# Generasi 8 | Best Fitness: 17405 | avg: 17492.0
# Generasi 9 | Best Fitness: 17315 | avg: 17424.2
# Generasi 10 | Best Fitness: 17175 | avg: 17388.0
# Generasi 11 | Best Fitness: 17065 | avg: 17249.4
# Generasi 12 | Best Fitness: 16985 | avg: 17133.3
# Generasi 13 | Best Fitness: 16895 | avg: 17034.6
# Generasi 14 | Best Fitness: 16810 | avg: 16989.3
# Generasi 15 | Best Fitness: 16740 | avg: 16904.9
# Generasi 16 | Best Fitness: 16655 | avg: 16821.1
# Generasi 17 | Best Fitness: 16575 | avg: 16744.5
# Generasi 18 | Best Fitness: 16415 | avg: 16627.6
# Generasi 19 | Best Fitness: 16335 | avg: 16502.3
# Generasi 20 | Best Fitness: 16255 | avg: 16404.9
# Generasi 21 | Best Fitness: 16245 | avg: 16336.3
# Generasi 22 | Best Fitness: 16165 | avg: 16272.6
# Generasi 23 | Best Fitness: 16085 | avg: 16237.0
# Generasi 24 | Best Fitness: 15935 | avg: 16151.6
# Generasi 25 | Best Fitness: 15935 | avg: 16065.6
# Generasi 26 | Best Fitness: 15845 | avg: 15978.6
# Generasi 27 | Best Fitness: 15755 | avg: 15881.1
# Generasi 28 | Best Fitness: 15615 | avg: 15794.2
# Generasi 29 | Best Fitness: 15440 | avg: 15699.1
# Generasi 30 | Best Fitness: 15440 | avg: 15591.0
# Generasi 31 | Best Fitness: 15340 | avg: 15474.4
# Generasi 32 | Best Fitness: 15310 | avg: 15430.0
# Generasi 33 | Best Fitness: 15260 | avg: 15362.8
# Generasi 34 | Best Fitness: 15160 | avg: 15296.3
# Generasi 35 | Best Fitness: 15080 | avg: 15231.8
# Generasi 36 | Best Fitness: 15010 | avg: 15134.0
# Generasi 37 | Best Fitness: 14880 | avg: 15058.8
# Generasi 38 | Best Fitness: 14790 | avg: 14970.0
# Generasi 39 | Best Fitness: 14680 | avg: 14896.1
# Generasi 40 | Best Fitness: 14680 | avg: 14822.7
# Generasi 41 | Best Fitness: 14560 | avg: 14721.2
# Generasi 42 | Best Fitness: 14490 | avg: 14656.2
# Generasi 43 | Best Fitness: 14390 | avg: 14564.4
# Generasi 44 | Best Fitness: 14300 | avg: 14484.6
# Generasi 45 | Best Fitness: 14250 | avg: 14371.8
# Generasi 46 | Best Fitness: 14140 | avg: 14305.1
# Generasi 47 | Best Fitness: 14060 | avg: 14221.8
# Generasi 48 | Best Fitness: 14030 | avg: 14156.4
# Generasi 49 | Best Fitness: 13910 | avg: 14087.4
# Generasi 50 | Best Fitness: 13830 | avg: 13991.4
# Generasi 51 | Best Fitness: 13810 | avg: 13928.9
# Generasi 52 | Best Fitness: 13730 | avg: 13851.8
# Generasi 53 | Best Fitness: 13650 | avg: 13768.0
# Generasi 54 | Best Fitness: 13630 | avg: 13711.2
# Generasi 55 | Best Fitness: 13530 | avg: 13666.7
# Generasi 56 | Best Fitness: 13440 | avg: 13601.0
# Generasi 57 | Best Fitness: 13280 | avg: 13512.5
# Generasi 58 | Best Fitness: 13190 | avg: 13371.3
# Generasi 59 | Best Fitness: 13190 | avg: 13288.0
# Generasi 60 | Best Fitness: 13110 | avg: 13223.1
# Generasi 61 | Best Fitness: 13110 | avg: 13201.8
# Generasi 62 | Best Fitness: 13020 | avg: 13153.3
# Generasi 63 | Best Fitness: 13020 | avg: 13107.2
# Generasi 64 | Best Fitness: 12920 | avg: 13040.0
# Generasi 65 | Best Fitness: 12920 | avg: 13008.2
# Generasi 66 | Best Fitness: 12830 | avg: 12939.3
# Generasi 67 | Best Fitness: 12830 | avg: 12912.8
# Generasi 68 | Best Fitness: 12770 | avg: 12865.3
# Generasi 69 | Best Fitness: 12740 | avg: 12841.8
# Generasi 70 | Best Fitness: 12670 | avg: 12775.4
# Generasi 71 | Best Fitness: 12580 | avg: 12714.0
# Generasi 72 | Best Fitness: 12490 | avg: 12630.7
# Generasi 73 | Best Fitness: 12480 | avg: 12587.7
# Generasi 74 | Best Fitness: 12430 | avg: 12515.9
# Generasi 75 | Best Fitness: 12430 | avg: 12500.9
# Generasi 76 | Best Fitness: 12420 | avg: 12453.4
# Generasi 77 | Best Fitness: 12330 | avg: 12453.0
# Generasi 78 | Best Fitness: 12330 | avg: 12428.2
# Generasi 79 | Best Fitness: 12280 | avg: 12357.6
# Generasi 80 | Best Fitness: 12150 | avg: 12327.0
# Generasi 81 | Best Fitness: 12150 | avg: 12234.3
# Generasi 82 | Best Fitness: 12070 | avg: 12177.4
# Generasi 83 | Best Fitness: 12070 | avg: 12160.2
# Generasi 84 | Best Fitness: 12070 | avg: 12128.3
# Generasi 85 | Best Fitness: 11970 | avg: 12092.4
# Generasi 86 | Best Fitness: 11970 | avg: 12064.6
# Generasi 87 | Best Fitness: 11870 | avg: 12006.2
# Generasi 88 | Best Fitness: 11790 | avg: 11949.4
# Generasi 89 | Best Fitness: 11710 | avg: 11854.3
# Generasi 90 | Best Fitness: 11630 | avg: 11769.0
# Generasi 91 | Best Fitness: 11610 | avg: 11702.2
# Generasi 92 | Best Fitness: 11530 | avg: 11642.6
# Generasi 93 | Best Fitness: 11530 | avg: 11606.6
# Generasi 94 | Best Fitness: 11510 | avg: 11558.5
# Generasi 95 | Best Fitness: 11510 | avg: 11546.4
# Generasi 96 | Best Fitness: 11500 | avg: 11546.0
# Generasi 97 | Best Fitness: 11500 | avg: 11528.9
# Generasi 98 | Best Fitness: 11500 | avg: 11518.5
# Generasi 99 | Best Fitness: 11430 | avg: 11520.6
# Generasi 100 | Best Fitness: 11360 | avg: 11511.6
# Generasi 101 | Best Fitness: 11360 | avg: 11451.6
# Generasi 102 | Best Fitness: 11360 | avg: 11397.6
# Generasi 103 | Best Fitness: 11290 | avg: 11387.2
# Generasi 104 | Best Fitness: 11290 | avg: 11354.6
# Generasi 105 | Best Fitness: 11210 | avg: 11318.1
# Generasi 106 | Best Fitness: 11210 | avg: 11270.0
# Generasi 107 | Best Fitness: 11210 | avg: 11229.4
# Generasi 108 | Best Fitness: 11210 | avg: 11234.4
# Generasi 109 | Best Fitness: 11210 | avg: 11228.7
# Generasi 110 | Best Fitness: 11210 | avg: 11245.8
# Generasi 111 | Best Fitness: 11210 | avg: 11231.4
# Generasi 112 | Best Fitness: 11210 | avg: 11238.5
# Generasi 113 | Best Fitness: 11210 | avg: 11238.2
# Generasi 114 | Best Fitness: 11210 | avg: 11234.2
# Generasi 115 | Best Fitness: 11110 | avg: 11235.7
# Generasi 116 | Best Fitness: 11100 | avg: 11204.4
# Generasi 117 | Best Fitness: 11100 | avg: 11140.8
# Generasi 118 | Best Fitness: 11100 | avg: 11135.4
# Generasi 119 | Best Fitness: 11100 | avg: 11136.7
# Generasi 120 | Best Fitness: 11010 | avg: 11140.8
# Generasi 121 | Best Fitness: 11010 | avg: 11116.8
# Generasi 122 | Best Fitness: 10980 | avg: 11091.2
# Generasi 123 | Best Fitness: 10980 | avg: 11030.7
# Generasi 124 | Best Fitness: 10980 | avg: 11006.3
# Generasi 125 | Best Fitness: 10870 | avg: 10987.0
# Generasi 126 | Best Fitness: 10870 | avg: 10962.2
# Generasi 127 | Best Fitness: 10810 | avg: 10900.3
# Generasi 128 | Best Fitness: 10730 | avg: 10883.6
# Generasi 129 | Best Fitness: 10720 | avg: 10838.6
# Generasi 130 | Best Fitness: 10720 | avg: 10772.1
# Generasi 131 | Best Fitness: 10710 | avg: 10746.0
# Generasi 132 | Best Fitness: 10620 | avg: 10744.9
# Generasi 133 | Best Fitness: 10610 | avg: 10714.0
# Generasi 134 | Best Fitness: 10610 | avg: 10647.4
# Generasi 135 | Best Fitness: 10610 | avg: 10651.0
# Generasi 136 | Best Fitness: 10590 | avg: 10631.1
# Generasi 137 | Best Fitness: 10590 | avg: 10628.6
# Generasi 138 | Best Fitness: 10590 | avg: 10629.0
# Generasi 139 | Best Fitness: 10560 | avg: 10605.2
# Generasi 140 | Best Fitness: 10490 | avg: 10598.8
# Generasi 141 | Best Fitness: 10460 | avg: 10559.2
# Generasi 142 | Best Fitness: 10460 | avg: 10494.8
# Generasi 143 | Best Fitness: 10380 | avg: 10483.0
# Generasi 144 | Best Fitness: 10380 | avg: 10470.7
# Generasi 145 | Best Fitness: 10380 | avg: 10433.8
# Generasi 146 | Best Fitness: 10380 | avg: 10407.1
# Generasi 147 | Best Fitness: 10300 | avg: 10398.0
# Generasi 148 | Best Fitness: 10300 | avg: 10384.2
# Generasi 149 | Best Fitness: 10280 | avg: 10336.7
# Generasi 150 | Best Fitness: 10280 | avg: 10329.5
# Generasi 151 | Best Fitness: 10280 | avg: 10313.3
# Generasi 152 | Best Fitness: 10260 | avg: 10305.8
# Generasi 153 | Best Fitness: 10200 | avg: 10292.6
# Generasi 154 | Best Fitness: 10200 | avg: 10274.0
# Generasi 155 | Best Fitness: 10200 | avg: 10234.2
# Generasi 156 | Best Fitness: 10200 | avg: 10222.7
# Generasi 157 | Best Fitness: 10200 | avg: 10216.3
# Generasi 158 | Best Fitness: 10200 | avg: 10212.8
# Generasi 159 | Best Fitness: 10200 | avg: 10221.7
# Generasi 160 | Best Fitness: 10200 | avg: 10226.0
# Generasi 161 | Best Fitness: 10190 | avg: 10219.9
# Generasi 162 | Best Fitness: 10090 | avg: 10224.5
# Generasi 163 | Best Fitness: 10090 | avg: 10180.1
# Generasi 164 | Best Fitness: 10070 | avg: 10114.4
# Generasi 165 | Best Fitness: 10070 | avg: 10121.6
# Generasi 166 | Best Fitness: 10030 | avg: 10102.4
# Generasi 167 | Best Fitness: 10030 | avg: 10075.1
# Generasi 168 | Best Fitness: 10010 | avg: 10066.3
# Generasi 169 | Best Fitness: 10010 | avg: 10051.1
# Generasi 170 | Best Fitness: 10010 | avg: 10042.1
# Generasi 171 | Best Fitness: 10010 | avg: 10020.4
# Generasi 172 | Best Fitness: 10010 | avg: 10032.8
# Generasi 173 | Best Fitness: 9990 | avg: 10034.6
# Generasi 174 | Best Fitness: 9990 | avg: 10025.1
# Generasi 175 | Best Fitness: 9990 | avg: 10020.2
# Generasi 176 | Best Fitness: 9990 | avg: 10023.4
# Generasi 177 | Best Fitness: 9990 | avg: 10011.7
# Generasi 178 | Best Fitness: 9990 | avg: 10005.6
# Generasi 179 | Best Fitness: 9990 | avg: 10023.4
# Generasi 180 | Best Fitness: 9990 | avg: 10018.0
# Generasi 181 | Best Fitness: 9990 | avg: 10003.7
# Generasi 182 | Best Fitness: 9990 | avg: 10009.9
# Generasi 183 | Best Fitness: 9990 | avg: 10015.2
# Generasi 184 | Best Fitness: 9990 | avg: 10014.6
# Generasi 185 | Best Fitness: 9990 | avg: 10006.0
# Generasi 186 | Best Fitness: 9990 | avg: 10014.2
# Generasi 187 | Best Fitness: 9970 | avg: 10011.8
# Generasi 188 | Best Fitness: 9970 | avg: 10008.6
# Generasi 189 | Best Fitness: 9970 | avg: 10001.9
# Generasi 190 | Best Fitness: 9970 | avg: 9996.6
# Generasi 191 | Best Fitness: 9950 | avg: 9997.8
# Generasi 192 | Best Fitness: 9950 | avg: 9997.8
# Generasi 193 | Best Fitness: 9950 | avg: 9988.7
# Generasi 194 | Best Fitness: 9870 | avg: 9980.4
# Generasi 195 | Best Fitness: 9870 | avg: 9952.0
# Generasi 196 | Best Fitness: 9870 | avg: 9913.2
# Generasi 197 | Best Fitness: 9870 | avg: 9884.6
# Generasi 198 | Best Fitness: 9870 | avg: 9901.5
# Generasi 199 | Best Fitness: 9870 | avg: 9899.2
# Generasi 200 | Best Fitness: 9870 | avg: 9889.0
# Generasi 201 | Best Fitness: 9870 | avg: 9899.8
# Generasi 202 | Best Fitness: 9870 | avg: 9903.0
# Generasi 203 | Best Fitness: 9870 | avg: 9896.1
# Generasi 204 | Best Fitness: 9870 | avg: 9896.5
# Generasi 205 | Best Fitness: 9870 | avg: 9897.3
# Generasi 206 | Best Fitness: 9870 | avg: 9896.5
# Generasi 207 | Best Fitness: 9870 | avg: 9900.8
# Generasi 208 | Best Fitness: 9870 | avg: 9879.9
# Generasi 209 | Best Fitness: 9870 | avg: 9909.2
# Generasi 210 | Best Fitness: 9870 | avg: 9892.8
# Generasi 211 | Best Fitness: 9860 | avg: 9897.4
# Generasi 212 | Best Fitness: 9860 | avg: 9891.5
# Generasi 213 | Best Fitness: 9840 | avg: 9896.1
# Generasi 214 | Best Fitness: 9840 | avg: 9877.9
# Generasi 215 | Best Fitness: 9840 | avg: 9885.9
# Generasi 216 | Best Fitness: 9840 | avg: 9852.2
# Generasi 217 | Best Fitness: 9840 | avg: 9852.6
# Generasi 218 | Best Fitness: 9840 | avg: 9867.3
# Generasi 219 | Best Fitness: 9840 | avg: 9863.4
# Generasi 220 | Best Fitness: 9830 | avg: 9861.6
# Generasi 221 | Best Fitness: 9830 | avg: 9852.0
# Generasi 222 | Best Fitness: 9830 | avg: 9849.4
# Generasi 223 | Best Fitness: 9830 | avg: 9853.3
# Generasi 224 | Best Fitness: 9830 | avg: 9869.1
# Generasi 225 | Best Fitness: 9830 | avg: 9857.0
# Generasi 226 | Best Fitness: 9830 | avg: 9865.8
# Generasi 227 | Best Fitness: 9830 | avg: 9854.2
# Generasi 228 | Best Fitness: 9830 | avg: 9862.1
# Generasi 229 | Best Fitness: 9830 | avg: 9843.2
# Generasi 230 | Best Fitness: 9815 | avg: 9872.1
# Generasi 231 | Best Fitness: 9815 | avg: 9854.7
# Generasi 232 | Best Fitness: 9795 | avg: 9834.1
# Generasi 233 | Best Fitness: 9785 | avg: 9831.9
# Generasi 234 | Best Fitness: 9785 | avg: 9826.7
# Generasi 235 | Best Fitness: 9785 | avg: 9820.1
# Generasi 236 | Best Fitness: 9785 | avg: 9801.4
# Generasi 237 | Best Fitness: 9785 | avg: 9812.4
# Generasi 238 | Best Fitness: 9785 | avg: 9802.2
# Generasi 239 | Best Fitness: 9785 | avg: 9816.2
# Generasi 240 | Best Fitness: 9785 | avg: 9813.6
# Generasi 241 | Best Fitness: 9785 | avg: 9813.0
# Generasi 242 | Best Fitness: 9785 | avg: 9811.5
# Generasi 243 | Best Fitness: 9785 | avg: 9806.5
# Generasi 244 | Best Fitness: 9685 | avg: 9807.0
# Generasi 245 | Best Fitness: 9685 | avg: 9799.2
# Generasi 246 | Best Fitness: 9685 | avg: 9738.9
# Generasi 247 | Best Fitness: 9665 | avg: 9724.0
# Generasi 248 | Best Fitness: 9665 | avg: 9703.9
# Generasi 249 | Best Fitness: 9665 | avg: 9706.3
# Generasi 250 | Best Fitness: 9665 | avg: 9696.2
# Generasi 251 | Best Fitness: 9665 | avg: 9693.3
# Generasi 252 | Best Fitness: 9665 | avg: 9686.9
# Generasi 253 | Best Fitness: 9665 | avg: 9688.3
# Generasi 254 | Best Fitness: 9665 | avg: 9694.5
# Generasi 255 | Best Fitness: 9665 | avg: 9695.7
# Generasi 256 | Best Fitness: 9665 | avg: 9702.6
# Generasi 257 | Best Fitness: 9655 | avg: 9696.9
# Generasi 258 | Best Fitness: 9655 | avg: 9687.0
# Generasi 259 | Best Fitness: 9555 | avg: 9686.1
# Generasi 260 | Best Fitness: 9555 | avg: 9653.9
# Generasi 261 | Best Fitness: 9555 | avg: 9601.5
# Generasi 262 | Best Fitness: 9555 | avg: 9572.9
# Generasi 263 | Best Fitness: 9555 | avg: 9587.8
# Generasi 264 | Best Fitness: 9555 | avg: 9582.6
# Generasi 265 | Best Fitness: 9555 | avg: 9585.6
# Generasi 266 | Best Fitness: 9555 | avg: 9586.6
# Generasi 267 | Best Fitness: 9555 | avg: 9586.3
# Generasi 268 | Best Fitness: 9555 | avg: 9574.9
# Generasi 269 | Best Fitness: 9555 | avg: 9586.6
# Generasi 270 | Best Fitness: 9555 | avg: 9586.2
# Generasi 271 | Best Fitness: 9555 | avg: 9582.9
# Generasi 272 | Best Fitness: 9555 | avg: 9574.5
# Generasi 273 | Best Fitness: 9535 | avg: 9591.4
# Generasi 274 | Best Fitness: 9525 | avg: 9568.4
# Generasi 275 | Best Fitness: 9525 | avg: 9568.0
# Generasi 276 | Best Fitness: 9525 | avg: 9559.1
# Generasi 277 | Best Fitness: 9525 | avg: 9555.8
# Generasi 278 | Best Fitness: 9525 | avg: 9559.1
# Generasi 279 | Best Fitness: 9525 | avg: 9550.2
# Generasi 280 | Best Fitness: 9525 | avg: 9552.5
# Generasi 281 | Best Fitness: 9525 | avg: 9550.1
# Generasi 282 | Best Fitness: 9525 | avg: 9553.2
# Generasi 283 | Best Fitness: 9525 | avg: 9555.1
# Generasi 284 | Best Fitness: 9445 | avg: 9555.2
# Generasi 285 | Best Fitness: 9445 | avg: 9534.9
# Generasi 286 | Best Fitness: 9445 | avg: 9479.8
# Generasi 287 | Best Fitness: 9425 | avg: 9462.0
# Generasi 288 | Best Fitness: 9425 | avg: 9480.4
# Generasi 289 | Best Fitness: 9425 | avg: 9451.2
# Generasi 290 | Best Fitness: 9425 | avg: 9462.5
# Generasi 291 | Best Fitness: 9425 | avg: 9447.0
# Generasi 292 | Best Fitness: 9425 | avg: 9454.7
# Generasi 293 | Best Fitness: 9425 | avg: 9452.0
# Generasi 294 | Best Fitness: 9425 | avg: 9457.3
# Generasi 295 | Best Fitness: 9425 | avg: 9440.9
# Generasi 296 | Best Fitness: 9415 | avg: 9451.2
# Generasi 297 | Best Fitness: 9415 | avg: 9447.7
# Generasi 298 | Best Fitness: 9415 | avg: 9458.0
# Generasi 299 | Best Fitness: 9415 | avg: 9446.4
# Generasi 300 | Best Fitness: 9415 | avg: 9441.0
# Generasi 301 | Best Fitness: 9415 | avg: 9441.7
# Generasi 302 | Best Fitness: 9415 | avg: 9448.2
# Generasi 303 | Best Fitness: 9415 | avg: 9433.2
# Generasi 304 | Best Fitness: 9415 | avg: 9439.4
# Generasi 305 | Best Fitness: 9415 | avg: 9448.5
# Generasi 306 | Best Fitness: 9415 | avg: 9437.8
# Generasi 307 | Best Fitness: 9415 | avg: 9433.2
# Generasi 308 | Best Fitness: 9415 | avg: 9453.1
# Generasi 309 | Best Fitness: 9385 | avg: 9441.8
# Generasi 310 | Best Fitness: 9385 | avg: 9430.1
# Generasi 311 | Best Fitness: 9385 | avg: 9426.7
# Generasi 312 | Best Fitness: 9385 | avg: 9406.8
# Generasi 313 | Best Fitness: 9385 | avg: 9417.0
# Generasi 314 | Best Fitness: 9385 | avg: 9417.0
# Generasi 315 | Best Fitness: 9385 | avg: 9411.4
# Generasi 316 | Best Fitness: 9385 | avg: 9410.5
# Generasi 317 | Best Fitness: 9385 | avg: 9409.5
# Generasi 318 | Best Fitness: 9385 | avg: 9411.1
# Generasi 319 | Best Fitness: 9385 | avg: 9419.2
# Generasi 320 | Best Fitness: 9365 | avg: 9424.4
# Generasi 321 | Best Fitness: 9365 | avg: 9405.2
# Generasi 322 | Best Fitness: 9365 | avg: 9397.6
# Generasi 323 | Best Fitness: 9365 | avg: 9379.8
# Generasi 324 | Best Fitness: 9345 | avg: 9401.9
# Generasi 325 | Best Fitness: 9345 | avg: 9379.8
# Generasi 326 | Best Fitness: 9325 | avg: 9370.4
# Generasi 327 | Best Fitness: 9325 | avg: 9377.8
# Generasi 328 | Best Fitness: 9325 | avg: 9357.9
# Generasi 329 | Best Fitness: 9325 | avg: 9343.0
# Generasi 330 | Best Fitness: 9325 | avg: 9356.5
# Generasi 331 | Best Fitness: 9245 | avg: 9345.2
# Generasi 332 | Best Fitness: 9245 | avg: 9330.4
# Generasi 333 | Best Fitness: 9245 | avg: 9284.1
# Generasi 334 | Best Fitness: 9245 | avg: 9278.0
# Generasi 335 | Best Fitness: 9245 | avg: 9272.2
# Generasi 336 | Best Fitness: 9245 | avg: 9264.2
# Generasi 337 | Best Fitness: 9245 | avg: 9278.5
# Generasi 338 | Best Fitness: 9245 | avg: 9287.1
# Generasi 339 | Best Fitness: 9245 | avg: 9262.9
# Generasi 340 | Best Fitness: 9245 | avg: 9273.7
# Generasi 341 | Best Fitness: 9245 | avg: 9264.8
# Generasi 342 | Best Fitness: 9245 | avg: 9263.3
# Generasi 343 | Best Fitness: 9245 | avg: 9272.2
# Generasi 344 | Best Fitness: 9245 | avg: 9271.0
# Generasi 345 | Best Fitness: 9245 | avg: 9269.8
# Generasi 346 | Best Fitness: 9245 | avg: 9271.8
# Generasi 347 | Best Fitness: 9245 | avg: 9273.5
# Generasi 348 | Best Fitness: 9245 | avg: 9265.4
# Generasi 349 | Best Fitness: 9245 | avg: 9276.7
# Generasi 350 | Best Fitness: 9245 | avg: 9271.3
# Generasi 351 | Best Fitness: 9245 | avg: 9267.6
# Generasi 352 | Best Fitness: 9225 | avg: 9271.2
# Generasi 353 | Best Fitness: 9225 | avg: 9277.7
# Generasi 354 | Best Fitness: 9225 | avg: 9257.5
# Generasi 355 | Best Fitness: 9225 | avg: 9257.0
# Generasi 356 | Best Fitness: 9225 | avg: 9259.7
# Generasi 357 | Best Fitness: 9225 | avg: 9249.1
# Generasi 358 | Best Fitness: 9225 | avg: 9250.4
# Generasi 359 | Best Fitness: 9225 | avg: 9265.1
# Generasi 360 | Best Fitness: 9225 | avg: 9252.1
# Generasi 361 | Best Fitness: 9225 | avg: 9244.2
# Generasi 362 | Best Fitness: 9225 | avg: 9249.1
# Generasi 363 | Best Fitness: 9225 | avg: 9239.4
# Generasi 364 | Best Fitness: 9225 | avg: 9262.8
# Generasi 365 | Best Fitness: 9225 | avg: 9249.4
# Generasi 366 | Best Fitness: 9225 | avg: 9249.5
# Generasi 367 | Best Fitness: 9225 | avg: 9248.6
# Generasi 368 | Best Fitness: 9225 | avg: 9250.8
# Generasi 369 | Best Fitness: 9225 | avg: 9254.2
# Generasi 370 | Best Fitness: 9225 | avg: 9241.0
# Generasi 371 | Best Fitness: 9225 | avg: 9251.3
# Generasi 372 | Best Fitness: 9225 | avg: 9255.5
# Generasi 373 | Best Fitness: 9225 | avg: 9259.8
# Generasi 374 | Best Fitness: 9225 | avg: 9249.4
# Generasi 375 | Best Fitness: 9225 | avg: 9255.7
# Generasi 376 | Best Fitness: 9225 | avg: 9243.6
# Generasi 377 | Best Fitness: 9225 | avg: 9248.8
# Generasi 378 | Best Fitness: 9225 | avg: 9242.4
# Generasi 379 | Best Fitness: 9225 | avg: 9264.3
# Generasi 380 | Best Fitness: 9225 | avg: 9254.4
# Generasi 381 | Best Fitness: 9225 | avg: 9250.0
# Generasi 382 | Best Fitness: 9225 | avg: 9257.2
# Generasi 383 | Best Fitness: 9225 | avg: 9261.6
# Generasi 384 | Best Fitness: 9225 | avg: 9259.0
# Generasi 385 | Best Fitness: 9225 | avg: 9248.2
# Generasi 386 | Best Fitness: 9225 | avg: 9264.0
# Generasi 387 | Best Fitness: 9225 | avg: 9248.5
# Generasi 388 | Best Fitness: 9225 | avg: 9241.4
# Generasi 389 | Best Fitness: 9225 | avg: 9256.6
# Generasi 390 | Best Fitness: 9225 | avg: 9255.0
# Generasi 391 | Best Fitness: 9225 | avg: 9260.0
# Generasi 392 | Best Fitness: 9225 | avg: 9264.4
# Generasi 393 | Best Fitness: 9225 | avg: 9248.2
# Generasi 394 | Best Fitness: 9225 | avg: 9249.0
# Generasi 395 | Best Fitness: 9225 | avg: 9251.4
# Generasi 396 | Best Fitness: 9225 | avg: 9250.2
# Generasi 397 | Best Fitness: 9225 | avg: 9257.4
# Generasi 398 | Best Fitness: 9225 | avg: 9244.8
# Generasi 399 | Best Fitness: 9225 | avg: 9254.4
# Generasi 400 | Best Fitness: 9225 | avg: 9257.9
# Generasi 401 | Best Fitness: 9225 | avg: 9254.7
# Generasi 402 | Best Fitness: 9225 | avg: 9256.8
# Generasi 403 | Best Fitness: 9225 | avg: 9249.8
# Generasi 404 | Best Fitness: 9225 | avg: 9246.4
# Generasi 405 | Best Fitness: 9225 | avg: 9254.6
# Generasi 406 | Best Fitness: 9225 | avg: 9260.6
# Generasi 407 | Best Fitness: 9225 | avg: 9244.5
# Generasi 408 | Best Fitness: 9225 | avg: 9249.8
# Generasi 409 | Best Fitness: 9225 | avg: 9249.6
# Generasi 410 | Best Fitness: 9225 | avg: 9255.5
# Generasi 411 | Best Fitness: 9225 | avg: 9259.4
# Generasi 412 | Best Fitness: 9225 | avg: 9249.3
# Generasi 413 | Best Fitness: 9225 | avg: 9252.1
# Generasi 414 | Best Fitness: 9225 | avg: 9259.4
# Generasi 415 | Best Fitness: 9205 | avg: 9247.7
# Generasi 416 | Best Fitness: 9205 | avg: 9256.0
# Generasi 417 | Best Fitness: 9185 | avg: 9230.3
# Generasi 418 | Best Fitness: 9185 | avg: 9232.7
# Generasi 419 | Best Fitness: 9165 | avg: 9212.5
# Generasi 420 | Best Fitness: 9165 | avg: 9212.1
# Generasi 421 | Best Fitness: 9165 | avg: 9197.1
# Generasi 422 | Best Fitness: 9075 | avg: 9190.8
# Generasi 423 | Best Fitness: 9075 | avg: 9179.4
# Generasi 424 | Best Fitness: 9075 | avg: 9126.2
# Generasi 425 | Best Fitness: 9075 | avg: 9091.4
# Generasi 426 | Best Fitness: 9075 | avg: 9102.2
# Generasi 427 | Best Fitness: 9075 | avg: 9102.7
# Generasi 428 | Best Fitness: 9075 | avg: 9101.5
# Generasi 429 | Best Fitness: 9075 | avg: 9115.3
# Generasi 430 | Best Fitness: 9075 | avg: 9099.3
# Generasi 431 | Best Fitness: 9075 | avg: 9106.5
# Generasi 432 | Best Fitness: 9075 | avg: 9104.4
# Generasi 433 | Best Fitness: 9075 | avg: 9100.1
# Generasi 434 | Best Fitness: 9075 | avg: 9112.9
# Generasi 435 | Best Fitness: 9075 | avg: 9104.5
# Generasi 436 | Best Fitness: 9075 | avg: 9117.3
# Generasi 437 | Best Fitness: 9075 | avg: 9099.1
# Generasi 438 | Best Fitness: 9075 | avg: 9104.6
# Generasi 439 | Best Fitness: 9075 | avg: 9101.0
# Generasi 440 | Best Fitness: 9075 | avg: 9114.4
# Generasi 441 | Best Fitness: 9075 | avg: 9090.1
# Generasi 442 | Best Fitness: 9075 | avg: 9118.0
# Generasi 443 | Best Fitness: 9075 | avg: 9099.6
# Generasi 444 | Best Fitness: 9075 | avg: 9091.8
# Generasi 445 | Best Fitness: 9075 | avg: 9102.8
# Generasi 446 | Best Fitness: 9075 | avg: 9100.0
# Generasi 447 | Best Fitness: 9075 | avg: 9111.4
# Generasi 448 | Best Fitness: 9075 | avg: 9107.3
# Generasi 449 | Best Fitness: 9075 | avg: 9086.4
# Generasi 450 | Best Fitness: 9075 | avg: 9107.7
# Generasi 451 | Best Fitness: 9075 | avg: 9093.9
# Generasi 452 | Best Fitness: 9075 | avg: 9101.8
# Generasi 453 | Best Fitness: 9055 | avg: 9090.9
# Generasi 454 | Best Fitness: 9055 | avg: 9105.4
# Generasi 455 | Best Fitness: 9055 | avg: 9080.0
# Generasi 456 | Best Fitness: 9055 | avg: 9077.3
# Generasi 457 | Best Fitness: 9055 | avg: 9080.8
# Generasi 458 | Best Fitness: 9055 | avg: 9081.3
# Generasi 459 | Best Fitness: 9055 | avg: 9079.8
# Generasi 460 | Best Fitness: 9055 | avg: 9079.1
# Generasi 461 | Best Fitness: 9055 | avg: 9078.3
# Generasi 462 | Best Fitness: 9055 | avg: 9080.0
# Generasi 463 | Best Fitness: 9055 | avg: 9088.3
# Generasi 464 | Best Fitness: 9055 | avg: 9069.3
# Generasi 465 | Best Fitness: 9055 | avg: 9087.0
# Generasi 466 | Best Fitness: 9055 | avg: 9082.8
# Generasi 467 | Best Fitness: 9055 | avg: 9088.7
# Generasi 468 | Best Fitness: 9055 | avg: 9087.4
# Generasi 469 | Best Fitness: 9055 | avg: 9083.2
# Generasi 470 | Best Fitness: 9055 | avg: 9084.0
# Generasi 471 | Best Fitness: 9055 | avg: 9083.4
# Generasi 472 | Best Fitness: 9055 | avg: 9079.1
# Generasi 473 | Best Fitness: 9055 | avg: 9087.0
# Generasi 474 | Best Fitness: 9055 | avg: 9073.5
# Generasi 475 | Best Fitness: 9055 | avg: 9072.0
# Generasi 476 | Best Fitness: 9055 | avg: 9087.2
# Generasi 477 | Best Fitness: 9055 | avg: 9081.0
# Generasi 478 | Best Fitness: 9055 | avg: 9087.2
# Generasi 479 | Best Fitness: 9055 | avg: 9073.0
# Generasi 480 | Best Fitness: 9055 | avg: 9076.7
# Generasi 481 | Best Fitness: 9055 | avg: 9089.5
# Generasi 482 | Best Fitness: 9055 | avg: 9083.0
# Generasi 483 | Best Fitness: 9055 | avg: 9093.2
# Generasi 484 | Best Fitness: 9055 | avg: 9083.5
# Generasi 485 | Best Fitness: 9055 | avg: 9080.2
# Generasi 486 | Best Fitness: 9055 | avg: 9072.8
# Generasi 487 | Best Fitness: 9055 | avg: 9085.4
# Generasi 488 | Best Fitness: 9055 | avg: 9075.1
# Generasi 489 | Best Fitness: 9055 | avg: 9091.9
# Generasi 490 | Best Fitness: 9055 | avg: 9082.6
# Generasi 491 | Best Fitness: 9055 | avg: 9084.7
# Generasi 492 | Best Fitness: 9055 | avg: 9080.8
# Generasi 493 | Best Fitness: 9055 | avg: 9081.7
# Generasi 494 | Best Fitness: 9055 | avg: 9078.2
# Generasi 495 | Best Fitness: 9055 | avg: 9072.8
# Generasi 496 | Best Fitness: 9055 | avg: 9088.2
# Generasi 497 | Best Fitness: 9055 | avg: 9084.4
# Generasi 498 | Best Fitness: 9055 | avg: 9077.2
# Generasi 499 | Best Fitness: 9055 | avg: 9076.3
# Generasi 500 | Best Fitness: 9055 | avg: 9095.4
# Generasi 501 | Best Fitness: 9055 | avg: 9098.6
# Generasi 502 | Best Fitness: 9055 | avg: 9091.5
# Generasi 503 | Best Fitness: 9055 | avg: 9083.7
# Generasi 504 | Best Fitness: 9055 | avg: 9075.1
# Generasi 505 | Best Fitness: 9055 | avg: 9080.4
# Generasi 506 | Best Fitness: 9055 | avg: 9077.2
# Generasi 507 | Best Fitness: 9055 | avg: 9087.5
# Generasi 508 | Best Fitness: 9055 | avg: 9084.8
# Generasi 509 | Best Fitness: 9055 | avg: 9083.5
# Generasi 510 | Best Fitness: 9055 | avg: 9095.2
# Generasi 511 | Best Fitness: 9055 | avg: 9077.1
# Generasi 512 | Best Fitness: 9055 | avg: 9090.3
# Generasi 513 | Best Fitness: 9055 | avg: 9080.6
# Generasi 514 | Best Fitness: 9055 | avg: 9067.7
# Generasi 515 | Best Fitness: 9055 | avg: 9080.0
# Generasi 516 | Best Fitness: 9055 | avg: 9076.0
# Generasi 517 | Best Fitness: 9055 | avg: 9083.8
# Generasi 518 | Best Fitness: 9055 | avg: 9082.1
# Generasi 519 | Best Fitness: 9055 | avg: 9080.0
# Generasi 520 | Best Fitness: 9055 | avg: 9081.0
# Generasi 521 | Best Fitness: 9055 | avg: 9082.0
# Generasi 522 | Best Fitness: 9055 | avg: 9084.4
# Generasi 523 | Best Fitness: 9055 | avg: 9074.4
# Generasi 524 | Best Fitness: 9055 | avg: 9072.8
# Generasi 525 | Best Fitness: 9055 | avg: 9084.7
# Generasi 526 | Best Fitness: 9055 | avg: 9082.6
# Generasi 527 | Best Fitness: 9055 | avg: 9083.9
# Generasi 528 | Best Fitness: 9055 | avg: 9069.7
# Generasi 529 | Best Fitness: 9055 | avg: 9088.9
# Generasi 530 | Best Fitness: 9055 | avg: 9084.2
# Generasi 531 | Best Fitness: 9055 | avg: 9097.6
# Generasi 532 | Best Fitness: 9055 | avg: 9077.2
# Generasi 533 | Best Fitness: 9055 | avg: 9081.8
# Generasi 534 | Best Fitness: 9055 | avg: 9088.7
# Generasi 535 | Best Fitness: 9035 | avg: 9077.9
# Generasi 536 | Best Fitness: 9035 | avg: 9070.7
# Generasi 537 | Best Fitness: 9035 | avg: 9075.4
# Generasi 538 | Best Fitness: 9035 | avg: 9060.0
# Generasi 539 | Best Fitness: 9035 | avg: 9066.7
# Generasi 540 | Best Fitness: 9035 | avg: 9068.1
# Generasi 541 | Best Fitness: 9035 | avg: 9070.1
# Generasi 542 | Best Fitness: 9035 | avg: 9068.2
# Generasi 543 | Best Fitness: 9035 | avg: 9050.4
# Generasi 544 | Best Fitness: 9035 | avg: 9063.6
# Generasi 545 | Best Fitness: 9035 | avg: 9064.7
# Generasi 546 | Best Fitness: 9035 | avg: 9062.0
# Generasi 547 | Best Fitness: 9035 | avg: 9054.9
# Generasi 548 | Best Fitness: 9035 | avg: 9054.8
# Generasi 549 | Best Fitness: 9035 | avg: 9073.5
# Generasi 550 | Best Fitness: 9035 | avg: 9064.2
# Generasi 551 | Best Fitness: 9035 | avg: 9077.3
# Generasi 552 | Best Fitness: 9035 | avg: 9057.4
# Generasi 553 | Best Fitness: 9035 | avg: 9050.8
# Generasi 554 | Best Fitness: 9035 | avg: 9052.2
# Generasi 555 | Best Fitness: 9035 | avg: 9052.7
# Generasi 556 | Best Fitness: 9035 | avg: 9057.6
# Generasi 557 | Best Fitness: 9035 | avg: 9070.3
# Generasi 558 | Best Fitness: 9035 | avg: 9059.4
# Generasi 559 | Best Fitness: 9035 | avg: 9062.5
# Generasi 560 | Best Fitness: 9035 | avg: 9050.0
# Generasi 561 | Best Fitness: 9035 | avg: 9066.1
# Generasi 562 | Best Fitness: 9035 | avg: 9060.1
# Generasi 563 | Best Fitness: 9035 | avg: 9072.8
# Generasi 564 | Best Fitness: 9035 | avg: 9067.3
# Generasi 565 | Best Fitness: 9035 | avg: 9060.9
# Generasi 566 | Best Fitness: 9035 | avg: 9062.3
# Generasi 567 | Best Fitness: 9035 | avg: 9055.4
# Generasi 568 | Best Fitness: 9035 | avg: 9058.7
# Generasi 569 | Best Fitness: 9035 | avg: 9069.2
# Generasi 570 | Best Fitness: 9035 | avg: 9077.4
# Generasi 571 | Best Fitness: 9035 | avg: 9062.5
# Generasi 572 | Best Fitness: 9035 | avg: 9049.5
# Generasi 573 | Best Fitness: 9035 | avg: 9066.2
# Generasi 574 | Best Fitness: 9035 | avg: 9067.7
# Generasi 575 | Best Fitness: 9035 | avg: 9073.5
# Generasi 576 | Best Fitness: 9035 | avg: 9062.0
# Generasi 577 | Best Fitness: 9035 | avg: 9057.0
# Generasi 578 | Best Fitness: 9035 | avg: 9064.2
# Generasi 579 | Best Fitness: 9035 | avg: 9059.2
# Generasi 580 | Best Fitness: 9035 | avg: 9066.1
# Generasi 581 | Best Fitness: 9035 | avg: 9052.0
# Generasi 582 | Best Fitness: 9035 | avg: 9060.0
# Generasi 583 | Best Fitness: 9035 | avg: 9062.5
# Generasi 584 | Best Fitness: 9035 | avg: 9071.3
# Generasi 585 | Best Fitness: 9035 | avg: 9062.0
# Generasi 586 | Best Fitness: 9035 | avg: 9075.6
# Generasi 587 | Best Fitness: 9035 | avg: 9063.1
# Generasi 588 | Best Fitness: 9035 | avg: 9064.2
# Generasi 589 | Best Fitness: 9035 | avg: 9062.5
# Generasi 590 | Best Fitness: 9035 | avg: 9065.1
# Generasi 591 | Best Fitness: 9035 | avg: 9067.7
# Generasi 592 | Best Fitness: 9035 | avg: 9053.6
# Generasi 593 | Best Fitness: 9035 | avg: 9055.4
# Generasi 594 | Best Fitness: 9035 | avg: 9071.8
# Generasi 595 | Best Fitness: 9035 | avg: 9058.6
# Generasi 596 | Best Fitness: 9035 | avg: 9067.6
# Generasi 597 | Best Fitness: 9035 | avg: 9048.2
# Generasi 598 | Best Fitness: 9035 | avg: 9052.1
# Generasi 599 | Best Fitness: 9035 | avg: 9069.5
# Generasi 600 | Best Fitness: 9035 | avg: 9062.8
# Generasi 601 | Best Fitness: 9035 | avg: 9062.7
# Generasi 602 | Best Fitness: 9035 | avg: 9062.6
# Generasi 603 | Best Fitness: 9035 | avg: 9058.6
# Generasi 604 | Best Fitness: 9035 | avg: 9064.1
# Generasi 605 | Best Fitness: 9035 | avg: 9074.1
# Generasi 606 | Best Fitness: 9035 | avg: 9058.0
# Generasi 607 | Best Fitness: 9035 | avg: 9069.8
# Generasi 608 | Best Fitness: 9035 | avg: 9080.9
# Generasi 609 | Best Fitness: 9035 | avg: 9067.7
# Generasi 610 | Best Fitness: 9035 | avg: 9062.8
# Generasi 611 | Best Fitness: 9035 | avg: 9062.4
# Generasi 612 | Best Fitness: 9035 | avg: 9066.0
# Generasi 613 | Best Fitness: 9035 | avg: 9059.1
# Generasi 614 | Best Fitness: 9035 | avg: 9068.2
# Generasi 615 | Best Fitness: 9035 | avg: 9060.8
# Generasi 616 | Best Fitness: 9035 | avg: 9058.4
# Generasi 617 | Best Fitness: 9035 | avg: 9063.8
# Generasi 618 | Best Fitness: 9035 | avg: 9066.7
# Generasi 619 | Best Fitness: 9035 | avg: 9059.8
# Generasi 620 | Best Fitness: 9035 | avg: 9057.3
# Generasi 621 | Best Fitness: 9035 | avg: 9060.8
# Generasi 622 | Best Fitness: 9035 | avg: 9060.6
# Generasi 623 | Best Fitness: 9035 | avg: 9063.2
# Generasi 624 | Best Fitness: 9035 | avg: 9054.2
# Generasi 625 | Best Fitness: 9035 | avg: 9074.8
# Generasi 626 | Best Fitness: 9035 | avg: 9059.8
# Generasi 627 | Best Fitness: 9035 | avg: 9071.0
# Generasi 628 | Best Fitness: 9035 | avg: 9048.9
# Generasi 629 | Best Fitness: 9035 | avg: 9069.2
# Generasi 630 | Best Fitness: 9035 | avg: 9067.8
# Generasi 631 | Best Fitness: 9035 | avg: 9053.6
# Generasi 632 | Best Fitness: 9035 | avg: 9060.2
# Generasi 633 | Best Fitness: 9035 | avg: 9055.0
# Generasi 634 | Best Fitness: 9035 | avg: 9053.3
# Generasi 635 | Best Fitness: 9035 | avg: 9059.8
# Generasi 636 | Best Fitness: 9035 | avg: 9060.1
# Generasi 637 | Best Fitness: 9035 | avg: 9064.6
# Generasi 638 | Best Fitness: 9035 | avg: 9067.0
# Generasi 639 | Best Fitness: 9035 | avg: 9064.6
# Generasi 640 | Best Fitness: 9035 | avg: 9062.5
# Generasi 641 | Best Fitness: 9035 | avg: 9066.3
# Generasi 642 | Best Fitness: 9035 | avg: 9058.6
# Generasi 643 | Best Fitness: 9035 | avg: 9061.4
# Generasi 644 | Best Fitness: 9035 | avg: 9057.9
# Generasi 645 | Best Fitness: 9035 | avg: 9057.6
# Generasi 646 | Best Fitness: 9035 | avg: 9052.9
# Generasi 647 | Best Fitness: 9035 | avg: 9073.9
# Generasi 648 | Best Fitness: 9035 | avg: 9065.6
# Generasi 649 | Best Fitness: 9035 | avg: 9056.2
# Generasi 650 | Best Fitness: 9035 | avg: 9058.5
# Generasi 651 | Best Fitness: 9035 | avg: 9057.8
# Generasi 652 | Best Fitness: 9035 | avg: 9054.0
# Generasi 653 | Best Fitness: 9035 | avg: 9069.4
# Generasi 654 | Best Fitness: 9035 | avg: 9054.6
# Generasi 655 | Best Fitness: 9035 | avg: 9055.6
# Generasi 656 | Best Fitness: 9035 | avg: 9071.7
# Generasi 657 | Best Fitness: 9035 | avg: 9053.7
# Generasi 658 | Best Fitness: 9035 | avg: 9067.4
# Generasi 659 | Best Fitness: 9035 | avg: 9063.1
# Generasi 660 | Best Fitness: 9035 | avg: 9055.0
# Generasi 661 | Best Fitness: 9035 | avg: 9055.3
# Generasi 662 | Best Fitness: 9035 | avg: 9062.0
# Generasi 663 | Best Fitness: 9035 | avg: 9058.6
# Generasi 664 | Best Fitness: 9035 | avg: 9058.3
# Generasi 665 | Best Fitness: 9035 | avg: 9058.2
# Generasi 666 | Best Fitness: 9035 | avg: 9053.6
# Generasi 667 | Best Fitness: 9035 | avg: 9066.0
# Generasi 668 | Best Fitness: 9035 | avg: 9063.0
# Generasi 669 | Best Fitness: 9035 | avg: 9061.8
# Generasi 670 | Best Fitness: 9035 | avg: 9063.5
# Generasi 671 | Best Fitness: 9035 | avg: 9052.7
# Generasi 672 | Best Fitness: 9035 | avg: 9066.6
# Generasi 673 | Best Fitness: 9035 | avg: 9063.5
# Generasi 674 | Best Fitness: 9035 | avg: 9057.5
# Generasi 675 | Best Fitness: 9035 | avg: 9066.7
# Generasi 676 | Best Fitness: 9035 | avg: 9069.6
# Generasi 677 | Best Fitness: 9035 | avg: 9060.0
# Generasi 678 | Best Fitness: 9035 | avg: 9065.4
# Generasi 679 | Best Fitness: 9035 | avg: 9082.9
# Generasi 680 | Best Fitness: 9035 | avg: 9069.9
# Generasi 681 | Best Fitness: 9035 | avg: 9059.1
# Generasi 682 | Best Fitness: 9035 | avg: 9060.6
# Generasi 683 | Best Fitness: 9035 | avg: 9060.0
# Generasi 684 | Best Fitness: 9035 | avg: 9053.9
# Generasi 685 | Best Fitness: 9035 | avg: 9061.0
# Generasi 686 | Best Fitness: 9035 | avg: 9066.3
# Generasi 687 | Best Fitness: 9035 | avg: 9054.7
# Generasi 688 | Best Fitness: 9035 | avg: 9064.0
# Generasi 689 | Best Fitness: 9035 | avg: 9065.4
# Generasi 690 | Best Fitness: 9035 | avg: 9070.1
# Generasi 691 | Best Fitness: 9035 | avg: 9062.9
# Generasi 692 | Best Fitness: 9035 | avg: 9060.3
# Generasi 693 | Best Fitness: 9035 | avg: 9060.2
# Generasi 694 | Best Fitness: 9035 | avg: 9057.8
# Generasi 695 | Best Fitness: 9035 | avg: 9064.0
# Generasi 696 | Best Fitness: 9035 | avg: 9057.9
# Generasi 697 | Best Fitness: 9035 | avg: 9057.7
# Generasi 698 | Best Fitness: 9035 | avg: 9051.6
# Generasi 699 | Best Fitness: 9035 | avg: 9066.1
# Generasi 700 | Best Fitness: 9035 | avg: 9059.9
# Generasi 701 | Best Fitness: 9035 | avg: 9056.0
# Generasi 702 | Best Fitness: 9035 | avg: 9062.4
# Generasi 703 | Best Fitness: 9035 | avg: 9075.3
# Generasi 704 | Best Fitness: 9035 | avg: 9068.1
# Generasi 705 | Best Fitness: 9035 | avg: 9060.0
# Generasi 706 | Best Fitness: 9035 | avg: 9068.8
# Generasi 707 | Best Fitness: 9035 | avg: 9071.7
# Generasi 708 | Best Fitness: 9035 | avg: 9061.4
# Generasi 709 | Best Fitness: 9035 | avg: 9058.2
# Generasi 710 | Best Fitness: 9035 | avg: 9064.1
# Generasi 711 | Best Fitness: 9035 | avg: 9064.6
# Generasi 712 | Best Fitness: 9035 | avg: 9066.4
# Generasi 713 | Best Fitness: 9035 | avg: 9059.1
# Generasi 714 | Best Fitness: 9035 | avg: 9070.9
# Generasi 715 | Best Fitness: 9035 | avg: 9052.0
# Generasi 716 | Best Fitness: 9035 | avg: 9062.0
# Generasi 717 | Best Fitness: 9035 | avg: 9057.9
# Generasi 718 | Best Fitness: 9035 | avg: 9056.8
# Generasi 719 | Best Fitness: 9035 | avg: 9061.8
# Generasi 720 | Best Fitness: 9035 | avg: 9062.2
# Generasi 721 | Best Fitness: 9035 | avg: 9081.6
# Generasi 722 | Best Fitness: 9035 | avg: 9054.2
# Generasi 723 | Best Fitness: 9035 | avg: 9058.2
# Generasi 724 | Best Fitness: 9035 | avg: 9061.3
# Generasi 725 | Best Fitness: 9035 | avg: 9054.2
# Generasi 726 | Best Fitness: 9035 | avg: 9063.4
# Generasi 727 | Best Fitness: 9035 | avg: 9052.4
# Generasi 728 | Best Fitness: 9035 | avg: 9054.0
# Generasi 729 | Best Fitness: 9035 | avg: 9054.5
# Generasi 730 | Best Fitness: 9035 | avg: 9068.4
# Generasi 731 | Best Fitness: 9035 | avg: 9056.8
# Generasi 732 | Best Fitness: 9035 | avg: 9057.4
# Generasi 733 | Best Fitness: 9035 | avg: 9070.5
# Generasi 734 | Best Fitness: 9035 | avg: 9062.5
# Generasi 735 | Best Fitness: 9035 | avg: 9062.6
# Generasi 736 | Best Fitness: 9035 | avg: 9062.6
# Generasi 737 | Best Fitness: 9035 | avg: 9065.4
# Generasi 738 | Best Fitness: 9035 | avg: 9048.9
# Generasi 739 | Best Fitness: 9035 | avg: 9049.4
# Generasi 740 | Best Fitness: 9035 | avg: 9080.5
# Generasi 741 | Best Fitness: 9035 | avg: 9057.4
# Generasi 742 | Best Fitness: 9035 | avg: 9072.5
# Generasi 743 | Best Fitness: 9035 | avg: 9060.4
# Generasi 744 | Best Fitness: 9035 | avg: 9057.3
# Generasi 745 | Best Fitness: 9035 | avg: 9073.2
# Generasi 746 | Best Fitness: 9035 | avg: 9051.8
# Generasi 747 | Best Fitness: 9035 | avg: 9060.5
# Generasi 748 | Best Fitness: 9035 | avg: 9064.9
# Generasi 749 | Best Fitness: 9035 | avg: 9069.8
# Generasi 750 | Best Fitness: 9035 | avg: 9071.7
# Generasi 751 | Best Fitness: 9035 | avg: 9060.4
# Generasi 752 | Best Fitness: 9035 | avg: 9057.0
# Generasi 753 | Best Fitness: 9035 | avg: 9064.7
# Generasi 754 | Best Fitness: 9035 | avg: 9059.6
# Generasi 755 | Best Fitness: 9035 | avg: 9061.4
# Generasi 756 | Best Fitness: 9035 | avg: 9068.5
# Generasi 757 | Best Fitness: 9035 | avg: 9063.6
# Generasi 758 | Best Fitness: 9035 | avg: 9060.6
# Generasi 759 | Best Fitness: 9035 | avg: 9076.8
# Generasi 760 | Best Fitness: 9035 | avg: 9058.7
# Generasi 761 | Best Fitness: 9035 | avg: 9055.4
# Generasi 762 | Best Fitness: 9035 | avg: 9063.0
# Generasi 763 | Best Fitness: 9035 | avg: 9058.9
# Generasi 764 | Best Fitness: 9035 | avg: 9059.6
# Generasi 765 | Best Fitness: 9035 | avg: 9055.7
# Generasi 766 | Best Fitness: 9035 | avg: 9077.2
# Generasi 767 | Best Fitness: 9035 | avg: 9064.8
# Generasi 768 | Best Fitness: 9035 | avg: 9060.4
# Generasi 769 | Best Fitness: 9035 | avg: 9061.0
# Generasi 770 | Best Fitness: 9035 | avg: 9054.6
# Generasi 771 | Best Fitness: 9035 | avg: 9065.4
# Generasi 772 | Best Fitness: 9035 | avg: 9066.5
# Generasi 773 | Best Fitness: 9035 | avg: 9058.1
# Generasi 774 | Best Fitness: 9035 | avg: 9059.0
# Generasi 775 | Best Fitness: 9035 | avg: 9062.6
# Generasi 776 | Best Fitness: 9035 | avg: 9072.8
# Generasi 777 | Best Fitness: 9035 | avg: 9056.4
# Generasi 778 | Best Fitness: 9035 | avg: 9076.0
# Generasi 779 | Best Fitness: 9035 | avg: 9056.2
# Generasi 780 | Best Fitness: 9035 | avg: 9061.0
# Generasi 781 | Best Fitness: 9035 | avg: 9064.1
# Generasi 782 | Best Fitness: 9035 | avg: 9052.0
# Generasi 783 | Best Fitness: 9035 | avg: 9053.2
# Generasi 784 | Best Fitness: 9035 | avg: 9057.3
# Generasi 785 | Best Fitness: 9035 | avg: 9060.0
# Generasi 786 | Best Fitness: 9035 | avg: 9066.8
# Generasi 787 | Best Fitness: 9035 | avg: 9060.1
# Generasi 788 | Best Fitness: 9035 | avg: 9063.0
# Generasi 789 | Best Fitness: 9035 | avg: 9065.4
# Generasi 790 | Best Fitness: 9035 | avg: 9066.9
# Generasi 791 | Best Fitness: 9035 | avg: 9060.1
# Generasi 792 | Best Fitness: 9035 | avg: 9058.2
# Generasi 793 | Best Fitness: 9035 | avg: 9052.0
# Generasi 794 | Best Fitness: 9035 | avg: 9056.4
# Generasi 795 | Best Fitness: 9035 | avg: 9062.5
# Generasi 796 | Best Fitness: 9035 | avg: 9064.6
# Generasi 797 | Best Fitness: 9035 | avg: 9068.7
# Generasi 798 | Best Fitness: 9035 | avg: 9056.2
# Generasi 799 | Best Fitness: 9035 | avg: 9066.8
# Generasi 800 | Best Fitness: 9035 | avg: 9069.7
# Generasi 801 | Best Fitness: 9035 | avg: 9061.6
# Generasi 802 | Best Fitness: 9035 | avg: 9060.5
# Generasi 803 | Best Fitness: 9035 | avg: 9066.8
# Generasi 804 | Best Fitness: 9035 | avg: 9062.7
# Generasi 805 | Best Fitness: 9035 | avg: 9066.4
# Generasi 806 | Best Fitness: 9035 | avg: 9051.4
# Generasi 807 | Best Fitness: 9035 | avg: 9066.9
# Generasi 808 | Best Fitness: 9035 | avg: 9060.6
# Generasi 809 | Best Fitness: 9035 | avg: 9068.0
# Generasi 810 | Best Fitness: 9035 | avg: 9068.6
# Generasi 811 | Best Fitness: 9035 | avg: 9063.6
# Generasi 812 | Best Fitness: 9035 | avg: 9064.9
# Generasi 813 | Best Fitness: 9035 | avg: 9066.1
# Generasi 814 | Best Fitness: 9035 | avg: 9069.3
# Generasi 815 | Best Fitness: 9035 | avg: 9059.6
# Generasi 816 | Best Fitness: 9035 | avg: 9071.6
# Generasi 817 | Best Fitness: 9035 | avg: 9062.3
# Generasi 818 | Best Fitness: 9035 | avg: 9067.2
# Generasi 819 | Best Fitness: 9035 | avg: 9055.9
# Generasi 820 | Best Fitness: 9035 | avg: 9059.2
# Generasi 821 | Best Fitness: 9035 | avg: 9059.4
# Generasi 822 | Best Fitness: 9035 | avg: 9071.0
# Generasi 823 | Best Fitness: 9035 | avg: 9065.6
# Generasi 824 | Best Fitness: 9035 | avg: 9059.2
# Generasi 825 | Best Fitness: 9035 | avg: 9062.2
# Generasi 826 | Best Fitness: 9035 | avg: 9074.2
# Generasi 827 | Best Fitness: 9035 | avg: 9067.5
# Generasi 828 | Best Fitness: 9035 | avg: 9057.6
# Generasi 829 | Best Fitness: 9035 | avg: 9061.7
# Generasi 830 | Best Fitness: 9035 | avg: 9065.5
# Generasi 831 | Best Fitness: 9035 | avg: 9067.1
# Generasi 832 | Best Fitness: 9035 | avg: 9055.8
# Generasi 833 | Best Fitness: 9035 | avg: 9060.2
# Generasi 834 | Best Fitness: 9015 | avg: 9050.9
# Generasi 835 | Best Fitness: 9015 | avg: 9056.9
# Generasi 836 | Best Fitness: 9015 | avg: 9054.3
# Generasi 837 | Best Fitness: 9015 | avg: 9035.8
# Generasi 838 | Best Fitness: 9015 | avg: 9037.6
# Generasi 839 | Best Fitness: 9015 | avg: 9035.8
# Generasi 840 | Best Fitness: 9015 | avg: 9035.9
# Generasi 841 | Best Fitness: 9015 | avg: 9045.4
# Generasi 842 | Best Fitness: 9015 | avg: 9043.6
# Generasi 843 | Best Fitness: 9015 | avg: 9052.4
# Generasi 844 | Best Fitness: 9015 | avg: 9035.0
# Generasi 845 | Best Fitness: 9015 | avg: 9031.2
# Generasi 846 | Best Fitness: 9015 | avg: 9036.3
# Generasi 847 | Best Fitness: 9015 | avg: 9044.5
# Generasi 848 | Best Fitness: 9015 | avg: 9053.2
# Generasi 849 | Best Fitness: 9015 | avg: 9042.6
# Generasi 850 | Best Fitness: 9015 | avg: 9038.5
# Generasi 851 | Best Fitness: 9015 | avg: 9045.7
# Generasi 852 | Best Fitness: 9015 | avg: 9047.6
# Generasi 853 | Best Fitness: 9015 | avg: 9041.6
# Generasi 854 | Best Fitness: 9015 | avg: 9052.6
# Generasi 855 | Best Fitness: 9015 | avg: 9041.6
# Generasi 856 | Best Fitness: 9015 | avg: 9055.7
# Generasi 857 | Best Fitness: 9015 | avg: 9040.6
# Generasi 858 | Best Fitness: 9015 | avg: 9047.7
# Generasi 859 | Best Fitness: 9015 | avg: 9041.1
# Generasi 860 | Best Fitness: 9015 | avg: 9031.3
# Generasi 861 | Best Fitness: 9015 | avg: 9040.6
# Generasi 862 | Best Fitness: 9015 | avg: 9034.0
# Generasi 863 | Best Fitness: 9015 | avg: 9052.6
# Generasi 864 | Best Fitness: 9015 | avg: 9047.3
# Generasi 865 | Best Fitness: 9015 | avg: 9044.0
# Generasi 866 | Best Fitness: 9015 | avg: 9043.4
# Generasi 867 | Best Fitness: 9015 | avg: 9049.1
# Generasi 868 | Best Fitness: 9015 | avg: 9053.5
# Generasi 869 | Best Fitness: 9015 | avg: 9051.3
# Generasi 870 | Best Fitness: 9015 | avg: 9050.7
# Generasi 871 | Best Fitness: 9015 | avg: 9059.8
# Generasi 872 | Best Fitness: 9015 | avg: 9051.1
# Generasi 873 | Best Fitness: 9015 | avg: 9041.1
# Generasi 874 | Best Fitness: 9015 | avg: 9046.8
# Generasi 875 | Best Fitness: 9015 | avg: 9051.7
# Generasi 876 | Best Fitness: 9015 | avg: 9039.8
# Generasi 877 | Best Fitness: 9015 | avg: 9049.1
# Generasi 878 | Best Fitness: 9015 | avg: 9039.7
# Generasi 879 | Best Fitness: 9015 | avg: 9045.6
# Generasi 880 | Best Fitness: 9015 | avg: 9036.8
# Generasi 881 | Best Fitness: 9015 | avg: 9038.5
# Generasi 882 | Best Fitness: 9015 | avg: 9052.3
# Generasi 883 | Best Fitness: 9015 | avg: 9038.1
# Generasi 884 | Best Fitness: 9015 | avg: 9037.3
# Generasi 885 | Best Fitness: 9015 | avg: 9042.7
# Generasi 886 | Best Fitness: 9015 | avg: 9044.3
# Generasi 887 | Best Fitness: 9015 | avg: 9052.6
# Generasi 888 | Best Fitness: 9015 | avg: 9041.6
# Generasi 889 | Best Fitness: 9015 | avg: 9038.7
# Generasi 890 | Best Fitness: 9015 | avg: 9046.0
# Generasi 891 | Best Fitness: 9015 | avg: 9038.6
# Generasi 892 | Best Fitness: 9015 | avg: 9042.0
# Generasi 893 | Best Fitness: 9015 | avg: 9030.1
# Generasi 894 | Best Fitness: 9015 | avg: 9040.2
# Generasi 895 | Best Fitness: 9015 | avg: 9042.0
# Generasi 896 | Best Fitness: 9015 | avg: 9036.9
# Generasi 897 | Best Fitness: 9015 | avg: 9047.4
# Generasi 898 | Best Fitness: 9015 | avg: 9045.0
# Generasi 899 | Best Fitness: 9015 | avg: 9042.1
# Generasi 900 | Best Fitness: 9015 | avg: 9044.2
# Generasi 901 | Best Fitness: 9015 | avg: 9051.3
# Generasi 902 | Best Fitness: 9015 | avg: 9044.2
# Generasi 903 | Best Fitness: 9015 | avg: 9039.0
# Generasi 904 | Best Fitness: 9015 | avg: 9040.1
# Generasi 905 | Best Fitness: 9015 | avg: 9056.3
# Generasi 906 | Best Fitness: 9015 | avg: 9041.7
# Generasi 907 | Best Fitness: 9015 | avg: 9043.3
# Generasi 908 | Best Fitness: 9015 | avg: 9038.6
# Generasi 909 | Best Fitness: 9015 | avg: 9044.5
# Generasi 910 | Best Fitness: 9015 | avg: 9053.6
# Generasi 911 | Best Fitness: 9015 | avg: 9053.4
# Generasi 912 | Best Fitness: 9015 | avg: 9038.8
# Generasi 913 | Best Fitness: 9015 | avg: 9032.9
# Generasi 914 | Best Fitness: 9015 | avg: 9043.7
# Generasi 915 | Best Fitness: 9015 | avg: 9041.6
# Generasi 916 | Best Fitness: 9015 | avg: 9034.8
# Generasi 917 | Best Fitness: 9015 | avg: 9047.3
# Generasi 918 | Best Fitness: 9015 | avg: 9052.4
# Generasi 919 | Best Fitness: 9015 | avg: 9047.9
# Generasi 920 | Best Fitness: 9015 | avg: 9056.0
# Generasi 921 | Best Fitness: 9015 | avg: 9050.6
# Generasi 922 | Best Fitness: 9015 | avg: 9047.3
# Generasi 923 | Best Fitness: 9015 | avg: 9037.5
# Generasi 924 | Best Fitness: 9015 | avg: 9050.7
# Generasi 925 | Best Fitness: 9015 | avg: 9048.2
# Generasi 926 | Best Fitness: 9015 | avg: 9042.6
# Generasi 927 | Best Fitness: 9015 | avg: 9041.8
# Generasi 928 | Best Fitness: 9015 | avg: 9028.5
# Generasi 929 | Best Fitness: 9015 | avg: 9042.1
# Generasi 930 | Best Fitness: 9015 | avg: 9039.1
# Generasi 931 | Best Fitness: 9015 | avg: 9035.4
# Generasi 932 | Best Fitness: 9015 | avg: 9041.0
# Generasi 933 | Best Fitness: 9015 | avg: 9044.2
# Generasi 934 | Best Fitness: 9015 | avg: 9048.6
# Generasi 935 | Best Fitness: 9015 | avg: 9046.4
# Generasi 936 | Best Fitness: 9015 | avg: 9043.1
# Generasi 937 | Best Fitness: 9015 | avg: 9053.0
# Generasi 938 | Best Fitness: 9015 | avg: 9036.4
# Generasi 939 | Best Fitness: 9015 | avg: 9044.5
# Generasi 940 | Best Fitness: 9015 | avg: 9046.4
# Generasi 941 | Best Fitness: 9015 | avg: 9045.5
# Generasi 942 | Best Fitness: 9015 | avg: 9039.8
# Generasi 943 | Best Fitness: 9015 | avg: 9041.2
# Generasi 944 | Best Fitness: 9015 | avg: 9046.2
# Generasi 945 | Best Fitness: 8995 | avg: 9037.5
# Generasi 946 | Best Fitness: 8995 | avg: 9045.0
# Generasi 947 | Best Fitness: 8995 | avg: 9028.3
# Generasi 948 | Best Fitness: 8995 | avg: 9022.1
# Generasi 949 | Best Fitness: 8995 | avg: 9036.8
# Generasi 950 | Best Fitness: 8995 | avg: 9023.8
# Generasi 951 | Best Fitness: 8995 | avg: 9019.9
# Generasi 952 | Best Fitness: 8995 | avg: 9022.7
# Generasi 953 | Best Fitness: 8995 | avg: 9026.9
# Generasi 954 | Best Fitness: 8995 | avg: 9021.1
# Generasi 955 | Best Fitness: 8995 | avg: 9018.2
# Generasi 956 | Best Fitness: 8995 | avg: 9020.6
# Generasi 957 | Best Fitness: 8995 | avg: 9027.1
# Generasi 958 | Best Fitness: 8995 | avg: 9020.2
# Generasi 959 | Best Fitness: 8995 | avg: 9021.1
# Generasi 960 | Best Fitness: 8995 | avg: 9035.1
# Generasi 961 | Best Fitness: 8995 | avg: 9016.9
# Generasi 962 | Best Fitness: 8995 | avg: 9014.0
# Generasi 963 | Best Fitness: 8995 | avg: 9022.0
# Generasi 964 | Best Fitness: 8995 | avg: 9026.4
# Generasi 965 | Best Fitness: 8995 | avg: 9024.0
# Generasi 966 | Best Fitness: 8995 | avg: 9020.8
# Generasi 967 | Best Fitness: 8995 | avg: 9008.8
# Generasi 968 | Best Fitness: 8995 | avg: 9010.4
# Generasi 969 | Best Fitness: 8995 | avg: 9014.5
# Generasi 970 | Best Fitness: 8995 | avg: 9016.8
# Generasi 971 | Best Fitness: 8995 | avg: 9023.8
# Generasi 972 | Best Fitness: 8995 | avg: 9021.5
# Generasi 973 | Best Fitness: 8995 | avg: 9032.6
# Generasi 974 | Best Fitness: 8995 | avg: 9026.8
# Generasi 975 | Best Fitness: 8995 | avg: 9026.4
# Generasi 976 | Best Fitness: 8995 | avg: 9021.0
# Generasi 977 | Best Fitness: 8995 | avg: 9020.8
# Generasi 978 | Best Fitness: 8995 | avg: 9026.6
# Generasi 979 | Best Fitness: 8995 | avg: 9024.9
# Generasi 980 | Best Fitness: 8995 | avg: 9019.0
# Generasi 981 | Best Fitness: 8995 | avg: 9024.4
# Generasi 982 | Best Fitness: 8995 | avg: 9032.8
# Generasi 983 | Best Fitness: 8995 | avg: 9020.1
# Generasi 984 | Best Fitness: 8995 | avg: 9020.4
# Generasi 985 | Best Fitness: 8995 | avg: 9029.1
# Generasi 986 | Best Fitness: 8995 | avg: 9022.1
# Generasi 987 | Best Fitness: 8995 | avg: 9016.4
# Generasi 988 | Best Fitness: 8995 | avg: 9019.4
# Generasi 989 | Best Fitness: 8995 | avg: 9026.4
# Generasi 990 | Best Fitness: 8995 | avg: 9029.8
# Generasi 991 | Best Fitness: 8995 | avg: 9015.5
# Generasi 992 | Best Fitness: 8995 | avg: 9018.5
# Generasi 993 | Best Fitness: 8995 | avg: 9018.2
# ...
# Generasi 2678 | Best Fitness: 8835 | avg: 8873.5
# Generasi 2679 | Best Fitness: 8835 | avg: 8855.9
# Generasi 2680 | Best Fitness: 8835 | avg: 8854.0
# Generasi 2681 | Best Fitness: 8835 | avg: 8865.0
# Generasi 2682 | Best Fitness: 8835 | avg: 8861.0
# Generasi 2683 | Best Fitness: 8835 | avg: 8857.2
# Generasi 2684 | Best Fitness: 8835 | avg: 8866.2
# Generasi 2685 | Best Fitness: 8835 | avg: 8854.6
# Generasi 2686 | Best Fitness: 8835 | avg: 8866.3
# Generasi 2687 | Best Fitness: 8835 | avg: 8861.5
# Generasi 2688 | Best Fitness: 8835 | avg: 8865.4
# Generasi 2689 | Best Fitness: 8835 | avg: 8872.1
# Generasi 2690 | Best Fitness: 8835 | avg: 8859.5
# Generasi 2691 | Best Fitness: 8835 | avg: 8868.1
# Generasi 2692 | Best Fitness: 8835 | avg: 8863.7
# Generasi 2693 | Best Fitness: 8835 | avg: 8860.4
# Generasi 2694 | Best Fitness: 8835 | avg: 8874.0
# Generasi 2695 | Best Fitness: 8835 | avg: 8866.7
# Generasi 2696 | Best Fitness: 8835 | avg: 8869.9
# Generasi 2697 | Best Fitness: 8835 | avg: 8851.8
# Generasi 2698 | Best Fitness: 8835 | avg: 8860.9
# Generasi 2699 | Best Fitness: 8835 | avg: 8866.2
# Generasi 2700 | Best Fitness: 8835 | avg: 8874.0
# Generasi 2701 | Best Fitness: 8835 | avg: 8866.1
# Generasi 2702 | Best Fitness: 8835 | avg: 8872.1
# Generasi 2703 | Best Fitness: 8835 | avg: 8864.2
# Generasi 2704 | Best Fitness: 8835 | avg: 8863.9
# Generasi 2705 | Best Fitness: 8835 | avg: 8858.0
# Generasi 2706 | Best Fitness: 8835 | avg: 8869.3
# Generasi 2707 | Best Fitness: 8835 | avg: 8865.8
# Generasi 2708 | Best Fitness: 8835 | avg: 8868.0
# Generasi 2709 | Best Fitness: 8835 | avg: 8855.2
# Generasi 2710 | Best Fitness: 8835 | avg: 8856.7
# Generasi 2711 | Best Fitness: 8835 | avg: 8867.3
# Generasi 2712 | Best Fitness: 8835 | avg: 8874.7
# Generasi 2713 | Best Fitness: 8835 | avg: 8858.0
# Generasi 2714 | Best Fitness: 8835 | avg: 8850.0
# Generasi 2715 | Best Fitness: 8835 | avg: 8857.6
# Generasi 2716 | Best Fitness: 8835 | avg: 8858.8
# Generasi 2717 | Best Fitness: 8835 | avg: 8867.2
# Generasi 2718 | Best Fitness: 8835 | avg: 8857.9
# Generasi 2719 | Best Fitness: 8835 | avg: 8863.8
# Generasi 2720 | Best Fitness: 8835 | avg: 8858.4
# Generasi 2721 | Best Fitness: 8835 | avg: 8866.4
# Generasi 2722 | Best Fitness: 8835 | avg: 8850.1
# Generasi 2723 | Best Fitness: 8835 | avg: 8865.4
# Generasi 2724 | Best Fitness: 8835 | avg: 8861.8
# Generasi 2725 | Best Fitness: 8835 | avg: 8865.5
# Generasi 2726 | Best Fitness: 8835 | avg: 8867.4
# Generasi 2727 | Best Fitness: 8835 | avg: 8864.6
# Generasi 2728 | Best Fitness: 8835 | avg: 8858.5
# Generasi 2729 | Best Fitness: 8835 | avg: 8859.3
# Generasi 2730 | Best Fitness: 8835 | avg: 8857.9
# Generasi 2731 | Best Fitness: 8835 | avg: 8869.3
# Generasi 2732 | Best Fitness: 8835 | avg: 8874.0
# Generasi 2733 | Best Fitness: 8835 | avg: 8858.4
# Generasi 2734 | Best Fitness: 8835 | avg: 8879.4
# Generasi 2735 | Best Fitness: 8835 | avg: 8869.4
# Generasi 2736 | Best Fitness: 8835 | avg: 8860.1
# Generasi 2737 | Best Fitness: 8835 | avg: 8856.9
# Generasi 2738 | Best Fitness: 8835 | avg: 8867.8
# Generasi 2739 | Best Fitness: 8835 | avg: 8863.5
# Generasi 2740 | Best Fitness: 8835 | avg: 8867.7
# Generasi 2741 | Best Fitness: 8835 | avg: 8860.2
# Generasi 2742 | Best Fitness: 8835 | avg: 8855.5
# Generasi 2743 | Best Fitness: 8835 | avg: 8869.2
# Generasi 2744 | Best Fitness: 8835 | avg: 8857.5
# Generasi 2745 | Best Fitness: 8835 | avg: 8857.2
# Generasi 2746 | Best Fitness: 8835 | avg: 8854.8
# Generasi 2747 | Best Fitness: 8835 | avg: 8873.5
# Generasi 2748 | Best Fitness: 8835 | avg: 8858.8
# Generasi 2749 | Best Fitness: 8835 | avg: 8863.5
# Generasi 2750 | Best Fitness: 8835 | avg: 8856.6
# Generasi 2751 | Best Fitness: 8835 | avg: 8864.2
# Generasi 2752 | Best Fitness: 8835 | avg: 8870.2
# Generasi 2753 | Best Fitness: 8835 | avg: 8874.8
# Generasi 2754 | Best Fitness: 8835 | avg: 8856.9
# Generasi 2755 | Best Fitness: 8835 | avg: 8861.8
# Generasi 2756 | Best Fitness: 8835 | avg: 8864.0
# Generasi 2757 | Best Fitness: 8835 | avg: 8858.0
# Generasi 2758 | Best Fitness: 8835 | avg: 8865.7
# Generasi 2759 | Best Fitness: 8835 | avg: 8865.8
# Generasi 2760 | Best Fitness: 8835 | avg: 8850.9
# Generasi 2761 | Best Fitness: 8835 | avg: 8855.2
# Generasi 2762 | Best Fitness: 8835 | avg: 8863.9
# Generasi 2763 | Best Fitness: 8835 | avg: 8853.6
# Generasi 2764 | Best Fitness: 8835 | avg: 8857.6
# Generasi 2765 | Best Fitness: 8835 | avg: 8867.6
# Generasi 2766 | Best Fitness: 8835 | avg: 8870.3
# Generasi 2767 | Best Fitness: 8835 | avg: 8857.7
# Generasi 2768 | Best Fitness: 8835 | avg: 8864.5
# Generasi 2769 | Best Fitness: 8835 | avg: 8867.7
# Generasi 2770 | Best Fitness: 8835 | avg: 8869.6
# Generasi 2771 | Best Fitness: 8835 | avg: 8870.3
# Generasi 2772 | Best Fitness: 8835 | avg: 8867.8
# Generasi 2773 | Best Fitness: 8835 | avg: 8861.8
# Generasi 2774 | Best Fitness: 8835 | avg: 8858.0
# Generasi 2775 | Best Fitness: 8835 | avg: 8857.0
# Generasi 2776 | Best Fitness: 8835 | avg: 8861.0
# Generasi 2777 | Best Fitness: 8835 | avg: 8867.5
# Generasi 2778 | Best Fitness: 8835 | avg: 8854.0
# Generasi 2779 | Best Fitness: 8835 | avg: 8858.0
# Generasi 2780 | Best Fitness: 8835 | avg: 8851.5
# Generasi 2781 | Best Fitness: 8835 | avg: 8857.3
# Generasi 2782 | Best Fitness: 8835 | avg: 8864.0
# Generasi 2783 | Best Fitness: 8835 | avg: 8868.4
# Generasi 2784 | Best Fitness: 8835 | avg: 8857.9
# Generasi 2785 | Best Fitness: 8835 | avg: 8858.5
# Generasi 2786 | Best Fitness: 8835 | avg: 8880.0
# Generasi 2787 | Best Fitness: 8835 | avg: 8856.1
# Generasi 2788 | Best Fitness: 8835 | avg: 8866.6
# Generasi 2789 | Best Fitness: 8835 | avg: 8856.8
# Generasi 2790 | Best Fitness: 8835 | avg: 8862.3
# Generasi 2791 | Best Fitness: 8835 | avg: 8857.3
# Generasi 2792 | Best Fitness: 8835 | avg: 8858.4
# Generasi 2793 | Best Fitness: 8835 | avg: 8864.9
# Generasi 2794 | Best Fitness: 8835 | avg: 8861.5
# Generasi 2795 | Best Fitness: 8835 | avg: 8871.3
# Generasi 2796 | Best Fitness: 8835 | avg: 8861.2
# Generasi 2797 | Best Fitness: 8835 | avg: 8863.2
# Generasi 2798 | Best Fitness: 8835 | avg: 8871.2
# Generasi 2799 | Best Fitness: 8835 | avg: 8859.4
# Generasi 2800 | Best Fitness: 8835 | avg: 8856.0
# Generasi 2801 | Best Fitness: 8835 | avg: 8855.4
# Generasi 2802 | Best Fitness: 8835 | avg: 8859.6
# Generasi 2803 | Best Fitness: 8835 | avg: 8862.0
# Generasi 2804 | Best Fitness: 8835 | avg: 8851.4
# Generasi 2805 | Best Fitness: 8835 | avg: 8857.7
# Generasi 2806 | Best Fitness: 8835 | avg: 8866.4
# Generasi 2807 | Best Fitness: 8835 | avg: 8866.1
# Generasi 2808 | Best Fitness: 8835 | avg: 8868.2
# Generasi 2809 | Best Fitness: 8835 | avg: 8860.5
# Generasi 2810 | Best Fitness: 8835 | avg: 8870.0
# Generasi 2811 | Best Fitness: 8835 | avg: 8873.8
# Generasi 2812 | Best Fitness: 8835 | avg: 8868.6
# Generasi 2813 | Best Fitness: 8835 | avg: 8857.5
# Generasi 2814 | Best Fitness: 8835 | avg: 8877.1
# Generasi 2815 | Best Fitness: 8835 | avg: 8872.2
# Generasi 2816 | Best Fitness: 8835 | avg: 8866.3
# Generasi 2817 | Best Fitness: 8835 | avg: 8872.6
# Generasi 2818 | Best Fitness: 8835 | avg: 8874.8
# Generasi 2819 | Best Fitness: 8835 | avg: 8864.8
# Generasi 2820 | Best Fitness: 8835 | avg: 8866.2
# Generasi 2821 | Best Fitness: 8835 | avg: 8854.9
# Generasi 2822 | Best Fitness: 8835 | avg: 8857.0
# Generasi 2823 | Best Fitness: 8835 | avg: 8857.6
# Generasi 2824 | Best Fitness: 8835 | avg: 8857.0
# Generasi 2825 | Best Fitness: 8835 | avg: 8868.1
# Generasi 2826 | Best Fitness: 8835 | avg: 8854.0
# Generasi 2827 | Best Fitness: 8835 | avg: 8860.3
# Generasi 2828 | Best Fitness: 8835 | avg: 8869.2
# Generasi 2829 | Best Fitness: 8835 | avg: 8862.4
# Generasi 2830 | Best Fitness: 8835 | avg: 8874.7
# Generasi 2831 | Best Fitness: 8835 | avg: 8868.4
# Generasi 2832 | Best Fitness: 8835 | avg: 8867.1
# Generasi 2833 | Best Fitness: 8835 | avg: 8855.2
# Generasi 2834 | Best Fitness: 8835 | avg: 8849.2
# Generasi 2835 | Best Fitness: 8835 | avg: 8860.9
# Generasi 2836 | Best Fitness: 8835 | avg: 8865.4
# Generasi 2837 | Best Fitness: 8835 | avg: 8857.6
# Generasi 2838 | Best Fitness: 8835 | avg: 8873.0
# Generasi 2839 | Best Fitness: 8835 | avg: 8859.0
# Generasi 2840 | Best Fitness: 8835 | avg: 8867.9
# Generasi 2841 | Best Fitness: 8835 | avg: 8865.8
# Generasi 2842 | Best Fitness: 8835 | avg: 8863.7
# Generasi 2843 | Best Fitness: 8835 | avg: 8865.9
# Generasi 2844 | Best Fitness: 8835 | avg: 8881.1
# Generasi 2845 | Best Fitness: 8835 | avg: 8860.4
# Generasi 2846 | Best Fitness: 8835 | avg: 8856.4
# Generasi 2847 | Best Fitness: 8835 | avg: 8863.0
# Generasi 2848 | Best Fitness: 8835 | avg: 8868.7
# Generasi 2849 | Best Fitness: 8835 | avg: 8867.6
# Generasi 2850 | Best Fitness: 8835 | avg: 8856.0
# Generasi 2851 | Best Fitness: 8835 | avg: 8867.6
# Generasi 2852 | Best Fitness: 8835 | avg: 8864.2
# Generasi 2853 | Best Fitness: 8835 | avg: 8855.1
# Generasi 2854 | Best Fitness: 8835 | avg: 8855.6
# Generasi 2855 | Best Fitness: 8835 | avg: 8868.4
# Generasi 2856 | Best Fitness: 8835 | avg: 8855.7
# Generasi 2857 | Best Fitness: 8835 | avg: 8860.6
# Generasi 2858 | Best Fitness: 8835 | avg: 8870.4
# Generasi 2859 | Best Fitness: 8835 | avg: 8866.8
# Generasi 2860 | Best Fitness: 8835 | avg: 8854.6
# Generasi 2861 | Best Fitness: 8835 | avg: 8871.6
# Generasi 2862 | Best Fitness: 8835 | avg: 8869.4
# Generasi 2863 | Best Fitness: 8835 | avg: 8857.3
# Generasi 2864 | Best Fitness: 8835 | avg: 8869.0
# Generasi 2865 | Best Fitness: 8835 | avg: 8858.0
# Generasi 2866 | Best Fitness: 8835 | avg: 8858.1
# Generasi 2867 | Best Fitness: 8835 | avg: 8862.3
# Generasi 2868 | Best Fitness: 8835 | avg: 8858.3
# Generasi 2869 | Best Fitness: 8835 | avg: 8864.6
# Generasi 2870 | Best Fitness: 8835 | avg: 8856.9
# Generasi 2871 | Best Fitness: 8835 | avg: 8861.7
# Generasi 2872 | Best Fitness: 8835 | avg: 8864.0
# Generasi 2873 | Best Fitness: 8835 | avg: 8854.0
# Generasi 2874 | Best Fitness: 8835 | avg: 8858.8
# Generasi 2875 | Best Fitness: 8835 | avg: 8858.6
# Generasi 2876 | Best Fitness: 8835 | avg: 8866.0
# Generasi 2877 | Best Fitness: 8835 | avg: 8862.6
# Generasi 2878 | Best Fitness: 8835 | avg: 8874.2
# Generasi 2879 | Best Fitness: 8835 | avg: 8855.2
# Generasi 2880 | Best Fitness: 8835 | avg: 8863.1
# Generasi 2881 | Best Fitness: 8835 | avg: 8861.2
# Generasi 2882 | Best Fitness: 8835 | avg: 8859.5
# Generasi 2883 | Best Fitness: 8835 | avg: 8859.5
# Generasi 2884 | Best Fitness: 8835 | avg: 8861.8
# Generasi 2885 | Best Fitness: 8835 | avg: 8861.9
# Generasi 2886 | Best Fitness: 8835 | avg: 8869.1
# Generasi 2887 | Best Fitness: 8835 | avg: 8864.9
# Generasi 2888 | Best Fitness: 8835 | avg: 8871.0
# Generasi 2889 | Best Fitness: 8835 | avg: 8864.4
# Generasi 2890 | Best Fitness: 8835 | avg: 8855.9
# Generasi 2891 | Best Fitness: 8835 | avg: 8857.9
# Generasi 2892 | Best Fitness: 8835 | avg: 8862.4
# Generasi 2893 | Best Fitness: 8835 | avg: 8875.7
# Generasi 2894 | Best Fitness: 8835 | avg: 8871.5
# Generasi 2895 | Best Fitness: 8835 | avg: 8866.1
# Generasi 2896 | Best Fitness: 8835 | avg: 8866.4
# Generasi 2897 | Best Fitness: 8835 | avg: 8863.8
# Generasi 2898 | Best Fitness: 8835 | avg: 8857.5
# Generasi 2899 | Best Fitness: 8835 | avg: 8863.2
# Generasi 2900 | Best Fitness: 8835 | avg: 8866.9
# Generasi 2901 | Best Fitness: 8835 | avg: 8870.2
# Generasi 2902 | Best Fitness: 8835 | avg: 8872.8
# Generasi 2903 | Best Fitness: 8835 | avg: 8868.5
# Generasi 2904 | Best Fitness: 8835 | avg: 8868.5
# Generasi 2905 | Best Fitness: 8835 | avg: 8867.6
# Generasi 2906 | Best Fitness: 8835 | avg: 8864.6
# Generasi 2907 | Best Fitness: 8835 | avg: 8856.1
# Generasi 2908 | Best Fitness: 8835 | avg: 8872.0
# Generasi 2909 | Best Fitness: 8835 | avg: 8855.8
# Generasi 2910 | Best Fitness: 8835 | avg: 8865.6
# Generasi 2911 | Best Fitness: 8835 | avg: 8871.8
# Generasi 2912 | Best Fitness: 8835 | avg: 8854.3
# Generasi 2913 | Best Fitness: 8835 | avg: 8873.1
# Generasi 2914 | Best Fitness: 8835 | avg: 8860.4
# Generasi 2915 | Best Fitness: 8835 | avg: 8868.5
# Generasi 2916 | Best Fitness: 8835 | avg: 8867.6
# Generasi 2917 | Best Fitness: 8835 | avg: 8859.6
# Generasi 2918 | Best Fitness: 8835 | avg: 8863.4
# Generasi 2919 | Best Fitness: 8835 | avg: 8864.6
# Generasi 2920 | Best Fitness: 8835 | avg: 8861.6
# Generasi 2921 | Best Fitness: 8835 | avg: 8866.3
# Generasi 2922 | Best Fitness: 8835 | avg: 8867.6
# Generasi 2923 | Best Fitness: 8835 | avg: 8856.7
# Generasi 2924 | Best Fitness: 8835 | avg: 8863.9
# Generasi 2925 | Best Fitness: 8835 | avg: 8866.4
# Generasi 2926 | Best Fitness: 8835 | avg: 8868.9
# Generasi 2927 | Best Fitness: 8835 | avg: 8856.7
# Generasi 2928 | Best Fitness: 8835 | avg: 8866.9
# Generasi 2929 | Best Fitness: 8835 | avg: 8854.6
# Generasi 2930 | Best Fitness: 8835 | avg: 8866.3
# Generasi 2931 | Best Fitness: 8835 | avg: 8857.6
# Generasi 2932 | Best Fitness: 8835 | avg: 8864.9
# Generasi 2933 | Best Fitness: 8835 | avg: 8851.4
# Generasi 2934 | Best Fitness: 8835 | avg: 8861.5
# Generasi 2935 | Best Fitness: 8835 | avg: 8873.9
# Generasi 2936 | Best Fitness: 8835 | avg: 8850.6
# Generasi 2937 | Best Fitness: 8835 | avg: 8863.0
# Generasi 2938 | Best Fitness: 8835 | avg: 8864.3
# Generasi 2939 | Best Fitness: 8835 | avg: 8867.8
# Generasi 2940 | Best Fitness: 8835 | avg: 8874.1
# Generasi 2941 | Best Fitness: 8835 | avg: 8858.6
# Generasi 2942 | Best Fitness: 8835 | avg: 8857.2
# Generasi 2943 | Best Fitness: 8835 | avg: 8872.1
# Generasi 2944 | Best Fitness: 8835 | avg: 8859.3
# Generasi 2945 | Best Fitness: 8835 | avg: 8864.6
# Generasi 2946 | Best Fitness: 8835 | avg: 8864.9
# Generasi 2947 | Best Fitness: 8835 | avg: 8862.4
# Generasi 2948 | Best Fitness: 8835 | avg: 8864.3
# Generasi 2949 | Best Fitness: 8835 | avg: 8870.4
# Generasi 2950 | Best Fitness: 8835 | avg: 8857.8
# Generasi 2951 | Best Fitness: 8835 | avg: 8870.2
# Generasi 2952 | Best Fitness: 8835 | avg: 8861.8
# Generasi 2953 | Best Fitness: 8835 | avg: 8862.9
# Generasi 2954 | Best Fitness: 8835 | avg: 8864.4
# Generasi 2955 | Best Fitness: 8835 | avg: 8858.5
# Generasi 2956 | Best Fitness: 8835 | avg: 8862.0
# Generasi 2957 | Best Fitness: 8835 | avg: 8870.8
# Generasi 2958 | Best Fitness: 8835 | avg: 8862.8
# Generasi 2959 | Best Fitness: 8835 | avg: 8868.0
# Generasi 2960 | Best Fitness: 8835 | avg: 8867.2
# Generasi 2961 | Best Fitness: 8835 | avg: 8854.6
# Generasi 2962 | Best Fitness: 8835 | avg: 8858.9
# Generasi 2963 | Best Fitness: 8835 | avg: 8874.8
# Generasi 2964 | Best Fitness: 8835 | avg: 8873.8
# Generasi 2965 | Best Fitness: 8835 | avg: 8860.0
# Generasi 2966 | Best Fitness: 8835 | avg: 8860.2
# Generasi 2967 | Best Fitness: 8835 | avg: 8869.2
# Generasi 2968 | Best Fitness: 8835 | avg: 8854.8
# Generasi 2969 | Best Fitness: 8835 | avg: 8865.2
# Generasi 2970 | Best Fitness: 8835 | avg: 8861.9
# Generasi 2971 | Best Fitness: 8835 | avg: 8852.6
# Generasi 2972 | Best Fitness: 8835 | avg: 8860.3
# Generasi 2973 | Best Fitness: 8835 | avg: 8855.3
# Generasi 2974 | Best Fitness: 8835 | avg: 8862.8
# Generasi 2975 | Best Fitness: 8835 | avg: 8853.9
# Generasi 2976 | Best Fitness: 8835 | avg: 8852.0
# Generasi 2977 | Best Fitness: 8835 | avg: 8854.7
# Generasi 2978 | Best Fitness: 8835 | avg: 8869.4
# Generasi 2979 | Best Fitness: 8835 | avg: 8867.6
# Generasi 2980 | Best Fitness: 8835 | avg: 8858.4
# Generasi 2981 | Best Fitness: 8835 | avg: 8864.8
# Generasi 2982 | Best Fitness: 8835 | avg: 8850.7
# Generasi 2983 | Best Fitness: 8835 | avg: 8872.8
# Generasi 2984 | Best Fitness: 8835 | avg: 8869.0
# Generasi 2985 | Best Fitness: 8835 | avg: 8861.8
# Generasi 2986 | Best Fitness: 8835 | avg: 8857.4
# Generasi 2987 | Best Fitness: 8835 | avg: 8851.2
# Generasi 2988 | Best Fitness: 8835 | avg: 8864.6
# Generasi 2989 | Best Fitness: 8835 | avg: 8872.3
# Generasi 2990 | Best Fitness: 8835 | avg: 8858.0
# Generasi 2991 | Best Fitness: 8835 | avg: 8857.6
# Generasi 2992 | Best Fitness: 8835 | avg: 8864.4
# Generasi 2993 | Best Fitness: 8835 | avg: 8859.4
# Generasi 2994 | Best Fitness: 8835 | avg: 8871.4
# Generasi 2995 | Best Fitness: 8835 | avg: 8871.2
# Generasi 2996 | Best Fitness: 8835 | avg: 8868.4
# Generasi 2997 | Best Fitness: 8835 | avg: 8865.6
# Generasi 2998 | Best Fitness: 8835 | avg: 8868.0
# Generasi 2999 | Best Fitness: 8835 | avg: 8876.5
# Best Fitness: 8835
# Detail Evaluasi:
# {'guruBentrok': 71, 'distribusiMapel': 24, 'mapelSiang': 26, 'durasiGuru': 34, 'waktuMGMP': 21, 'cekWaliKelas': 12, 'konsistensiGuruMapel': 31}

# %%
best_index = best["index"]

best_mapel = pop_mapel[best_index]
best_guru  = pop_guru[best_index]

# %%
# print(best_mapel[0])
# print(type(best_mapel[0]))

# %% [markdown]
# ---
# # EXPORT FITNESS (OUTPUT)

# %%
path_file = os.path.join("../hasil/bestFitness", FITNESS_EXPORT)

with open(path_file, mode="w", newline="") as file:

    writer = csv.writer(file)

    writer.writerow(["kelas","slot","mapel","guru"])

    for kelas in range(len(best_mapel)):

        for slot in range(len(best_mapel[kelas])):

            mapel = best_mapel[kelas][slot]
            guru  = best_guru[kelas][slot]

            writer.writerow([
                kelas + 1,
                slot+ 1,
                mapel,
                guru
            ])

# %% [markdown]
# ---
# # Example

# %%
kelas_idx = 1

data = []

for slot in range(SLOT_PER_KELAS):

    mapel_id = best_mapel[kelas_idx, slot]
    guru_id  = best_guru[kelas_idx, slot]
    hari     = slotHari[slot]

    data.append({
        "Slot": slot + 1,
        "Hari": hari,
        "Mapel": mapel_id,
        "Guru": guru_id
    })

df = pd.DataFrame(data)

print(df)
# Out:
#     Slot  Hari  Mapel  Guru
# 0      1     1      5    27
# 1      2     1      5    27
# 2      3     1      2    39
# 3      4     1      2    39
# 4      5     1      5    27
# 5      6     1      5    27
# 6      7     1      3    36
# 7      8     1      3    36
# 8      9     2      3    36
# 9     10     2      6     2
# 10    11     2      6     2
# 11    12     2      6     2
# 12    13     2     10    15
# 13    14     2     10    15
# 14    15     2      4    19
# 15    16     2      4    19
# 16    17     3      1    31
# 17    18     3      1    31
# 18    19     3      4    19
# 19    20     3      4    19
# 20    21     3     13    53
# 21    22     3     13    53
# 22    23     3     11    37
# 23    24     3     11    37
# 24    25     4     12    51
# 25    26     4     12    51
# 26    27     4     12    51
# 27    28     4      9    42
# 28    29     4      9    42
# 29    30     4      3    36
# 30    31     4      3    36
# 31    32     5      8     5
# 32    33     5      8     5
# 33    34     5      7    37
# 34    35     5      7    37
# 35    36     5      7    37

# %% [markdown]
# ---
#
# # Bimbingan

# %% [markdown]
# 12/03/2026
#
# mulai pengerjaan jurnal (UI opsional)
# buku TA
# apakah boleh fitness != 0
# UI nya hanya crud via spreadsheet, yang penting page generate jadwal
# dokumentasikan iterasi untuk diagram garis
# mutasi dan crossover
# minus GWO
# bikin template excell UI untuk CRUD
#
# ===================================================
# before (sistem akbar)
# 21680 awal data masuk
#
# after (sistem akbar)
# 2480 akhir stelah optimasi
#
# hal manual vs digitalize = apakah jadwal lebih oke atau tidak?
# perbandingan runtime GA single vs GA-GWO
#
# SK keluar tgl nya februari
#
# kemudian bisa ngisi bimgingna online

# %% [markdown]
# ---
# # catatan saya
# Generate Population
#
# FOR generation
#
#     Evaluasi Fitness
#
#     GA Operator
#         Selection
#         Crossover
#         Mutation
#
#     GWO Local Search
#         update solusi menuju alpha beta delta
#
#     Repair Operator
#
# END

# %% [markdown]
# # CRUD
# # halaman generate jadwal ()

# %% [markdown]
# # /master
