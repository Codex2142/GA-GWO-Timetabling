# %%
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# # JURNAL

# %% [markdown]
# ### SKENARIO 1

# %%
guided_df = pd.read_csv("../hasil/record/GA-GUIDED.csv")
traditional_df = pd.read_csv("../hasil/record/AVG-4.csv")
gwo_ga_guided_df = pd.read_csv("../hasil/record/GA-GWO15-8.csv")

# %%
gwo_ga_guided_df
# Out:
#       iterasi method   best       avg
# 0           0     GA  14385  17233.40
# 1           1     GA  11885  13909.30
# 2           2     GA  10385  11337.95
# 3           3     GA   9380  10082.40
# 4           4     GA   8995   9447.80
# ...       ...    ...    ...       ...
# 2975     1495     GA    670    758.45
# 2976     1496     GA    670    750.00
# 2977     1497     GA    670    758.25
# 2978     1498     GA    670    744.95
# 2979     1499     GA    670    743.80
#
# [2980 rows x 4 columns]

# %%
traditional_df
# Out:
#       iterasi method   best      avg
# 0           0     GA  19635  21357.7
# 1           1     GA  18855  20210.4
# 2           2     GA  18300  19673.8
# 3           3     GA  18220  18974.4
# 4           4     GA  18140  18461.1
# ...       ...    ...    ...      ...
# 1495     1495     GA   1995   2085.5
# 1496     1496     GA   1995   2072.1
# 1497     1497     GA   1995   2082.9
# 1498     1498     GA   1995   2085.4
# 1499     1499     GA   1995   2072.5
#
# [1500 rows x 4 columns]

# %%
guided_df
# Out:
#       iterasi method   best       avg
# 0           0     GA  14730  16936.65
# 1           1     GA  11960  13838.25
# 2           2     GA  10155  11580.05
# 3           3     GA   9485  10205.45
# 4           4     GA   9040   9496.15
# ...       ...    ...    ...       ...
# 1495     1495     GA   1000   1072.50
# 1496     1496     GA   1000   1074.15
# 1497     1497     GA   1000   1081.40
# 1498     1498     GA   1000   1068.05
# 1499     1499     GA   1000   1076.10
#
# [1500 rows x 4 columns]

# %%
plt.figure(figsize=(10,8))
plt.plot(
    traditional_df['iterasi'],
    traditional_df['best'],
    label='Traditional GA',
    linewidth=2
)

plt.plot(
    guided_df['iterasi'],
    guided_df['best'],
    label='Guided Operators GA',
    linewidth=2
)

plt.plot(
    gwo_ga_guided_df['iterasi'],
    gwo_ga_guided_df['best'],
    label='GA-GWO',
    linewidth=2
)

plt.xlabel('Iteration')
plt.ylabel('Best Fitness')
plt.title('Best Fitness Convergence Comparison')
plt.legend()
plt.grid(True)

plt.show()

# %%
plt.figure(figsize=(10,8))
plt.plot(
    traditional_df['iterasi'],
    traditional_df['avg'],
    label='Traditional GA',
    linewidth=2
)

plt.plot(
    guided_df['iterasi'],
    guided_df['avg'],
    label='Guided Operators GA',
    linewidth=2
)

plt.plot(
    gwo_ga_guided_df['iterasi'],
    gwo_ga_guided_df['avg'],
    label='Guided GA-GWO',
    linewidth=2
)

plt.xlabel('Iteration')
plt.ylabel('Average Fitness')
plt.title('Average Fitness Convergence Comparison')
plt.legend()
plt.grid(True)

plt.show()

# %% [markdown]
# ### SKENARIO 2

# %%
guided_df = pd.read_csv("../hasil/record/GA-GUIDED2.csv")
traditional_df = pd.read_csv("../hasil/record/GA-NOHELPER2.csv")

# %%
plt.figure(figsize=(10,8))
plt.plot(
    traditional_df['iterasi'],
    traditional_df['best'],
    label='Traditional GA',
    linewidth=2
)

plt.plot(
    guided_df['iterasi'],
    guided_df['best'],
    label='Guided Operators GA',
    linewidth=2
)

plt.plot(
    gwo_ga_guided_df['iterasi'],
    gwo_ga_guided_df['best'],
    label='Guided Operators GA',
    linewidth=2
)

plt.xlabel('Iteration')
plt.ylabel('Best Fitness')
plt.title('Best Fitness Convergence Comparison')
plt.legend()
plt.grid(True)

plt.show()

# %% [markdown]
# ### SKENARIO 3

# %%
guided_df = pd.read_csv("../hasil/record/GA-GUIDED3.csv")
traditional_df = pd.read_csv("../hasil/record/GA-NOHELPER3.csv")

# %%
plt.figure(figsize=(10,8))
plt.plot(
    traditional_df['iterasi'],
    traditional_df['best'],
    label='Traditional GA',
    linewidth=2
)

plt.plot(
    guided_df['iterasi'],
    guided_df['best'],
    label='Guided Operators GA',
    linewidth=2
)

plt.xlabel('Iteration')
plt.ylabel('Best Fitness')
plt.title('Best Fitness Convergence Comparison')
plt.legend()
plt.grid(True)

plt.show()
