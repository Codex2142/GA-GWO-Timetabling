# %% [markdown]
# ---
# # Import LiB

# %%
import pandas as pd
import random
from collections import defaultdict, Counter
import numpy as np
import csv
import os

# %% [markdown]
# ---
# # INIT GLOBAL CONST

# %%
POPULASI = 200
ITERATION = 500
MUTATION_PROB = 0.8
CROSSOVER_PROB = 0.7 
TOURNAMENT_SIZE = 50
SLOT_PER_KELAS = 36
JUMLAH_KELAS = 27
FITNESS_EXPORT = "BEST-GA-GWO15-5.csv"
RECORD_EXPORT = "GA-GWO15-5.csv"

# %% [markdown]
# ---
# # IMPORT DATA

# %%
guru_df = pd.read_csv('../dataset/guru.csv')
kelas_df = pd.read_csv('../dataset/kelas.csv')
mapel_df = pd.read_csv('../dataset/mapel.csv')
relasi_guru_mapel_df = pd.read_csv('../dataset/relasi_guru_mapel.csv')
slot_df = pd.read_csv('../dataset/slot.csv')
wali_kelas_df = pd.read_csv('../dataset/wali_kelas.csv')

# %% [markdown]
# ---
# # DICT MAKER

# %%
# =========================================================
# Mapping hari -> id
# Digunakan agar proses komputasi lebih cepat dibanding
# menggunakan string nama hari secara langsung.
# =========================================================
hariId = {
    "Senin": 1,
    "Selasa": 2,
    "Rabu": 3,
    "Kamis": 4,
    "Jumat": 5,
}

# =========================================================
# Slot per hari
# Menghitung jumlah slot jam pelajaran untuk setiap hari
# berdasarkan data slot_df.
# Hasilnya akan digunakan saat evaluasi fitness dan
# pembentukan jadwal.
# =========================================================

# Hitung jumlah slot tiap hari dari dataframe slot
slotPerHariDict = slot_df['hari'].value_counts().to_dict()

# Ubah key dari nama hari menjadi id hari
slotPerHariDict = {hariId[k]: v for k, v in slotPerHariDict.items()}

# Disimpan dalam numpy array agar perhitungan evaluasi
# (loop, indexing) lebih cepat
slotPerHari = np.array([
    slotPerHariDict[1],
    slotPerHariDict[2],
    slotPerHariDict[3],
    slotPerHariDict[4],
    slotPerHariDict[5]
])

# =========================================================
# Kelas -> tingkatan
# Mapping setiap kelas dengan tingkatan (misal kelas X, XI, XII)
# Informasi ini penting karena beberapa guru hanya mengajar
# mapel pada tingkatan tertentu.
# =========================================================
kelasTingkatan = dict(
    zip(kelas_df['kelas_id'], kelas_df['tingkatan'])
)

# Ambil seluruh id kelas dan urutkan
kelasIds = np.array(sorted(kelasTingkatan.keys()))

# Jumlah total kelas dalam sistem
JUMLAH_KELAS = len(kelasIds)

# =========================================================
# Mapel -> jam per minggu
# Menyimpan jumlah jam pelajaran setiap mapel per minggu
# =========================================================
jamPerMingguMapel = dict(
    zip(mapel_df['mapel_id'], mapel_df['jam_per_minggu'])
)

# Array id mapel
mapelIds = np.array(list(jamPerMingguMapel.keys()))

# Array jumlah jam tiap mapel
jamMapel = np.array(list(jamPerMingguMapel.values()))

# =========================================================
# MGMP Mapel
# MGMP = waktu rapat guru mapel tertentu
# Mapel tidak boleh dijadwalkan pada hari MGMP tersebut
# =========================================================
mgmpMapel = dict(
    zip(mapel_df['mapel_id'], mapel_df['MGMP'])
)

# Konversi hari MGMP dari string menjadi id hari
mgmpMapel = {
    mapel_id: hariId[hari]
    for mapel_id, hari in mgmpMapel.items()
}

# =========================================================
# Batas slot siang
# Slot setelah batas ini dianggap slot siang.
# Beberapa mapel diusahakan tidak ditempatkan di slot siang.
# =========================================================
batasSiang = np.array([
    5,  # senin
    5,  # selasa
    4,  # rabu
    5,  # kamis
    4   # jumat
])

# =========================================================
# Batas MGMP per hari
# Jumlah maksimum mapel MGMP yang boleh muncul dalam
# satu hari tertentu.
# =========================================================
batasMGMP = np.array([
    2,
    2,
    2,
    2,
    1
])

# =========================================================
# Guru valid untuk mapel + tingkatan
# Membuat relasi guru yang boleh mengajar mapel tertentu
# pada tingkatan tertentu.
# key   = (mapel_id, tingkatan)
# value = list guru yang boleh mengajar
# =========================================================
guruValidMapel = defaultdict(list)

for row in relasi_guru_mapel_df.itertuples():

    # pasangan mapel dan tingkatan
    key = (row.mapel_id, row.tingkatan)

    # tambahkan guru yang memenuhi kriteria
    guruValidMapel[key].append(row.guru_id)

# ubah menjadi dictionary biasa
guruValidMapel = dict(guruValidMapel)

# =========================================================
# Guru mengajar durasi
# Menghitung total beban mengajar setiap guru
# digunakan untuk mengecek constraint durasi guru
# =========================================================
maxJamGuru = (
    relasi_guru_mapel_df
    .groupby("guru_id")["durasi"]
    .sum()
    .to_dict()
)

# =========================================================
# Wali kelas
# Mapping guru yang menjadi wali kelas untuk kelas tertentu.
# Digunakan sebagai constraint tambahan dalam penjadwalan.
# =========================================================
waliKelas = dict(
    zip(wali_kelas_df['guru_id'], wali_kelas_df['kelas_id'])
)

# =========================================================
# Slot -> hari
# Setiap slot memiliki informasi hari ke berapa.
# Digunakan untuk mengetahui posisi hari dari setiap gen
# dalam kromosom.
# =========================================================
slotHari = np.array([
    hariId[row.hari]
    for row in slot_df.itertuples()
])

# Jumlah slot untuk setiap kelas
SLOT_PER_KELAS = len(slotHari)

# =========================================================
# Total gen kromosom
# Dalam representasi GA:
# kromosom = jadwal seluruh kelas
# gen      = satu slot pelajaran
# =========================================================
TOTAL_SLOT = JUMLAH_KELAS * SLOT_PER_KELAS

# =========================================================
# Fitness weight
# Bobot penalti setiap constraint dalam evaluasi fitness.
# Semakin besar bobotnya, semakin penting constraint tersebut.
# =========================================================
fitnessWeight = {
    "guruBentrok": 100,          # guru mengajar di dua kelas pada waktu sama
    "distribusiMapel": 20,       # distribusi mapel tidak merata
    "konsistensiGuruMapel": 20,  # mapel diajar guru berbeda
    "durasiGuru": 10,            # jam mengajar melebihi batas
    "waktuMGMP": 5,              # melanggar jadwal MGMP
    "mapelSiang": 5,             # mapel muncul di slot siang
    "cekWaliKelas": 5            # wali kelas tidak sesuai
}

# =========================================================
# Blok jam mata pelajaran
# Beberapa mapel harus diajarkan secara berurutan
# (misalnya 2 jam berturut-turut).
# Fungsi ini menentukan pembagian blok jam tersebut.
# =========================================================
def blokDistribusi(jam):

    # mapel 2 jam -> 1 blok 2 jam
    if jam == 2:
        return [2]

    # mapel 3 jam -> 1 blok 3 jam
    if jam == 3:
        return [3]

    # mapel 4 jam -> 2 blok (2+2)
    if jam == 4:
        return [2,2]

    # mapel 5 jam -> 2 blok (2+3)
    if jam == 5:
        return [2,3]

    # default
    return [jam]


# ======================================
# slot awal dan akhir hari
# Digunakan untuk mengetahui batas indeks
# slot setiap hari dalam kromosom.
# ======================================

# indeks slot pertama tiap hari
slotAwalHari = np.concatenate(([0], np.cumsum(slotPerHari)[:-1]))

# indeks slot terakhir tiap hari
slotAkhirHari = np.cumsum(slotPerHari)


# ======================================
# blok mapel
# Menyimpan pembagian blok jam untuk
# setiap mata pelajaran.
# ======================================

blokMapel = {}

for mapel_id, jam in jamPerMingguMapel.items():

    # menentukan blok distribusi jam mapel
    blokMapel[mapel_id] = blokDistribusi(jam)

# %% [markdown]
# ---
# # INDIVIDU CONSTRUCT

# %% [markdown]
# ### Generate Per kelas

# %%
def generatePerKelas(tingkatan):

    # list sementara yang berisi blok-blok mapel
    # format: (mapel_id, guru_id, panjang_blok)
    blok_list = []

    # loop semua mata pelajaran yang ada di sistem
    for mapel_id, jam in jamPerMingguMapel.items():

        # ambil daftar guru yang valid untuk:
        # - mapel tersebut
        # - tingkatan kelas tertentu
        guruValid = guruValidMapel.get((mapel_id, tingkatan))

        # jika tidak ada guru yang bisa mengajar mapel ini
        # maka mapel tersebut dilewati
        if not guruValid:
            continue

        # pilih guru secara acak dari guru valid
        # randomisasi ini penting untuk membuat populasi awal GA bervariasi
        guru = random.choice(guruValid)

        # ambil distribusi blok jam mapel
        # contoh:
        # 4 jam -> [2,2]
        # 5 jam -> [2,3]
        blok = blokMapel[mapel_id]
    
        # setiap blok dimasukkan sebagai item dalam list
        for b in blok:
            blok_list.append((mapel_id, guru, b))

    # acak urutan blok mapel
    # agar posisi mapel dalam jadwal tidak selalu sama
    random.shuffle(blok_list)

    # array untuk menyimpan hasil jadwal
    mapel_arr = []
    guru_arr = []

    # konversi blok mapel menjadi slot-slot individu
    for mapel_id, guru, panjang in blok_list:

        # tambahkan mapel sebanyak panjang blok
        # misalnya blok = 2 -> [mapel,mapel]
        mapel_arr.extend([mapel_id]*panjang)

        # guru juga diulang sesuai panjang blok
        guru_arr.extend([guru]*panjang)

    # konversi ke numpy array agar operasi lebih cepat
    mapel_arr = np.array(mapel_arr, dtype=np.int16)
    guru_arr  = np.array(guru_arr, dtype=np.int16)

    # =====================================================
    # memastikan panjang jadwal sesuai jumlah slot kelas
    # =====================================================

    # jika jumlah slot melebihi slot tersedia
    if len(mapel_arr) > SLOT_PER_KELAS:

        # potong ke ukuran yang sesuai
        mapel_arr = mapel_arr[:SLOT_PER_KELAS]
        guru_arr  = guru_arr[:SLOT_PER_KELAS]

    # jika slot masih kurang
    while len(mapel_arr) < SLOT_PER_KELAS:

        # pilih mapel secara acak
        mapel = random.choice(mapelIds)

        # cek apakah ada guru yang bisa mengajar mapel tersebut
        guruValid = guruValidMapel.get((mapel, tingkatan))

        if guruValid:

            # pilih guru secara acak
            guru = random.choice(guruValid)

            # tambahkan ke slot jadwal
            mapel_arr = np.append(mapel_arr, mapel)
            guru_arr  = np.append(guru_arr, guru)

    # return jadwal untuk satu kelas
    return mapel_arr, guru_arr

# %% [markdown]
# ### Membuat individu (1 jadwal penuh)

# %%
def individuConstruct():

    # Membuat matriks kosong untuk menyimpan jadwal mapel dan guru
    # Dimensi:
    # baris  = jumlah kelas
    # kolom  = jumlah slot waktu per kelas
    #
    # mapel_matrix -> menyimpan ID mata pelajaran pada setiap slot
    # guru_matrix  -> menyimpan ID guru yang mengajar pada slot tersebut
    mapel_matrix = np.zeros((JUMLAH_KELAS, SLOT_PER_KELAS), dtype=np.int16)
    guru_matrix  = np.zeros((JUMLAH_KELAS, SLOT_PER_KELAS), dtype=np.int16)

    # Loop setiap kelas yang ada di sistem
    # enumerate digunakan agar kita mendapatkan:
    # i        -> index baris pada matrix
    # kelas_id -> id kelas sebenarnya
    for i, kelas_id in enumerate(kelasIds):

        # Ambil tingkatan kelas
        # Contoh: kelas 10A -> tingkatan 10
        # Tingkatan ini digunakan untuk menentukan
        # guru yang boleh mengajar mapel tertentu
        tingkatan = kelasTingkatan[kelas_id]

        # Generate jadwal untuk satu kelas
        # fungsi ini akan menghasilkan:
        # mapel_row -> array mapel sepanjang SLOT_PER_KELAS
        # guru_row  -> array guru sepanjang SLOT_PER_KELAS
        mapel_row, guru_row = generatePerKelas(tingkatan)

        # Masukkan hasil jadwal tersebut ke baris matrix
        # sehingga setiap baris mewakili satu kelas
        mapel_matrix[i] = mapel_row
        guru_matrix[i]  = guru_row

    # Return satu individu jadwal lengkap
    # yang terdiri dari:
    # - matrix mapel
    # - matrix guru
    return mapel_matrix, guru_matrix

# %% [markdown]
# ### Membuat Populasi

# %%
def generatePopulation(POPULASI):

    # Membuat array 3 dimensi untuk menyimpan populasi jadwal
    #
    # Dimensi:
    # POPULASI      -> jumlah individu dalam populasi GA
    # JUMLAH_KELAS  -> jumlah kelas dalam sistem
    # SLOT_PER_KELAS -> jumlah slot waktu per kelas
    #
    # pop_mapel menyimpan mata pelajaran
    # pop_guru menyimpan guru yang mengajar
    pop_mapel = np.zeros((POPULASI, JUMLAH_KELAS, SLOT_PER_KELAS), dtype=np.int16)
    pop_guru  = np.zeros((POPULASI, JUMLAH_KELAS, SLOT_PER_KELAS), dtype=np.int16)

    # Loop untuk membuat setiap individu dalam populasi
    for i in range(POPULASI):

        # Membuat satu individu jadwal lengkap
        # fungsi ini menghasilkan:
        # mapel_matrix -> jadwal mapel seluruh kelas
        # guru_matrix  -> jadwal guru seluruh kelas
        mapel_matrix, guru_matrix = individuConstruct()

        # Simpan individu ke dalam populasi
        # indeks i menunjukkan individu ke-i
        pop_mapel[i] = mapel_matrix
        pop_guru[i]  = guru_matrix

    # Return populasi awal
    # pop_mapel dan pop_guru berisi seluruh individu jadwal
    return pop_mapel, pop_guru

# %%
# Memanggil fungsi untuk membangkitkan populasi
pop_mapel, pop_guru = generatePopulation(POPULASI)

# %% [markdown]
# ### Debug

# %%
# kelas = 0
# ind = 0

# print("Mapel kelas", kelas+1)
# print(pop_mapel[ind, kelas])

# print("Guru kelas", kelas+1)
# print(pop_guru[ind, kelas])

# %% [markdown]
# ---
# # EVAL

# %% [markdown]
# ### Guru Bentrok

# %%
def guruBentrok(guru_matrix):

        # Variabel untuk menghitung total pelanggaran bentrok guru
        pelanggaran = 0

        # Loop setiap slot waktu
        # SLOT_PER_KELAS merepresentasikan jumlah slot waktu dalam satu hari/minggu
        # yang sama untuk semua kelas
        for slot in range(SLOT_PER_KELAS):

            # Ambil semua guru yang mengajar pada slot waktu yang sama
            # guru_matrix memiliki bentuk:
            # (JUMLAH_KELAS, SLOT_PER_KELAS)
            # guru_matrix[:, slot] berarti:
            # semua kelas pada slot waktu yang sama
            guruSlot = guru_matrix[:, slot]

            # Mengambil nilai guru yang unik
            # Jika tidak ada bentrok maka jumlah unik = jumlah kelas
            unik = np.unique(guruSlot)

            # Hitung jumlah bentrok
            # Contoh:
            # guruSlot = [3, 5, 3, 7]
            # artinya guru 3 mengajar di dua kelas pada waktu yang sama
            # unik = [3,5,7]
            # bentrok = 4 - 3 = 1
            pelanggaran += len(guruSlot) - len(unik)

        # Mengembalikan total jumlah konflik guru
        return pelanggaran

# %% [markdown]
# ### Durasi GUru mengajar

# %%
def durasiGuru(guru_matrix, maxJamGuru):

    # Variabel untuk menghitung total pelanggaran
    # Pelanggaran terjadi jika total jam mengajar guru
    # melebihi batas maksimal yang diperbolehkan
    pelanggaran = 0

    # Mengubah matrix guru menjadi array 1 dimensi
    # sehingga seluruh slot dari semua kelas digabung
    # contoh:
    # guru_matrix.shape = (10 kelas, 36 slot)
    # flatten() -> array 360 slot
    semuaGuru = guru_matrix.flatten()

    # Menghitung jumlah kemunculan setiap guru
    # guru_ids -> daftar guru unik
    # counts   -> jumlah slot yang diajar oleh guru tersebut
    # contoh:
    # guru_ids = [1,2,3]
    # counts   = [40,35,28]
    guru_ids, counts = np.unique(semuaGuru, return_counts=True)

    # Loop setiap guru yang muncul dalam jadwal
    for guru, jam in zip(guru_ids, counts):

        # Ambil batas maksimal jam mengajar guru
        # dari dictionary maxJamGuru
        # jika guru tidak ditemukan maka default = 0
        max_jam = maxJamGuru.get(guru, 0)

        # Jika jam mengajar melebihi batas
        if jam > max_jam:

            # Tambahkan selisihnya sebagai pelanggaran
            # contoh:
            # jam = 30
            # max_jam = 24
            # pelanggaran = 6
            pelanggaran += (jam - max_jam)

    # Return total pelanggaran durasi guru
    return pelanggaran

# %% [markdown]
# ### Distribusi Mapel

# %%
def hitungBlok(slots):

    # Mengurutkan slot agar mudah mendeteksi slot yang berurutan
    # contoh: [5,2,3] -> [2,3,5]
    slots = sorted(slots)

    # list untuk menyimpan panjang setiap blok berurutan
    blok = []

    # panjang blok saat ini
    panjang = 1

    # loop dari slot kedua sampai terakhir
    for i in range(1,len(slots)):

        # jika slot sekarang berurutan dengan slot sebelumnya
        # contoh: 3 setelah 2
        if slots[i] == slots[i-1] + 1:
            panjang += 1

        else:
            # jika tidak berurutan maka blok sebelumnya selesai
            blok.append(panjang)

            # mulai blok baru
            panjang = 1

    # masukkan blok terakhir
    blok.append(panjang)

    # contoh output:
    # slots = [2,3,5,6,7]
    # blok  = [2,3]
    return blok



def distribusiMapel(mapel_matrix):

    # menghitung total pelanggaran distribusi mapel
    pelanggaran = 0

    # loop setiap kelas
    for kelas in range(JUMLAH_KELAS):

        # ambil jadwal mapel untuk kelas tersebut
        jadwal = mapel_matrix[kelas]

        # dictionary untuk menyimpan slot setiap mapel
        # key   = mapel_id
        # value = daftar slot
        mapelSlot = defaultdict(list)

        # loop setiap slot pada jadwal
        for slot, mapel in enumerate(jadwal):

            # simpan slot kemunculan mapel
            mapelSlot[mapel].append(slot)

        # cek setiap mapel dalam kelas tersebut
        for mapel, slots in mapelSlot.items():

            # ambil distribusi blok yang diharapkan
            # contoh:
            # mapel 4 jam -> [2,2]
            blok_expected = blokMapel.get(mapel, [])

            # jika hanya 1 blok maka tidak perlu dicek distribusi
            # contoh: 2 jam -> [2]
            if len(blok_expected) <= 1:
                continue

            # hitung blok aktual dari jadwal
            # contoh:
            # slots = [1,2,5,6]
            # blok_real = [2,2]
            blok_real = hitungBlok(slots)

            # cek apakah distribusi blok sesuai
            # sorted digunakan agar urutan blok tidak masalah
            if sorted(blok_real) != sorted(blok_expected):

                # jika tidak sesuai maka pelanggaran bertambah
                pelanggaran += 1

            # cek distribusi hari
            # ambil hari dari setiap slot
            hariSet = set(slotHari[s] for s in slots)

            # jika jumlah hari kurang dari jumlah blok
            # berarti ada blok mapel yang berada di hari yang sama
            if len(hariSet) < len(blok_expected):

                # tambahkan pelanggaran
                pelanggaran += 1

    # return total pelanggaran distribusi mapel
    return pelanggaran

# %% [markdown]
# ### Mapel PJOK

# %%
def mapelSiang(mapel_matrix):

    # ID mata pelajaran yang tidak diinginkan berada di slot siang
    # contoh: mapel tertentu seperti olahraga
    # mapel berat sering dihindari di jam terakhir
    TARGET_MAPEL = 8

    # variabel untuk menghitung total pelanggaran
    pelanggaran = 0

    # loop semua slot waktu dalam satu minggu
    for slot in range(SLOT_PER_KELAS):

        # ambil hari dari slot tersebut
        # slotHari menyimpan mapping slot -> hari
        hari = slotHari[slot]

        # ambil batas slot siang untuk hari tersebut
        # contoh:
        # senin batas = 5
        batas = batasSiang[hari-1]

        # menghitung slot keberapa dalam hari tersebut
        #
        # contoh:
        # slot global = 14
        # slot awal hari = 12
        # slotHariKe = 2
        slotHariKe = slot - slotAwalHari[hari-1]

        # jika slot masih sebelum batas siang
        # maka tidak perlu dicek
        if slotHariKe < batas:
            continue

        # jika sudah melewati batas siang
        # maka hitung jumlah TARGET_MAPEL pada slot tersebut
        # mapel_matrix[:, slot] -> semua kelas pada slot yang sama
        # contoh:
        # [8,3,8,5]
        # berarti ada 2 pelanggaran
        pelanggaran += np.sum(mapel_matrix[:, slot] == TARGET_MAPEL)

    # return total pelanggaran mapel siang
    return pelanggaran

# %% [markdown]
# ### Waktu MGMP

# %%
def waktuMGMP(mapel_matrix):

    # Variabel untuk menghitung total pelanggaran
    pelanggaran = 0

    # Loop setiap kelas
    for kelas in range(JUMLAH_KELAS):

        # Ambil jadwal mapel untuk kelas tersebut
        jadwal = mapel_matrix[kelas]

        # Loop setiap mapel yang memiliki aturan MGMP
        # mgmpMapel berisi mapping:
        # mapel_id -> hari MGMP
        for mapel, hariMGMP in mgmpMapel.items():

            # Mengubah hari MGMP menjadi index array (0-based)
            hari_idx = hariMGMP - 1

            # Menentukan batas slot awal dan akhir hari tersebut
            # agar hanya slot di hari MGMP yang diperiksa
            start = slotAwalHari[hari_idx]
            end   = slotAkhirHari[hari_idx]

            # Menghitung berapa kali mapel tersebut muncul
            # pada hari MGMP untuk kelas ini
            jumlah = np.sum(jadwal[start:end] == mapel)

            # Jika jumlah kemunculan melebihi batas yang diperbolehkan
            if jumlah > batasMGMP[hari_idx]:

                # Tambahkan selisihnya sebagai pelanggaran
                pelanggaran += jumlah - batasMGMP[hari_idx]

    # Return total pelanggaran MGMP
    return pelanggaran

# %% [markdown]
# ### Wali Kelas

# %%
def cekWaliKelas(guru_matrix):

    # Variabel untuk menghitung total pelanggaran
    pelanggaran = 0

    # Loop setiap pasangan wali kelas
    # waliKelas berisi mapping:
    # guru_id -> kelas_id
    for guru, kelas in waliKelas.items():

        # Mengecek apakah guru tersebut mengajar di kelas yang menjadi wali-nya
        # guru_matrix[kelas-1] mengambil seluruh slot pada kelas tersebut
        # kelas-1 digunakan karena index array dimulai dari 0
        # contoh:
        # kelas = 3 -> index = 2
        if guru not in guru_matrix[kelas-1]:

            # Jika guru wali tidak mengajar di kelasnya sama sekali
            # maka dianggap pelanggaran
            pelanggaran += 1

    # Return total pelanggaran wali kelas
    return pelanggaran

# %% [markdown]
# ### Konsistensi GUru mapel

# %%
def konsistensiGuruMapel(mapel_matrix, guru_matrix):

    # Variabel untuk menghitung total pelanggaran
    pelanggaran = 0

    # Loop setiap kelas
    for kelas in range(JUMLAH_KELAS):

        # Ambil jadwal mapel dan guru untuk kelas tersebut
        jadwalMapel = mapel_matrix[kelas]
        jadwalGuru  = guru_matrix[kelas]

        # Ambil daftar mapel unik yang muncul di kelas tersebut
        # agar tidak mengecek mapel yang sama berulang kali
        for mapel in np.unique(jadwalMapel):

            # Ambil semua guru yang mengajar mapel tersebut
            # jadwalMapel == mapel -> menghasilkan mask boolean
            # kemudian digunakan untuk memilih guru yang mengajar mapel itu
            guruSet = np.unique(jadwalGuru[jadwalMapel == mapel])

            # Jika lebih dari satu guru mengajar mapel yang sama
            # maka terjadi pelanggaran konsistensi
            if len(guruSet) > 1:

                # Tambahkan selisih jumlah guru sebagai pelanggaran
                # contoh:
                # guruSet = [3,7]
                # pelanggaran = 1
                # guruSet = [3,7,8]
                # pelanggaran = 2
                pelanggaran += len(guruSet) - 1

    # Return total pelanggaran konsistensi guru-mapel
    return pelanggaran

# %% [markdown]
# ### main eval

# %%
def evaluasiIndividu(mapel_matrix, guru_matrix, maxJamGuru):

    # Fungsi ini mengevaluasi satu individu jadwal (satu solusi)
    # dengan menghitung jumlah pelanggaran untuk setiap constraint.

    # mapel_matrix : matriks mata pelajaran
    # baris = kelas
    # kolom = slot waktu

    # guru_matrix : matriks guru yang mengajar
    # strukturnya sama dengan mapel_matrix

    # maxJamGuru : dictionary yang berisi batas maksimal jam mengajar tiap guru

    # Fungsi mengembalikan dictionary yang berisi jumlah pelanggaran
    # untuk setiap jenis constraint

    return {

        # Mengecek apakah ada guru yang mengajar di lebih dari satu kelas
        # pada slot waktu yang sama
        "guruBentrok": guruBentrok(guru_matrix),

        # Mengecek apakah distribusi jam mata pelajaran sesuai dengan
        # blok yang seharusnya (misalnya 2+1 jam atau 3 jam)
        "distribusiMapel": distribusiMapel(mapel_matrix),

        # Mengecek apakah mata pelajaran tertentu muncul di jam siang
        # yang seharusnya dihindari
        "mapelSiang": mapelSiang(mapel_matrix),

        # Mengecek apakah total jam mengajar guru melebihi batas maksimum
        "durasiGuru": durasiGuru(guru_matrix, maxJamGuru),

        # Mengecek aturan MGMP, misalnya jumlah maksimal mapel tertentu
        # dalam satu hari
        "waktuMGMP": waktuMGMP(mapel_matrix),

        # Mengecek apakah wali kelas mengajar di kelasnya sendiri
        "cekWaliKelas": cekWaliKelas(guru_matrix),

        # Mengecek apakah satu mapel dalam satu kelas diajar oleh lebih
        # dari satu guru (harusnya konsisten satu guru)
        "konsistensiGuruMapel": konsistensiGuruMapel(mapel_matrix, guru_matrix)
    }

# %% [markdown]
# ### Looping setiap individu

# %%
def hitungFitness(hasilEvaluasi):

    # Variabel untuk menyimpan total nilai fitness
    # Fitness biasanya merepresentasikan total penalti dari semua pelanggaran
    fitness = 0

    # Melakukan iterasi pada setiap jenis constraint
    # hasilEvaluasi berupa dictionary seperti:
    # {
    #   "guruBentrok": 5,
    #   "distribusiMapel": 3,
    #   "mapelSiang": 1,
    #   ...
    # }

    for k, v in hasilEvaluasi.items():

        # k = nama constraint
        # v = jumlah pelanggaran constraint tersebut

        # fitnessWeight adalah dictionary berisi bobot tiap constraint
        # contoh:
        # fitnessWeight = {
        #     "guruBentrok": 100,
        #     "distribusiMapel": 20,
        #     "mapelSiang": 5,
        #     ...
        # }

        # Pelanggaran dikalikan dengan bobot constraint
        # lalu ditambahkan ke total fitness
        fitness += fitnessWeight[k] * v

    # Mengembalikan total fitness
    # Semakin kecil nilai fitness -> semakin baik solusi jadwal
    return fitness

# %% [markdown]
# ### Menyimpan hasil eval tiap individu

# %%
def evaluasiPopulasi(pop_mapel, pop_guru, maxJamGuru):

    # List untuk menyimpan hasil evaluasi setiap individu dalam populasi
    hasilPopulasi = []

    # pop_mapel.shape[0] = jumlah individu dalam populasi
    # setiap individu adalah satu kandidat solusi jadwal
    for i in range(pop_mapel.shape[0]):

        # Mengambil jadwal mapel dari individu ke-i
        # bentuknya matrix: kelas × slot
        mapel_matrix = pop_mapel[i]

        # Mengambil jadwal guru dari individu ke-i
        # strukturnya sama dengan mapel_matrix
        guru_matrix  = pop_guru[i]

        # Mengevaluasi individu menggunakan semua constraint
        # hasilnya berupa dictionary jumlah pelanggaran
        evaluasi = evaluasiIndividu(mapel_matrix, guru_matrix, maxJamGuru)

        # Menghitung nilai fitness berdasarkan jumlah pelanggaran
        # dan bobot masing-masing constraint
        fitness = hitungFitness(evaluasi)

        # Menyimpan hasil evaluasi individu dalam bentuk dictionary
        hasilPopulasi.append({
            "fitness": fitness,     # nilai fitness individu
            "evaluasi": evaluasi,   # detail pelanggaran constraint
            "index": i              # posisi individu dalam populasi
        })

    # Mengembalikan seluruh hasil evaluasi populasi
    return hasilPopulasi

# %%
hasil = evaluasiPopulasi(pop_mapel, pop_guru, maxJamGuru)

# %% [markdown]
# ### Output debug

# %%
# best = min(hasil, key=lambda x: x["fitness"])

# print("Best Fitness:", best["fitness"])
# print("Detail Evaluasi:")
# print(best["evaluasi"])

# %% [markdown]
# ---
# # GA

# %% [markdown]
# ### Tournament

# %%
def tournamentSelection(pop_mapel, pop_guru, hasilPopulasi):

    # Mengambil beberapa individu secara acak dari populasi
    # jumlah individu yang diambil ditentukan oleh TOURNAMENT_SIZE
    # contoh: jika TOURNAMENT_SIZE = 3 maka akan dipilih 3 kandidat secara acak
    kandidat = random.sample(hasilPopulasi, TOURNAMENT_SIZE)

    # Dari kandidat tersebut dipilih individu dengan fitness terbaik
    # min digunakan karena dalam timetabling fitness yang lebih kecil lebih baik
    terbaik = min(kandidat, key=lambda x: x["fitness"])

    # Mengambil index individu terbaik dalam populasi
    idx = terbaik["index"]

    # Mengembalikan jadwal mapel dan guru dari individu terpilih
    # .copy() digunakan agar perubahan pada offspring tidak mengubah parent asli
    return pop_mapel[idx].copy(), pop_guru[idx].copy()

# %% [markdown]
# ### Crossover

# %%
def crossover(parent1_mapel, parent1_guru, parent2_mapel, parent2_guru):

    # Menentukan titik pemotongan crossover berdasarkan jumlah kelas
    # split berada di antara 1 sampai JUMLAH_KELAS-1
    # artinya sebagian kelas diambil dari parent1 dan sisanya dari parent2
    split = random.randint(1, JUMLAH_KELAS - 1)

    # Membuat matriks anak dengan ukuran yang sama seperti parent
    # diinisialisasi dengan nilai 0
    child1_mapel = np.zeros_like(parent1_mapel)
    child1_guru  = np.zeros_like(parent1_guru)

    child2_mapel = np.zeros_like(parent1_mapel)
    child2_guru  = np.zeros_like(parent1_guru)

    # Membentuk child1:
    # kelas sebelum titik split diambil dari parent1
    child1_mapel[:split] = parent1_mapel[:split]

    # kelas setelah titik split diambil dari parent2
    child1_mapel[split:] = parent2_mapel[split:]

    # Guru mengikuti struktur yang sama dengan mapel
    child1_guru[:split] = parent1_guru[:split]
    child1_guru[split:] = parent2_guru[split:]

    # Membentuk child2:
    # kebalikan dari child1
    # kelas sebelum split dari parent2
    child2_mapel[:split] = parent2_mapel[:split]

    # kelas setelah split dari parent1
    child2_mapel[split:] = parent1_mapel[split:]

    # Guru mengikuti struktur yang sama dengan mapel
    child2_guru[:split] = parent2_guru[:split]
    child2_guru[split:] = parent1_guru[split:]

    # Mengembalikan dua anak hasil crossover
    return child1_mapel, child1_guru, child2_mapel, child2_guru

# %% [markdown]
# ### Mutasi

# %%
def mutasi(mapel_matrix, guru_matrix):

    # Mengevaluasi individu untuk mengetahui jumlah pelanggaran tiap constraint
    evaluasi = evaluasiIndividu(mapel_matrix, guru_matrix, maxJamGuru)

    # Menentukan constraint yang memiliki pelanggaran paling besar
    # constraint ini akan menjadi target mutasi
    constraint = max(evaluasi, key=evaluasi.get)

    # Memilih kelas secara acak yang akan dimodifikasi
    kelas = random.randint(0, JUMLAH_KELAS - 1)

    # Jika pelanggaran terbesar berasal dari distribusi mapel
    if constraint == "distribusiMapel":

        # Memilih dua slot berurutan untuk ditukar
        slot1 = random.randint(0, SLOT_PER_KELAS - 2)
        slot2 = slot1 + 1

        # Menukar posisi mapel pada dua slot tersebut
        mapel_matrix[kelas,slot1], mapel_matrix[kelas,slot2] = \
            mapel_matrix[kelas,slot2], mapel_matrix[kelas,slot1]

        # Menukar guru yang mengajar pada slot yang sama
        guru_matrix[kelas,slot1], guru_matrix[kelas,slot2] = \
            guru_matrix[kelas,slot2], guru_matrix[kelas,slot1]

    # Jika pelanggaran terbesar adalah guru bentrok
    elif constraint == "guruBentrok":

        # Memilih slot acak pada kelas tersebut
        slot = random.randint(0, SLOT_PER_KELAS-1)

        # Mengambil mapel pada slot tersebut
        mapel = mapel_matrix[kelas,slot]

        # Menentukan tingkatan kelas (misalnya kelas 10,11,12)
        tingkatan = kelasTingkatan[kelasIds[kelas]]

        # Mengambil daftar guru yang valid untuk mapel dan tingkatan tersebut
        guruValid = guruValidMapel.get((mapel, tingkatan))

        # Jika ada guru yang valid
        if guruValid:

            # Mengganti guru dengan salah satu guru valid secara acak
            guru_matrix[kelas,slot] = random.choice(guruValid)

    # Jika constraint lain yang dominan
    else:

        # Memilih dua slot acak dalam satu kelas
        slot1 = random.randint(0, SLOT_PER_KELAS - 1)
        slot2 = random.randint(0, SLOT_PER_KELAS - 1)

        # Menukar posisi mapel antara dua slot tersebut
        mapel_matrix[kelas,slot1], mapel_matrix[kelas,slot2] = \
            mapel_matrix[kelas,slot2], mapel_matrix[kelas,slot1]

        # Menukar guru pada slot yang sama
        guru_matrix[kelas,slot1], guru_matrix[kelas,slot2] = \
            guru_matrix[kelas,slot2], guru_matrix[kelas,slot1]

    # Mengembalikan individu yang telah dimutasi
    return mapel_matrix, guru_matrix

# %% [markdown]
# ### Repair

# %%
def repairOperator(mapel_matrix, guru_matrix):

    # Mengevaluasi individu untuk mengetahui jumlah pelanggaran constraint
    evaluasi = evaluasiIndividu(mapel_matrix, guru_matrix, maxJamGuru)

    # Repair hanya dilakukan jika terdapat pelanggaran guru bentrok
    if evaluasi["guruBentrok"] > 0:

        # Iterasi setiap slot waktu
        for slot in range(SLOT_PER_KELAS):

            # Mengambil semua guru yang mengajar pada slot tersebut
            # (dari semua kelas pada waktu yang sama)
            guruSlot = guru_matrix[:,slot]

            # Mengambil guru unik dan jumlah kemunculannya
            unik, counts = np.unique(guruSlot, return_counts=True)

            # Mendeteksi guru yang muncul lebih dari sekali pada slot yang sama
            # artinya guru tersebut mengajar di lebih dari satu kelas
            bentrok = unik[counts > 1]

            # Memproses setiap guru yang mengalami bentrok
            for g in bentrok:

                # Mencari kelas mana saja yang menggunakan guru tersebut
                kelasBentrok = np.where(guruSlot == g)[0]

                # Memilih salah satu kelas secara acak untuk diperbaiki
                kelas = random.choice(kelasBentrok)

                # Mengambil mapel pada kelas dan slot tersebut
                mapel = mapel_matrix[kelas,slot]

                # Menentukan tingkatan kelas (misal kelas 10, 11, 12)
                tingkatan = kelasTingkatan[kelasIds[kelas]]

                # Mengambil daftar guru yang valid untuk mapel dan tingkatan ini
                guruValid = guruValidMapel.get((mapel, tingkatan))

                # Jika ada guru yang valid
                if guruValid:

                    # Mengganti guru yang bentrok dengan guru valid lain secara acak
                    guru_matrix[kelas,slot] = random.choice(guruValid)

    # Mengembalikan jadwal yang telah diperbaiki
    return mapel_matrix, guru_matrix

# %% [markdown]
# ---
# # GWO

# %%
def runGWO(pop_mapel, pop_guru, hasilPop):

    # Mengurutkan populasi berdasarkan fitness (fitness kecil = solusi lebih baik)
    hasilSorted = sorted(hasilPop, key=lambda x: x["fitness"])

    # Menentukan tiga wolf terbaik (leader dalam GWO)
    alpha = hasilSorted[0]["index"]   # solusi terbaik
    beta  = hasilSorted[1]["index"]   # solusi kedua terbaik
    delta = hasilSorted[2]["index"]   # solusi ketiga terbaik

    # Mengambil jadwal mapel dan guru dari masing-masing wolf
    alpha_mapel = pop_mapel[alpha]
    alpha_guru  = pop_guru[alpha]

    beta_mapel = pop_mapel[beta]
    beta_guru  = pop_guru[beta]

    delta_mapel = pop_mapel[delta]
    delta_guru  = pop_guru[delta]

    # Menyimpan populasi baru hasil update GWO
    new_pop_mapel = []
    new_pop_guru  = []

    # Iterasi setiap individu dalam populasi
    for i in range(len(pop_mapel)):

        # Salin individu agar tidak merusak populasi asli
        mapel = pop_mapel[i].copy()
        guru  = pop_guru[i].copy()

        # Jika individu adalah alpha (solusi terbaik)
        # maka dipertahankan tanpa perubahan (elitism)
        if i == alpha:
            new_pop_mapel.append(mapel)
            new_pop_guru.append(guru)
            continue

        # =========================
        # pilih kelas & hari
        # =========================

        # Memilih kelas secara acak
        kelas = random.randint(0, JUMLAH_KELAS-1)

        # Memilih hari secara acak (misalnya 0–4 untuk Senin–Jumat)
        hari  = random.randint(0, 4)

        # Menentukan batas slot awal dan akhir pada hari tersebut
        start = slotAwalHari[hari]
        end   = slotAkhirHari[hari]

        # =========================
        # pilih wolf guide
        # =========================

        # Memilih wolf yang akan menjadi panduan update posisi
        r = random.random()

        # Probabilitas memilih alpha, beta, atau delta
        if r < 0.5:
            src_mapel = alpha_mapel
            src_guru  = alpha_guru
        elif r < 0.8:
            src_mapel = beta_mapel
            src_guru  = beta_guru
        else:
            src_mapel = delta_mapel
            src_guru  = delta_guru

        # =========================
        # partial slot copy
        # =========================

        # Panjang slot pada hari tersebut
        panjang = end - start

        # Menentukan ukuran segmen yang akan disalin
        size = random.randint(1, max(1, panjang//2))

        # Menentukan posisi awal segmen
        s = random.randint(start, end-size)

        # Menyalin sebagian jadwal dari wolf panduan
        mapel[kelas, s:s+size] = src_mapel[kelas, s:s+size]
        guru[kelas,  s:s+size] = src_guru[kelas,  s:s+size]

        # =========================
        # local swap improvement
        # =========================

        # Dengan probabilitas 50% dilakukan pertukaran slot lokal
        # untuk eksplorasi solusi baru
        if random.random() < 0.5:

            slot1 = random.randint(start, end-1)
            slot2 = random.randint(start, end-1)

            # Menukar posisi mapel
            mapel[kelas,slot1], mapel[kelas,slot2] = mapel[kelas,slot2], mapel[kelas,slot1]

            # Menukar guru yang mengajar
            guru[kelas,slot1],  guru[kelas,slot2]  = guru[kelas,slot2],  guru[kelas,slot1]

        # =========================
        # repair constraint
        # =========================

        # Memperbaiki solusi jika terjadi pelanggaran constraint
        mapel, guru = repairOperator(mapel, guru)

        # Menambahkan individu yang sudah diupdate ke populasi baru
        new_pop_mapel.append(mapel)
        new_pop_guru.append(guru)

    # Mengembalikan populasi baru dalam bentuk numpy array
    return np.array(new_pop_mapel), np.array(new_pop_guru)

# %% [markdown]
# # MAIN

# %%
def runGA():

    # Membuat populasi awal jadwal mapel dan guru
    pop_mapel, pop_guru = generatePopulation(POPULASI)

    # Mengevaluasi seluruh populasi awal
    hasilPop = evaluasiPopulasi(pop_mapel, pop_guru, maxJamGuru)

    # Menyimpan fitness terbaik global
    bestFitness = float("inf")

    # Menyimpan log perkembangan fitness
    log_data = []

    # Iterasi utama algoritma
    for gen in range(ITERATION):

        # Menyimpan populasi baru hasil GA
        new_pop_mapel = []
        new_pop_guru  = []

        # ==========================
        # PROSES GA
        # ==========================

        # Membuat populasi baru sampai jumlah individu terpenuhi
        while len(new_pop_mapel) < POPULASI:

            # Memilih parent menggunakan tournament selection
            p1_mapel, p1_guru = tournamentSelection(pop_mapel, pop_guru, hasilPop)
            p2_mapel, p2_guru = tournamentSelection(pop_mapel, pop_guru, hasilPop)

            # Jika memenuhi probabilitas crossover
            if random.random() < CROSSOVER_PROB:

                # Melakukan class-based crossover
                c1_mapel, c1_guru, c2_mapel, c2_guru = crossover(
                    p1_mapel, p1_guru, p2_mapel, p2_guru
                )

            else:

                # Jika tidak crossover, anak adalah copy dari parent
                c1_mapel, c1_guru = p1_mapel.copy(), p1_guru.copy()
                c2_mapel, c2_guru = p2_mapel.copy(), p2_guru.copy()

            # Mutasi anak pertama jika memenuhi probabilitas mutasi
            if random.random() < MUTATION_PROB:
                c1_mapel, c1_guru = mutasi(c1_mapel, c1_guru)

            # Mutasi anak kedua
            if random.random() < MUTATION_PROB:
                c2_mapel, c2_guru = mutasi(c2_mapel, c2_guru)

            # Repair untuk memperbaiki pelanggaran constraint
            c1_mapel, c1_guru = repairOperator(c1_mapel, c1_guru)
            c2_mapel, c2_guru = repairOperator(c2_mapel, c2_guru)

            # Menambahkan anak pertama ke populasi baru
            new_pop_mapel.append(c1_mapel)
            new_pop_guru.append(c1_guru)

            # Menambahkan anak kedua jika populasi belum penuh
            if len(new_pop_mapel) < POPULASI:
                new_pop_mapel.append(c2_mapel)
                new_pop_guru.append(c2_guru)

        # Mengganti populasi lama dengan populasi baru
        pop_mapel = np.array(new_pop_mapel)
        pop_guru  = np.array(new_pop_guru)

        # Mengevaluasi populasi baru
        hasilPop = evaluasiPopulasi(pop_mapel, pop_guru, maxJamGuru)

        # ==========================
        # PROSESS GWO
        # ==========================

        # Setiap 20 generasi dilakukan fase optimasi GWO
        if gen % 20 == 0 and gen != 0:

            print("----- GWO PHASE -----")

            # Melakukan iterasi GWO sebanyak 20 kali
            for iter_gwo in range(20):

                # Update posisi populasi menggunakan Grey Wolf Optimizer
                pop_mapel, pop_guru = runGWO(pop_mapel, pop_guru, hasilPop)

                # Evaluasi kembali populasi hasil GWO
                hasilPop = evaluasiPopulasi(pop_mapel, pop_guru, maxJamGuru)

                # Mengambil fitness terbaik dalam populasi
                best_gwo = min(x["fitness"] for x in hasilPop)

                # Menghitung rata-rata fitness populasi
                avg_gwo  = sum(x["fitness"] for x in hasilPop) / len(hasilPop)

                # Menyimpan log GWO
                log_data.append([gen, "GWO", best_gwo, avg_gwo])

                print("GWO Iter", iter_gwo,"Best:", best_gwo,"Avg:", round(avg_gwo))

        # ==========================
        # BEST FITNESS
        # ==========================

        # Mengambil individu terbaik dalam populasi
        best = min(hasilPop, key=lambda x: x["fitness"])

        # Menghitung rata-rata fitness populasi
        avg = np.mean([x['fitness'] for x in hasilPop])

        # Update best global fitness jika ditemukan yang lebih baik
        if best["fitness"] < bestFitness:
            bestFitness = best["fitness"]

        # Menyimpan log GA
        log_data.append([gen,"GA", bestFitness, avg])

        # Menampilkan progress generasi
        print("Generasi", gen, "| Best Fitness:", bestFitness, "| avg:", avg)

    # ==========================
    # OUTPUT
    # ==========================

    # Menentukan path file untuk menyimpan log
    path_file = os.path.join("../hasil/record", RECORD_EXPORT)

    # Menyimpan log fitness ke file CSV
    with open(path_file, mode="w", newline="") as file:

        writer = csv.writer(file)

        # Header kolom
        writer.writerow(["iterasi", "method","best", "avg"])

        # Data log
        writer.writerows(log_data)

    # Mengembalikan individu terbaik
    return best

# %% [markdown]
# ### Main Call

# %%
best = runGA()

print("Best Fitness:", best["fitness"])
print("Detail Evaluasi:")
print(best["evaluasi"])
# Out:
# Generasi 0 | Best Fitness: 14405 | avg: 17264.325
# Generasi 1 | Best Fitness: 12455 | avg: 13577.75
# Generasi 2 | Best Fitness: 11385 | avg: 12054.6
# Generasi 3 | Best Fitness: 10570 | avg: 11252.875
# Generasi 4 | Best Fitness: 10050 | avg: 10712.075
# Generasi 5 | Best Fitness: 9720 | avg: 10252.725
# Generasi 6 | Best Fitness: 9430 | avg: 9955.55
# Generasi 7 | Best Fitness: 9290 | avg: 9732.05
# Generasi 8 | Best Fitness: 9145 | avg: 9420.55
# Generasi 9 | Best Fitness: 9065 | avg: 9313.125
# Generasi 10 | Best Fitness: 8885 | avg: 9214.525
# Generasi 11 | Best Fitness: 8755 | avg: 9041.825
# Generasi 12 | Best Fitness: 8695 | avg: 8967.2
# Generasi 13 | Best Fitness: 8555 | avg: 8885.375
# Generasi 14 | Best Fitness: 8370 | avg: 8767.85
# Generasi 15 | Best Fitness: 8315 | avg: 8609.15
# Generasi 16 | Best Fitness: 8245 | avg: 8491.05
# Generasi 17 | Best Fitness: 8165 | avg: 8424.925
# Generasi 18 | Best Fitness: 8010 | avg: 8327.975
# Generasi 19 | Best Fitness: 7820 | avg: 8187.475
# ----- GWO PHASE -----
# GWO Iter 0 Best: 7780 Avg: 8082
# GWO Iter 1 Best: 7780 Avg: 8136
# GWO Iter 2 Best: 7780 Avg: 8180
# GWO Iter 3 Best: 7780 Avg: 8204
# GWO Iter 4 Best: 7780 Avg: 8233
# GWO Iter 5 Best: 7780 Avg: 8251
# GWO Iter 6 Best: 7780 Avg: 8265
# GWO Iter 7 Best: 7780 Avg: 8288
# GWO Iter 8 Best: 7780 Avg: 8309
# GWO Iter 9 Best: 7780 Avg: 8329
# GWO Iter 10 Best: 7780 Avg: 8341
# GWO Iter 11 Best: 7780 Avg: 8350
# GWO Iter 12 Best: 7780 Avg: 8371
# GWO Iter 13 Best: 7780 Avg: 8382
# GWO Iter 14 Best: 7780 Avg: 8395
# GWO Iter 15 Best: 7780 Avg: 8410
# GWO Iter 16 Best: 7780 Avg: 8426
# GWO Iter 17 Best: 7780 Avg: 8444
# GWO Iter 18 Best: 7780 Avg: 8450
# GWO Iter 19 Best: 7780 Avg: 8458
# Generasi 20 | Best Fitness: 7780 | avg: 8458.35
# Generasi 21 | Best Fitness: 7515 | avg: 8063.625
# Generasi 22 | Best Fitness: 7485 | avg: 7821.575
# Generasi 23 | Best Fitness: 7335 | avg: 7599.025
# Generasi 24 | Best Fitness: 7180 | avg: 7480.975
# Generasi 25 | Best Fitness: 7085 | avg: 7371.35
# Generasi 26 | Best Fitness: 6940 | avg: 7247.525
# Generasi 27 | Best Fitness: 6805 | avg: 7100.025
# Generasi 28 | Best Fitness: 6650 | avg: 6955.925
# Generasi 29 | Best Fitness: 6360 | avg: 6786.225
# Generasi 30 | Best Fitness: 6245 | avg: 6570.15
# Generasi 31 | Best Fitness: 6145 | avg: 6389.0
# Generasi 32 | Best Fitness: 6020 | avg: 6256.275
# Generasi 33 | Best Fitness: 5845 | avg: 6146.525
# Generasi 34 | Best Fitness: 5760 | avg: 5981.55
# Generasi 35 | Best Fitness: 5480 | avg: 5860.9
# Generasi 36 | Best Fitness: 5350 | avg: 5680.5
# Generasi 37 | Best Fitness: 5140 | avg: 5503.9
# Generasi 38 | Best Fitness: 5020 | avg: 5354.6
# Generasi 39 | Best Fitness: 4895 | avg: 5175.0
# ----- GWO PHASE -----
# GWO Iter 0 Best: 4815 Avg: 5084
# GWO Iter 1 Best: 4815 Avg: 5116
# GWO Iter 2 Best: 4815 Avg: 5159
# GWO Iter 3 Best: 4815 Avg: 5181
# GWO Iter 4 Best: 4815 Avg: 5210
# GWO Iter 5 Best: 4815 Avg: 5223
# GWO Iter 6 Best: 4815 Avg: 5241
# GWO Iter 7 Best: 4815 Avg: 5253
# GWO Iter 8 Best: 4815 Avg: 5278
# GWO Iter 9 Best: 4815 Avg: 5298
# GWO Iter 10 Best: 4815 Avg: 5331
# GWO Iter 11 Best: 4815 Avg: 5343
# GWO Iter 12 Best: 4815 Avg: 5351
# GWO Iter 13 Best: 4815 Avg: 5370
# GWO Iter 14 Best: 4815 Avg: 5391
# GWO Iter 15 Best: 4815 Avg: 5417
# GWO Iter 16 Best: 4815 Avg: 5435
# GWO Iter 17 Best: 4815 Avg: 5456
# GWO Iter 18 Best: 4815 Avg: 5466
# GWO Iter 19 Best: 4815 Avg: 5477
# Generasi 40 | Best Fitness: 4815 | avg: 5477.225
# Generasi 41 | Best Fitness: 4800 | avg: 5092.6
# Generasi 42 | Best Fitness: 4675 | avg: 4906.8
# Generasi 43 | Best Fitness: 4630 | avg: 4854.775
# Generasi 44 | Best Fitness: 4505 | avg: 4758.075
# Generasi 45 | Best Fitness: 4475 | avg: 4653.025
# Generasi 46 | Best Fitness: 4415 | avg: 4557.675
# Generasi 47 | Best Fitness: 4345 | avg: 4543.425
# Generasi 48 | Best Fitness: 4265 | avg: 4483.225
# Generasi 49 | Best Fitness: 4205 | avg: 4392.425
# Generasi 50 | Best Fitness: 4125 | avg: 4314.5
# Generasi 51 | Best Fitness: 4085 | avg: 4233.425
# Generasi 52 | Best Fitness: 4000 | avg: 4187.0
# Generasi 53 | Best Fitness: 3915 | avg: 4102.775
# Generasi 54 | Best Fitness: 3850 | avg: 4015.275
# Generasi 55 | Best Fitness: 3725 | avg: 3970.75
# Generasi 56 | Best Fitness: 3705 | avg: 3856.475
# Generasi 57 | Best Fitness: 3705 | avg: 3810.325
# Generasi 58 | Best Fitness: 3665 | avg: 3785.8
# Generasi 59 | Best Fitness: 3645 | avg: 3758.15
# ----- GWO PHASE -----
# GWO Iter 0 Best: 3635 Avg: 3771
# GWO Iter 1 Best: 3635 Avg: 3796
# GWO Iter 2 Best: 3635 Avg: 3822
# GWO Iter 3 Best: 3625 Avg: 3839
# GWO Iter 4 Best: 3625 Avg: 3866
# GWO Iter 5 Best: 3625 Avg: 3883
# GWO Iter 6 Best: 3625 Avg: 3910
# GWO Iter 7 Best: 3605 Avg: 3932
# GWO Iter 8 Best: 3605 Avg: 3952
# GWO Iter 9 Best: 3605 Avg: 3976
# GWO Iter 10 Best: 3605 Avg: 3994
# GWO Iter 11 Best: 3605 Avg: 4007
# GWO Iter 12 Best: 3605 Avg: 4032
# GWO Iter 13 Best: 3605 Avg: 4049
# GWO Iter 14 Best: 3605 Avg: 4068
# GWO Iter 15 Best: 3605 Avg: 4091
# GWO Iter 16 Best: 3605 Avg: 4110
# GWO Iter 17 Best: 3605 Avg: 4138
# GWO Iter 18 Best: 3605 Avg: 4162
# GWO Iter 19 Best: 3605 Avg: 4177
# Generasi 60 | Best Fitness: 3605 | avg: 4176.95
# Generasi 61 | Best Fitness: 3565 | avg: 3835.2
# Generasi 62 | Best Fitness: 3550 | avg: 3669.55
# Generasi 63 | Best Fitness: 3530 | avg: 3651.6
# Generasi 64 | Best Fitness: 3515 | avg: 3634.0
# Generasi 65 | Best Fitness: 3495 | avg: 3599.325
# Generasi 66 | Best Fitness: 3475 | avg: 3594.8
# Generasi 67 | Best Fitness: 3455 | avg: 3584.3
# Generasi 68 | Best Fitness: 3435 | avg: 3558.125
# Generasi 69 | Best Fitness: 3435 | avg: 3521.625
# Generasi 70 | Best Fitness: 3425 | avg: 3525.325
# Generasi 71 | Best Fitness: 3405 | avg: 3523.2
# Generasi 72 | Best Fitness: 3335 | avg: 3505.625
# Generasi 73 | Best Fitness: 3275 | avg: 3449.025
# Generasi 74 | Best Fitness: 3190 | avg: 3375.375
# Generasi 75 | Best Fitness: 3190 | avg: 3309.475
# Generasi 76 | Best Fitness: 3170 | avg: 3257.85
# Generasi 77 | Best Fitness: 3070 | avg: 3251.9
# Generasi 78 | Best Fitness: 3050 | avg: 3215.85
# Generasi 79 | Best Fitness: 3030 | avg: 3127.95
# ----- GWO PHASE -----
# GWO Iter 0 Best: 3010 Avg: 3140
# GWO Iter 1 Best: 3010 Avg: 3165
# GWO Iter 2 Best: 3010 Avg: 3190
# GWO Iter 3 Best: 3005 Avg: 3212
# GWO Iter 4 Best: 3005 Avg: 3228
# GWO Iter 5 Best: 3005 Avg: 3253
# GWO Iter 6 Best: 3005 Avg: 3266
# GWO Iter 7 Best: 3005 Avg: 3285
# GWO Iter 8 Best: 3005 Avg: 3306
# GWO Iter 9 Best: 3005 Avg: 3324
# GWO Iter 10 Best: 3005 Avg: 3348
# GWO Iter 11 Best: 3005 Avg: 3367
# GWO Iter 12 Best: 3005 Avg: 3392
# GWO Iter 13 Best: 3005 Avg: 3406
# GWO Iter 14 Best: 3005 Avg: 3426
# GWO Iter 15 Best: 3005 Avg: 3437
# GWO Iter 16 Best: 3005 Avg: 3461
# GWO Iter 17 Best: 3005 Avg: 3486
# GWO Iter 18 Best: 3005 Avg: 3510
# GWO Iter 19 Best: 3005 Avg: 3526
# Generasi 80 | Best Fitness: 3005 | avg: 3525.7
# Generasi 81 | Best Fitness: 2980 | avg: 3174.075
# Generasi 82 | Best Fitness: 2960 | avg: 3064.8
# Generasi 83 | Best Fitness: 2950 | avg: 3038.4
# Generasi 84 | Best Fitness: 2940 | avg: 3016.925
# Generasi 85 | Best Fitness: 2890 | avg: 3011.375
# Generasi 86 | Best Fitness: 2870 | avg: 2976.875
# Generasi 87 | Best Fitness: 2860 | avg: 2943.925
# Generasi 88 | Best Fitness: 2835 | avg: 2931.2
# Generasi 89 | Best Fitness: 2830 | avg: 2918.975
# Generasi 90 | Best Fitness: 2810 | avg: 2898.1
# Generasi 91 | Best Fitness: 2800 | avg: 2896.55
# Generasi 92 | Best Fitness: 2795 | avg: 2876.5
# Generasi 93 | Best Fitness: 2785 | avg: 2869.75
# Generasi 94 | Best Fitness: 2775 | avg: 2860.475
# Generasi 95 | Best Fitness: 2760 | avg: 2845.375
# Generasi 96 | Best Fitness: 2735 | avg: 2836.25
# Generasi 97 | Best Fitness: 2715 | avg: 2802.725
# Generasi 98 | Best Fitness: 2700 | avg: 2794.4
# Generasi 99 | Best Fitness: 2695 | avg: 2775.95
# ----- GWO PHASE -----
# GWO Iter 0 Best: 2670 Avg: 2793
# GWO Iter 1 Best: 2670 Avg: 2816
# GWO Iter 2 Best: 2670 Avg: 2836
# GWO Iter 3 Best: 2670 Avg: 2857
# GWO Iter 4 Best: 2670 Avg: 2888
# GWO Iter 5 Best: 2670 Avg: 2916
# GWO Iter 6 Best: 2670 Avg: 2936
# GWO Iter 7 Best: 2670 Avg: 2954
# GWO Iter 8 Best: 2670 Avg: 2970
# GWO Iter 9 Best: 2670 Avg: 2997
# GWO Iter 10 Best: 2670 Avg: 3017
# GWO Iter 11 Best: 2670 Avg: 3037
# GWO Iter 12 Best: 2670 Avg: 3059
# GWO Iter 13 Best: 2670 Avg: 3089
# GWO Iter 14 Best: 2670 Avg: 3114
# GWO Iter 15 Best: 2670 Avg: 3135
# GWO Iter 16 Best: 2670 Avg: 3150
# GWO Iter 17 Best: 2670 Avg: 3188
# GWO Iter 18 Best: 2670 Avg: 3201
# GWO Iter 19 Best: 2670 Avg: 3229
# Generasi 100 | Best Fitness: 2670 | avg: 3229.0
# Generasi 101 | Best Fitness: 2665 | avg: 2840.65
# Generasi 102 | Best Fitness: 2665 | avg: 2739.0
# Generasi 103 | Best Fitness: 2660 | avg: 2736.175
# Generasi 104 | Best Fitness: 2655 | avg: 2742.575
# Generasi 105 | Best Fitness: 2650 | avg: 2732.5
# Generasi 106 | Best Fitness: 2635 | avg: 2721.725
# Generasi 107 | Best Fitness: 2625 | avg: 2710.875
# Generasi 108 | Best Fitness: 2600 | avg: 2706.35
# Generasi 109 | Best Fitness: 2585 | avg: 2691.2
# Generasi 110 | Best Fitness: 2565 | avg: 2662.65
# Generasi 111 | Best Fitness: 2565 | avg: 2642.8
# Generasi 112 | Best Fitness: 2565 | avg: 2624.275
# Generasi 113 | Best Fitness: 2560 | avg: 2633.025
# Generasi 114 | Best Fitness: 2540 | avg: 2626.275
# Generasi 115 | Best Fitness: 2535 | avg: 2625.15
# Generasi 116 | Best Fitness: 2530 | avg: 2604.075
# Generasi 117 | Best Fitness: 2525 | avg: 2600.525
# Generasi 118 | Best Fitness: 2500 | avg: 2595.9
# Generasi 119 | Best Fitness: 2480 | avg: 2579.675
# ----- GWO PHASE -----
# GWO Iter 0 Best: 2470 Avg: 2581
# GWO Iter 1 Best: 2470 Avg: 2603
# GWO Iter 2 Best: 2470 Avg: 2635
# GWO Iter 3 Best: 2470 Avg: 2662
# GWO Iter 4 Best: 2470 Avg: 2686
# GWO Iter 5 Best: 2470 Avg: 2706
# GWO Iter 6 Best: 2470 Avg: 2735
# GWO Iter 7 Best: 2470 Avg: 2760
# GWO Iter 8 Best: 2470 Avg: 2775
# GWO Iter 9 Best: 2470 Avg: 2805
# GWO Iter 10 Best: 2470 Avg: 2837
# GWO Iter 11 Best: 2465 Avg: 2861
# GWO Iter 12 Best: 2465 Avg: 2878
# GWO Iter 13 Best: 2465 Avg: 2907
# GWO Iter 14 Best: 2465 Avg: 2937
# GWO Iter 15 Best: 2465 Avg: 2966
# GWO Iter 16 Best: 2465 Avg: 2980
# GWO Iter 17 Best: 2465 Avg: 3008
# GWO Iter 18 Best: 2465 Avg: 3028
# GWO Iter 19 Best: 2465 Avg: 3052
# Generasi 120 | Best Fitness: 2465 | avg: 3052.375
# Generasi 121 | Best Fitness: 2465 | avg: 2636.7
# Generasi 122 | Best Fitness: 2465 | avg: 2529.7
# Generasi 123 | Best Fitness: 2455 | avg: 2530.9
# Generasi 124 | Best Fitness: 2450 | avg: 2529.575
# Generasi 125 | Best Fitness: 2450 | avg: 2521.25
# Generasi 126 | Best Fitness: 2420 | avg: 2522.925
# Generasi 127 | Best Fitness: 2410 | avg: 2505.275
# Generasi 128 | Best Fitness: 2410 | avg: 2477.85
# Generasi 129 | Best Fitness: 2380 | avg: 2476.15
# Generasi 130 | Best Fitness: 2380 | avg: 2468.2
# Generasi 131 | Best Fitness: 2360 | avg: 2452.8
# Generasi 132 | Best Fitness: 2360 | avg: 2452.525
# Generasi 133 | Best Fitness: 2330 | avg: 2434.625
# Generasi 134 | Best Fitness: 2310 | avg: 2411.2
# Generasi 135 | Best Fitness: 2290 | avg: 2380.55
# Generasi 136 | Best Fitness: 2280 | avg: 2367.55
# Generasi 137 | Best Fitness: 2260 | avg: 2336.775
# Generasi 138 | Best Fitness: 2240 | avg: 2328.875
# Generasi 139 | Best Fitness: 2220 | avg: 2328.375
# ----- GWO PHASE -----
# GWO Iter 0 Best: 2220 Avg: 2331
# GWO Iter 1 Best: 2220 Avg: 2367
# GWO Iter 2 Best: 2215 Avg: 2386
# GWO Iter 3 Best: 2215 Avg: 2407
# GWO Iter 4 Best: 2215 Avg: 2438
# GWO Iter 5 Best: 2215 Avg: 2461
# GWO Iter 6 Best: 2215 Avg: 2491
# GWO Iter 7 Best: 2215 Avg: 2513
# GWO Iter 8 Best: 2215 Avg: 2539
# GWO Iter 9 Best: 2215 Avg: 2566
# GWO Iter 10 Best: 2215 Avg: 2586
# GWO Iter 11 Best: 2215 Avg: 2608
# GWO Iter 12 Best: 2215 Avg: 2628
# GWO Iter 13 Best: 2215 Avg: 2644
# GWO Iter 14 Best: 2215 Avg: 2669
# GWO Iter 15 Best: 2215 Avg: 2690
# GWO Iter 16 Best: 2215 Avg: 2713
# GWO Iter 17 Best: 2215 Avg: 2744
# GWO Iter 18 Best: 2215 Avg: 2769
# GWO Iter 19 Best: 2215 Avg: 2793
# Generasi 140 | Best Fitness: 2215 | avg: 2792.625
# Generasi 141 | Best Fitness: 2215 | avg: 2373.4
# Generasi 142 | Best Fitness: 2195 | avg: 2292.05
# Generasi 143 | Best Fitness: 2190 | avg: 2280.0
# Generasi 144 | Best Fitness: 2170 | avg: 2263.575
# Generasi 145 | Best Fitness: 2150 | avg: 2242.5
# Generasi 146 | Best Fitness: 2130 | avg: 2246.075
# Generasi 147 | Best Fitness: 2115 | avg: 2200.075
# Generasi 148 | Best Fitness: 2110 | avg: 2196.425
# Generasi 149 | Best Fitness: 2090 | avg: 2184.225
# Generasi 150 | Best Fitness: 2085 | avg: 2173.2
# Generasi 151 | Best Fitness: 2070 | avg: 2149.725
# Generasi 152 | Best Fitness: 2060 | avg: 2148.675
# Generasi 153 | Best Fitness: 2060 | avg: 2139.275
# Generasi 154 | Best Fitness: 2060 | avg: 2135.775
# Generasi 155 | Best Fitness: 2060 | avg: 2129.825
# Generasi 156 | Best Fitness: 2055 | avg: 2135.55
# Generasi 157 | Best Fitness: 2055 | avg: 2130.35
# Generasi 158 | Best Fitness: 2050 | avg: 2122.825
# Generasi 159 | Best Fitness: 2045 | avg: 2125.45
# ----- GWO PHASE -----
# GWO Iter 0 Best: 2040 Avg: 2148
# GWO Iter 1 Best: 2040 Avg: 2174
# GWO Iter 2 Best: 2040 Avg: 2200
# GWO Iter 3 Best: 2040 Avg: 2225
# GWO Iter 4 Best: 2040 Avg: 2251
# GWO Iter 5 Best: 2040 Avg: 2282
# GWO Iter 6 Best: 2040 Avg: 2309
# GWO Iter 7 Best: 2040 Avg: 2331
# GWO Iter 8 Best: 2040 Avg: 2357
# GWO Iter 9 Best: 2040 Avg: 2384
# GWO Iter 10 Best: 2040 Avg: 2402
# GWO Iter 11 Best: 2040 Avg: 2427
# GWO Iter 12 Best: 2040 Avg: 2449
# GWO Iter 13 Best: 2040 Avg: 2475
# GWO Iter 14 Best: 2040 Avg: 2496
# GWO Iter 15 Best: 2040 Avg: 2519
# GWO Iter 16 Best: 2040 Avg: 2550
# GWO Iter 17 Best: 2040 Avg: 2566
# GWO Iter 18 Best: 2040 Avg: 2588
# GWO Iter 19 Best: 2040 Avg: 2619
# Generasi 160 | Best Fitness: 2040 | avg: 2619.15
# Generasi 161 | Best Fitness: 2040 | avg: 2215.8
# Generasi 162 | Best Fitness: 2040 | avg: 2101.85
# Generasi 163 | Best Fitness: 2020 | avg: 2108.175
# Generasi 164 | Best Fitness: 2015 | avg: 2098.25
# Generasi 165 | Best Fitness: 2010 | avg: 2087.425
# Generasi 166 | Best Fitness: 2005 | avg: 2084.9
# Generasi 167 | Best Fitness: 2005 | avg: 2087.975
# Generasi 168 | Best Fitness: 2005 | avg: 2068.3
# Generasi 169 | Best Fitness: 2005 | avg: 2076.4
# Generasi 170 | Best Fitness: 1985 | avg: 2082.05
# Generasi 171 | Best Fitness: 1980 | avg: 2060.5
# Generasi 172 | Best Fitness: 1960 | avg: 2058.725
# Generasi 173 | Best Fitness: 1960 | avg: 2052.425
# Generasi 174 | Best Fitness: 1960 | avg: 2043.275
# Generasi 175 | Best Fitness: 1940 | avg: 2041.025
# Generasi 176 | Best Fitness: 1930 | avg: 2030.45
# Generasi 177 | Best Fitness: 1930 | avg: 2004.225
# Generasi 178 | Best Fitness: 1930 | avg: 1997.925
# Generasi 179 | Best Fitness: 1925 | avg: 1996.6
# ----- GWO PHASE -----
# GWO Iter 0 Best: 1925 Avg: 2028
# GWO Iter 1 Best: 1925 Avg: 2059
# GWO Iter 2 Best: 1925 Avg: 2086
# GWO Iter 3 Best: 1925 Avg: 2107
# GWO Iter 4 Best: 1925 Avg: 2134
# GWO Iter 5 Best: 1925 Avg: 2155
# GWO Iter 6 Best: 1925 Avg: 2181
# GWO Iter 7 Best: 1925 Avg: 2206
# GWO Iter 8 Best: 1925 Avg: 2239
# GWO Iter 9 Best: 1925 Avg: 2260
# GWO Iter 10 Best: 1925 Avg: 2282
# GWO Iter 11 Best: 1925 Avg: 2308
# GWO Iter 12 Best: 1925 Avg: 2334
# GWO Iter 13 Best: 1920 Avg: 2354
# GWO Iter 14 Best: 1920 Avg: 2383
# GWO Iter 15 Best: 1920 Avg: 2410
# GWO Iter 16 Best: 1920 Avg: 2432
# GWO Iter 17 Best: 1920 Avg: 2452
# GWO Iter 18 Best: 1920 Avg: 2476
# GWO Iter 19 Best: 1920 Avg: 2494
# Generasi 180 | Best Fitness: 1920 | avg: 2494.1
# Generasi 181 | Best Fitness: 1900 | avg: 2142.9
# Generasi 182 | Best Fitness: 1900 | avg: 1989.3
# Generasi 183 | Best Fitness: 1880 | avg: 1973.85
# Generasi 184 | Best Fitness: 1880 | avg: 1962.3
# Generasi 185 | Best Fitness: 1865 | avg: 1947.7
# Generasi 186 | Best Fitness: 1865 | avg: 1951.7
# Generasi 187 | Best Fitness: 1855 | avg: 1942.05
# Generasi 188 | Best Fitness: 1855 | avg: 1934.575
# Generasi 189 | Best Fitness: 1855 | avg: 1929.575
# Generasi 190 | Best Fitness: 1845 | avg: 1931.95
# Generasi 191 | Best Fitness: 1840 | avg: 1923.875
# Generasi 192 | Best Fitness: 1825 | avg: 1926.35
# Generasi 193 | Best Fitness: 1820 | avg: 1904.35
# Generasi 194 | Best Fitness: 1820 | avg: 1893.975
# Generasi 195 | Best Fitness: 1810 | avg: 1889.6
# Generasi 196 | Best Fitness: 1810 | avg: 1886.0
# Generasi 197 | Best Fitness: 1810 | avg: 1875.3
# Generasi 198 | Best Fitness: 1810 | avg: 1880.15
# Generasi 199 | Best Fitness: 1805 | avg: 1879.65
# ----- GWO PHASE -----
# GWO Iter 0 Best: 1790 Avg: 1901
# GWO Iter 1 Best: 1790 Avg: 1925
# GWO Iter 2 Best: 1790 Avg: 1961
# GWO Iter 3 Best: 1790 Avg: 1981
# GWO Iter 4 Best: 1790 Avg: 2012
# GWO Iter 5 Best: 1790 Avg: 2035
# GWO Iter 6 Best: 1790 Avg: 2058
# GWO Iter 7 Best: 1790 Avg: 2088
# GWO Iter 8 Best: 1790 Avg: 2117
# GWO Iter 9 Best: 1790 Avg: 2143
# GWO Iter 10 Best: 1790 Avg: 2164
# GWO Iter 11 Best: 1790 Avg: 2203
# GWO Iter 12 Best: 1790 Avg: 2227
# GWO Iter 13 Best: 1790 Avg: 2247
# GWO Iter 14 Best: 1790 Avg: 2270
# GWO Iter 15 Best: 1790 Avg: 2292
# GWO Iter 16 Best: 1790 Avg: 2326
# GWO Iter 17 Best: 1790 Avg: 2338
# GWO Iter 18 Best: 1790 Avg: 2358
# GWO Iter 19 Best: 1790 Avg: 2386
# Generasi 200 | Best Fitness: 1790 | avg: 2385.975
# Generasi 201 | Best Fitness: 1770 | avg: 2016.4
# Generasi 202 | Best Fitness: 1770 | avg: 1854.8
# Generasi 203 | Best Fitness: 1765 | avg: 1837.05
# Generasi 204 | Best Fitness: 1750 | avg: 1843.475
# Generasi 205 | Best Fitness: 1745 | avg: 1831.725
# Generasi 206 | Best Fitness: 1745 | avg: 1815.2
# Generasi 207 | Best Fitness: 1730 | avg: 1818.675
# Generasi 208 | Best Fitness: 1725 | avg: 1819.3
# Generasi 209 | Best Fitness: 1725 | avg: 1805.275
# Generasi 210 | Best Fitness: 1725 | avg: 1798.2
# Generasi 211 | Best Fitness: 1725 | avg: 1797.575
# Generasi 212 | Best Fitness: 1725 | avg: 1788.025
# Generasi 213 | Best Fitness: 1725 | avg: 1799.475
# Generasi 214 | Best Fitness: 1725 | avg: 1795.975
# Generasi 215 | Best Fitness: 1715 | avg: 1800.075
# Generasi 216 | Best Fitness: 1715 | avg: 1802.175
# Generasi 217 | Best Fitness: 1710 | avg: 1794.4
# Generasi 218 | Best Fitness: 1710 | avg: 1795.225
# Generasi 219 | Best Fitness: 1700 | avg: 1783.275
# ----- GWO PHASE -----
# GWO Iter 0 Best: 1700 Avg: 1806
# GWO Iter 1 Best: 1700 Avg: 1831
# GWO Iter 2 Best: 1700 Avg: 1860
# GWO Iter 3 Best: 1700 Avg: 1887
# GWO Iter 4 Best: 1700 Avg: 1909
# GWO Iter 5 Best: 1700 Avg: 1938
# GWO Iter 6 Best: 1700 Avg: 1961
# GWO Iter 7 Best: 1700 Avg: 1982
# GWO Iter 8 Best: 1700 Avg: 2010
# GWO Iter 9 Best: 1700 Avg: 2030
# GWO Iter 10 Best: 1700 Avg: 2055
# GWO Iter 11 Best: 1700 Avg: 2082
# GWO Iter 12 Best: 1700 Avg: 2109
# GWO Iter 13 Best: 1700 Avg: 2131
# GWO Iter 14 Best: 1700 Avg: 2159
# GWO Iter 15 Best: 1700 Avg: 2184
# GWO Iter 16 Best: 1700 Avg: 2213
# GWO Iter 17 Best: 1700 Avg: 2238
# GWO Iter 18 Best: 1700 Avg: 2262
# GWO Iter 19 Best: 1700 Avg: 2289
# Generasi 220 | Best Fitness: 1700 | avg: 2288.875
# Generasi 221 | Best Fitness: 1700 | avg: 1851.975
# Generasi 222 | Best Fitness: 1700 | avg: 1763.85
# Generasi 223 | Best Fitness: 1690 | avg: 1774.175
# Generasi 224 | Best Fitness: 1690 | avg: 1766.975
# Generasi 225 | Best Fitness: 1690 | avg: 1758.65
# Generasi 226 | Best Fitness: 1690 | avg: 1755.475
# Generasi 227 | Best Fitness: 1685 | avg: 1768.7
# Generasi 228 | Best Fitness: 1680 | avg: 1750.9
# Generasi 229 | Best Fitness: 1675 | avg: 1757.025
# Generasi 230 | Best Fitness: 1655 | avg: 1751.375
# Generasi 231 | Best Fitness: 1655 | avg: 1740.025
# Generasi 232 | Best Fitness: 1655 | avg: 1726.85
# Generasi 233 | Best Fitness: 1650 | avg: 1725.625
# Generasi 234 | Best Fitness: 1650 | avg: 1722.55
# Generasi 235 | Best Fitness: 1630 | avg: 1719.2
# Generasi 236 | Best Fitness: 1610 | avg: 1717.125
# Generasi 237 | Best Fitness: 1610 | avg: 1703.075
# Generasi 238 | Best Fitness: 1590 | avg: 1685.8
# Generasi 239 | Best Fitness: 1570 | avg: 1682.625
# ----- GWO PHASE -----
# GWO Iter 0 Best: 1570 Avg: 1680
# GWO Iter 1 Best: 1570 Avg: 1721
# GWO Iter 2 Best: 1570 Avg: 1751
# GWO Iter 3 Best: 1570 Avg: 1771
# GWO Iter 4 Best: 1570 Avg: 1796
# GWO Iter 5 Best: 1570 Avg: 1828
# GWO Iter 6 Best: 1570 Avg: 1856
# GWO Iter 7 Best: 1570 Avg: 1886
# GWO Iter 8 Best: 1570 Avg: 1904
# GWO Iter 9 Best: 1570 Avg: 1923
# GWO Iter 10 Best: 1570 Avg: 1950
# GWO Iter 11 Best: 1570 Avg: 1982
# GWO Iter 12 Best: 1570 Avg: 2007
# GWO Iter 13 Best: 1570 Avg: 2042
# GWO Iter 14 Best: 1570 Avg: 2063
# GWO Iter 15 Best: 1570 Avg: 2089
# GWO Iter 16 Best: 1570 Avg: 2114
# GWO Iter 17 Best: 1570 Avg: 2132
# GWO Iter 18 Best: 1570 Avg: 2148
# GWO Iter 19 Best: 1570 Avg: 2185
# Generasi 240 | Best Fitness: 1570 | avg: 2184.85
# Generasi 241 | Best Fitness: 1570 | avg: 1773.4
# Generasi 242 | Best Fitness: 1570 | avg: 1644.475
# Generasi 243 | Best Fitness: 1570 | avg: 1654.35
# Generasi 244 | Best Fitness: 1550 | avg: 1644.725
# Generasi 245 | Best Fitness: 1550 | avg: 1631.3
# Generasi 246 | Best Fitness: 1550 | avg: 1620.675
# Generasi 247 | Best Fitness: 1550 | avg: 1616.5
# Generasi 248 | Best Fitness: 1550 | avg: 1617.05
# Generasi 249 | Best Fitness: 1535 | avg: 1613.275
# Generasi 250 | Best Fitness: 1530 | avg: 1606.925
# Generasi 251 | Best Fitness: 1515 | avg: 1610.025
# Generasi 252 | Best Fitness: 1515 | avg: 1587.85
# Generasi 253 | Best Fitness: 1510 | avg: 1593.95
# Generasi 254 | Best Fitness: 1495 | avg: 1589.025
# Generasi 255 | Best Fitness: 1490 | avg: 1575.1
# Generasi 256 | Best Fitness: 1470 | avg: 1556.7
# Generasi 257 | Best Fitness: 1470 | avg: 1553.85
# Generasi 258 | Best Fitness: 1470 | avg: 1532.4
# Generasi 259 | Best Fitness: 1465 | avg: 1537.675
# ----- GWO PHASE -----
# GWO Iter 0 Best: 1450 Avg: 1574
# GWO Iter 1 Best: 1450 Avg: 1597
# GWO Iter 2 Best: 1450 Avg: 1623
# GWO Iter 3 Best: 1450 Avg: 1656
# GWO Iter 4 Best: 1450 Avg: 1681
# GWO Iter 5 Best: 1450 Avg: 1718
# GWO Iter 6 Best: 1450 Avg: 1746
# GWO Iter 7 Best: 1450 Avg: 1778
# GWO Iter 8 Best: 1450 Avg: 1810
# GWO Iter 9 Best: 1450 Avg: 1829
# GWO Iter 10 Best: 1450 Avg: 1862
# GWO Iter 11 Best: 1450 Avg: 1881
# GWO Iter 12 Best: 1450 Avg: 1910
# GWO Iter 13 Best: 1450 Avg: 1929
# GWO Iter 14 Best: 1450 Avg: 1959
# GWO Iter 15 Best: 1450 Avg: 1986
# GWO Iter 16 Best: 1450 Avg: 2006
# GWO Iter 17 Best: 1450 Avg: 2027
# GWO Iter 18 Best: 1450 Avg: 2054
# GWO Iter 19 Best: 1450 Avg: 2081
# Generasi 260 | Best Fitness: 1450 | avg: 2081.225
# Generasi 261 | Best Fitness: 1450 | avg: 1608.575
# Generasi 262 | Best Fitness: 1450 | avg: 1518.575
# Generasi 263 | Best Fitness: 1450 | avg: 1528.5
# Generasi 264 | Best Fitness: 1435 | avg: 1518.825
# Generasi 265 | Best Fitness: 1435 | avg: 1513.825
# Generasi 266 | Best Fitness: 1435 | avg: 1503.775
# Generasi 267 | Best Fitness: 1435 | avg: 1518.175
# Generasi 268 | Best Fitness: 1435 | avg: 1507.575
# Generasi 269 | Best Fitness: 1435 | avg: 1505.075
# Generasi 270 | Best Fitness: 1435 | avg: 1504.5
# Generasi 271 | Best Fitness: 1435 | avg: 1514.975
# Generasi 272 | Best Fitness: 1435 | avg: 1512.875
# Generasi 273 | Best Fitness: 1435 | avg: 1516.075
# Generasi 274 | Best Fitness: 1435 | avg: 1513.95
# Generasi 275 | Best Fitness: 1435 | avg: 1506.475
# Generasi 276 | Best Fitness: 1435 | avg: 1507.875
# Generasi 277 | Best Fitness: 1435 | avg: 1501.025
# Generasi 278 | Best Fitness: 1435 | avg: 1507.525
# Generasi 279 | Best Fitness: 1435 | avg: 1499.25
# ----- GWO PHASE -----
# GWO Iter 0 Best: 1425 Avg: 1542
# GWO Iter 1 Best: 1425 Avg: 1573
# GWO Iter 2 Best: 1415 Avg: 1595
# GWO Iter 3 Best: 1415 Avg: 1630
# GWO Iter 4 Best: 1415 Avg: 1654
# GWO Iter 5 Best: 1415 Avg: 1681
# GWO Iter 6 Best: 1415 Avg: 1708
# GWO Iter 7 Best: 1415 Avg: 1740
# GWO Iter 8 Best: 1415 Avg: 1762
# GWO Iter 9 Best: 1415 Avg: 1781
# GWO Iter 10 Best: 1415 Avg: 1812
# GWO Iter 11 Best: 1415 Avg: 1852
# GWO Iter 12 Best: 1415 Avg: 1882
# GWO Iter 13 Best: 1415 Avg: 1904
# GWO Iter 14 Best: 1415 Avg: 1929
# GWO Iter 15 Best: 1415 Avg: 1952
# GWO Iter 16 Best: 1415 Avg: 1976
# GWO Iter 17 Best: 1415 Avg: 1996
# GWO Iter 18 Best: 1415 Avg: 2015
# GWO Iter 19 Best: 1415 Avg: 2041
# Generasi 280 | Best Fitness: 1415 | avg: 2040.525
# Generasi 281 | Best Fitness: 1415 | avg: 1618.025
# Generasi 282 | Best Fitness: 1415 | avg: 1496.05
# Generasi 283 | Best Fitness: 1415 | avg: 1485.25
# Generasi 284 | Best Fitness: 1415 | avg: 1488.825
# Generasi 285 | Best Fitness: 1410 | avg: 1489.875
# Generasi 286 | Best Fitness: 1410 | avg: 1493.85
# Generasi 287 | Best Fitness: 1410 | avg: 1475.475
# Generasi 288 | Best Fitness: 1410 | avg: 1478.275
# Generasi 289 | Best Fitness: 1410 | avg: 1481.225
# Generasi 290 | Best Fitness: 1405 | avg: 1481.9
# Generasi 291 | Best Fitness: 1405 | avg: 1477.425
# Generasi 292 | Best Fitness: 1400 | avg: 1477.0
# Generasi 293 | Best Fitness: 1400 | avg: 1466.825
# Generasi 294 | Best Fitness: 1400 | avg: 1458.65
# Generasi 295 | Best Fitness: 1390 | avg: 1470.0
# Generasi 296 | Best Fitness: 1390 | avg: 1464.35
# Generasi 297 | Best Fitness: 1390 | avg: 1460.275
# Generasi 298 | Best Fitness: 1390 | avg: 1465.625
# Generasi 299 | Best Fitness: 1385 | avg: 1464.55
# ----- GWO PHASE -----
# GWO Iter 0 Best: 1385 Avg: 1486
# GWO Iter 1 Best: 1385 Avg: 1515
# GWO Iter 2 Best: 1385 Avg: 1544
# GWO Iter 3 Best: 1385 Avg: 1571
# GWO Iter 4 Best: 1385 Avg: 1605
# GWO Iter 5 Best: 1385 Avg: 1632
# GWO Iter 6 Best: 1385 Avg: 1669
# GWO Iter 7 Best: 1385 Avg: 1688
# GWO Iter 8 Best: 1385 Avg: 1714
# GWO Iter 9 Best: 1385 Avg: 1744
# GWO Iter 10 Best: 1385 Avg: 1768
# GWO Iter 11 Best: 1385 Avg: 1792
# GWO Iter 12 Best: 1385 Avg: 1816
# GWO Iter 13 Best: 1385 Avg: 1847
# GWO Iter 14 Best: 1385 Avg: 1868
# GWO Iter 15 Best: 1385 Avg: 1899
# GWO Iter 16 Best: 1385 Avg: 1921
# GWO Iter 17 Best: 1385 Avg: 1947
# GWO Iter 18 Best: 1385 Avg: 1963
# GWO Iter 19 Best: 1385 Avg: 1985
# Generasi 300 | Best Fitness: 1385 | avg: 1984.925
# Generasi 301 | Best Fitness: 1385 | avg: 1562.65
# Generasi 302 | Best Fitness: 1385 | avg: 1460.25
# Generasi 303 | Best Fitness: 1385 | avg: 1457.85
# Generasi 304 | Best Fitness: 1385 | avg: 1460.1
# Generasi 305 | Best Fitness: 1385 | avg: 1453.9
# Generasi 306 | Best Fitness: 1385 | avg: 1457.275
# Generasi 307 | Best Fitness: 1370 | avg: 1459.475
# Generasi 308 | Best Fitness: 1370 | avg: 1450.575
# Generasi 309 | Best Fitness: 1350 | avg: 1436.875
# Generasi 310 | Best Fitness: 1330 | avg: 1425.675
# Generasi 311 | Best Fitness: 1330 | avg: 1413.325
# Generasi 312 | Best Fitness: 1330 | avg: 1401.25
# Generasi 313 | Best Fitness: 1330 | avg: 1398.5
# Generasi 314 | Best Fitness: 1310 | avg: 1406.25
# Generasi 315 | Best Fitness: 1310 | avg: 1400.275
# Generasi 316 | Best Fitness: 1310 | avg: 1376.3
# Generasi 317 | Best Fitness: 1310 | avg: 1387.95
# Generasi 318 | Best Fitness: 1305 | avg: 1383.0
# Generasi 319 | Best Fitness: 1305 | avg: 1370.275
# ----- GWO PHASE -----
# GWO Iter 0 Best: 1305 Avg: 1411
# GWO Iter 1 Best: 1305 Avg: 1444
# GWO Iter 2 Best: 1305 Avg: 1476
# GWO Iter 3 Best: 1305 Avg: 1494
# GWO Iter 4 Best: 1305 Avg: 1521
# GWO Iter 5 Best: 1305 Avg: 1549
# GWO Iter 6 Best: 1305 Avg: 1572
# GWO Iter 7 Best: 1305 Avg: 1599
# GWO Iter 8 Best: 1305 Avg: 1618
# GWO Iter 9 Best: 1305 Avg: 1646
# GWO Iter 10 Best: 1305 Avg: 1663
# GWO Iter 11 Best: 1305 Avg: 1686
# GWO Iter 12 Best: 1305 Avg: 1711
# GWO Iter 13 Best: 1305 Avg: 1734
# GWO Iter 14 Best: 1305 Avg: 1764
# GWO Iter 15 Best: 1305 Avg: 1788
# GWO Iter 16 Best: 1305 Avg: 1818
# GWO Iter 17 Best: 1305 Avg: 1841
# GWO Iter 18 Best: 1305 Avg: 1863
# GWO Iter 19 Best: 1305 Avg: 1884
# Generasi 320 | Best Fitness: 1305 | avg: 1884.25
# Generasi 321 | Best Fitness: 1305 | avg: 1471.425
# Generasi 322 | Best Fitness: 1305 | avg: 1378.65
# Generasi 323 | Best Fitness: 1305 | avg: 1386.7
# Generasi 324 | Best Fitness: 1305 | avg: 1376.45
# Generasi 325 | Best Fitness: 1305 | avg: 1380.2
# Generasi 326 | Best Fitness: 1305 | avg: 1381.0
# Generasi 327 | Best Fitness: 1305 | avg: 1366.075
# Generasi 328 | Best Fitness: 1305 | avg: 1383.85
# Generasi 329 | Best Fitness: 1305 | avg: 1377.625
# Generasi 330 | Best Fitness: 1305 | avg: 1376.1
# Generasi 331 | Best Fitness: 1305 | avg: 1386.175
# Generasi 332 | Best Fitness: 1305 | avg: 1378.725
# Generasi 333 | Best Fitness: 1305 | avg: 1368.0
# Generasi 334 | Best Fitness: 1305 | avg: 1381.125
# Generasi 335 | Best Fitness: 1305 | avg: 1376.025
# Generasi 336 | Best Fitness: 1305 | avg: 1376.45
# Generasi 337 | Best Fitness: 1295 | avg: 1374.95
# Generasi 338 | Best Fitness: 1295 | avg: 1375.85
# Generasi 339 | Best Fitness: 1295 | avg: 1365.775
# ----- GWO PHASE -----
# GWO Iter 0 Best: 1295 Avg: 1391
# GWO Iter 1 Best: 1295 Avg: 1418
# GWO Iter 2 Best: 1295 Avg: 1443
# GWO Iter 3 Best: 1295 Avg: 1461
# GWO Iter 4 Best: 1295 Avg: 1488
# GWO Iter 5 Best: 1295 Avg: 1523
# GWO Iter 6 Best: 1295 Avg: 1547
# GWO Iter 7 Best: 1295 Avg: 1580
# GWO Iter 8 Best: 1295 Avg: 1613
# GWO Iter 9 Best: 1295 Avg: 1650
# GWO Iter 10 Best: 1295 Avg: 1672
# GWO Iter 11 Best: 1295 Avg: 1706
# GWO Iter 12 Best: 1295 Avg: 1738
# GWO Iter 13 Best: 1295 Avg: 1763
# GWO Iter 14 Best: 1295 Avg: 1793
# GWO Iter 15 Best: 1295 Avg: 1816
# GWO Iter 16 Best: 1295 Avg: 1835
# GWO Iter 17 Best: 1295 Avg: 1862
# GWO Iter 18 Best: 1295 Avg: 1889
# GWO Iter 19 Best: 1295 Avg: 1909
# Generasi 340 | Best Fitness: 1295 | avg: 1908.85
# Generasi 341 | Best Fitness: 1295 | avg: 1485.6
# Generasi 342 | Best Fitness: 1295 | avg: 1362.775
# Generasi 343 | Best Fitness: 1275 | avg: 1360.775
# Generasi 344 | Best Fitness: 1275 | avg: 1366.8
# Generasi 345 | Best Fitness: 1275 | avg: 1353.375
# Generasi 346 | Best Fitness: 1255 | avg: 1340.35
# Generasi 347 | Best Fitness: 1255 | avg: 1341.575
# Generasi 348 | Best Fitness: 1250 | avg: 1324.4
# Generasi 349 | Best Fitness: 1250 | avg: 1322.35
# Generasi 350 | Best Fitness: 1250 | avg: 1314.425
# Generasi 351 | Best Fitness: 1250 | avg: 1323.2
# Generasi 352 | Best Fitness: 1250 | avg: 1317.675
# Generasi 353 | Best Fitness: 1250 | avg: 1327.55
# Generasi 354 | Best Fitness: 1230 | avg: 1327.8
# Generasi 355 | Best Fitness: 1230 | avg: 1312.5
# Generasi 356 | Best Fitness: 1230 | avg: 1298.05
# Generasi 357 | Best Fitness: 1230 | avg: 1298.375
# Generasi 358 | Best Fitness: 1230 | avg: 1298.05
# Generasi 359 | Best Fitness: 1230 | avg: 1291.275
# ----- GWO PHASE -----
# GWO Iter 0 Best: 1230 Avg: 1326
# GWO Iter 1 Best: 1230 Avg: 1358
# GWO Iter 2 Best: 1230 Avg: 1389
# GWO Iter 3 Best: 1230 Avg: 1428
# GWO Iter 4 Best: 1230 Avg: 1446
# GWO Iter 5 Best: 1230 Avg: 1471
# GWO Iter 6 Best: 1230 Avg: 1493
# GWO Iter 7 Best: 1230 Avg: 1524
# GWO Iter 8 Best: 1230 Avg: 1547
# GWO Iter 9 Best: 1230 Avg: 1576
# GWO Iter 10 Best: 1230 Avg: 1592
# GWO Iter 11 Best: 1230 Avg: 1619
# GWO Iter 12 Best: 1230 Avg: 1643
# GWO Iter 13 Best: 1230 Avg: 1662
# GWO Iter 14 Best: 1230 Avg: 1687
# GWO Iter 15 Best: 1230 Avg: 1721
# GWO Iter 16 Best: 1230 Avg: 1746
# GWO Iter 17 Best: 1230 Avg: 1768
# GWO Iter 18 Best: 1230 Avg: 1791
# GWO Iter 19 Best: 1230 Avg: 1818
# Generasi 360 | Best Fitness: 1230 | avg: 1818.375
# Generasi 361 | Best Fitness: 1230 | avg: 1394.025
# Generasi 362 | Best Fitness: 1210 | avg: 1300.325
# Generasi 363 | Best Fitness: 1210 | avg: 1301.325
# Generasi 364 | Best Fitness: 1210 | avg: 1278.975
# Generasi 365 | Best Fitness: 1210 | avg: 1290.025
# Generasi 366 | Best Fitness: 1210 | avg: 1281.95
# Generasi 367 | Best Fitness: 1210 | avg: 1291.725
# Generasi 368 | Best Fitness: 1210 | avg: 1277.9
# Generasi 369 | Best Fitness: 1210 | avg: 1286.175
# Generasi 370 | Best Fitness: 1210 | avg: 1289.875
# Generasi 371 | Best Fitness: 1210 | avg: 1279.65
# Generasi 372 | Best Fitness: 1210 | avg: 1286.875
# Generasi 373 | Best Fitness: 1210 | avg: 1281.175
# Generasi 374 | Best Fitness: 1205 | avg: 1279.325
# Generasi 375 | Best Fitness: 1205 | avg: 1278.4
# Generasi 376 | Best Fitness: 1205 | avg: 1282.425
# Generasi 377 | Best Fitness: 1185 | avg: 1272.4
# Generasi 378 | Best Fitness: 1185 | avg: 1274.9
# Generasi 379 | Best Fitness: 1185 | avg: 1265.525
# ----- GWO PHASE -----
# GWO Iter 0 Best: 1185 Avg: 1286
# GWO Iter 1 Best: 1185 Avg: 1316
# GWO Iter 2 Best: 1185 Avg: 1337
# GWO Iter 3 Best: 1185 Avg: 1358
# GWO Iter 4 Best: 1185 Avg: 1386
# GWO Iter 5 Best: 1185 Avg: 1418
# GWO Iter 6 Best: 1185 Avg: 1453
# GWO Iter 7 Best: 1185 Avg: 1476
# GWO Iter 8 Best: 1185 Avg: 1496
# GWO Iter 9 Best: 1185 Avg: 1524
# GWO Iter 10 Best: 1185 Avg: 1545
# GWO Iter 11 Best: 1185 Avg: 1558
# GWO Iter 12 Best: 1185 Avg: 1589
# GWO Iter 13 Best: 1185 Avg: 1621
# GWO Iter 14 Best: 1185 Avg: 1648
# GWO Iter 15 Best: 1185 Avg: 1673
# GWO Iter 16 Best: 1185 Avg: 1691
# GWO Iter 17 Best: 1185 Avg: 1719
# GWO Iter 18 Best: 1185 Avg: 1743
# GWO Iter 19 Best: 1185 Avg: 1766
# Generasi 380 | Best Fitness: 1185 | avg: 1766.075
# Generasi 381 | Best Fitness: 1185 | avg: 1334.475
# Generasi 382 | Best Fitness: 1185 | avg: 1259.5
# Generasi 383 | Best Fitness: 1165 | avg: 1253.375
# Generasi 384 | Best Fitness: 1160 | avg: 1252.775
# Generasi 385 | Best Fitness: 1160 | avg: 1232.925
# Generasi 386 | Best Fitness: 1160 | avg: 1241.975
# Generasi 387 | Best Fitness: 1160 | avg: 1213.15
# Generasi 388 | Best Fitness: 1160 | avg: 1231.25
# Generasi 389 | Best Fitness: 1160 | avg: 1230.05
# Generasi 390 | Best Fitness: 1160 | avg: 1226.875
# Generasi 391 | Best Fitness: 1160 | avg: 1233.975
# Generasi 392 | Best Fitness: 1160 | avg: 1232.175
# Generasi 393 | Best Fitness: 1160 | avg: 1224.05
# Generasi 394 | Best Fitness: 1140 | avg: 1234.025
# Generasi 395 | Best Fitness: 1140 | avg: 1223.85
# Generasi 396 | Best Fitness: 1140 | avg: 1200.3
# Generasi 397 | Best Fitness: 1140 | avg: 1210.4
# Generasi 398 | Best Fitness: 1140 | avg: 1217.9
# Generasi 399 | Best Fitness: 1140 | avg: 1201.35
# ----- GWO PHASE -----
# GWO Iter 0 Best: 1140 Avg: 1229
# GWO Iter 1 Best: 1140 Avg: 1267
# GWO Iter 2 Best: 1140 Avg: 1301
# GWO Iter 3 Best: 1140 Avg: 1323
# GWO Iter 4 Best: 1140 Avg: 1354
# GWO Iter 5 Best: 1140 Avg: 1385
# GWO Iter 6 Best: 1140 Avg: 1413
# GWO Iter 7 Best: 1140 Avg: 1446
# GWO Iter 8 Best: 1140 Avg: 1463
# GWO Iter 9 Best: 1140 Avg: 1492
# GWO Iter 10 Best: 1140 Avg: 1508
# GWO Iter 11 Best: 1140 Avg: 1535
# GWO Iter 12 Best: 1140 Avg: 1555
# GWO Iter 13 Best: 1140 Avg: 1591
# GWO Iter 14 Best: 1140 Avg: 1623
# GWO Iter 15 Best: 1140 Avg: 1647
# GWO Iter 16 Best: 1140 Avg: 1673
# GWO Iter 17 Best: 1140 Avg: 1695
# GWO Iter 18 Best: 1140 Avg: 1724
# GWO Iter 19 Best: 1140 Avg: 1751
# Generasi 400 | Best Fitness: 1140 | avg: 1750.6
# Generasi 401 | Best Fitness: 1140 | avg: 1328.55
# Generasi 402 | Best Fitness: 1140 | avg: 1223.5
# Generasi 403 | Best Fitness: 1140 | avg: 1217.15
# Generasi 404 | Best Fitness: 1140 | avg: 1221.775
# Generasi 405 | Best Fitness: 1140 | avg: 1212.075
# Generasi 406 | Best Fitness: 1140 | avg: 1216.325
# Generasi 407 | Best Fitness: 1120 | avg: 1212.075
# Generasi 408 | Best Fitness: 1100 | avg: 1213.575
# Generasi 409 | Best Fitness: 1100 | avg: 1179.775
# Generasi 410 | Best Fitness: 1100 | avg: 1173.25
# Generasi 411 | Best Fitness: 1100 | avg: 1164.175
# Generasi 412 | Best Fitness: 1100 | avg: 1169.25
# Generasi 413 | Best Fitness: 1100 | avg: 1167.175
# Generasi 414 | Best Fitness: 1100 | avg: 1171.35
# Generasi 415 | Best Fitness: 1100 | avg: 1177.675
# Generasi 416 | Best Fitness: 1100 | avg: 1172.525
# Generasi 417 | Best Fitness: 1100 | avg: 1158.725
# Generasi 418 | Best Fitness: 1100 | avg: 1170.025
# Generasi 419 | Best Fitness: 1100 | avg: 1175.9
# ----- GWO PHASE -----
# GWO Iter 0 Best: 1100 Avg: 1195
# GWO Iter 1 Best: 1100 Avg: 1225
# GWO Iter 2 Best: 1100 Avg: 1246
# GWO Iter 3 Best: 1100 Avg: 1271
# GWO Iter 4 Best: 1100 Avg: 1306
# GWO Iter 5 Best: 1100 Avg: 1329
# GWO Iter 6 Best: 1100 Avg: 1352
# GWO Iter 7 Best: 1100 Avg: 1379
# GWO Iter 8 Best: 1100 Avg: 1405
# GWO Iter 9 Best: 1100 Avg: 1429
# GWO Iter 10 Best: 1100 Avg: 1455
# GWO Iter 11 Best: 1100 Avg: 1486
# GWO Iter 12 Best: 1100 Avg: 1511
# GWO Iter 13 Best: 1100 Avg: 1537
# GWO Iter 14 Best: 1100 Avg: 1566
# GWO Iter 15 Best: 1100 Avg: 1597
# GWO Iter 16 Best: 1100 Avg: 1616
# GWO Iter 17 Best: 1100 Avg: 1643
# GWO Iter 18 Best: 1100 Avg: 1668
# GWO Iter 19 Best: 1100 Avg: 1692
# Generasi 420 | Best Fitness: 1100 | avg: 1691.7
# Generasi 421 | Best Fitness: 1100 | avg: 1300.325
# Generasi 422 | Best Fitness: 1100 | avg: 1175.9
# Generasi 423 | Best Fitness: 1095 | avg: 1176.325
# Generasi 424 | Best Fitness: 1095 | avg: 1165.925
# Generasi 425 | Best Fitness: 1095 | avg: 1150.85
# Generasi 426 | Best Fitness: 1095 | avg: 1176.125
# Generasi 427 | Best Fitness: 1095 | avg: 1165.5
# Generasi 428 | Best Fitness: 1095 | avg: 1167.0
# Generasi 429 | Best Fitness: 1095 | avg: 1170.45
# Generasi 430 | Best Fitness: 1095 | avg: 1161.225
# Generasi 431 | Best Fitness: 1095 | avg: 1165.25
# Generasi 432 | Best Fitness: 1065 | avg: 1189.875
# Generasi 433 | Best Fitness: 1065 | avg: 1166.2
# Generasi 434 | Best Fitness: 1065 | avg: 1141.5
# Generasi 435 | Best Fitness: 1065 | avg: 1139.9
# Generasi 436 | Best Fitness: 1065 | avg: 1139.65
# Generasi 437 | Best Fitness: 1065 | avg: 1142.725
# Generasi 438 | Best Fitness: 1065 | avg: 1137.175
# Generasi 439 | Best Fitness: 1065 | avg: 1146.725
# ----- GWO PHASE -----
# GWO Iter 0 Best: 1065 Avg: 1167
# GWO Iter 1 Best: 1065 Avg: 1197
# GWO Iter 2 Best: 1065 Avg: 1221
# GWO Iter 3 Best: 1065 Avg: 1249
# GWO Iter 4 Best: 1065 Avg: 1270
# GWO Iter 5 Best: 1065 Avg: 1300
# GWO Iter 6 Best: 1065 Avg: 1334
# GWO Iter 7 Best: 1065 Avg: 1359
# GWO Iter 8 Best: 1065 Avg: 1389
# GWO Iter 9 Best: 1065 Avg: 1405
# GWO Iter 10 Best: 1065 Avg: 1433
# GWO Iter 11 Best: 1065 Avg: 1474
# GWO Iter 12 Best: 1065 Avg: 1498
# GWO Iter 13 Best: 1065 Avg: 1519
# GWO Iter 14 Best: 1065 Avg: 1538
# GWO Iter 15 Best: 1065 Avg: 1564
# GWO Iter 16 Best: 1065 Avg: 1589
# GWO Iter 17 Best: 1065 Avg: 1616
# GWO Iter 18 Best: 1065 Avg: 1642
# GWO Iter 19 Best: 1065 Avg: 1663
# Generasi 440 | Best Fitness: 1065 | avg: 1663.375
# Generasi 441 | Best Fitness: 1065 | avg: 1258.025
# Generasi 442 | Best Fitness: 1065 | avg: 1138.1
# Generasi 443 | Best Fitness: 1065 | avg: 1136.6
# Generasi 444 | Best Fitness: 1065 | avg: 1136.575
# Generasi 445 | Best Fitness: 1065 | avg: 1135.25
# Generasi 446 | Best Fitness: 1065 | avg: 1142.15
# Generasi 447 | Best Fitness: 1065 | avg: 1139.675
# Generasi 448 | Best Fitness: 1045 | avg: 1132.675
# Generasi 449 | Best Fitness: 1045 | avg: 1141.3
# Generasi 450 | Best Fitness: 1045 | avg: 1117.1
# Generasi 451 | Best Fitness: 1045 | avg: 1111.0
# Generasi 452 | Best Fitness: 1045 | avg: 1121.075
# Generasi 453 | Best Fitness: 1045 | avg: 1111.05
# Generasi 454 | Best Fitness: 1045 | avg: 1117.475
# Generasi 455 | Best Fitness: 1045 | avg: 1120.35
# Generasi 456 | Best Fitness: 1045 | avg: 1118.5
# Generasi 457 | Best Fitness: 1045 | avg: 1124.8
# Generasi 458 | Best Fitness: 1045 | avg: 1113.25
# Generasi 459 | Best Fitness: 1045 | avg: 1118.875
# ----- GWO PHASE -----
# GWO Iter 0 Best: 1045 Avg: 1160
# GWO Iter 1 Best: 1045 Avg: 1193
# GWO Iter 2 Best: 1045 Avg: 1222
# GWO Iter 3 Best: 1045 Avg: 1242
# GWO Iter 4 Best: 1045 Avg: 1280
# GWO Iter 5 Best: 1045 Avg: 1302
# GWO Iter 6 Best: 1045 Avg: 1325
# GWO Iter 7 Best: 1045 Avg: 1357
# GWO Iter 8 Best: 1045 Avg: 1386
# GWO Iter 9 Best: 1045 Avg: 1407
# GWO Iter 10 Best: 1045 Avg: 1431
# GWO Iter 11 Best: 1045 Avg: 1462
# GWO Iter 12 Best: 1045 Avg: 1496
# GWO Iter 13 Best: 1045 Avg: 1515
# GWO Iter 14 Best: 1045 Avg: 1547
# GWO Iter 15 Best: 1045 Avg: 1576
# GWO Iter 16 Best: 1045 Avg: 1601
# GWO Iter 17 Best: 1045 Avg: 1630
# GWO Iter 18 Best: 1045 Avg: 1643
# GWO Iter 19 Best: 1045 Avg: 1670
# Generasi 460 | Best Fitness: 1045 | avg: 1670.05
# Generasi 461 | Best Fitness: 1045 | avg: 1218.65
# Generasi 462 | Best Fitness: 1045 | avg: 1113.05
# Generasi 463 | Best Fitness: 1045 | avg: 1112.425
# Generasi 464 | Best Fitness: 1045 | avg: 1122.625
# Generasi 465 | Best Fitness: 1045 | avg: 1111.625
# Generasi 466 | Best Fitness: 1045 | avg: 1116.0
# Generasi 467 | Best Fitness: 1045 | avg: 1114.1
# Generasi 468 | Best Fitness: 1045 | avg: 1115.375
# Generasi 469 | Best Fitness: 1045 | avg: 1125.2
# Generasi 470 | Best Fitness: 1030 | avg: 1115.925
# Generasi 471 | Best Fitness: 1030 | avg: 1116.5
# Generasi 472 | Best Fitness: 1030 | avg: 1093.275
# Generasi 473 | Best Fitness: 1030 | avg: 1112.625
# Generasi 474 | Best Fitness: 1030 | avg: 1091.55
# Generasi 475 | Best Fitness: 1030 | avg: 1109.325
# Generasi 476 | Best Fitness: 1030 | avg: 1095.525
# Generasi 477 | Best Fitness: 1030 | avg: 1107.65
# Generasi 478 | Best Fitness: 1030 | avg: 1108.175
# Generasi 479 | Best Fitness: 1030 | avg: 1103.075
# ----- GWO PHASE -----
# GWO Iter 0 Best: 1030 Avg: 1145
# GWO Iter 1 Best: 1030 Avg: 1171
# GWO Iter 2 Best: 1030 Avg: 1201
# GWO Iter 3 Best: 1030 Avg: 1224
# GWO Iter 4 Best: 1030 Avg: 1258
# GWO Iter 5 Best: 1030 Avg: 1291
# GWO Iter 6 Best: 1030 Avg: 1318
# GWO Iter 7 Best: 1030 Avg: 1339
# GWO Iter 8 Best: 1030 Avg: 1375
# GWO Iter 9 Best: 1030 Avg: 1398
# GWO Iter 10 Best: 1030 Avg: 1422
# GWO Iter 11 Best: 1030 Avg: 1455
# GWO Iter 12 Best: 1030 Avg: 1483
# GWO Iter 13 Best: 1030 Avg: 1503
# GWO Iter 14 Best: 1030 Avg: 1523
# GWO Iter 15 Best: 1030 Avg: 1548
# GWO Iter 16 Best: 1030 Avg: 1577
# GWO Iter 17 Best: 1030 Avg: 1613
# GWO Iter 18 Best: 1030 Avg: 1629
# GWO Iter 19 Best: 1030 Avg: 1652
# Generasi 480 | Best Fitness: 1030 | avg: 1652.15
# Generasi 481 | Best Fitness: 1030 | avg: 1230.725
# Generasi 482 | Best Fitness: 1030 | avg: 1102.525
# Generasi 483 | Best Fitness: 1030 | avg: 1104.325
# Generasi 484 | Best Fitness: 1030 | avg: 1108.025
# Generasi 485 | Best Fitness: 1030 | avg: 1102.825
# Generasi 486 | Best Fitness: 1030 | avg: 1108.225
# Generasi 487 | Best Fitness: 1030 | avg: 1107.8
# Generasi 488 | Best Fitness: 1030 | avg: 1097.875
# Generasi 489 | Best Fitness: 1030 | avg: 1105.1
# Generasi 490 | Best Fitness: 1030 | avg: 1106.35
# Generasi 491 | Best Fitness: 1030 | avg: 1097.375
# Generasi 492 | Best Fitness: 1030 | avg: 1107.95
# Generasi 493 | Best Fitness: 1030 | avg: 1101.35
# Generasi 494 | Best Fitness: 1030 | avg: 1102.775
# Generasi 495 | Best Fitness: 1030 | avg: 1095.975
# Generasi 496 | Best Fitness: 1030 | avg: 1091.225
# Generasi 497 | Best Fitness: 1030 | avg: 1099.975
# Generasi 498 | Best Fitness: 1030 | avg: 1099.875
# Generasi 499 | Best Fitness: 1030 | avg: 1099.0
# Best Fitness: 1030
# Detail Evaluasi:
# {'guruBentrok': 0, 'distribusiMapel': 17, 'mapelSiang': 1, 'durasiGuru': 14, 'waktuMGMP': 2, 'cekWaliKelas': 11, 'konsistensiGuruMapel': 24}

# %%
best_index = best["index"]

best_mapel = pop_mapel[best_index]
best_guru  = pop_guru[best_index]

# %%
# print(best_mapel[0])
# print(type(best_mapel[0]))

# %% [markdown]
# ---
# # EXPORT FITNESS

# %%
path_file = os.path.join("../hasil/bestFitness", FITNESS_EXPORT)

with open(path_file, mode="w", newline="") as file:

    writer = csv.writer(file)

    writer.writerow(["kelas","slot","mapel","guru"])

    for kelas in range(len(best_mapel)):

        for slot in range(len(best_mapel[kelas])):

            mapel = best_mapel[kelas][slot]
            guru  = best_guru[kelas][slot]

            writer.writerow([
                kelas + 1,
                slot+ 1,
                mapel,
                guru
            ])

# %% [markdown]
# ---
# # Example

# %%
kelas_idx = 1

data = []

for slot in range(SLOT_PER_KELAS):

    mapel_id = best_mapel[kelas_idx, slot]
    guru_id  = best_guru[kelas_idx, slot]
    hari     = slotHari[slot]

    data.append({
        "Slot": slot + 1,
        "Hari": hari,
        "Mapel": mapel_id,
        "Guru": guru_id
    })

df = pd.DataFrame(data)

print(df)
# Out:
#     Slot  Hari  Mapel  Guru
# 0      1     1      5    48
# 1      2     1      5    48
# 2      3     1      4    47
# 3      4     1      4    47
# 4      5     1      6    44
# 5      6     1      6    44
# 6      7     1      6    44
# 7      8     1     13    53
# 8      9     2     13    53
# 9     10     2      3    29
# 10    11     2      3    29
# 11    12     2      3    29
# 12    13     2      4    47
# 13    14     2      4    47
# 14    15     2      7    21
# 15    16     2      7    21
# 16    17     3      7    21
# 17    18     3      5    48
# 18    19     3      5    48
# 19    20     3     11    43
# 20    21     3     11    43
# 21    22     3      3    29
# 22    23     3      3    29
# 23    24     3      1    39
# 24    25     4      1    39
# 25    26     4      2    39
# 26    27     4      2    39
# 27    28     4      9    38
# 28    29     4      9    38
# 29    30     4     12    51
# 30    31     4     12    51
# 31    32     5     12    51
# 32    33     5     10    46
# 33    34     5     10    46
# 34    35     5      8     5
# 35    36     5      8     5

# %% [markdown]
# ---
#
# # Bimbingan

# %% [markdown]
# 12/03/2026
#
# mulai pengerjaan jurnal (UI opsional)
# buku TA
# apakah boleh fitness != 0
# UI nya hanya crud via spreadsheet, yang penting page generate jadwal
# dokumentasikan iterasi untuk diagram garis
# mutasi dan crossover
# minus GWO
# bikin template excell UI untuk CRUD
#
# ===================================================
# before (sistem akbar)
# 21680 awal data masuk
#
# after (sistem akbar)
# 2480 akhir stelah optimasi
#
# hal manual vs digitalize = apakah jadwal lebih oke atau tidak?
# perbandingan runtime GA single vs GA-GWO
#
# SK keluar tgl nya februari
#
# kemudian bisa ngisi bimgingna online

# %% [markdown]
# ---
# # catatan saya
# Generate Population
#
# FOR generation
#
#     Evaluasi Fitness
#
#     GA Operator
#         Selection
#         Crossover
#         Mutation
#
#     GWO Local Search
#         update solusi menuju alpha beta delta
#
#     Repair Operator
#
# END
