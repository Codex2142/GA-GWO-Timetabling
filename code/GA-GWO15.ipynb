# %% [markdown]
# ---
# # Import LiB

# %%
import pandas as pd
import random
from collections import defaultdict, Counter
import numpy as np
import csv
import os

# %% [markdown]
# ---
# # INIT GLOBAL CONST

# %%
POPULASI = 50
ITERATION = 1500
MUTATION_PROB = 0.8
CROSSOVER_PROB = 0.7 
TOURNAMENT_SIZE = 10
SLOT_PER_KELAS = 36
JUMLAH_KELAS = 27
FITNESS_EXPORT = "RUNTIME-GUIDED-GA-GWO.csv" # input user
RECORD_EXPORT = "RUNTIME-GUIDED-GA-GWO.csv" # input user

# %% [markdown]
# ---
# # IMPORT DATA

# %%
guru_df = pd.read_csv('../dataset/guru.csv')
kelas_df = pd.read_csv('../dataset/kelas.csv')
mapel_df = pd.read_csv('../dataset/mapel.csv')
relasi_guru_mapel_df = pd.read_csv('../dataset/relasi_guru_mapel.csv')
slot_df = pd.read_csv('../dataset/slot.csv')
wali_kelas_df = pd.read_csv('../dataset/wali_kelas.csv')

# %% [markdown]
# ---
# # DICT MAKER

# %%
# =========================================================
# Mapping hari -> id
# Digunakan agar proses komputasi lebih cepat dibanding
# menggunakan string nama hari secara langsung.
# =========================================================
hariId = {
    "Senin": 1,
    "Selasa": 2,
    "Rabu": 3,
    "Kamis": 4,
    "Jumat": 5,
}

# =========================================================
# Slot per hari
# Menghitung jumlah slot jam pelajaran untuk setiap hari
# berdasarkan data slot_df.
# Hasilnya akan digunakan saat evaluasi fitness dan
# pembentukan jadwal.
# =========================================================

# Hitung jumlah slot tiap hari dari dataframe slot
slotPerHariDict = slot_df['hari'].value_counts().to_dict()

# Ubah key dari nama hari menjadi id hari
slotPerHariDict = {hariId[k]: v for k, v in slotPerHariDict.items()}

# Disimpan dalam numpy array agar perhitungan evaluasi
# (loop, indexing) lebih cepat
slotPerHari = np.array([
    slotPerHariDict[1],
    slotPerHariDict[2],
    slotPerHariDict[3],
    slotPerHariDict[4],
    slotPerHariDict[5]
])

# =========================================================
# Kelas -> tingkatan
# Mapping setiap kelas dengan tingkatan (misal kelas X, XI, XII)
# Informasi ini penting karena beberapa guru hanya mengajar
# mapel pada tingkatan tertentu.
# =========================================================
kelasTingkatan = dict(
    zip(kelas_df['kelas_id'], kelas_df['tingkatan'])
)

# Ambil seluruh id kelas dan urutkan
kelasIds = np.array(sorted(kelasTingkatan.keys()))

# Jumlah total kelas dalam sistem
JUMLAH_KELAS = len(kelasIds)

# =========================================================
# Mapel -> jam per minggu
# Menyimpan jumlah jam pelajaran setiap mapel per minggu
# =========================================================
jamPerMingguMapel = dict(
    zip(mapel_df['mapel_id'], mapel_df['jam_per_minggu'])
)

# Array id mapel
mapelIds = np.array(list(jamPerMingguMapel.keys()))

# Array jumlah jam tiap mapel
jamMapel = np.array(list(jamPerMingguMapel.values()))

# =========================================================
# MGMP Mapel
# MGMP = waktu rapat guru mapel tertentu
# Mapel tidak boleh dijadwalkan pada hari MGMP tersebut
# =========================================================
mgmpMapel = dict(
    zip(mapel_df['mapel_id'], mapel_df['MGMP'])
)

# Konversi hari MGMP dari string menjadi id hari
mgmpMapel = {
    mapel_id: hariId[hari]
    for mapel_id, hari in mgmpMapel.items()
}

# =========================================================
# Batas slot siang
# Slot setelah batas ini dianggap slot siang.
# Beberapa mapel diusahakan tidak ditempatkan di slot siang.
# =========================================================
batasSiang = np.array([
    5,  # senin
    5,  # selasa
    4,  # rabu
    5,  # kamis
    4   # jumat
])

# =========================================================
# Batas MGMP per hari
# Jumlah maksimum mapel MGMP yang boleh muncul dalam
# satu hari tertentu.
# =========================================================
batasMGMP = np.array([
    2,
    2,
    2,
    2,
    1
])

# =========================================================
# Guru valid untuk mapel + tingkatan
# Membuat relasi guru yang boleh mengajar mapel tertentu
# pada tingkatan tertentu.
# key   = (mapel_id, tingkatan)
# value = list guru yang boleh mengajar
# =========================================================
guruValidMapel = defaultdict(list)

for row in relasi_guru_mapel_df.itertuples():

    # pasangan mapel dan tingkatan
    key = (row.mapel_id, row.tingkatan)

    # tambahkan guru yang memenuhi kriteria
    guruValidMapel[key].append(row.guru_id)

# ubah menjadi dictionary biasa
guruValidMapel = dict(guruValidMapel)

# =========================================================
# Guru mengajar durasi
# Menghitung total beban mengajar setiap guru
# digunakan untuk mengecek constraint durasi guru
# =========================================================
maxJamGuru = (
    relasi_guru_mapel_df
    .groupby("guru_id")["durasi"]
    .sum()
    .to_dict()
)

# =========================================================
# Wali kelas
# Mapping guru yang menjadi wali kelas untuk kelas tertentu.
# Digunakan sebagai constraint tambahan dalam penjadwalan.
# =========================================================
waliKelas = dict(
    zip(wali_kelas_df['guru_id'], wali_kelas_df['kelas_id'])
)

# =========================================================
# Slot -> hari
# Setiap slot memiliki informasi hari ke berapa.
# Digunakan untuk mengetahui posisi hari dari setiap gen
# dalam kromosom.
# =========================================================
slotHari = np.array([
    hariId[row.hari]
    for row in slot_df.itertuples()
])

# Jumlah slot untuk setiap kelas
SLOT_PER_KELAS = len(slotHari)

# =========================================================
# Total gen kromosom
# Dalam representasi GA:
# kromosom = jadwal seluruh kelas
# gen      = satu slot pelajaran
# =========================================================
TOTAL_SLOT = JUMLAH_KELAS * SLOT_PER_KELAS

# =========================================================
# Fitness weight
# Bobot penalti setiap constraint dalam evaluasi fitness.
# Semakin besar bobotnya, semakin penting constraint tersebut.
# =========================================================
fitnessWeight = {
    "guruBentrok": 100,          # guru mengajar di dua kelas pada waktu sama
    "distribusiMapel": 20,       # distribusi mapel tidak merata
    "konsistensiGuruMapel": 20,  # mapel diajar guru berbeda
    "durasiGuru": 10,            # jam mengajar melebihi batas
    "waktuMGMP": 5,              # melanggar jadwal MGMP
    "mapelSiang": 5,             # mapel muncul di slot siang
    "cekWaliKelas": 5            # wali kelas tidak sesuai
}

# =========================================================
# Blok jam mata pelajaran
# Beberapa mapel harus diajarkan secara berurutan
# (misalnya 2 jam berturut-turut).
# Fungsi ini menentukan pembagian blok jam tersebut.
# =========================================================
def blokDistribusi(jam):

    # mapel 2 jam -> 1 blok 2 jam
    if jam == 2:
        return [2]

    # mapel 3 jam -> 1 blok 3 jam
    if jam == 3:
        return [3]

    # mapel 4 jam -> 2 blok (2+2)
    if jam == 4:
        return [2,2]

    # mapel 5 jam -> 2 blok (2+3)
    if jam == 5:
        return [2,3]

    # default
    return [jam]


# ======================================
# slot awal dan akhir hari
# Digunakan untuk mengetahui batas indeks
# slot setiap hari dalam kromosom.
# ======================================

# indeks slot pertama tiap hari
slotAwalHari = np.concatenate(([0], np.cumsum(slotPerHari)[:-1]))

# indeks slot terakhir tiap hari
slotAkhirHari = np.cumsum(slotPerHari)


# ======================================
# blok mapel
# Menyimpan pembagian blok jam untuk
# setiap mata pelajaran.
# ======================================

blokMapel = {}

for mapel_id, jam in jamPerMingguMapel.items():

    # menentukan blok distribusi jam mapel
    blokMapel[mapel_id] = blokDistribusi(jam)

# %% [markdown]
# ---
# # INDIVIDU CONSTRUCT

# %% [markdown]
# ### Generate Per kelas

# %%
def generatePerKelas(tingkatan):

    # list sementara yang berisi blok-blok mapel
    # format: (mapel_id, guru_id, panjang_blok)
    blok_list = []

    # loop semua mata pelajaran yang ada di sistem
    for mapel_id, jam in jamPerMingguMapel.items():

        # ambil daftar guru yang valid untuk:
        # - mapel tersebut
        # - tingkatan kelas tertentu
        guruValid = guruValidMapel.get((mapel_id, tingkatan))

        # jika tidak ada guru yang bisa mengajar mapel ini
        # maka mapel tersebut dilewati
        if not guruValid:
            continue

        # pilih guru secara acak dari guru valid
        # randomisasi ini penting untuk membuat populasi awal GA bervariasi
        guru = random.choice(guruValid)

        # ambil distribusi blok jam mapel
        # contoh:
        # 4 jam -> [2,2]
        # 5 jam -> [2,3]
        blok = blokMapel[mapel_id]
    
        # setiap blok dimasukkan sebagai item dalam list
        for b in blok:
            blok_list.append((mapel_id, guru, b))

    # acak urutan blok mapel
    # agar posisi mapel dalam jadwal tidak selalu sama
    random.shuffle(blok_list)

    # array untuk menyimpan hasil jadwal
    mapel_arr = []
    guru_arr = []

    # konversi blok mapel menjadi slot-slot individu
    for mapel_id, guru, panjang in blok_list:

        # tambahkan mapel sebanyak panjang blok
        # misalnya blok = 2 -> [mapel,mapel]
        mapel_arr.extend([mapel_id]*panjang)

        # guru juga diulang sesuai panjang blok
        guru_arr.extend([guru]*panjang)

    # konversi ke numpy array agar operasi lebih cepat
    mapel_arr = np.array(mapel_arr, dtype=np.int16)
    guru_arr  = np.array(guru_arr, dtype=np.int16)

    # =====================================================
    # memastikan panjang jadwal sesuai jumlah slot kelas
    # =====================================================

    # jika jumlah slot melebihi slot tersedia
    if len(mapel_arr) > SLOT_PER_KELAS:

        # potong ke ukuran yang sesuai
        mapel_arr = mapel_arr[:SLOT_PER_KELAS]
        guru_arr  = guru_arr[:SLOT_PER_KELAS]

    # jika slot masih kurang
    while len(mapel_arr) < SLOT_PER_KELAS:

        # pilih mapel secara acak
        mapel = random.choice(mapelIds)

        # cek apakah ada guru yang bisa mengajar mapel tersebut
        guruValid = guruValidMapel.get((mapel, tingkatan))

        if guruValid:

            # pilih guru secara acak
            guru = random.choice(guruValid)

            # tambahkan ke slot jadwal
            mapel_arr = np.append(mapel_arr, mapel)
            guru_arr  = np.append(guru_arr, guru)

    # return jadwal untuk satu kelas
    return mapel_arr, guru_arr

# %% [markdown]
# ### Membuat individu (1 jadwal penuh)

# %%
def individuConstruct():

    # Membuat matriks kosong untuk menyimpan jadwal mapel dan guru
    # Dimensi:
    # baris  = jumlah kelas
    # kolom  = jumlah slot waktu per kelas
    #
    # mapel_matrix -> menyimpan ID mata pelajaran pada setiap slot
    # guru_matrix  -> menyimpan ID guru yang mengajar pada slot tersebut
    mapel_matrix = np.zeros((JUMLAH_KELAS, SLOT_PER_KELAS), dtype=np.int16)
    guru_matrix  = np.zeros((JUMLAH_KELAS, SLOT_PER_KELAS), dtype=np.int16)

    # Loop setiap kelas yang ada di sistem
    # enumerate digunakan agar kita mendapatkan:
    # i        -> index baris pada matrix
    # kelas_id -> id kelas sebenarnya
    for i, kelas_id in enumerate(kelasIds):

        # Ambil tingkatan kelas
        # Contoh: kelas 10A -> tingkatan 10
        # Tingkatan ini digunakan untuk menentukan
        # guru yang boleh mengajar mapel tertentu
        tingkatan = kelasTingkatan[kelas_id]

        # Generate jadwal untuk satu kelas
        # fungsi ini akan menghasilkan:
        # mapel_row -> array mapel sepanjang SLOT_PER_KELAS
        # guru_row  -> array guru sepanjang SLOT_PER_KELAS
        mapel_row, guru_row = generatePerKelas(tingkatan)

        # Masukkan hasil jadwal tersebut ke baris matrix
        # sehingga setiap baris mewakili satu kelas
        mapel_matrix[i] = mapel_row
        guru_matrix[i]  = guru_row

    # Return satu individu jadwal lengkap
    # yang terdiri dari:
    # - matrix mapel
    # - matrix guru
    return mapel_matrix, guru_matrix

# %% [markdown]
# ### Membuat Populasi

# %%
def generatePopulation(POPULASI):

    # Membuat array 3 dimensi untuk menyimpan populasi jadwal
    #
    # Dimensi:
    # POPULASI      -> jumlah individu dalam populasi GA
    # JUMLAH_KELAS  -> jumlah kelas dalam sistem
    # SLOT_PER_KELAS -> jumlah slot waktu per kelas
    #
    # pop_mapel menyimpan mata pelajaran
    # pop_guru menyimpan guru yang mengajar
    pop_mapel = np.zeros((POPULASI, JUMLAH_KELAS, SLOT_PER_KELAS), dtype=np.int16)
    pop_guru  = np.zeros((POPULASI, JUMLAH_KELAS, SLOT_PER_KELAS), dtype=np.int16)

    # Loop untuk membuat setiap individu dalam populasi
    for i in range(POPULASI):

        # Membuat satu individu jadwal lengkap
        # fungsi ini menghasilkan:
        # mapel_matrix -> jadwal mapel seluruh kelas
        # guru_matrix  -> jadwal guru seluruh kelas
        mapel_matrix, guru_matrix = individuConstruct()

        # Simpan individu ke dalam populasi
        # indeks i menunjukkan individu ke-i
        pop_mapel[i] = mapel_matrix
        pop_guru[i]  = guru_matrix

    # Return populasi awal
    # pop_mapel dan pop_guru berisi seluruh individu jadwal
    return pop_mapel, pop_guru

# %%
# Memanggil fungsi untuk membangkitkan populasi
pop_mapel, pop_guru = generatePopulation(POPULASI)

# %% [markdown]
# ### Debug

# %%
kelas = 0
ind = 0

print("Mapel kelas", kelas+1)
print(pop_mapel[ind, kelas])

print("Guru kelas", kelas+1)
print(pop_guru[ind, kelas])
# Out:
# Mapel kelas 1
# [ 4  4  6  6  6  5  5  4  4  7  7  7 12 12 12  1  1  3  3  3  3  3 10 10
#  13 13  5  5  2  2  8  8  9  9 11 11]
# Guru kelas 1
# [19 19  2  2  2 27 27 19 19 37 37 37 51 51 51 31 31 36 36 36 36 36 15 15
#  53 53 27 27 39 39 17 17 38 38 43 43]

# %% [markdown]
# ---
# # EVAL

# %% [markdown]
# ### Guru Bentrok

# %%
def guruBentrok(guru_matrix):

        # Variabel untuk menghitung total pelanggaran bentrok guru
        pelanggaran = 0

        # Loop setiap slot waktu
        # SLOT_PER_KELAS merepresentasikan jumlah slot waktu dalam satu hari/minggu
        # yang sama untuk semua kelas
        for slot in range(SLOT_PER_KELAS):

            # Ambil semua guru yang mengajar pada slot waktu yang sama
            # guru_matrix memiliki bentuk:
            # (JUMLAH_KELAS, SLOT_PER_KELAS)
            # guru_matrix[:, slot] berarti:
            # semua kelas pada slot waktu yang sama
            guruSlot = guru_matrix[:, slot]

            # Mengambil nilai guru yang unik
            # Jika tidak ada bentrok maka jumlah unik = jumlah kelas
            unik = np.unique(guruSlot)

            # Hitung jumlah bentrok
            # Contoh:
            # guruSlot = [3, 5, 3, 7]
            # artinya guru 3 mengajar di dua kelas pada waktu yang sama
            # unik = [3,5,7]
            # bentrok = 4 - 3 = 1
            pelanggaran += len(guruSlot) - len(unik)

        # Mengembalikan total jumlah konflik guru
        return pelanggaran

# %% [markdown]
# ### Durasi GUru mengajar

# %%
def durasiGuru(guru_matrix, maxJamGuru):

    # Variabel untuk menghitung total pelanggaran
    # Pelanggaran terjadi jika total jam mengajar guru
    # melebihi batas maksimal yang diperbolehkan
    pelanggaran = 0

    # Mengubah matrix guru menjadi array 1 dimensi
    # sehingga seluruh slot dari semua kelas digabung
    # contoh:
    # guru_matrix.shape = (10 kelas, 36 slot)
    # flatten() -> array 360 slot
    semuaGuru = guru_matrix.flatten()

    # Menghitung jumlah kemunculan setiap guru
    # guru_ids -> daftar guru unik
    # counts   -> jumlah slot yang diajar oleh guru tersebut
    # contoh:
    # guru_ids = [1,2,3]
    # counts   = [40,35,28]
    guru_ids, counts = np.unique(semuaGuru, return_counts=True)

    # Loop setiap guru yang muncul dalam jadwal
    for guru, jam in zip(guru_ids, counts):

        # Ambil batas maksimal jam mengajar guru
        # dari dictionary maxJamGuru
        # jika guru tidak ditemukan maka default = 0
        max_jam = maxJamGuru.get(guru, 0)

        # Jika jam mengajar melebihi batas
        if jam > max_jam:

            # Tambahkan selisihnya sebagai pelanggaran
            # contoh:
            # jam = 30
            # max_jam = 24
            # pelanggaran = 6
            pelanggaran += (jam - max_jam)

    # Return total pelanggaran durasi guru
    return pelanggaran

# %% [markdown]
# ### Distribusi Mapel

# %%
def hitungBlok(slots):

    # Mengurutkan slot agar mudah mendeteksi slot yang berurutan
    # contoh: [5,2,3] -> [2,3,5]
    slots = sorted(slots)

    # list untuk menyimpan panjang setiap blok berurutan
    blok = []

    # panjang blok saat ini
    panjang = 1

    # loop dari slot kedua sampai terakhir
    for i in range(1,len(slots)):

        # jika slot sekarang berurutan dengan slot sebelumnya
        # contoh: 3 setelah 2
        if slots[i] == slots[i-1] + 1:
            panjang += 1

        else:
            # jika tidak berurutan maka blok sebelumnya selesai
            blok.append(panjang)

            # mulai blok baru
            panjang = 1

    # masukkan blok terakhir
    blok.append(panjang)

    # contoh output:
    # slots = [2,3,5,6,7]
    # blok  = [2,3]
    return blok



def distribusiMapel(mapel_matrix):

    # menghitung total pelanggaran distribusi mapel
    pelanggaran = 0

    # loop setiap kelas
    for kelas in range(JUMLAH_KELAS):

        # ambil jadwal mapel untuk kelas tersebut
        jadwal = mapel_matrix[kelas]

        # dictionary untuk menyimpan slot setiap mapel
        # key   = mapel_id
        # value = daftar slot
        mapelSlot = defaultdict(list)

        # loop setiap slot pada jadwal
        for slot, mapel in enumerate(jadwal):

            # simpan slot kemunculan mapel
            mapelSlot[mapel].append(slot)

        # cek setiap mapel dalam kelas tersebut
        for mapel, slots in mapelSlot.items():

            # ambil distribusi blok yang diharapkan
            # contoh:
            # mapel 4 jam -> [2,2]
            blok_expected = blokMapel.get(mapel, [])

            # jika hanya 1 blok maka tidak perlu dicek distribusi
            # contoh: 2 jam -> [2]
            if len(blok_expected) <= 1:
                continue

            # hitung blok aktual dari jadwal
            # contoh:
            # slots = [1,2,5,6]
            # blok_real = [2,2]
            blok_real = hitungBlok(slots)

            # cek apakah distribusi blok sesuai
            # sorted digunakan agar urutan blok tidak masalah
            if sorted(blok_real) != sorted(blok_expected):

                # jika tidak sesuai maka pelanggaran bertambah
                pelanggaran += 1

            # cek distribusi hari
            # ambil hari dari setiap slot
            hariSet = set(slotHari[s] for s in slots)

            # jika jumlah hari kurang dari jumlah blok
            # berarti ada blok mapel yang berada di hari yang sama
            if len(hariSet) < len(blok_expected):

                # tambahkan pelanggaran
                pelanggaran += 1

    # return total pelanggaran distribusi mapel
    return pelanggaran

# %% [markdown]
# ### Mapel PJOK

# %%
def mapelSiang(mapel_matrix):

    # ID mata pelajaran yang tidak diinginkan berada di slot siang
    # contoh: mapel tertentu seperti olahraga
    # mapel berat sering dihindari di jam terakhir
    TARGET_MAPEL = 8

    # variabel untuk menghitung total pelanggaran
    pelanggaran = 0

    # loop semua slot waktu dalam satu minggu
    for slot in range(SLOT_PER_KELAS):

        # ambil hari dari slot tersebut
        # slotHari menyimpan mapping slot -> hari
        hari = slotHari[slot]

        # ambil batas slot siang untuk hari tersebut
        # contoh:
        # senin batas = 5
        batas = batasSiang[hari-1]

        # menghitung slot keberapa dalam hari tersebut
        #
        # contoh:
        # slot global = 14
        # slot awal hari = 12
        # slotHariKe = 2
        slotHariKe = slot - slotAwalHari[hari-1]

        # jika slot masih sebelum batas siang
        # maka tidak perlu dicek
        if slotHariKe < batas:
            continue

        # jika sudah melewati batas siang
        # maka hitung jumlah TARGET_MAPEL pada slot tersebut
        # mapel_matrix[:, slot] -> semua kelas pada slot yang sama
        # contoh:
        # [8,3,8,5]
        # berarti ada 2 pelanggaran
        pelanggaran += np.sum(mapel_matrix[:, slot] == TARGET_MAPEL)

    # return total pelanggaran mapel siang
    return pelanggaran

# %% [markdown]
# ### Waktu MGMP

# %%
def waktuMGMP(mapel_matrix):

    # Variabel untuk menghitung total pelanggaran
    pelanggaran = 0

    # Loop setiap kelas
    for kelas in range(JUMLAH_KELAS):

        # Ambil jadwal mapel untuk kelas tersebut
        jadwal = mapel_matrix[kelas]

        # Loop setiap mapel yang memiliki aturan MGMP
        # mgmpMapel berisi mapping:
        # mapel_id -> hari MGMP
        for mapel, hariMGMP in mgmpMapel.items():

            # Mengubah hari MGMP menjadi index array (0-based)
            hari_idx = hariMGMP - 1

            # Menentukan batas slot awal dan akhir hari tersebut
            # agar hanya slot di hari MGMP yang diperiksa
            start = slotAwalHari[hari_idx]
            end   = slotAkhirHari[hari_idx]

            # Menghitung berapa kali mapel tersebut muncul
            # pada hari MGMP untuk kelas ini
            jumlah = np.sum(jadwal[start:end] == mapel)

            # Jika jumlah kemunculan melebihi batas yang diperbolehkan
            if jumlah > batasMGMP[hari_idx]:

                # Tambahkan selisihnya sebagai pelanggaran
                pelanggaran += jumlah - batasMGMP[hari_idx]

    # Return total pelanggaran MGMP
    return pelanggaran

# %% [markdown]
# ### Wali Kelas

# %%
def cekWaliKelas(guru_matrix):

    # Variabel untuk menghitung total pelanggaran
    pelanggaran = 0

    # Loop setiap pasangan wali kelas
    # waliKelas berisi mapping:
    # guru_id -> kelas_id
    for guru, kelas in waliKelas.items():

        # Mengecek apakah guru tersebut mengajar di kelas yang menjadi wali-nya
        # guru_matrix[kelas-1] mengambil seluruh slot pada kelas tersebut
        # kelas-1 digunakan karena index array dimulai dari 0
        # contoh:
        # kelas = 3 -> index = 2
        if guru not in guru_matrix[kelas-1]:

            # Jika guru wali tidak mengajar di kelasnya sama sekali
            # maka dianggap pelanggaran
            pelanggaran += 1

    # Return total pelanggaran wali kelas
    return pelanggaran

# %% [markdown]
# ### Konsistensi GUru mapel

# %%
def konsistensiGuruMapel(mapel_matrix, guru_matrix):

    # Variabel untuk menghitung total pelanggaran
    pelanggaran = 0

    # Loop setiap kelas
    for kelas in range(JUMLAH_KELAS):

        # Ambil jadwal mapel dan guru untuk kelas tersebut
        jadwalMapel = mapel_matrix[kelas]
        jadwalGuru  = guru_matrix[kelas]

        # Ambil daftar mapel unik yang muncul di kelas tersebut
        # agar tidak mengecek mapel yang sama berulang kali
        for mapel in np.unique(jadwalMapel):

            # Ambil semua guru yang mengajar mapel tersebut
            # jadwalMapel == mapel -> menghasilkan mask boolean
            # kemudian digunakan untuk memilih guru yang mengajar mapel itu
            guruSet = np.unique(jadwalGuru[jadwalMapel == mapel])

            # Jika lebih dari satu guru mengajar mapel yang sama
            # maka terjadi pelanggaran konsistensi
            if len(guruSet) > 1:

                # Tambahkan selisih jumlah guru sebagai pelanggaran
                # contoh:
                # guruSet = [3,7]
                # pelanggaran = 1
                # guruSet = [3,7,8]
                # pelanggaran = 2
                pelanggaran += len(guruSet) - 1

    # Return total pelanggaran konsistensi guru-mapel
    return pelanggaran

# %% [markdown]
# ### main eval

# %%
def evaluasiIndividu(mapel_matrix, guru_matrix, maxJamGuru):

    # Fungsi ini mengevaluasi satu individu jadwal (satu solusi)
    # dengan menghitung jumlah pelanggaran untuk setiap constraint.

    # mapel_matrix : matriks mata pelajaran
    # baris = kelas
    # kolom = slot waktu

    # guru_matrix : matriks guru yang mengajar
    # strukturnya sama dengan mapel_matrix

    # maxJamGuru : dictionary yang berisi batas maksimal jam mengajar tiap guru

    # Fungsi mengembalikan dictionary yang berisi jumlah pelanggaran
    # untuk setiap jenis constraint

    return {

        # Mengecek apakah ada guru yang mengajar di lebih dari satu kelas
        # pada slot waktu yang sama
        "guruBentrok": guruBentrok(guru_matrix),

        # Mengecek apakah distribusi jam mata pelajaran sesuai dengan
        # blok yang seharusnya (misalnya 2+1 jam atau 3 jam)
        "distribusiMapel": distribusiMapel(mapel_matrix),

        # Mengecek apakah mata pelajaran tertentu muncul di jam siang
        # yang seharusnya dihindari
        "mapelSiang": mapelSiang(mapel_matrix),

        # Mengecek apakah total jam mengajar guru melebihi batas maksimum
        "durasiGuru": durasiGuru(guru_matrix, maxJamGuru),

        # Mengecek aturan MGMP, misalnya jumlah maksimal mapel tertentu
        # dalam satu hari
        "waktuMGMP": waktuMGMP(mapel_matrix),

        # Mengecek apakah wali kelas mengajar di kelasnya sendiri
        "cekWaliKelas": cekWaliKelas(guru_matrix),

        # Mengecek apakah satu mapel dalam satu kelas diajar oleh lebih
        # dari satu guru (harusnya konsisten satu guru)
        "konsistensiGuruMapel": konsistensiGuruMapel(mapel_matrix, guru_matrix)
    }

# %% [markdown]
# ### Looping setiap individu

# %%
def hitungFitness(hasilEvaluasi):

    # Variabel untuk menyimpan total nilai fitness
    # Fitness biasanya merepresentasikan total penalti dari semua pelanggaran
    fitness = 0

    # Melakukan iterasi pada setiap jenis constraint
    # hasilEvaluasi berupa dictionary seperti:
    # {
    #   "guruBentrok": 5,
    #   "distribusiMapel": 3,
    #   "mapelSiang": 1,
    # }

    for k, v in hasilEvaluasi.items():

        # k = nama constraint
        # v = jumlah pelanggaran constraint tersebut

        # fitnessWeight adalah dictionary berisi bobot tiap constraint
        # contoh:
        # fitnessWeight = {
        #     "guruBentrok": 100,
        #     "distribusiMapel": 20,
        #     "mapelSiang": 5,
        # }

        # Pelanggaran dikalikan dengan bobot constraint
        # lalu ditambahkan ke total fitness
        fitness += fitnessWeight[k] * v

    # Mengembalikan total fitness
    # Semakin kecil nilai fitness -> semakin baik solusi jadwal
    return fitness

# %% [markdown]
# ### Menyimpan hasil eval tiap individu

# %%
def evaluasiPopulasi(pop_mapel, pop_guru, maxJamGuru):

    # List untuk menyimpan hasil evaluasi setiap individu dalam populasi
    hasilPopulasi = []

    # pop_mapel.shape[0] = jumlah individu dalam populasi
    # setiap individu adalah satu kandidat solusi jadwal
    for i in range(pop_mapel.shape[0]):

        # Mengambil jadwal mapel dari individu ke-i
        # bentuknya matrix: kelas × slot
        mapel_matrix = pop_mapel[i]

        # Mengambil jadwal guru dari individu ke-i
        # strukturnya sama dengan mapel_matrix
        guru_matrix  = pop_guru[i]

        # Mengevaluasi individu menggunakan semua constraint
        # hasilnya berupa dictionary jumlah pelanggaran
        evaluasi = evaluasiIndividu(mapel_matrix, guru_matrix, maxJamGuru)

        # Menghitung nilai fitness berdasarkan jumlah pelanggaran
        # dan bobot masing-masing constraint
        fitness = hitungFitness(evaluasi)

        # Menyimpan hasil evaluasi individu dalam bentuk dictionary
        hasilPopulasi.append({
            "fitness": fitness,     # nilai fitness individu
            "evaluasi": evaluasi,   # detail pelanggaran constraint
            "index": i              # posisi individu dalam populasi
        })

    # Mengembalikan seluruh hasil evaluasi populasi
    return hasilPopulasi

# %%
hasil = evaluasiPopulasi(pop_mapel, pop_guru, maxJamGuru)

# %% [markdown]
# ### Output debug

# %%
# best = min(hasil, key=lambda x: x["fitness"])

# print("Best Fitness:", best["fitness"])
# print("Detail Evaluasi:")
# print(best["evaluasi"])

# %% [markdown]
# ---
# # GA

# %% [markdown]
# ### Tournament

# %%
def tournamentSelection(pop_mapel, pop_guru, hasilPopulasi):

    # Mengambil beberapa individu secara acak dari populasi
    # jumlah individu yang diambil ditentukan oleh TOURNAMENT_SIZE
    # contoh: jika TOURNAMENT_SIZE = 3 maka akan dipilih 3 kandidat secara acak
    kandidat = random.sample(hasilPopulasi, TOURNAMENT_SIZE)

    # Dari kandidat tersebut dipilih individu dengan fitness terbaik
    # min digunakan karena dalam timetabling fitness yang lebih kecil lebih baik
    terbaik = min(kandidat, key=lambda x: x["fitness"])

    # Mengambil index individu terbaik dalam populasi
    idx = terbaik["index"]

    # Mengembalikan jadwal mapel dan guru dari individu terpilih
    # .copy() digunakan agar perubahan pada offspring tidak mengubah parent asli
    return pop_mapel[idx].copy(), pop_guru[idx].copy()

# %% [markdown]
# ### Crossover

# %%
def crossover(parent1_mapel, parent1_guru, parent2_mapel, parent2_guru):

    # Menentukan titik pemotongan crossover berdasarkan jumlah kelas
    # split berada di antara 1 sampai JUMLAH_KELAS-1
    # artinya sebagian kelas diambil dari parent1 dan sisanya dari parent2
    split = random.randint(1, JUMLAH_KELAS - 1)

    # Membuat matriks anak dengan ukuran yang sama seperti parent
    # diinisialisasi dengan nilai 0
    child1_mapel = np.zeros_like(parent1_mapel)
    child1_guru  = np.zeros_like(parent1_guru)

    child2_mapel = np.zeros_like(parent1_mapel)
    child2_guru  = np.zeros_like(parent1_guru)

    # Membentuk child1:
    # kelas sebelum titik split diambil dari parent1
    child1_mapel[:split] = parent1_mapel[:split]

    # kelas setelah titik split diambil dari parent2
    child1_mapel[split:] = parent2_mapel[split:]

    # Guru mengikuti struktur yang sama dengan mapel
    child1_guru[:split] = parent1_guru[:split]
    child1_guru[split:] = parent2_guru[split:]

    # Membentuk child2:
    # kebalikan dari child1
    # kelas sebelum split dari parent2
    child2_mapel[:split] = parent2_mapel[:split]

    # kelas setelah split dari parent1
    child2_mapel[split:] = parent1_mapel[split:]

    # Guru mengikuti struktur yang sama dengan mapel
    child2_guru[:split] = parent2_guru[:split]
    child2_guru[split:] = parent1_guru[split:]

    # Mengembalikan dua anak hasil crossover
    return child1_mapel, child1_guru, child2_mapel, child2_guru

# %% [markdown]
# ### Mutasi

# %%
def mutasi(mapel_matrix, guru_matrix):

    # Mengevaluasi individu untuk mengetahui jumlah pelanggaran tiap constraint
    evaluasi = evaluasiIndividu(mapel_matrix, guru_matrix, maxJamGuru)

    # Menentukan constraint yang memiliki pelanggaran paling besar
    # constraint ini akan menjadi target mutasi
    constraint = max(evaluasi, key=evaluasi.get)

    # Memilih kelas secara acak yang akan dimodifikasi
    kelas = random.randint(0, JUMLAH_KELAS - 1)

    # Jika pelanggaran terbesar berasal dari distribusi mapel
    if constraint == "distribusiMapel":

        # Memilih dua slot berurutan untuk ditukar
        slot1 = random.randint(0, SLOT_PER_KELAS - 2)
        slot2 = slot1 + 1

        # Menukar posisi mapel pada dua slot tersebut
        mapel_matrix[kelas,slot1], mapel_matrix[kelas,slot2] = \
            mapel_matrix[kelas,slot2], mapel_matrix[kelas,slot1]

        # Menukar guru yang mengajar pada slot yang sama
        guru_matrix[kelas,slot1], guru_matrix[kelas,slot2] = \
            guru_matrix[kelas,slot2], guru_matrix[kelas,slot1]

    # Jika pelanggaran terbesar adalah guru bentrok
    elif constraint == "guruBentrok":

        # Memilih slot acak pada kelas tersebut
        slot = random.randint(0, SLOT_PER_KELAS-1)

        # Mengambil mapel pada slot tersebut
        mapel = mapel_matrix[kelas,slot]

        # Menentukan tingkatan kelas (misalnya kelas 10,11,12)
        tingkatan = kelasTingkatan[kelasIds[kelas]]

        # Mengambil daftar guru yang valid untuk mapel dan tingkatan tersebut
        guruValid = guruValidMapel.get((mapel, tingkatan))

        # Jika ada guru yang valid
        if guruValid:

            # Mengganti guru dengan salah satu guru valid secara acak
            guru_matrix[kelas,slot] = random.choice(guruValid)

    # Jika constraint lain yang dominan
    else:

        # Memilih dua slot acak dalam satu kelas
        slot1 = random.randint(0, SLOT_PER_KELAS - 1)
        slot2 = random.randint(0, SLOT_PER_KELAS - 1)

        # Menukar posisi mapel antara dua slot tersebut
        mapel_matrix[kelas,slot1], mapel_matrix[kelas,slot2] = \
            mapel_matrix[kelas,slot2], mapel_matrix[kelas,slot1]

        # Menukar guru pada slot yang sama
        guru_matrix[kelas,slot1], guru_matrix[kelas,slot2] = \
            guru_matrix[kelas,slot2], guru_matrix[kelas,slot1]

    # Mengembalikan individu yang telah dimutasi
    return mapel_matrix, guru_matrix

# %% [markdown]
# ### Repair

# %%
def repairOperator(mapel_matrix, guru_matrix):

    # Mengevaluasi individu untuk mengetahui jumlah pelanggaran constraint
    evaluasi = evaluasiIndividu(mapel_matrix, guru_matrix, maxJamGuru)

    # Repair hanya dilakukan jika terdapat pelanggaran guru bentrok
    if evaluasi["guruBentrok"] > 0:

        # Iterasi setiap slot waktu
        for slot in range(SLOT_PER_KELAS):

            # Mengambil semua guru yang mengajar pada slot tersebut
            # (dari semua kelas pada waktu yang sama)
            guruSlot = guru_matrix[:,slot]

            # Mengambil guru unik dan jumlah kemunculannya
            unik, counts = np.unique(guruSlot, return_counts=True)

            # Mendeteksi guru yang muncul lebih dari sekali pada slot yang sama
            # artinya guru tersebut mengajar di lebih dari satu kelas
            bentrok = unik[counts > 1]

            # Memproses setiap guru yang mengalami bentrok
            for g in bentrok:

                # Mencari kelas mana saja yang menggunakan guru tersebut
                kelasBentrok = np.where(guruSlot == g)[0]

                # Memilih salah satu kelas secara acak untuk diperbaiki
                kelas = random.choice(kelasBentrok)

                # Mengambil mapel pada kelas dan slot tersebut
                mapel = mapel_matrix[kelas,slot]

                # Menentukan tingkatan kelas (misal kelas 10, 11, 12)
                tingkatan = kelasTingkatan[kelasIds[kelas]]

                # Mengambil daftar guru yang valid untuk mapel dan tingkatan ini
                guruValid = guruValidMapel.get((mapel, tingkatan))

                # Jika ada guru yang valid
                if guruValid:

                    # Mengganti guru yang bentrok dengan guru valid lain secara acak
                    guru_matrix[kelas,slot] = random.choice(guruValid)

    # Mengembalikan jadwal yang telah diperbaiki
    return mapel_matrix, guru_matrix

# %% [markdown]
# ---
# # GWO

# %%
def runGWO(pop_mapel, pop_guru, hasilPop, iter_gwo=0, max_iter=20):

    hasilSorted = sorted(hasilPop, key=lambda x: x["fitness"])

    alpha = hasilSorted[0]["index"]
    beta  = hasilSorted[1]["index"]
    delta = hasilSorted[2]["index"]

    alpha_mapel = pop_mapel[alpha]
    alpha_guru  = pop_guru[alpha]

    beta_mapel = pop_mapel[beta]
    beta_guru  = pop_guru[beta]

    delta_mapel = pop_mapel[delta]
    delta_guru  = pop_guru[delta]

    # parameter convergence GWO
    a = 2 * (1 - (iter_gwo / max_iter))

    new_pop_mapel = []
    new_pop_guru  = []

    for i in range(len(pop_mapel)):

        mapel = pop_mapel[i].copy()
        guru  = pop_guru[i].copy()

        # elitism
        if i == alpha:
            new_pop_mapel.append(mapel)
            new_pop_guru.append(guru)
            continue

        # ===============================
        # pilih beberapa kelas sekaligus
        # ===============================
        kelas_list = random.sample(range(JUMLAH_KELAS), k=3)

        for kelas in kelas_list:

            # pilih hari random
            hari = random.randint(0,4)

            start = slotAwalHari[hari]
            end   = slotAkhirHari[hari]

            # ukuran segmen
            panjang = end-start
            size = random.randint(1, max(2, panjang//2))
            s = random.randint(start, end-size)

            for slot in range(s, s+size):

                # ===============================
                # GWO voting (alpha beta delta)
                # ===============================

                kandidat_mapel = [
                    alpha_mapel[kelas,slot],
                    beta_mapel[kelas,slot],
                    delta_mapel[kelas,slot]
                ]

                kandidat_guru = [
                    alpha_guru[kelas,slot],
                    beta_guru[kelas,slot],
                    delta_guru[kelas,slot]
                ]

                # majority vote
                mapel_vote = Counter(kandidat_mapel).most_common(1)[0][0]
                guru_vote  = Counter(kandidat_guru).most_common(1)[0][0]

                # eksplorasi jika a besar
                if random.random() < a/2:
                    mapel[kelas,slot] = mapel_vote
                    guru[kelas,slot]  = guru_vote

                # eksplorasi random
                else:
                    tingkatan = kelasTingkatan[kelasIds[kelas]]
                    guruValid = guruValidMapel.get((mapel_vote, tingkatan))

                    if guruValid:
                        mapel[kelas,slot] = mapel_vote
                        guru[kelas,slot]  = random.choice(guruValid)

        # ===============================
        # local improvement swap
        # ===============================

        if random.random() < 0.5:

            kelas = random.randint(0,JUMLAH_KELAS-1)
            slot1 = random.randint(0,SLOT_PER_KELAS-1)
            slot2 = random.randint(0,SLOT_PER_KELAS-1)

            mapel[kelas,slot1], mapel[kelas,slot2] = mapel[kelas,slot2], mapel[kelas,slot1]
            guru[kelas,slot1],  guru[kelas,slot2]  = guru[kelas,slot2],  guru[kelas,slot1]

        # repair constraint
        mapel, guru = repairOperator(mapel, guru)

        # ===============================
        # accept only if better
        # ===============================

        oldFitness = hasilPop[i]["fitness"]

        evaluasi = evaluasiIndividu(mapel, guru, maxJamGuru)
        newFitness = hitungFitness(evaluasi)

        if newFitness <= oldFitness:
            new_pop_mapel.append(mapel)
            new_pop_guru.append(guru)
        else:
            new_pop_mapel.append(pop_mapel[i])
            new_pop_guru.append(pop_guru[i])

    return np.array(new_pop_mapel), np.array(new_pop_guru)

# %% [markdown]
# # MAIN

# %%
def runGA():

    # Membuat populasi awal jadwal mapel dan guru
    pop_mapel, pop_guru = generatePopulation(POPULASI)

    # Mengevaluasi seluruh populasi awal
    hasilPop = evaluasiPopulasi(pop_mapel, pop_guru, maxJamGuru)

    # Menyimpan fitness terbaik global
    bestFitness = float("inf")

    # Menyimpan log perkembangan fitness
    log_data = []

    # Iterasi utama algoritma
    for gen in range(ITERATION):

        # laoding efffect nang kene

        # Menyimpan populasi baru hasil GA
        new_pop_mapel = []
        new_pop_guru  = []

        # ==========================
        # PROSES GA
        # ==========================

        # Membuat populasi baru sampai jumlah individu terpenuhi
        while len(new_pop_mapel) < POPULASI:

            # Memilih parent menggunakan tournament selection
            p1_mapel, p1_guru = tournamentSelection(pop_mapel, pop_guru, hasilPop)
            p2_mapel, p2_guru = tournamentSelection(pop_mapel, pop_guru, hasilPop)

            # Jika memenuhi probabilitas crossover
            if random.random() < CROSSOVER_PROB:

                # Melakukan class-based crossover
                c1_mapel, c1_guru, c2_mapel, c2_guru = crossover(
                    p1_mapel, p1_guru, p2_mapel, p2_guru
                )

            else:

                # Jika tidak crossover, anak adalah copy dari parent
                c1_mapel, c1_guru = p1_mapel.copy(), p1_guru.copy()
                c2_mapel, c2_guru = p2_mapel.copy(), p2_guru.copy()

            # Mutasi anak pertama jika memenuhi probabilitas mutasi
            if random.random() < MUTATION_PROB:
                c1_mapel, c1_guru = mutasi(c1_mapel, c1_guru)

            # Mutasi anak kedua
            if random.random() < MUTATION_PROB:
                c2_mapel, c2_guru = mutasi(c2_mapel, c2_guru)

            # Repair untuk memperbaiki pelanggaran constraint
            c1_mapel, c1_guru = repairOperator(c1_mapel, c1_guru)
            c2_mapel, c2_guru = repairOperator(c2_mapel, c2_guru)

            # Menambahkan anak pertama ke populasi baru
            new_pop_mapel.append(c1_mapel)
            new_pop_guru.append(c1_guru)

            # Menambahkan anak kedua jika populasi belum penuh
            if len(new_pop_mapel) < POPULASI:
                new_pop_mapel.append(c2_mapel)
                new_pop_guru.append(c2_guru)

        # Mengganti populasi lama dengan populasi baru
        pop_mapel = np.array(new_pop_mapel)
        pop_guru  = np.array(new_pop_guru)

        # Mengevaluasi populasi baru
        hasilPop = evaluasiPopulasi(pop_mapel, pop_guru, maxJamGuru)

        # ==========================
        # PROSESS GWO
        # ==========================

        # Setiap 20 generasi dilakukan fase optimasi GWO
        if gen % 20 == 0 and gen != 0:

            print("----- GWO PHASE -----")

            # Melakukan iterasi GWO sebanyak 20 kali
            for iter_gwo in range(20):

                # Update posisi populasi menggunakan Grey Wolf Optimizer
                pop_mapel, pop_guru = runGWO(pop_mapel, pop_guru, hasilPop)

                # Evaluasi kembali populasi hasil GWO
                hasilPop = evaluasiPopulasi(pop_mapel, pop_guru, maxJamGuru)

                # Mengambil fitness terbaik dalam populasi
                best_gwo = min(x["fitness"] for x in hasilPop)

                # Menghitung rata-rata fitness populasi
                avg_gwo  = sum(x["fitness"] for x in hasilPop) / len(hasilPop)

                # Menyimpan log GWO
                log_data.append([gen, "GWO", best_gwo, avg_gwo])

                print("GWO Iter", iter_gwo,"Best:", best_gwo,"Avg:", round(avg_gwo))

        # ==========================
        # BEST FITNESS
        # ==========================

        # Mengambil individu terbaik dalam populasi
        best = min(hasilPop, key=lambda x: x["fitness"])

        # Menghitung rata-rata fitness populasi
        avg = np.mean([x['fitness'] for x in hasilPop])

        # Update best global fitness jika ditemukan yang lebih baik
        if best["fitness"] < bestFitness:
            bestFitness = best["fitness"]

        # Menyimpan log GA
        log_data.append([gen,"GA", bestFitness, avg])

        # Menampilkan progress generasi
        print("Generasi", gen, "| Best Fitness:", bestFitness, "| avg:", avg)

    # ==========================
    # OUTPUT
    # ==========================

    # Menentukan path file untuk menyimpan log
    path_file = os.path.join("../hasil/record", RECORD_EXPORT)

    # Menyimpan log fitness ke file CSV
    with open(path_file, mode="w", newline="") as file:

        writer = csv.writer(file)

        # Header kolom
        writer.writerow(["iterasi", "method","best", "avg"])

        # Data log
        writer.writerows(log_data)

    # Mengembalikan individu terbaik
    return best

# %% [markdown]
# ### Main Call

# %%
best = runGA()

print("Best Fitness:", best["fitness"])
print("Detail Evaluasi:")
print(best["evaluasi"])
# Out:
# Generasi 0 | Best Fitness: 16120 | avg: 17621.8
# Generasi 1 | Best Fitness: 13230 | avg: 14906.9
# Generasi 2 | Best Fitness: 11720 | avg: 13191.2
# Generasi 3 | Best Fitness: 11000 | avg: 12197.4
# Generasi 4 | Best Fitness: 10430 | avg: 11041.6
# Generasi 5 | Best Fitness: 9795 | avg: 10459.7
# Generasi 6 | Best Fitness: 9520 | avg: 10057.8
# Generasi 7 | Best Fitness: 9370 | avg: 9707.4
# Generasi 8 | Best Fitness: 9160 | avg: 9505.4
# Generasi 9 | Best Fitness: 9015 | avg: 9352.5
# Generasi 10 | Best Fitness: 8925 | avg: 9245.9
# Generasi 11 | Best Fitness: 8755 | avg: 9025.0
# Generasi 12 | Best Fitness: 8665 | avg: 8938.2
# Generasi 13 | Best Fitness: 8650 | avg: 8896.2
# Generasi 14 | Best Fitness: 8570 | avg: 8800.7
# Generasi 15 | Best Fitness: 8500 | avg: 8756.2
# Generasi 16 | Best Fitness: 8500 | avg: 8711.3
# Generasi 17 | Best Fitness: 8490 | avg: 8662.2
# Generasi 18 | Best Fitness: 8445 | avg: 8663.5
# Generasi 19 | Best Fitness: 8385 | avg: 8627.0
# ----- GWO PHASE -----
# GWO Iter 0 Best: 8270 Avg: 8519
# GWO Iter 1 Best: 8270 Avg: 8507
# GWO Iter 2 Best: 8270 Avg: 8490
# GWO Iter 3 Best: 8220 Avg: 8480
# GWO Iter 4 Best: 8220 Avg: 8472
# GWO Iter 5 Best: 8220 Avg: 8464
# GWO Iter 6 Best: 8220 Avg: 8457
# GWO Iter 7 Best: 8165 Avg: 8449
# GWO Iter 8 Best: 8165 Avg: 8442
# GWO Iter 9 Best: 8165 Avg: 8437
# GWO Iter 10 Best: 8165 Avg: 8434
# GWO Iter 11 Best: 8165 Avg: 8431
# GWO Iter 12 Best: 8165 Avg: 8425
# GWO Iter 13 Best: 8165 Avg: 8421
# GWO Iter 14 Best: 8165 Avg: 8412
# GWO Iter 15 Best: 8165 Avg: 8410
# GWO Iter 16 Best: 8165 Avg: 8405
# GWO Iter 17 Best: 8165 Avg: 8403
# GWO Iter 18 Best: 8165 Avg: 8401
# GWO Iter 19 Best: 8165 Avg: 8396
# Generasi 20 | Best Fitness: 8165 | avg: 8395.8
# Generasi 21 | Best Fitness: 8030 | avg: 8346.6
# Generasi 22 | Best Fitness: 7885 | avg: 8221.1
# Generasi 23 | Best Fitness: 7855 | avg: 8116.9
# Generasi 24 | Best Fitness: 7820 | avg: 8036.3
# Generasi 25 | Best Fitness: 7710 | avg: 7967.4
# Generasi 26 | Best Fitness: 7710 | avg: 7884.0
# Generasi 27 | Best Fitness: 7545 | avg: 7850.5
# Generasi 28 | Best Fitness: 7545 | avg: 7763.9
# Generasi 29 | Best Fitness: 7515 | avg: 7753.0
# Generasi 30 | Best Fitness: 7495 | avg: 7687.6
# Generasi 31 | Best Fitness: 7450 | avg: 7641.9
# Generasi 32 | Best Fitness: 7280 | avg: 7598.3
# Generasi 33 | Best Fitness: 7170 | avg: 7495.8
# Generasi 34 | Best Fitness: 7085 | avg: 7383.1
# Generasi 35 | Best Fitness: 7070 | avg: 7252.8
# Generasi 36 | Best Fitness: 7000 | avg: 7192.5
# Generasi 37 | Best Fitness: 6960 | avg: 7166.5
# Generasi 38 | Best Fitness: 6775 | avg: 7159.3
# Generasi 39 | Best Fitness: 6740 | avg: 7011.6
# ----- GWO PHASE -----
# GWO Iter 0 Best: 6600 Avg: 6860
# GWO Iter 1 Best: 6600 Avg: 6842
# GWO Iter 2 Best: 6590 Avg: 6830
# GWO Iter 3 Best: 6590 Avg: 6819
# GWO Iter 4 Best: 6540 Avg: 6806
# GWO Iter 5 Best: 6540 Avg: 6794
# GWO Iter 6 Best: 6525 Avg: 6788
# GWO Iter 7 Best: 6505 Avg: 6777
# GWO Iter 8 Best: 6480 Avg: 6768
# GWO Iter 9 Best: 6480 Avg: 6761
# GWO Iter 10 Best: 6445 Avg: 6758
# GWO Iter 11 Best: 6445 Avg: 6750
# GWO Iter 12 Best: 6445 Avg: 6742
# GWO Iter 13 Best: 6445 Avg: 6738
# GWO Iter 14 Best: 6445 Avg: 6732
# GWO Iter 15 Best: 6360 Avg: 6727
# GWO Iter 16 Best: 6360 Avg: 6721
# GWO Iter 17 Best: 6360 Avg: 6716
# GWO Iter 18 Best: 6360 Avg: 6710
# GWO Iter 19 Best: 6360 Avg: 6706
# Generasi 40 | Best Fitness: 6360 | avg: 6706.0
# Generasi 41 | Best Fitness: 6285 | avg: 6614.8
# Generasi 42 | Best Fitness: 6255 | avg: 6468.3
# Generasi 43 | Best Fitness: 6165 | avg: 6397.1
# Generasi 44 | Best Fitness: 6165 | avg: 6347.0
# Generasi 45 | Best Fitness: 6095 | avg: 6282.3
# Generasi 46 | Best Fitness: 6065 | avg: 6256.4
# Generasi 47 | Best Fitness: 6060 | avg: 6232.8
# Generasi 48 | Best Fitness: 6025 | avg: 6175.5
# Generasi 49 | Best Fitness: 5890 | avg: 6137.8
# Generasi 50 | Best Fitness: 5795 | avg: 6015.3
# Generasi 51 | Best Fitness: 5775 | avg: 5941.7
# Generasi 52 | Best Fitness: 5770 | avg: 5956.3
# Generasi 53 | Best Fitness: 5735 | avg: 5904.5
# Generasi 54 | Best Fitness: 5735 | avg: 5906.3
# Generasi 55 | Best Fitness: 5715 | avg: 5888.5
# Generasi 56 | Best Fitness: 5665 | avg: 5849.5
# Generasi 57 | Best Fitness: 5600 | avg: 5784.5
# Generasi 58 | Best Fitness: 5600 | avg: 5741.7
# Generasi 59 | Best Fitness: 5510 | avg: 5699.7
# ----- GWO PHASE -----
# GWO Iter 0 Best: 5460 Avg: 5662
# GWO Iter 1 Best: 5450 Avg: 5653
# GWO Iter 2 Best: 5450 Avg: 5636
# GWO Iter 3 Best: 5450 Avg: 5631
# GWO Iter 4 Best: 5435 Avg: 5624
# GWO Iter 5 Best: 5405 Avg: 5618
# GWO Iter 6 Best: 5405 Avg: 5611
# GWO Iter 7 Best: 5405 Avg: 5607
# GWO Iter 8 Best: 5405 Avg: 5598
# GWO Iter 9 Best: 5395 Avg: 5593
# GWO Iter 10 Best: 5395 Avg: 5586
# GWO Iter 11 Best: 5395 Avg: 5584
# GWO Iter 12 Best: 5395 Avg: 5582
# GWO Iter 13 Best: 5395 Avg: 5578
# GWO Iter 14 Best: 5395 Avg: 5568
# GWO Iter 15 Best: 5385 Avg: 5564
# GWO Iter 16 Best: 5385 Avg: 5560
# GWO Iter 17 Best: 5385 Avg: 5556
# GWO Iter 18 Best: 5385 Avg: 5553
# GWO Iter 19 Best: 5385 Avg: 5553
# Generasi 60 | Best Fitness: 5385 | avg: 5552.6
# Generasi 61 | Best Fitness: 5250 | avg: 5521.9
# Generasi 62 | Best Fitness: 5245 | avg: 5442.3
# Generasi 63 | Best Fitness: 5240 | avg: 5400.6
# Generasi 64 | Best Fitness: 5190 | avg: 5334.4
# Generasi 65 | Best Fitness: 5120 | avg: 5292.1
# Generasi 66 | Best Fitness: 5090 | avg: 5249.4
# Generasi 67 | Best Fitness: 5050 | avg: 5175.1
# Generasi 68 | Best Fitness: 4940 | avg: 5119.4
# Generasi 69 | Best Fitness: 4935 | avg: 5089.2
# Generasi 70 | Best Fitness: 4880 | avg: 5007.1
# Generasi 71 | Best Fitness: 4850 | avg: 5018.2
# Generasi 72 | Best Fitness: 4820 | avg: 4982.8
# Generasi 73 | Best Fitness: 4770 | avg: 4947.5
# Generasi 74 | Best Fitness: 4735 | avg: 4891.5
# Generasi 75 | Best Fitness: 4665 | avg: 4861.3
# Generasi 76 | Best Fitness: 4620 | avg: 4803.2
# Generasi 77 | Best Fitness: 4575 | avg: 4739.5
# Generasi 78 | Best Fitness: 4555 | avg: 4735.8
# Generasi 79 | Best Fitness: 4555 | avg: 4686.6
# ----- GWO PHASE -----
# GWO Iter 0 Best: 4535 Avg: 4636
# GWO Iter 1 Best: 4535 Avg: 4631
# GWO Iter 2 Best: 4530 Avg: 4628
# GWO Iter 3 Best: 4530 Avg: 4622
# GWO Iter 4 Best: 4515 Avg: 4617
# GWO Iter 5 Best: 4515 Avg: 4613
# GWO Iter 6 Best: 4495 Avg: 4610
# GWO Iter 7 Best: 4495 Avg: 4610
# GWO Iter 8 Best: 4495 Avg: 4607
# GWO Iter 9 Best: 4495 Avg: 4604
# GWO Iter 10 Best: 4495 Avg: 4602
# GWO Iter 11 Best: 4495 Avg: 4598
# GWO Iter 12 Best: 4445 Avg: 4592
# GWO Iter 13 Best: 4445 Avg: 4591
# GWO Iter 14 Best: 4445 Avg: 4589
# GWO Iter 15 Best: 4445 Avg: 4587
# GWO Iter 16 Best: 4445 Avg: 4584
# GWO Iter 17 Best: 4445 Avg: 4583
# GWO Iter 18 Best: 4445 Avg: 4582
# GWO Iter 19 Best: 4445 Avg: 4578
# Generasi 80 | Best Fitness: 4445 | avg: 4577.8
# Generasi 81 | Best Fitness: 4390 | avg: 4557.3
# Generasi 82 | Best Fitness: 4345 | avg: 4512.5
# Generasi 83 | Best Fitness: 4330 | avg: 4455.8
# Generasi 84 | Best Fitness: 4305 | avg: 4424.8
# Generasi 85 | Best Fitness: 4250 | avg: 4407.7
# Generasi 86 | Best Fitness: 4235 | avg: 4358.8
# Generasi 87 | Best Fitness: 4230 | avg: 4329.9
# Generasi 88 | Best Fitness: 4225 | avg: 4321.0
# Generasi 89 | Best Fitness: 4190 | avg: 4301.8
# Generasi 90 | Best Fitness: 4170 | avg: 4304.6
# Generasi 91 | Best Fitness: 4150 | avg: 4260.8
# Generasi 92 | Best Fitness: 4030 | avg: 4255.6
# Generasi 93 | Best Fitness: 3950 | avg: 4202.6
# Generasi 94 | Best Fitness: 3930 | avg: 4118.6
# Generasi 95 | Best Fitness: 3930 | avg: 4062.8
# Generasi 96 | Best Fitness: 3930 | avg: 4046.1
# Generasi 97 | Best Fitness: 3925 | avg: 3998.5
# Generasi 98 | Best Fitness: 3925 | avg: 3994.5
# Generasi 99 | Best Fitness: 3850 | avg: 4026.9
# ----- GWO PHASE -----
# GWO Iter 0 Best: 3830 Avg: 3964
# GWO Iter 1 Best: 3830 Avg: 3960
# GWO Iter 2 Best: 3830 Avg: 3955
# GWO Iter 3 Best: 3830 Avg: 3953
# GWO Iter 4 Best: 3830 Avg: 3949
# GWO Iter 5 Best: 3830 Avg: 3949
# GWO Iter 6 Best: 3830 Avg: 3948
# GWO Iter 7 Best: 3830 Avg: 3948
# GWO Iter 8 Best: 3830 Avg: 3948
# GWO Iter 9 Best: 3830 Avg: 3946
# GWO Iter 10 Best: 3830 Avg: 3945
# GWO Iter 11 Best: 3830 Avg: 3944
# GWO Iter 12 Best: 3830 Avg: 3943
# GWO Iter 13 Best: 3830 Avg: 3939
# GWO Iter 14 Best: 3830 Avg: 3939
# GWO Iter 15 Best: 3830 Avg: 3939
# GWO Iter 16 Best: 3830 Avg: 3936
# GWO Iter 17 Best: 3830 Avg: 3936
# GWO Iter 18 Best: 3830 Avg: 3934
# GWO Iter 19 Best: 3830 Avg: 3933
# Generasi 100 | Best Fitness: 3830 | avg: 3933.2
# Generasi 101 | Best Fitness: 3810 | avg: 3935.0
# Generasi 102 | Best Fitness: 3810 | avg: 3933.1
# Generasi 103 | Best Fitness: 3810 | avg: 3920.1
# Generasi 104 | Best Fitness: 3810 | avg: 3889.9
# Generasi 105 | Best Fitness: 3805 | avg: 3902.9
# Generasi 106 | Best Fitness: 3805 | avg: 3892.7
# Generasi 107 | Best Fitness: 3805 | avg: 3891.2
# Generasi 108 | Best Fitness: 3785 | avg: 3892.7
# Generasi 109 | Best Fitness: 3780 | avg: 3872.9
# Generasi 110 | Best Fitness: 3775 | avg: 3862.1
# Generasi 111 | Best Fitness: 3770 | avg: 3846.4
# Generasi 112 | Best Fitness: 3760 | avg: 3859.2
# Generasi 113 | Best Fitness: 3755 | avg: 3845.0
# Generasi 114 | Best Fitness: 3755 | avg: 3851.4
# Generasi 115 | Best Fitness: 3750 | avg: 3836.2
# Generasi 116 | Best Fitness: 3735 | avg: 3801.0
# Generasi 117 | Best Fitness: 3735 | avg: 3816.0
# Generasi 118 | Best Fitness: 3720 | avg: 3813.8
# Generasi 119 | Best Fitness: 3715 | avg: 3804.3
# ----- GWO PHASE -----
# GWO Iter 0 Best: 3715 Avg: 3772
# GWO Iter 1 Best: 3650 Avg: 3766
# GWO Iter 2 Best: 3650 Avg: 3761
# GWO Iter 3 Best: 3650 Avg: 3758
# GWO Iter 4 Best: 3650 Avg: 3758
# GWO Iter 5 Best: 3650 Avg: 3757
# GWO Iter 6 Best: 3650 Avg: 3755
# GWO Iter 7 Best: 3650 Avg: 3754
# GWO Iter 8 Best: 3650 Avg: 3752
# GWO Iter 9 Best: 3650 Avg: 3752
# GWO Iter 10 Best: 3650 Avg: 3751
# GWO Iter 11 Best: 3650 Avg: 3751
# GWO Iter 12 Best: 3650 Avg: 3751
# GWO Iter 13 Best: 3650 Avg: 3750
# GWO Iter 14 Best: 3650 Avg: 3748
# GWO Iter 15 Best: 3650 Avg: 3748
# GWO Iter 16 Best: 3650 Avg: 3748
# GWO Iter 17 Best: 3650 Avg: 3748
# GWO Iter 18 Best: 3650 Avg: 3747
# GWO Iter 19 Best: 3650 Avg: 3747
# Generasi 120 | Best Fitness: 3650 | avg: 3746.7
# Generasi 121 | Best Fitness: 3635 | avg: 3749.9
# Generasi 122 | Best Fitness: 3635 | avg: 3715.3
# Generasi 123 | Best Fitness: 3625 | avg: 3725.3
# Generasi 124 | Best Fitness: 3625 | avg: 3698.5
# Generasi 125 | Best Fitness: 3620 | avg: 3698.8
# Generasi 126 | Best Fitness: 3605 | avg: 3701.2
# Generasi 127 | Best Fitness: 3605 | avg: 3683.2
# Generasi 128 | Best Fitness: 3600 | avg: 3669.3
# Generasi 129 | Best Fitness: 3585 | avg: 3664.7
# Generasi 130 | Best Fitness: 3585 | avg: 3685.4
# Generasi 131 | Best Fitness: 3580 | avg: 3652.7
# Generasi 132 | Best Fitness: 3555 | avg: 3637.0
# Generasi 133 | Best Fitness: 3555 | avg: 3656.6
# Generasi 134 | Best Fitness: 3555 | avg: 3649.6
# Generasi 135 | Best Fitness: 3550 | avg: 3656.8
# Generasi 136 | Best Fitness: 3550 | avg: 3634.6
# Generasi 137 | Best Fitness: 3545 | avg: 3608.7
# Generasi 138 | Best Fitness: 3545 | avg: 3616.5
# Generasi 139 | Best Fitness: 3530 | avg: 3604.7
# ----- GWO PHASE -----
# GWO Iter 0 Best: 3525 Avg: 3608
# GWO Iter 1 Best: 3525 Avg: 3607
# GWO Iter 2 Best: 3525 Avg: 3607
# GWO Iter 3 Best: 3525 Avg: 3605
# GWO Iter 4 Best: 3525 Avg: 3599
# GWO Iter 5 Best: 3520 Avg: 3598
# GWO Iter 6 Best: 3520 Avg: 3594
# GWO Iter 7 Best: 3520 Avg: 3591
# GWO Iter 8 Best: 3520 Avg: 3590
# GWO Iter 9 Best: 3520 Avg: 3588
# GWO Iter 10 Best: 3520 Avg: 3587
# GWO Iter 11 Best: 3520 Avg: 3585
# GWO Iter 12 Best: 3520 Avg: 3585
# GWO Iter 13 Best: 3520 Avg: 3584
# GWO Iter 14 Best: 3520 Avg: 3583
# GWO Iter 15 Best: 3515 Avg: 3582
# GWO Iter 16 Best: 3515 Avg: 3582
# GWO Iter 17 Best: 3515 Avg: 3581
# GWO Iter 18 Best: 3515 Avg: 3580
# GWO Iter 19 Best: 3515 Avg: 3580
# Generasi 140 | Best Fitness: 3515 | avg: 3580.1
# Generasi 141 | Best Fitness: 3510 | avg: 3598.5
# Generasi 142 | Best Fitness: 3510 | avg: 3616.7
# Generasi 143 | Best Fitness: 3500 | avg: 3612.0
# Generasi 144 | Best Fitness: 3500 | avg: 3576.2
# Generasi 145 | Best Fitness: 3500 | avg: 3576.6
# Generasi 146 | Best Fitness: 3480 | avg: 3559.2
# Generasi 147 | Best Fitness: 3460 | avg: 3570.7
# Generasi 148 | Best Fitness: 3460 | avg: 3560.4
# Generasi 149 | Best Fitness: 3460 | avg: 3541.8
# Generasi 150 | Best Fitness: 3460 | avg: 3547.2
# Generasi 151 | Best Fitness: 3460 | avg: 3529.6
# Generasi 152 | Best Fitness: 3460 | avg: 3559.6
# Generasi 153 | Best Fitness: 3450 | avg: 3540.2
# Generasi 154 | Best Fitness: 3450 | avg: 3554.2
# Generasi 155 | Best Fitness: 3440 | avg: 3529.7
# Generasi 156 | Best Fitness: 3440 | avg: 3529.2
# Generasi 157 | Best Fitness: 3430 | avg: 3506.0
# Generasi 158 | Best Fitness: 3420 | avg: 3501.0
# Generasi 159 | Best Fitness: 3420 | avg: 3503.3
# ----- GWO PHASE -----
# GWO Iter 0 Best: 3410 Avg: 3488
# GWO Iter 1 Best: 3410 Avg: 3485
# GWO Iter 2 Best: 3370 Avg: 3479
# GWO Iter 3 Best: 3370 Avg: 3477
# GWO Iter 4 Best: 3370 Avg: 3475
# GWO Iter 5 Best: 3370 Avg: 3472
# GWO Iter 6 Best: 3370 Avg: 3468
# GWO Iter 7 Best: 3370 Avg: 3467
# GWO Iter 8 Best: 3370 Avg: 3467
# GWO Iter 9 Best: 3370 Avg: 3467
# GWO Iter 10 Best: 3370 Avg: 3466
# GWO Iter 11 Best: 3370 Avg: 3466
# GWO Iter 12 Best: 3370 Avg: 3465
# GWO Iter 13 Best: 3370 Avg: 3465
# GWO Iter 14 Best: 3370 Avg: 3464
# GWO Iter 15 Best: 3370 Avg: 3462
# GWO Iter 16 Best: 3370 Avg: 3462
# GWO Iter 17 Best: 3370 Avg: 3462
# GWO Iter 18 Best: 3370 Avg: 3462
# GWO Iter 19 Best: 3370 Avg: 3460
# Generasi 160 | Best Fitness: 3370 | avg: 3459.9
# Generasi 161 | Best Fitness: 3370 | avg: 3487.8
# Generasi 162 | Best Fitness: 3370 | avg: 3456.6
# Generasi 163 | Best Fitness: 3365 | avg: 3440.1
# Generasi 164 | Best Fitness: 3350 | avg: 3429.7
# Generasi 165 | Best Fitness: 3350 | avg: 3438.3
# Generasi 166 | Best Fitness: 3350 | avg: 3433.8
# Generasi 167 | Best Fitness: 3350 | avg: 3436.0
# Generasi 168 | Best Fitness: 3345 | avg: 3394.0
# Generasi 169 | Best Fitness: 3340 | avg: 3423.8
# Generasi 170 | Best Fitness: 3325 | avg: 3411.1
# Generasi 171 | Best Fitness: 3325 | avg: 3414.6
# Generasi 172 | Best Fitness: 3320 | avg: 3388.7
# Generasi 173 | Best Fitness: 3320 | avg: 3398.0
# Generasi 174 | Best Fitness: 3305 | avg: 3398.9
# Generasi 175 | Best Fitness: 3295 | avg: 3391.0
# Generasi 176 | Best Fitness: 3295 | avg: 3395.1
# Generasi 177 | Best Fitness: 3295 | avg: 3388.4
# Generasi 178 | Best Fitness: 3295 | avg: 3369.7
# Generasi 179 | Best Fitness: 3295 | avg: 3380.7
# ----- GWO PHASE -----
# GWO Iter 0 Best: 3295 Avg: 3370
# GWO Iter 1 Best: 3270 Avg: 3365
# GWO Iter 2 Best: 3270 Avg: 3361
# GWO Iter 3 Best: 3270 Avg: 3356
# GWO Iter 4 Best: 3270 Avg: 3354
# GWO Iter 5 Best: 3270 Avg: 3354
# GWO Iter 6 Best: 3270 Avg: 3351
# GWO Iter 7 Best: 3270 Avg: 3349
# GWO Iter 8 Best: 3270 Avg: 3347
# GWO Iter 9 Best: 3270 Avg: 3347
# GWO Iter 10 Best: 3270 Avg: 3346
# GWO Iter 11 Best: 3270 Avg: 3345
# GWO Iter 12 Best: 3270 Avg: 3344
# GWO Iter 13 Best: 3270 Avg: 3344
# GWO Iter 14 Best: 3270 Avg: 3342
# GWO Iter 15 Best: 3270 Avg: 3340
# GWO Iter 16 Best: 3270 Avg: 3340
# GWO Iter 17 Best: 3270 Avg: 3340
# GWO Iter 18 Best: 3270 Avg: 3339
# GWO Iter 19 Best: 3270 Avg: 3337
# Generasi 180 | Best Fitness: 3270 | avg: 3336.7
# Generasi 181 | Best Fitness: 3260 | avg: 3352.9
# Generasi 182 | Best Fitness: 3260 | avg: 3335.7
# Generasi 183 | Best Fitness: 3235 | avg: 3323.9
# Generasi 184 | Best Fitness: 3210 | avg: 3333.5
# Generasi 185 | Best Fitness: 3210 | avg: 3358.9
# Generasi 186 | Best Fitness: 3205 | avg: 3314.3
# Generasi 187 | Best Fitness: 3200 | avg: 3293.8
# Generasi 188 | Best Fitness: 3200 | avg: 3268.2
# Generasi 189 | Best Fitness: 3200 | avg: 3273.2
# Generasi 190 | Best Fitness: 3180 | avg: 3279.6
# Generasi 191 | Best Fitness: 3165 | avg: 3257.6
# Generasi 192 | Best Fitness: 3130 | avg: 3241.4
# Generasi 193 | Best Fitness: 3100 | avg: 3223.6
# Generasi 194 | Best Fitness: 3100 | avg: 3185.2
# Generasi 195 | Best Fitness: 3100 | avg: 3174.4
# Generasi 196 | Best Fitness: 3095 | avg: 3187.8
# Generasi 197 | Best Fitness: 3095 | avg: 3174.6
# Generasi 198 | Best Fitness: 3095 | avg: 3146.1
# Generasi 199 | Best Fitness: 3095 | avg: 3184.3
# ----- GWO PHASE -----
# GWO Iter 0 Best: 3085 Avg: 3153
# GWO Iter 1 Best: 3075 Avg: 3147
# GWO Iter 2 Best: 3075 Avg: 3144
# GWO Iter 3 Best: 3075 Avg: 3139
# GWO Iter 4 Best: 3075 Avg: 3139
# GWO Iter 5 Best: 3075 Avg: 3139
# GWO Iter 6 Best: 3075 Avg: 3136
# GWO Iter 7 Best: 3075 Avg: 3136
# GWO Iter 8 Best: 3075 Avg: 3136
# GWO Iter 9 Best: 3075 Avg: 3136
# GWO Iter 10 Best: 3075 Avg: 3136
# GWO Iter 11 Best: 3075 Avg: 3135
# GWO Iter 12 Best: 3075 Avg: 3134
# GWO Iter 13 Best: 3075 Avg: 3134
# GWO Iter 14 Best: 3075 Avg: 3134
# GWO Iter 15 Best: 3075 Avg: 3133
# GWO Iter 16 Best: 3075 Avg: 3133
# GWO Iter 17 Best: 3075 Avg: 3131
# GWO Iter 18 Best: 3060 Avg: 3130
# GWO Iter 19 Best: 3060 Avg: 3130
# Generasi 200 | Best Fitness: 3060 | avg: 3130.2
# Generasi 201 | Best Fitness: 3055 | avg: 3140.3
# Generasi 202 | Best Fitness: 3050 | avg: 3134.0
# Generasi 203 | Best Fitness: 3045 | avg: 3128.9
# Generasi 204 | Best Fitness: 3040 | avg: 3116.7
# Generasi 205 | Best Fitness: 3025 | avg: 3102.9
# Generasi 206 | Best Fitness: 3025 | avg: 3089.1
# Generasi 207 | Best Fitness: 3010 | avg: 3094.5
# Generasi 208 | Best Fitness: 3010 | avg: 3087.6
# Generasi 209 | Best Fitness: 3000 | avg: 3096.9
# Generasi 210 | Best Fitness: 3000 | avg: 3072.9
# Generasi 211 | Best Fitness: 2985 | avg: 3061.8
# Generasi 212 | Best Fitness: 2985 | avg: 3073.5
# Generasi 213 | Best Fitness: 2985 | avg: 3059.0
# Generasi 214 | Best Fitness: 2980 | avg: 3048.3
# Generasi 215 | Best Fitness: 2980 | avg: 3039.1
# Generasi 216 | Best Fitness: 2970 | avg: 3051.9
# Generasi 217 | Best Fitness: 2970 | avg: 3039.9
# Generasi 218 | Best Fitness: 2965 | avg: 3046.6
# Generasi 219 | Best Fitness: 2965 | avg: 3017.4
# ----- GWO PHASE -----
# GWO Iter 0 Best: 2960 Avg: 3015
# GWO Iter 1 Best: 2960 Avg: 3014
# GWO Iter 2 Best: 2960 Avg: 3011
# GWO Iter 3 Best: 2960 Avg: 3010
# GWO Iter 4 Best: 2945 Avg: 3007
# GWO Iter 5 Best: 2940 Avg: 3003
# GWO Iter 6 Best: 2940 Avg: 3003
# GWO Iter 7 Best: 2940 Avg: 3003
# GWO Iter 8 Best: 2940 Avg: 2999
# GWO Iter 9 Best: 2940 Avg: 2996
# GWO Iter 10 Best: 2940 Avg: 2996
# GWO Iter 11 Best: 2940 Avg: 2996
# GWO Iter 12 Best: 2940 Avg: 2996
# GWO Iter 13 Best: 2940 Avg: 2996
# GWO Iter 14 Best: 2940 Avg: 2996
# GWO Iter 15 Best: 2940 Avg: 2996
# GWO Iter 16 Best: 2940 Avg: 2996
# GWO Iter 17 Best: 2935 Avg: 2996
# GWO Iter 18 Best: 2935 Avg: 2995
# GWO Iter 19 Best: 2935 Avg: 2995
# Generasi 220 | Best Fitness: 2935 | avg: 2995.1
# Generasi 221 | Best Fitness: 2920 | avg: 3005.0
# Generasi 222 | Best Fitness: 2920 | avg: 2999.2
# Generasi 223 | Best Fitness: 2910 | avg: 2983.5
# Generasi 224 | Best Fitness: 2905 | avg: 2992.1
# Generasi 225 | Best Fitness: 2900 | avg: 3001.6
# Generasi 226 | Best Fitness: 2880 | avg: 2989.1
# Generasi 227 | Best Fitness: 2880 | avg: 2948.1
# Generasi 228 | Best Fitness: 2875 | avg: 2939.2
# Generasi 229 | Best Fitness: 2875 | avg: 2972.7
# Generasi 230 | Best Fitness: 2875 | avg: 2928.8
# Generasi 231 | Best Fitness: 2865 | avg: 2940.9
# Generasi 232 | Best Fitness: 2865 | avg: 2950.6
# Generasi 233 | Best Fitness: 2860 | avg: 2949.6
# Generasi 234 | Best Fitness: 2845 | avg: 2911.1
# Generasi 235 | Best Fitness: 2825 | avg: 2940.1
# Generasi 236 | Best Fitness: 2825 | avg: 2932.3
# Generasi 237 | Best Fitness: 2810 | avg: 2931.2
# Generasi 238 | Best Fitness: 2810 | avg: 2903.6
# Generasi 239 | Best Fitness: 2810 | avg: 2909.2
# ----- GWO PHASE -----
# GWO Iter 0 Best: 2805 Avg: 2875
# GWO Iter 1 Best: 2805 Avg: 2871
# GWO Iter 2 Best: 2805 Avg: 2868
# GWO Iter 3 Best: 2805 Avg: 2866
# GWO Iter 4 Best: 2805 Avg: 2865
# GWO Iter 5 Best: 2805 Avg: 2864
# GWO Iter 6 Best: 2800 Avg: 2862
# GWO Iter 7 Best: 2800 Avg: 2862
# GWO Iter 8 Best: 2800 Avg: 2862
# GWO Iter 9 Best: 2800 Avg: 2862
# GWO Iter 10 Best: 2800 Avg: 2862
# GWO Iter 11 Best: 2790 Avg: 2862
# GWO Iter 12 Best: 2790 Avg: 2862
# GWO Iter 13 Best: 2790 Avg: 2862
# GWO Iter 14 Best: 2790 Avg: 2862
# GWO Iter 15 Best: 2790 Avg: 2862
# GWO Iter 16 Best: 2790 Avg: 2862
# GWO Iter 17 Best: 2790 Avg: 2862
# GWO Iter 18 Best: 2790 Avg: 2862
# GWO Iter 19 Best: 2790 Avg: 2862
# Generasi 240 | Best Fitness: 2790 | avg: 2861.6
# Generasi 241 | Best Fitness: 2775 | avg: 2884.6
# Generasi 242 | Best Fitness: 2765 | avg: 2855.8
# Generasi 243 | Best Fitness: 2745 | avg: 2856.4
# Generasi 244 | Best Fitness: 2745 | avg: 2835.1
# Generasi 245 | Best Fitness: 2730 | avg: 2829.4
# Generasi 246 | Best Fitness: 2730 | avg: 2827.8
# Generasi 247 | Best Fitness: 2715 | avg: 2808.9
# Generasi 248 | Best Fitness: 2715 | avg: 2794.9
# Generasi 249 | Best Fitness: 2715 | avg: 2817.5
# Generasi 250 | Best Fitness: 2715 | avg: 2811.3
# Generasi 251 | Best Fitness: 2695 | avg: 2771.8
# Generasi 252 | Best Fitness: 2695 | avg: 2787.5
# Generasi 253 | Best Fitness: 2690 | avg: 2782.2
# Generasi 254 | Best Fitness: 2675 | avg: 2779.7
# Generasi 255 | Best Fitness: 2675 | avg: 2772.7
# Generasi 256 | Best Fitness: 2675 | avg: 2770.1
# Generasi 257 | Best Fitness: 2670 | avg: 2747.3
# Generasi 258 | Best Fitness: 2670 | avg: 2758.6
# Generasi 259 | Best Fitness: 2660 | avg: 2745.1
# ----- GWO PHASE -----
# GWO Iter 0 Best: 2660 Avg: 2728
# GWO Iter 1 Best: 2660 Avg: 2724
# GWO Iter 2 Best: 2660 Avg: 2724
# GWO Iter 3 Best: 2660 Avg: 2722
# GWO Iter 4 Best: 2660 Avg: 2722
# GWO Iter 5 Best: 2660 Avg: 2721
# GWO Iter 6 Best: 2660 Avg: 2715
# GWO Iter 7 Best: 2660 Avg: 2713
# GWO Iter 8 Best: 2660 Avg: 2712
# GWO Iter 9 Best: 2660 Avg: 2712
# GWO Iter 10 Best: 2660 Avg: 2710
# GWO Iter 11 Best: 2660 Avg: 2708
# GWO Iter 12 Best: 2660 Avg: 2706
# GWO Iter 13 Best: 2660 Avg: 2706
# GWO Iter 14 Best: 2660 Avg: 2706
# GWO Iter 15 Best: 2660 Avg: 2704
# GWO Iter 16 Best: 2660 Avg: 2704
# GWO Iter 17 Best: 2660 Avg: 2704
# GWO Iter 18 Best: 2660 Avg: 2703
# GWO Iter 19 Best: 2660 Avg: 2702
# Generasi 260 | Best Fitness: 2660 | avg: 2701.9
# Generasi 261 | Best Fitness: 2660 | avg: 2741.3
# Generasi 262 | Best Fitness: 2660 | avg: 2734.0
# Generasi 263 | Best Fitness: 2660 | avg: 2749.7
# Generasi 264 | Best Fitness: 2655 | avg: 2709.5
# Generasi 265 | Best Fitness: 2655 | avg: 2738.0
# Generasi 266 | Best Fitness: 2655 | avg: 2718.0
# Generasi 267 | Best Fitness: 2655 | avg: 2714.8
# Generasi 268 | Best Fitness: 2655 | avg: 2723.0
# Generasi 269 | Best Fitness: 2655 | avg: 2736.8
# Generasi 270 | Best Fitness: 2635 | avg: 2730.8
# Generasi 271 | Best Fitness: 2635 | avg: 2723.9
# Generasi 272 | Best Fitness: 2635 | avg: 2714.4
# Generasi 273 | Best Fitness: 2635 | avg: 2695.6
# Generasi 274 | Best Fitness: 2630 | avg: 2694.5
# Generasi 275 | Best Fitness: 2630 | avg: 2710.9
# Generasi 276 | Best Fitness: 2630 | avg: 2693.2
# Generasi 277 | Best Fitness: 2625 | avg: 2702.9
# Generasi 278 | Best Fitness: 2625 | avg: 2692.0
# Generasi 279 | Best Fitness: 2625 | avg: 2699.4
# ----- GWO PHASE -----
# GWO Iter 0 Best: 2625 Avg: 2682
# GWO Iter 1 Best: 2625 Avg: 2680
# GWO Iter 2 Best: 2625 Avg: 2675
# GWO Iter 3 Best: 2625 Avg: 2673
# GWO Iter 4 Best: 2625 Avg: 2667
# GWO Iter 5 Best: 2625 Avg: 2666
# GWO Iter 6 Best: 2625 Avg: 2665
# GWO Iter 7 Best: 2625 Avg: 2665
# GWO Iter 8 Best: 2625 Avg: 2665
# GWO Iter 9 Best: 2625 Avg: 2665
# GWO Iter 10 Best: 2625 Avg: 2665
# GWO Iter 11 Best: 2625 Avg: 2665
# GWO Iter 12 Best: 2625 Avg: 2665
# GWO Iter 13 Best: 2625 Avg: 2663
# GWO Iter 14 Best: 2605 Avg: 2663
# GWO Iter 15 Best: 2605 Avg: 2661
# GWO Iter 16 Best: 2605 Avg: 2661
# GWO Iter 17 Best: 2605 Avg: 2661
# GWO Iter 18 Best: 2605 Avg: 2660
# GWO Iter 19 Best: 2605 Avg: 2660
# Generasi 280 | Best Fitness: 2605 | avg: 2659.8
# Generasi 281 | Best Fitness: 2605 | avg: 2700.0
# Generasi 282 | Best Fitness: 2605 | avg: 2686.3
# Generasi 283 | Best Fitness: 2605 | avg: 2676.6
# Generasi 284 | Best Fitness: 2605 | avg: 2691.8
# Generasi 285 | Best Fitness: 2605 | avg: 2705.4
# Generasi 286 | Best Fitness: 2605 | avg: 2676.9
# Generasi 287 | Best Fitness: 2605 | avg: 2684.0
# Generasi 288 | Best Fitness: 2605 | avg: 2662.9
# Generasi 289 | Best Fitness: 2605 | avg: 2683.1
# Generasi 290 | Best Fitness: 2605 | avg: 2664.1
# Generasi 291 | Best Fitness: 2605 | avg: 2684.1
# Generasi 292 | Best Fitness: 2605 | avg: 2657.4
# Generasi 293 | Best Fitness: 2605 | avg: 2681.5
# Generasi 294 | Best Fitness: 2585 | avg: 2664.5
# Generasi 295 | Best Fitness: 2585 | avg: 2692.5
# Generasi 296 | Best Fitness: 2585 | avg: 2673.7
# Generasi 297 | Best Fitness: 2585 | avg: 2687.4
# Generasi 298 | Best Fitness: 2585 | avg: 2664.4
# Generasi 299 | Best Fitness: 2585 | avg: 2662.8
# ----- GWO PHASE -----
# GWO Iter 0 Best: 2565 Avg: 2656
# GWO Iter 1 Best: 2565 Avg: 2650
# GWO Iter 2 Best: 2565 Avg: 2647
# GWO Iter 3 Best: 2565 Avg: 2642
# GWO Iter 4 Best: 2565 Avg: 2640
# GWO Iter 5 Best: 2565 Avg: 2637
# GWO Iter 6 Best: 2565 Avg: 2637
# GWO Iter 7 Best: 2565 Avg: 2636
# GWO Iter 8 Best: 2565 Avg: 2636
# GWO Iter 9 Best: 2565 Avg: 2636
# GWO Iter 10 Best: 2565 Avg: 2635
# GWO Iter 11 Best: 2565 Avg: 2635
# GWO Iter 12 Best: 2565 Avg: 2635
# GWO Iter 13 Best: 2560 Avg: 2634
# GWO Iter 14 Best: 2560 Avg: 2634
# GWO Iter 15 Best: 2560 Avg: 2634
# GWO Iter 16 Best: 2560 Avg: 2632
# GWO Iter 17 Best: 2560 Avg: 2632
# GWO Iter 18 Best: 2555 Avg: 2632
# GWO Iter 19 Best: 2555 Avg: 2629
# Generasi 300 | Best Fitness: 2555 | avg: 2629.4
# Generasi 301 | Best Fitness: 2545 | avg: 2640.1
# Generasi 302 | Best Fitness: 2540 | avg: 2632.7
# Generasi 303 | Best Fitness: 2535 | avg: 2644.6
# Generasi 304 | Best Fitness: 2520 | avg: 2614.5
# Generasi 305 | Best Fitness: 2510 | avg: 2589.7
# Generasi 306 | Best Fitness: 2490 | avg: 2597.3
# Generasi 307 | Best Fitness: 2490 | avg: 2576.1
# Generasi 308 | Best Fitness: 2490 | avg: 2554.2
# Generasi 309 | Best Fitness: 2490 | avg: 2576.1
# Generasi 310 | Best Fitness: 2475 | avg: 2577.3
# Generasi 311 | Best Fitness: 2475 | avg: 2555.4
# Generasi 312 | Best Fitness: 2475 | avg: 2555.0
# Generasi 313 | Best Fitness: 2475 | avg: 2538.3
# Generasi 314 | Best Fitness: 2475 | avg: 2544.1
# Generasi 315 | Best Fitness: 2475 | avg: 2542.4
# Generasi 316 | Best Fitness: 2475 | avg: 2558.2
# Generasi 317 | Best Fitness: 2470 | avg: 2560.9
# Generasi 318 | Best Fitness: 2455 | avg: 2550.2
# Generasi 319 | Best Fitness: 2455 | avg: 2544.1
# ----- GWO PHASE -----
# GWO Iter 0 Best: 2450 Avg: 2514
# GWO Iter 1 Best: 2435 Avg: 2510
# GWO Iter 2 Best: 2435 Avg: 2508
# GWO Iter 3 Best: 2435 Avg: 2508
# GWO Iter 4 Best: 2435 Avg: 2504
# GWO Iter 5 Best: 2435 Avg: 2503
# GWO Iter 6 Best: 2435 Avg: 2502
# GWO Iter 7 Best: 2435 Avg: 2502
# GWO Iter 8 Best: 2435 Avg: 2502
# GWO Iter 9 Best: 2435 Avg: 2502
# GWO Iter 10 Best: 2435 Avg: 2502
# GWO Iter 11 Best: 2435 Avg: 2502
# GWO Iter 12 Best: 2435 Avg: 2502
# GWO Iter 13 Best: 2435 Avg: 2502
# GWO Iter 14 Best: 2435 Avg: 2500
# GWO Iter 15 Best: 2435 Avg: 2500
# GWO Iter 16 Best: 2435 Avg: 2500
# GWO Iter 17 Best: 2435 Avg: 2500
# GWO Iter 18 Best: 2435 Avg: 2500
# GWO Iter 19 Best: 2435 Avg: 2500
# Generasi 320 | Best Fitness: 2435 | avg: 2499.6
# Generasi 321 | Best Fitness: 2430 | avg: 2514.8
# Generasi 322 | Best Fitness: 2430 | avg: 2494.4
# Generasi 323 | Best Fitness: 2430 | avg: 2504.0
# Generasi 324 | Best Fitness: 2430 | avg: 2480.7
# Generasi 325 | Best Fitness: 2430 | avg: 2508.1
# Generasi 326 | Best Fitness: 2410 | avg: 2479.3
# Generasi 327 | Best Fitness: 2410 | avg: 2508.9
# Generasi 328 | Best Fitness: 2410 | avg: 2493.8
# Generasi 329 | Best Fitness: 2390 | avg: 2490.1
# Generasi 330 | Best Fitness: 2390 | avg: 2474.7
# Generasi 331 | Best Fitness: 2390 | avg: 2472.9
# Generasi 332 | Best Fitness: 2390 | avg: 2443.0
# Generasi 333 | Best Fitness: 2390 | avg: 2465.2
# Generasi 334 | Best Fitness: 2390 | avg: 2456.7
# Generasi 335 | Best Fitness: 2390 | avg: 2460.2
# Generasi 336 | Best Fitness: 2390 | avg: 2458.0
# Generasi 337 | Best Fitness: 2390 | avg: 2465.3
# Generasi 338 | Best Fitness: 2385 | avg: 2442.0
# Generasi 339 | Best Fitness: 2385 | avg: 2462.3
# ----- GWO PHASE -----
# GWO Iter 0 Best: 2385 Avg: 2450
# GWO Iter 1 Best: 2385 Avg: 2447
# GWO Iter 2 Best: 2385 Avg: 2444
# GWO Iter 3 Best: 2380 Avg: 2442
# GWO Iter 4 Best: 2380 Avg: 2440
# GWO Iter 5 Best: 2380 Avg: 2440
# GWO Iter 6 Best: 2380 Avg: 2438
# GWO Iter 7 Best: 2380 Avg: 2438
# GWO Iter 8 Best: 2380 Avg: 2436
# GWO Iter 9 Best: 2380 Avg: 2436
# GWO Iter 10 Best: 2380 Avg: 2434
# GWO Iter 11 Best: 2380 Avg: 2434
# GWO Iter 12 Best: 2380 Avg: 2432
# GWO Iter 13 Best: 2380 Avg: 2432
# GWO Iter 14 Best: 2380 Avg: 2431
# GWO Iter 15 Best: 2380 Avg: 2431
# GWO Iter 16 Best: 2380 Avg: 2431
# GWO Iter 17 Best: 2380 Avg: 2431
# GWO Iter 18 Best: 2380 Avg: 2431
# GWO Iter 19 Best: 2380 Avg: 2431
# Generasi 340 | Best Fitness: 2380 | avg: 2431.4
# Generasi 341 | Best Fitness: 2365 | avg: 2454.3
# Generasi 342 | Best Fitness: 2360 | avg: 2423.6
# Generasi 343 | Best Fitness: 2360 | avg: 2438.2
# Generasi 344 | Best Fitness: 2345 | avg: 2414.5
# Generasi 345 | Best Fitness: 2340 | avg: 2434.4
# Generasi 346 | Best Fitness: 2340 | avg: 2426.2
# Generasi 347 | Best Fitness: 2340 | avg: 2401.8
# Generasi 348 | Best Fitness: 2340 | avg: 2410.3
# Generasi 349 | Best Fitness: 2340 | avg: 2402.0
# Generasi 350 | Best Fitness: 2340 | avg: 2409.6
# Generasi 351 | Best Fitness: 2340 | avg: 2414.5
# Generasi 352 | Best Fitness: 2340 | avg: 2409.6
# Generasi 353 | Best Fitness: 2320 | avg: 2400.7
# Generasi 354 | Best Fitness: 2320 | avg: 2405.3
# Generasi 355 | Best Fitness: 2300 | avg: 2408.3
# Generasi 356 | Best Fitness: 2300 | avg: 2368.5
# Generasi 357 | Best Fitness: 2300 | avg: 2370.2
# Generasi 358 | Best Fitness: 2280 | avg: 2357.7
# Generasi 359 | Best Fitness: 2280 | avg: 2360.2
# ----- GWO PHASE -----
# GWO Iter 0 Best: 2260 Avg: 2357
# GWO Iter 1 Best: 2260 Avg: 2350
# GWO Iter 2 Best: 2240 Avg: 2348
# GWO Iter 3 Best: 2240 Avg: 2344
# GWO Iter 4 Best: 2240 Avg: 2341
# GWO Iter 5 Best: 2240 Avg: 2340
# GWO Iter 6 Best: 2240 Avg: 2338
# GWO Iter 7 Best: 2240 Avg: 2337
# GWO Iter 8 Best: 2240 Avg: 2335
# GWO Iter 9 Best: 2240 Avg: 2335
# GWO Iter 10 Best: 2240 Avg: 2334
# GWO Iter 11 Best: 2240 Avg: 2332
# GWO Iter 12 Best: 2240 Avg: 2332
# GWO Iter 13 Best: 2240 Avg: 2332
# GWO Iter 14 Best: 2240 Avg: 2332
# GWO Iter 15 Best: 2240 Avg: 2332
# GWO Iter 16 Best: 2240 Avg: 2332
# GWO Iter 17 Best: 2240 Avg: 2331
# GWO Iter 18 Best: 2240 Avg: 2328
# GWO Iter 19 Best: 2240 Avg: 2328
# Generasi 360 | Best Fitness: 2240 | avg: 2327.6
# Generasi 361 | Best Fitness: 2240 | avg: 2334.9
# Generasi 362 | Best Fitness: 2235 | avg: 2324.1
# Generasi 363 | Best Fitness: 2235 | avg: 2308.4
# Generasi 364 | Best Fitness: 2235 | avg: 2318.3
# Generasi 365 | Best Fitness: 2235 | avg: 2317.9
# Generasi 366 | Best Fitness: 2235 | avg: 2306.8
# Generasi 367 | Best Fitness: 2235 | avg: 2306.2
# Generasi 368 | Best Fitness: 2230 | avg: 2297.5
# Generasi 369 | Best Fitness: 2215 | avg: 2288.9
# Generasi 370 | Best Fitness: 2210 | avg: 2291.9
# Generasi 371 | Best Fitness: 2210 | avg: 2308.2
# Generasi 372 | Best Fitness: 2195 | avg: 2280.6
# Generasi 373 | Best Fitness: 2195 | avg: 2268.3
# Generasi 374 | Best Fitness: 2190 | avg: 2289.0
# Generasi 375 | Best Fitness: 2190 | avg: 2271.4
# Generasi 376 | Best Fitness: 2190 | avg: 2257.7
# Generasi 377 | Best Fitness: 2190 | avg: 2245.9
# Generasi 378 | Best Fitness: 2190 | avg: 2244.9
# Generasi 379 | Best Fitness: 2190 | avg: 2261.9
# ----- GWO PHASE -----
# GWO Iter 0 Best: 2190 Avg: 2259
# GWO Iter 1 Best: 2190 Avg: 2257
# GWO Iter 2 Best: 2190 Avg: 2252
# GWO Iter 3 Best: 2190 Avg: 2248
# GWO Iter 4 Best: 2190 Avg: 2246
# GWO Iter 5 Best: 2190 Avg: 2246
# GWO Iter 6 Best: 2190 Avg: 2246
# GWO Iter 7 Best: 2190 Avg: 2242
# GWO Iter 8 Best: 2190 Avg: 2241
# GWO Iter 9 Best: 2190 Avg: 2240
# GWO Iter 10 Best: 2190 Avg: 2238
# GWO Iter 11 Best: 2190 Avg: 2238
# GWO Iter 12 Best: 2190 Avg: 2238
# GWO Iter 13 Best: 2190 Avg: 2238
# GWO Iter 14 Best: 2170 Avg: 2237
# GWO Iter 15 Best: 2170 Avg: 2237
# GWO Iter 16 Best: 2170 Avg: 2237
# GWO Iter 17 Best: 2170 Avg: 2237
# GWO Iter 18 Best: 2170 Avg: 2237
# GWO Iter 19 Best: 2170 Avg: 2236
# Generasi 380 | Best Fitness: 2170 | avg: 2236.4
# Generasi 381 | Best Fitness: 2170 | avg: 2255.7
# Generasi 382 | Best Fitness: 2160 | avg: 2252.8
# Generasi 383 | Best Fitness: 2160 | avg: 2240.8
# Generasi 384 | Best Fitness: 2155 | avg: 2226.7
# Generasi 385 | Best Fitness: 2155 | avg: 2233.0
# Generasi 386 | Best Fitness: 2155 | avg: 2225.2
# Generasi 387 | Best Fitness: 2155 | avg: 2256.7
# Generasi 388 | Best Fitness: 2155 | avg: 2235.3
# Generasi 389 | Best Fitness: 2155 | avg: 2215.8
# Generasi 390 | Best Fitness: 2150 | avg: 2241.5
# Generasi 391 | Best Fitness: 2150 | avg: 2229.6
# Generasi 392 | Best Fitness: 2150 | avg: 2228.0
# Generasi 393 | Best Fitness: 2150 | avg: 2221.0
# Generasi 394 | Best Fitness: 2150 | avg: 2230.2
# Generasi 395 | Best Fitness: 2150 | avg: 2214.5
# Generasi 396 | Best Fitness: 2150 | avg: 2207.9
# Generasi 397 | Best Fitness: 2150 | avg: 2208.9
# Generasi 398 | Best Fitness: 2150 | avg: 2222.1
# Generasi 399 | Best Fitness: 2130 | avg: 2230.1
# ----- GWO PHASE -----
# GWO Iter 0 Best: 2130 Avg: 2210
# GWO Iter 1 Best: 2130 Avg: 2203
# GWO Iter 2 Best: 2130 Avg: 2201
# GWO Iter 3 Best: 2130 Avg: 2200
# GWO Iter 4 Best: 2130 Avg: 2197
# GWO Iter 5 Best: 2130 Avg: 2192
# GWO Iter 6 Best: 2130 Avg: 2192
# GWO Iter 7 Best: 2130 Avg: 2188
# GWO Iter 8 Best: 2130 Avg: 2188
# GWO Iter 9 Best: 2130 Avg: 2187
# GWO Iter 10 Best: 2130 Avg: 2185
# GWO Iter 11 Best: 2125 Avg: 2185
# GWO Iter 12 Best: 2125 Avg: 2185
# GWO Iter 13 Best: 2125 Avg: 2184
# GWO Iter 14 Best: 2125 Avg: 2184
# GWO Iter 15 Best: 2125 Avg: 2184
# GWO Iter 16 Best: 2125 Avg: 2184
# GWO Iter 17 Best: 2125 Avg: 2184
# GWO Iter 18 Best: 2125 Avg: 2184
# GWO Iter 19 Best: 2125 Avg: 2184
# Generasi 400 | Best Fitness: 2125 | avg: 2183.8
# Generasi 401 | Best Fitness: 2125 | avg: 2205.1
# Generasi 402 | Best Fitness: 2110 | avg: 2188.7
# Generasi 403 | Best Fitness: 2110 | avg: 2183.6
# Generasi 404 | Best Fitness: 2105 | avg: 2183.8
# Generasi 405 | Best Fitness: 2105 | avg: 2181.6
# Generasi 406 | Best Fitness: 2090 | avg: 2162.0
# Generasi 407 | Best Fitness: 2090 | avg: 2167.6
# Generasi 408 | Best Fitness: 2090 | avg: 2167.8
# Generasi 409 | Best Fitness: 2090 | avg: 2156.1
# Generasi 410 | Best Fitness: 2090 | avg: 2177.1
# Generasi 411 | Best Fitness: 2090 | avg: 2179.6
# Generasi 412 | Best Fitness: 2090 | avg: 2158.6
# Generasi 413 | Best Fitness: 2090 | avg: 2164.9
# Generasi 414 | Best Fitness: 2090 | avg: 2166.3
# Generasi 415 | Best Fitness: 2090 | avg: 2154.3
# Generasi 416 | Best Fitness: 2090 | avg: 2157.6
# Generasi 417 | Best Fitness: 2090 | avg: 2180.1
# Generasi 418 | Best Fitness: 2090 | avg: 2157.3
# Generasi 419 | Best Fitness: 2090 | avg: 2164.4
# ----- GWO PHASE -----
# GWO Iter 0 Best: 2085 Avg: 2141
# GWO Iter 1 Best: 2085 Avg: 2140
# GWO Iter 2 Best: 2085 Avg: 2136
# GWO Iter 3 Best: 2085 Avg: 2136
# GWO Iter 4 Best: 2085 Avg: 2134
# GWO Iter 5 Best: 2085 Avg: 2134
# GWO Iter 6 Best: 2085 Avg: 2132
# GWO Iter 7 Best: 2080 Avg: 2132
# GWO Iter 8 Best: 2070 Avg: 2131
# GWO Iter 9 Best: 2070 Avg: 2131
# GWO Iter 10 Best: 2070 Avg: 2129
# GWO Iter 11 Best: 2070 Avg: 2129
# GWO Iter 12 Best: 2070 Avg: 2128
# GWO Iter 13 Best: 2070 Avg: 2128
# GWO Iter 14 Best: 2070 Avg: 2127
# GWO Iter 15 Best: 2070 Avg: 2126
# GWO Iter 16 Best: 2070 Avg: 2126
# GWO Iter 17 Best: 2070 Avg: 2124
# GWO Iter 18 Best: 2070 Avg: 2124
# GWO Iter 19 Best: 2070 Avg: 2122
# Generasi 420 | Best Fitness: 2070 | avg: 2121.9
# Generasi 421 | Best Fitness: 2050 | avg: 2146.3
# Generasi 422 | Best Fitness: 2050 | avg: 2143.0
# Generasi 423 | Best Fitness: 2030 | avg: 2126.0
# Generasi 424 | Best Fitness: 2030 | avg: 2110.6
# Generasi 425 | Best Fitness: 2030 | avg: 2103.7
# Generasi 426 | Best Fitness: 2030 | avg: 2099.1
# Generasi 427 | Best Fitness: 2030 | avg: 2115.6
# Generasi 428 | Best Fitness: 2030 | avg: 2086.6
# Generasi 429 | Best Fitness: 2030 | avg: 2096.8
# Generasi 430 | Best Fitness: 2030 | avg: 2124.9
# Generasi 431 | Best Fitness: 2010 | avg: 2101.5
# Generasi 432 | Best Fitness: 2010 | avg: 2080.9
# Generasi 433 | Best Fitness: 2010 | avg: 2084.4
# Generasi 434 | Best Fitness: 1990 | avg: 2096.0
# Generasi 435 | Best Fitness: 1990 | avg: 2085.7
# Generasi 436 | Best Fitness: 1970 | avg: 2065.5
# Generasi 437 | Best Fitness: 1970 | avg: 2072.3
# Generasi 438 | Best Fitness: 1970 | avg: 2047.3
# Generasi 439 | Best Fitness: 1970 | avg: 2042.7
# ----- GWO PHASE -----
# GWO Iter 0 Best: 1950 Avg: 2032
# GWO Iter 1 Best: 1950 Avg: 2029
# GWO Iter 2 Best: 1950 Avg: 2025
# GWO Iter 3 Best: 1950 Avg: 2022
# GWO Iter 4 Best: 1950 Avg: 2019
# GWO Iter 5 Best: 1950 Avg: 2018
# GWO Iter 6 Best: 1950 Avg: 2018
# GWO Iter 7 Best: 1950 Avg: 2018
# GWO Iter 8 Best: 1950 Avg: 2018
# GWO Iter 9 Best: 1950 Avg: 2018
# GWO Iter 10 Best: 1950 Avg: 2018
# GWO Iter 11 Best: 1950 Avg: 2015
# GWO Iter 12 Best: 1950 Avg: 2015
# GWO Iter 13 Best: 1950 Avg: 2015
# GWO Iter 14 Best: 1950 Avg: 2013
# GWO Iter 15 Best: 1950 Avg: 2013
# GWO Iter 16 Best: 1950 Avg: 2013
# GWO Iter 17 Best: 1950 Avg: 2013
# GWO Iter 18 Best: 1950 Avg: 2013
# GWO Iter 19 Best: 1950 Avg: 2013
# Generasi 440 | Best Fitness: 1950 | avg: 2013.3
# Generasi 441 | Best Fitness: 1950 | avg: 2041.3
# Generasi 442 | Best Fitness: 1930 | avg: 2032.3
# Generasi 443 | Best Fitness: 1930 | avg: 2027.9
# Generasi 444 | Best Fitness: 1930 | avg: 2006.3
# Generasi 445 | Best Fitness: 1930 | avg: 1996.3
# Generasi 446 | Best Fitness: 1930 | avg: 1999.4
# Generasi 447 | Best Fitness: 1930 | avg: 2004.4
# Generasi 448 | Best Fitness: 1925 | avg: 2002.7
# Generasi 449 | Best Fitness: 1925 | avg: 1997.7
# Generasi 450 | Best Fitness: 1925 | avg: 1991.7
# Generasi 451 | Best Fitness: 1925 | avg: 1993.8
# Generasi 452 | Best Fitness: 1925 | avg: 1991.4
# Generasi 453 | Best Fitness: 1925 | avg: 2000.1
# Generasi 454 | Best Fitness: 1925 | avg: 1995.3
# Generasi 455 | Best Fitness: 1925 | avg: 2002.9
# Generasi 456 | Best Fitness: 1925 | avg: 1978.2
# Generasi 457 | Best Fitness: 1925 | avg: 1985.1
# Generasi 458 | Best Fitness: 1925 | avg: 1980.7
# Generasi 459 | Best Fitness: 1925 | avg: 2000.8
# ----- GWO PHASE -----
# GWO Iter 0 Best: 1925 Avg: 1993
# GWO Iter 1 Best: 1925 Avg: 1985
# GWO Iter 2 Best: 1925 Avg: 1982
# GWO Iter 3 Best: 1925 Avg: 1977
# GWO Iter 4 Best: 1925 Avg: 1975
# GWO Iter 5 Best: 1925 Avg: 1974
# GWO Iter 6 Best: 1925 Avg: 1973
# GWO Iter 7 Best: 1925 Avg: 1971
# GWO Iter 8 Best: 1925 Avg: 1971
# GWO Iter 9 Best: 1920 Avg: 1970
# GWO Iter 10 Best: 1920 Avg: 1970
# GWO Iter 11 Best: 1920 Avg: 1970
# GWO Iter 12 Best: 1920 Avg: 1970
# GWO Iter 13 Best: 1920 Avg: 1970
# GWO Iter 14 Best: 1920 Avg: 1970
# GWO Iter 15 Best: 1905 Avg: 1969
# GWO Iter 16 Best: 1905 Avg: 1969
# GWO Iter 17 Best: 1905 Avg: 1966
# GWO Iter 18 Best: 1905 Avg: 1966
# GWO Iter 19 Best: 1905 Avg: 1966
# Generasi 460 | Best Fitness: 1905 | avg: 1965.5
# Generasi 461 | Best Fitness: 1900 | avg: 1973.7
# Generasi 462 | Best Fitness: 1900 | avg: 1980.7
# Generasi 463 | Best Fitness: 1900 | avg: 1983.4
# Generasi 464 | Best Fitness: 1900 | avg: 1962.8
# Generasi 465 | Best Fitness: 1900 | avg: 1958.4
# Generasi 466 | Best Fitness: 1900 | avg: 1982.8
# Generasi 467 | Best Fitness: 1900 | avg: 1965.4
# Generasi 468 | Best Fitness: 1900 | avg: 1972.7
# Generasi 469 | Best Fitness: 1900 | avg: 1988.2
# Generasi 470 | Best Fitness: 1880 | avg: 1969.0
# Generasi 471 | Best Fitness: 1880 | avg: 1967.1
# Generasi 472 | Best Fitness: 1880 | avg: 1967.0
# Generasi 473 | Best Fitness: 1880 | avg: 1955.4
# Generasi 474 | Best Fitness: 1880 | avg: 1959.1
# Generasi 475 | Best Fitness: 1880 | avg: 1951.9
# Generasi 476 | Best Fitness: 1880 | avg: 1966.0
# Generasi 477 | Best Fitness: 1880 | avg: 1937.2
# Generasi 478 | Best Fitness: 1880 | avg: 1937.5
# Generasi 479 | Best Fitness: 1880 | avg: 1950.1
# ----- GWO PHASE -----
# GWO Iter 0 Best: 1880 Avg: 1933
# GWO Iter 1 Best: 1880 Avg: 1931
# GWO Iter 2 Best: 1880 Avg: 1926
# GWO Iter 3 Best: 1880 Avg: 1924
# GWO Iter 4 Best: 1880 Avg: 1922
# GWO Iter 5 Best: 1880 Avg: 1920
# GWO Iter 6 Best: 1880 Avg: 1920
# GWO Iter 7 Best: 1880 Avg: 1920
# GWO Iter 8 Best: 1880 Avg: 1919
# GWO Iter 9 Best: 1880 Avg: 1919
# GWO Iter 10 Best: 1880 Avg: 1919
# GWO Iter 11 Best: 1880 Avg: 1919
# GWO Iter 12 Best: 1880 Avg: 1918
# GWO Iter 13 Best: 1880 Avg: 1918
# GWO Iter 14 Best: 1880 Avg: 1918
# GWO Iter 15 Best: 1880 Avg: 1918
# GWO Iter 16 Best: 1880 Avg: 1918
# GWO Iter 17 Best: 1880 Avg: 1918
# GWO Iter 18 Best: 1880 Avg: 1917
# GWO Iter 19 Best: 1880 Avg: 1915
# Generasi 480 | Best Fitness: 1880 | avg: 1915.3
# Generasi 481 | Best Fitness: 1880 | avg: 1948.2
# Generasi 482 | Best Fitness: 1880 | avg: 1949.9
# Generasi 483 | Best Fitness: 1875 | avg: 1948.1
# Generasi 484 | Best Fitness: 1875 | avg: 1956.2
# Generasi 485 | Best Fitness: 1875 | avg: 1950.0
# Generasi 486 | Best Fitness: 1855 | avg: 1941.1
# Generasi 487 | Best Fitness: 1855 | avg: 1956.8
# Generasi 488 | Best Fitness: 1855 | avg: 1939.4
# Generasi 489 | Best Fitness: 1855 | avg: 1920.0
# Generasi 490 | Best Fitness: 1855 | avg: 1925.0
# Generasi 491 | Best Fitness: 1855 | avg: 1914.9
# Generasi 492 | Best Fitness: 1835 | avg: 1931.4
# Generasi 493 | Best Fitness: 1835 | avg: 1925.9
# Generasi 494 | Best Fitness: 1835 | avg: 1907.1
# Generasi 495 | Best Fitness: 1835 | avg: 1903.8
# Generasi 496 | Best Fitness: 1835 | avg: 1898.7
# Generasi 497 | Best Fitness: 1835 | avg: 1905.8
# Generasi 498 | Best Fitness: 1835 | avg: 1912.8
# Generasi 499 | Best Fitness: 1835 | avg: 1911.1
# ----- GWO PHASE -----
# GWO Iter 0 Best: 1835 Avg: 1912
# GWO Iter 1 Best: 1835 Avg: 1907
# GWO Iter 2 Best: 1835 Avg: 1907
# GWO Iter 3 Best: 1835 Avg: 1905
# GWO Iter 4 Best: 1835 Avg: 1900
# GWO Iter 5 Best: 1825 Avg: 1900
# GWO Iter 6 Best: 1825 Avg: 1900
# GWO Iter 7 Best: 1825 Avg: 1899
# GWO Iter 8 Best: 1825 Avg: 1899
# GWO Iter 9 Best: 1825 Avg: 1898
# GWO Iter 10 Best: 1825 Avg: 1898
# GWO Iter 11 Best: 1825 Avg: 1898
# GWO Iter 12 Best: 1825 Avg: 1898
# GWO Iter 13 Best: 1825 Avg: 1898
# GWO Iter 14 Best: 1825 Avg: 1897
# GWO Iter 15 Best: 1825 Avg: 1896
# GWO Iter 16 Best: 1825 Avg: 1896
# GWO Iter 17 Best: 1825 Avg: 1893
# GWO Iter 18 Best: 1825 Avg: 1891
# GWO Iter 19 Best: 1825 Avg: 1891
# Generasi 500 | Best Fitness: 1825 | avg: 1891.1
# Generasi 501 | Best Fitness: 1825 | avg: 1902.7
# Generasi 502 | Best Fitness: 1825 | avg: 1882.2
# Generasi 503 | Best Fitness: 1825 | avg: 1885.5
# Generasi 504 | Best Fitness: 1815 | avg: 1898.2
# Generasi 505 | Best Fitness: 1815 | avg: 1909.6
# Generasi 506 | Best Fitness: 1815 | avg: 1869.6
# Generasi 507 | Best Fitness: 1815 | avg: 1884.1
# Generasi 508 | Best Fitness: 1795 | avg: 1901.4
# Generasi 509 | Best Fitness: 1795 | avg: 1895.9
# Generasi 510 | Best Fitness: 1795 | avg: 1882.4
# Generasi 511 | Best Fitness: 1795 | avg: 1869.2
# Generasi 512 | Best Fitness: 1795 | avg: 1871.2
# Generasi 513 | Best Fitness: 1795 | avg: 1873.2
# Generasi 514 | Best Fitness: 1775 | avg: 1841.7
# Generasi 515 | Best Fitness: 1775 | avg: 1864.7
# Generasi 516 | Best Fitness: 1775 | avg: 1863.4
# Generasi 517 | Best Fitness: 1775 | avg: 1833.7
# Generasi 518 | Best Fitness: 1775 | avg: 1844.7
# Generasi 519 | Best Fitness: 1775 | avg: 1852.9
# ----- GWO PHASE -----
# GWO Iter 0 Best: 1775 Avg: 1867
# GWO Iter 1 Best: 1775 Avg: 1861
# GWO Iter 2 Best: 1775 Avg: 1855
# GWO Iter 3 Best: 1775 Avg: 1848
# GWO Iter 4 Best: 1775 Avg: 1844
# GWO Iter 5 Best: 1775 Avg: 1842
# GWO Iter 6 Best: 1775 Avg: 1842
# GWO Iter 7 Best: 1775 Avg: 1842
# GWO Iter 8 Best: 1775 Avg: 1842
# GWO Iter 9 Best: 1765 Avg: 1842
# GWO Iter 10 Best: 1765 Avg: 1838
# GWO Iter 11 Best: 1765 Avg: 1838
# GWO Iter 12 Best: 1765 Avg: 1836
# GWO Iter 13 Best: 1765 Avg: 1835
# GWO Iter 14 Best: 1765 Avg: 1835
# GWO Iter 15 Best: 1765 Avg: 1831
# GWO Iter 16 Best: 1765 Avg: 1831
# GWO Iter 17 Best: 1765 Avg: 1831
# GWO Iter 18 Best: 1765 Avg: 1830
# GWO Iter 19 Best: 1765 Avg: 1830
# Generasi 520 | Best Fitness: 1765 | avg: 1829.6
# Generasi 521 | Best Fitness: 1745 | avg: 1849.9
# Generasi 522 | Best Fitness: 1745 | avg: 1822.9
# Generasi 523 | Best Fitness: 1745 | avg: 1825.5
# Generasi 524 | Best Fitness: 1745 | avg: 1815.2
# Generasi 525 | Best Fitness: 1745 | avg: 1833.1
# Generasi 526 | Best Fitness: 1745 | avg: 1798.3
# Generasi 527 | Best Fitness: 1745 | avg: 1813.4
# Generasi 528 | Best Fitness: 1745 | avg: 1808.0
# Generasi 529 | Best Fitness: 1745 | avg: 1810.5
# Generasi 530 | Best Fitness: 1745 | avg: 1813.0
# Generasi 531 | Best Fitness: 1745 | avg: 1809.4
# Generasi 532 | Best Fitness: 1745 | avg: 1816.6
# Generasi 533 | Best Fitness: 1745 | avg: 1832.3
# Generasi 534 | Best Fitness: 1745 | avg: 1806.0
# Generasi 535 | Best Fitness: 1745 | avg: 1817.6
# Generasi 536 | Best Fitness: 1745 | avg: 1825.3
# Generasi 537 | Best Fitness: 1745 | avg: 1833.0
# Generasi 538 | Best Fitness: 1745 | avg: 1811.1
# Generasi 539 | Best Fitness: 1745 | avg: 1825.9
# ----- GWO PHASE -----
# GWO Iter 0 Best: 1735 Avg: 1824
# GWO Iter 1 Best: 1735 Avg: 1823
# GWO Iter 2 Best: 1735 Avg: 1821
# GWO Iter 3 Best: 1735 Avg: 1817
# GWO Iter 4 Best: 1735 Avg: 1814
# GWO Iter 5 Best: 1735 Avg: 1814
# GWO Iter 6 Best: 1735 Avg: 1813
# GWO Iter 7 Best: 1735 Avg: 1810
# GWO Iter 8 Best: 1735 Avg: 1810
# GWO Iter 9 Best: 1735 Avg: 1809
# GWO Iter 10 Best: 1735 Avg: 1809
# GWO Iter 11 Best: 1735 Avg: 1809
# GWO Iter 12 Best: 1735 Avg: 1809
# GWO Iter 13 Best: 1735 Avg: 1809
# GWO Iter 14 Best: 1735 Avg: 1808
# GWO Iter 15 Best: 1735 Avg: 1808
# GWO Iter 16 Best: 1735 Avg: 1808
# GWO Iter 17 Best: 1735 Avg: 1808
# GWO Iter 18 Best: 1735 Avg: 1808
# GWO Iter 19 Best: 1735 Avg: 1808
# Generasi 540 | Best Fitness: 1735 | avg: 1807.6
# Generasi 541 | Best Fitness: 1735 | avg: 1829.9
# Generasi 542 | Best Fitness: 1725 | avg: 1806.7
# Generasi 543 | Best Fitness: 1715 | avg: 1791.5
# Generasi 544 | Best Fitness: 1715 | avg: 1817.3
# Generasi 545 | Best Fitness: 1705 | avg: 1794.7
# Generasi 546 | Best Fitness: 1705 | avg: 1778.2
# Generasi 547 | Best Fitness: 1705 | avg: 1790.2
# Generasi 548 | Best Fitness: 1705 | avg: 1772.2
# Generasi 549 | Best Fitness: 1705 | avg: 1793.1
# Generasi 550 | Best Fitness: 1705 | avg: 1772.4
# Generasi 551 | Best Fitness: 1705 | avg: 1769.8
# Generasi 552 | Best Fitness: 1705 | avg: 1757.0
# Generasi 553 | Best Fitness: 1705 | avg: 1780.1
# Generasi 554 | Best Fitness: 1705 | avg: 1779.1
# Generasi 555 | Best Fitness: 1705 | avg: 1782.5
# Generasi 556 | Best Fitness: 1705 | avg: 1768.5
# Generasi 557 | Best Fitness: 1685 | avg: 1778.4
# Generasi 558 | Best Fitness: 1685 | avg: 1773.3
# Generasi 559 | Best Fitness: 1685 | avg: 1760.8
# ----- GWO PHASE -----
# GWO Iter 0 Best: 1685 Avg: 1763
# GWO Iter 1 Best: 1685 Avg: 1761
# GWO Iter 2 Best: 1685 Avg: 1756
# GWO Iter 3 Best: 1685 Avg: 1752
# GWO Iter 4 Best: 1685 Avg: 1752
# GWO Iter 5 Best: 1685 Avg: 1750
# GWO Iter 6 Best: 1685 Avg: 1750
# GWO Iter 7 Best: 1685 Avg: 1749
# GWO Iter 8 Best: 1685 Avg: 1747
# GWO Iter 9 Best: 1685 Avg: 1746
# GWO Iter 10 Best: 1685 Avg: 1746
# GWO Iter 11 Best: 1685 Avg: 1746
# GWO Iter 12 Best: 1685 Avg: 1744
# GWO Iter 13 Best: 1685 Avg: 1744
# GWO Iter 14 Best: 1685 Avg: 1744
# GWO Iter 15 Best: 1685 Avg: 1744
# GWO Iter 16 Best: 1685 Avg: 1744
# GWO Iter 17 Best: 1685 Avg: 1742
# GWO Iter 18 Best: 1685 Avg: 1742
# GWO Iter 19 Best: 1685 Avg: 1742
# Generasi 560 | Best Fitness: 1685 | avg: 1741.5
# Generasi 561 | Best Fitness: 1670 | avg: 1746.3
# Generasi 562 | Best Fitness: 1670 | avg: 1736.9
# Generasi 563 | Best Fitness: 1665 | avg: 1746.9
# Generasi 564 | Best Fitness: 1665 | avg: 1743.6
# Generasi 565 | Best Fitness: 1665 | avg: 1740.6
# Generasi 566 | Best Fitness: 1665 | avg: 1738.1
# Generasi 567 | Best Fitness: 1665 | avg: 1760.5
# Generasi 568 | Best Fitness: 1665 | avg: 1723.6
# Generasi 569 | Best Fitness: 1645 | avg: 1738.3
# Generasi 570 | Best Fitness: 1645 | avg: 1737.0
# Generasi 571 | Best Fitness: 1645 | avg: 1715.5
# Generasi 572 | Best Fitness: 1645 | avg: 1721.8
# Generasi 573 | Best Fitness: 1645 | avg: 1730.1
# Generasi 574 | Best Fitness: 1645 | avg: 1713.5
# Generasi 575 | Best Fitness: 1645 | avg: 1724.7
# Generasi 576 | Best Fitness: 1645 | avg: 1726.1
# Generasi 577 | Best Fitness: 1645 | avg: 1709.1
# Generasi 578 | Best Fitness: 1645 | avg: 1718.2
# Generasi 579 | Best Fitness: 1630 | avg: 1712.3
# ----- GWO PHASE -----
# GWO Iter 0 Best: 1630 Avg: 1713
# GWO Iter 1 Best: 1630 Avg: 1708
# GWO Iter 2 Best: 1625 Avg: 1704
# GWO Iter 3 Best: 1625 Avg: 1702
# GWO Iter 4 Best: 1625 Avg: 1700
# GWO Iter 5 Best: 1625 Avg: 1695
# GWO Iter 6 Best: 1625 Avg: 1695
# GWO Iter 7 Best: 1625 Avg: 1694
# GWO Iter 8 Best: 1625 Avg: 1694
# GWO Iter 9 Best: 1625 Avg: 1694
# GWO Iter 10 Best: 1625 Avg: 1692
# GWO Iter 11 Best: 1625 Avg: 1691
# GWO Iter 12 Best: 1625 Avg: 1691
# GWO Iter 13 Best: 1625 Avg: 1690
# GWO Iter 14 Best: 1625 Avg: 1687
# GWO Iter 15 Best: 1625 Avg: 1687
# GWO Iter 16 Best: 1605 Avg: 1687
# GWO Iter 17 Best: 1605 Avg: 1687
# GWO Iter 18 Best: 1605 Avg: 1686
# GWO Iter 19 Best: 1605 Avg: 1686
# Generasi 580 | Best Fitness: 1605 | avg: 1686.4
# Generasi 581 | Best Fitness: 1605 | avg: 1686.3
# Generasi 582 | Best Fitness: 1605 | avg: 1673.3
# Generasi 583 | Best Fitness: 1605 | avg: 1698.7
# Generasi 584 | Best Fitness: 1605 | avg: 1688.2
# Generasi 585 | Best Fitness: 1605 | avg: 1686.2
# Generasi 586 | Best Fitness: 1605 | avg: 1681.8
# Generasi 587 | Best Fitness: 1605 | avg: 1673.6
# Generasi 588 | Best Fitness: 1605 | avg: 1681.8
# Generasi 589 | Best Fitness: 1605 | avg: 1664.1
# Generasi 590 | Best Fitness: 1605 | avg: 1662.8
# Generasi 591 | Best Fitness: 1600 | avg: 1653.3
# Generasi 592 | Best Fitness: 1600 | avg: 1684.2
# Generasi 593 | Best Fitness: 1600 | avg: 1673.6
# Generasi 594 | Best Fitness: 1600 | avg: 1666.1
# Generasi 595 | Best Fitness: 1600 | avg: 1673.5
# ...
# Generasi 1301 | Best Fitness: 1085 | avg: 1145.7
# Generasi 1302 | Best Fitness: 1085 | avg: 1142.5
# Generasi 1303 | Best Fitness: 1085 | avg: 1125.6
# Generasi 1304 | Best Fitness: 1085 | avg: 1142.0
# Generasi 1305 | Best Fitness: 1085 | avg: 1139.6
# Generasi 1306 | Best Fitness: 1085 | avg: 1119.8
# Generasi 1307 | Best Fitness: 1085 | avg: 1130.4
# Generasi 1308 | Best Fitness: 1085 | avg: 1141.0
# Generasi 1309 | Best Fitness: 1085 | avg: 1138.7
# Generasi 1310 | Best Fitness: 1085 | avg: 1149.2
# Generasi 1311 | Best Fitness: 1085 | avg: 1127.3
# Generasi 1312 | Best Fitness: 1085 | avg: 1133.6
# Generasi 1313 | Best Fitness: 1085 | avg: 1153.5
# Generasi 1314 | Best Fitness: 1085 | avg: 1129.6
# Generasi 1315 | Best Fitness: 1085 | avg: 1134.2
# Generasi 1316 | Best Fitness: 1085 | avg: 1137.2
# Generasi 1317 | Best Fitness: 1085 | avg: 1151.1
# Generasi 1318 | Best Fitness: 1085 | avg: 1136.0
# Generasi 1319 | Best Fitness: 1085 | avg: 1129.3
# ----- GWO PHASE -----
# GWO Iter 0 Best: 1085 Avg: 1116
# GWO Iter 1 Best: 1085 Avg: 1114
# GWO Iter 2 Best: 1085 Avg: 1113
# GWO Iter 3 Best: 1085 Avg: 1111
# GWO Iter 4 Best: 1085 Avg: 1111
# GWO Iter 5 Best: 1085 Avg: 1110
# GWO Iter 6 Best: 1085 Avg: 1110
# GWO Iter 7 Best: 1085 Avg: 1110
# GWO Iter 8 Best: 1085 Avg: 1110
# GWO Iter 9 Best: 1085 Avg: 1110
# GWO Iter 10 Best: 1085 Avg: 1110
# GWO Iter 11 Best: 1085 Avg: 1110
# GWO Iter 12 Best: 1085 Avg: 1110
# GWO Iter 13 Best: 1085 Avg: 1110
# GWO Iter 14 Best: 1085 Avg: 1108
# GWO Iter 15 Best: 1085 Avg: 1106
# GWO Iter 16 Best: 1085 Avg: 1106
# GWO Iter 17 Best: 1085 Avg: 1106
# GWO Iter 18 Best: 1085 Avg: 1106
# GWO Iter 19 Best: 1085 Avg: 1104
# Generasi 1320 | Best Fitness: 1085 | avg: 1104.1
# Generasi 1321 | Best Fitness: 1085 | avg: 1161.0
# Generasi 1322 | Best Fitness: 1085 | avg: 1131.4
# Generasi 1323 | Best Fitness: 1085 | avg: 1127.7
# Generasi 1324 | Best Fitness: 1085 | avg: 1123.7
# Generasi 1325 | Best Fitness: 1085 | avg: 1153.4
# Generasi 1326 | Best Fitness: 1085 | avg: 1138.3
# Generasi 1327 | Best Fitness: 1085 | avg: 1141.5
# Generasi 1328 | Best Fitness: 1085 | avg: 1138.3
# Generasi 1329 | Best Fitness: 1085 | avg: 1138.4
# Generasi 1330 | Best Fitness: 1085 | avg: 1147.6
# Generasi 1331 | Best Fitness: 1085 | avg: 1138.9
# Generasi 1332 | Best Fitness: 1085 | avg: 1147.5
# Generasi 1333 | Best Fitness: 1085 | avg: 1153.8
# Generasi 1334 | Best Fitness: 1085 | avg: 1136.7
# Generasi 1335 | Best Fitness: 1085 | avg: 1130.1
# Generasi 1336 | Best Fitness: 1085 | avg: 1146.0
# Generasi 1337 | Best Fitness: 1085 | avg: 1141.8
# Generasi 1338 | Best Fitness: 1075 | avg: 1140.4
# Generasi 1339 | Best Fitness: 1075 | avg: 1136.8
# ----- GWO PHASE -----
# GWO Iter 0 Best: 1075 Avg: 1140
# GWO Iter 1 Best: 1075 Avg: 1134
# GWO Iter 2 Best: 1075 Avg: 1134
# GWO Iter 3 Best: 1075 Avg: 1132
# GWO Iter 4 Best: 1075 Avg: 1130
# GWO Iter 5 Best: 1075 Avg: 1130
# GWO Iter 6 Best: 1075 Avg: 1129
# GWO Iter 7 Best: 1075 Avg: 1128
# GWO Iter 8 Best: 1075 Avg: 1126
# GWO Iter 9 Best: 1075 Avg: 1123
# GWO Iter 10 Best: 1075 Avg: 1122
# GWO Iter 11 Best: 1075 Avg: 1122
# GWO Iter 12 Best: 1075 Avg: 1122
# GWO Iter 13 Best: 1075 Avg: 1122
# GWO Iter 14 Best: 1075 Avg: 1122
# GWO Iter 15 Best: 1075 Avg: 1122
# GWO Iter 16 Best: 1075 Avg: 1122
# GWO Iter 17 Best: 1075 Avg: 1122
# GWO Iter 18 Best: 1075 Avg: 1122
# GWO Iter 19 Best: 1075 Avg: 1122
# Generasi 1340 | Best Fitness: 1075 | avg: 1121.7
# Generasi 1341 | Best Fitness: 1075 | avg: 1108.9
# Generasi 1342 | Best Fitness: 1075 | avg: 1113.2
# Generasi 1343 | Best Fitness: 1075 | avg: 1123.8
# Generasi 1344 | Best Fitness: 1075 | avg: 1136.0
# Generasi 1345 | Best Fitness: 1075 | avg: 1120.2
# Generasi 1346 | Best Fitness: 1075 | avg: 1118.3
# Generasi 1347 | Best Fitness: 1075 | avg: 1130.3
# Generasi 1348 | Best Fitness: 1075 | avg: 1108.1
# Generasi 1349 | Best Fitness: 1075 | avg: 1144.0
# Generasi 1350 | Best Fitness: 1075 | avg: 1148.2
# Generasi 1351 | Best Fitness: 1075 | avg: 1114.8
# Generasi 1352 | Best Fitness: 1075 | avg: 1144.5
# Generasi 1353 | Best Fitness: 1075 | avg: 1122.9
# Generasi 1354 | Best Fitness: 1075 | avg: 1136.4
# Generasi 1355 | Best Fitness: 1075 | avg: 1139.6
# Generasi 1356 | Best Fitness: 1075 | avg: 1128.7
# Generasi 1357 | Best Fitness: 1075 | avg: 1126.8
# Generasi 1358 | Best Fitness: 1075 | avg: 1122.9
# Generasi 1359 | Best Fitness: 1075 | avg: 1125.2
# ----- GWO PHASE -----
# GWO Iter 0 Best: 1075 Avg: 1127
# GWO Iter 1 Best: 1075 Avg: 1125
# GWO Iter 2 Best: 1075 Avg: 1124
# GWO Iter 3 Best: 1075 Avg: 1122
# GWO Iter 4 Best: 1075 Avg: 1122
# GWO Iter 5 Best: 1075 Avg: 1122
# GWO Iter 6 Best: 1075 Avg: 1122
# GWO Iter 7 Best: 1075 Avg: 1122
# GWO Iter 8 Best: 1075 Avg: 1122
# GWO Iter 9 Best: 1075 Avg: 1122
# GWO Iter 10 Best: 1075 Avg: 1122
# GWO Iter 11 Best: 1075 Avg: 1122
# GWO Iter 12 Best: 1075 Avg: 1120
# GWO Iter 13 Best: 1075 Avg: 1119
# GWO Iter 14 Best: 1075 Avg: 1119
# GWO Iter 15 Best: 1075 Avg: 1119
# GWO Iter 16 Best: 1075 Avg: 1119
# GWO Iter 17 Best: 1075 Avg: 1119
# GWO Iter 18 Best: 1075 Avg: 1119
# GWO Iter 19 Best: 1075 Avg: 1119
# Generasi 1360 | Best Fitness: 1075 | avg: 1118.8
# Generasi 1361 | Best Fitness: 1075 | avg: 1134.1
# Generasi 1362 | Best Fitness: 1075 | avg: 1142.5
# Generasi 1363 | Best Fitness: 1075 | avg: 1131.9
# Generasi 1364 | Best Fitness: 1075 | avg: 1119.4
# Generasi 1365 | Best Fitness: 1075 | avg: 1120.9
# Generasi 1366 | Best Fitness: 1075 | avg: 1113.8
# Generasi 1367 | Best Fitness: 1075 | avg: 1124.7
# Generasi 1368 | Best Fitness: 1075 | avg: 1130.2
# Generasi 1369 | Best Fitness: 1075 | avg: 1116.9
# Generasi 1370 | Best Fitness: 1075 | avg: 1144.4
# Generasi 1371 | Best Fitness: 1075 | avg: 1126.3
# Generasi 1372 | Best Fitness: 1075 | avg: 1143.2
# Generasi 1373 | Best Fitness: 1055 | avg: 1136.8
# Generasi 1374 | Best Fitness: 1055 | avg: 1107.7
# Generasi 1375 | Best Fitness: 1055 | avg: 1106.6
# Generasi 1376 | Best Fitness: 1055 | avg: 1103.9
# Generasi 1377 | Best Fitness: 1055 | avg: 1106.8
# Generasi 1378 | Best Fitness: 1055 | avg: 1107.1
# Generasi 1379 | Best Fitness: 1055 | avg: 1095.2
# ----- GWO PHASE -----
# GWO Iter 0 Best: 1055 Avg: 1100
# GWO Iter 1 Best: 1055 Avg: 1097
# GWO Iter 2 Best: 1055 Avg: 1095
# GWO Iter 3 Best: 1055 Avg: 1093
# GWO Iter 4 Best: 1055 Avg: 1093
# GWO Iter 5 Best: 1055 Avg: 1093
# GWO Iter 6 Best: 1055 Avg: 1093
# GWO Iter 7 Best: 1055 Avg: 1093
# GWO Iter 8 Best: 1055 Avg: 1093
# GWO Iter 9 Best: 1055 Avg: 1092
# GWO Iter 10 Best: 1055 Avg: 1092
# GWO Iter 11 Best: 1055 Avg: 1092
# GWO Iter 12 Best: 1055 Avg: 1092
# GWO Iter 13 Best: 1055 Avg: 1092
# GWO Iter 14 Best: 1055 Avg: 1088
# GWO Iter 15 Best: 1055 Avg: 1088
# GWO Iter 16 Best: 1055 Avg: 1088
# GWO Iter 17 Best: 1055 Avg: 1088
# GWO Iter 18 Best: 1055 Avg: 1088
# GWO Iter 19 Best: 1055 Avg: 1087
# Generasi 1380 | Best Fitness: 1055 | avg: 1086.8
# Generasi 1381 | Best Fitness: 1055 | avg: 1091.4
# Generasi 1382 | Best Fitness: 1055 | avg: 1097.4
# Generasi 1383 | Best Fitness: 1055 | avg: 1118.0
# Generasi 1384 | Best Fitness: 1055 | avg: 1132.7
# Generasi 1385 | Best Fitness: 1055 | avg: 1113.4
# Generasi 1386 | Best Fitness: 1055 | avg: 1107.2
# Generasi 1387 | Best Fitness: 1055 | avg: 1099.5
# Generasi 1388 | Best Fitness: 1055 | avg: 1122.8
# Generasi 1389 | Best Fitness: 1055 | avg: 1113.3
# Generasi 1390 | Best Fitness: 1055 | avg: 1108.4
# Generasi 1391 | Best Fitness: 1055 | avg: 1100.3
# Generasi 1392 | Best Fitness: 1055 | avg: 1099.4
# Generasi 1393 | Best Fitness: 1055 | avg: 1098.4
# Generasi 1394 | Best Fitness: 1055 | avg: 1098.0
# Generasi 1395 | Best Fitness: 1055 | avg: 1106.4
# Generasi 1396 | Best Fitness: 1055 | avg: 1103.5
# Generasi 1397 | Best Fitness: 1055 | avg: 1096.2
# Generasi 1398 | Best Fitness: 1055 | avg: 1102.6
# Generasi 1399 | Best Fitness: 1055 | avg: 1114.0
# ----- GWO PHASE -----
# GWO Iter 0 Best: 1055 Avg: 1108
# GWO Iter 1 Best: 1055 Avg: 1102
# GWO Iter 2 Best: 1055 Avg: 1102
# GWO Iter 3 Best: 1055 Avg: 1101
# GWO Iter 4 Best: 1055 Avg: 1101
# GWO Iter 5 Best: 1055 Avg: 1100
# GWO Iter 6 Best: 1055 Avg: 1100
# GWO Iter 7 Best: 1055 Avg: 1100
# GWO Iter 8 Best: 1055 Avg: 1100
# GWO Iter 9 Best: 1055 Avg: 1098
# GWO Iter 10 Best: 1055 Avg: 1098
# GWO Iter 11 Best: 1055 Avg: 1098
# GWO Iter 12 Best: 1055 Avg: 1098
# GWO Iter 13 Best: 1055 Avg: 1098
# GWO Iter 14 Best: 1055 Avg: 1098
# GWO Iter 15 Best: 1055 Avg: 1098
# GWO Iter 16 Best: 1055 Avg: 1098
# GWO Iter 17 Best: 1055 Avg: 1098
# GWO Iter 18 Best: 1055 Avg: 1098
# GWO Iter 19 Best: 1055 Avg: 1098
# Generasi 1400 | Best Fitness: 1055 | avg: 1097.5
# Generasi 1401 | Best Fitness: 1055 | avg: 1106.7
# Generasi 1402 | Best Fitness: 1055 | avg: 1124.0
# Generasi 1403 | Best Fitness: 1055 | avg: 1106.6
# Generasi 1404 | Best Fitness: 1055 | avg: 1099.8
# Generasi 1405 | Best Fitness: 1055 | avg: 1113.3
# Generasi 1406 | Best Fitness: 1055 | avg: 1107.4
# Generasi 1407 | Best Fitness: 1055 | avg: 1096.9
# Generasi 1408 | Best Fitness: 1055 | avg: 1111.0
# Generasi 1409 | Best Fitness: 1055 | avg: 1107.9
# Generasi 1410 | Best Fitness: 1055 | avg: 1100.1
# Generasi 1411 | Best Fitness: 1055 | avg: 1105.4
# Generasi 1412 | Best Fitness: 1055 | avg: 1112.1
# Generasi 1413 | Best Fitness: 1055 | avg: 1111.6
# Generasi 1414 | Best Fitness: 1055 | avg: 1108.2
# Generasi 1415 | Best Fitness: 1055 | avg: 1100.8
# Generasi 1416 | Best Fitness: 1055 | avg: 1109.4
# Generasi 1417 | Best Fitness: 1055 | avg: 1117.8
# Generasi 1418 | Best Fitness: 1055 | avg: 1100.4
# Generasi 1419 | Best Fitness: 1055 | avg: 1112.2
# ----- GWO PHASE -----
# GWO Iter 0 Best: 1055 Avg: 1095
# GWO Iter 1 Best: 1055 Avg: 1094
# GWO Iter 2 Best: 1055 Avg: 1092
# GWO Iter 3 Best: 1055 Avg: 1091
# GWO Iter 4 Best: 1055 Avg: 1091
# GWO Iter 5 Best: 1055 Avg: 1091
# GWO Iter 6 Best: 1055 Avg: 1091
# GWO Iter 7 Best: 1055 Avg: 1091
# GWO Iter 8 Best: 1055 Avg: 1091
# GWO Iter 9 Best: 1055 Avg: 1091
# GWO Iter 10 Best: 1035 Avg: 1090
# GWO Iter 11 Best: 1035 Avg: 1090
# GWO Iter 12 Best: 1035 Avg: 1090
# GWO Iter 13 Best: 1035 Avg: 1090
# GWO Iter 14 Best: 1035 Avg: 1090
# GWO Iter 15 Best: 1035 Avg: 1090
# GWO Iter 16 Best: 1035 Avg: 1090
# GWO Iter 17 Best: 1035 Avg: 1090
# GWO Iter 18 Best: 1035 Avg: 1090
# GWO Iter 19 Best: 1035 Avg: 1090
# Generasi 1420 | Best Fitness: 1035 | avg: 1090.2
# Generasi 1421 | Best Fitness: 1035 | avg: 1100.4
# Generasi 1422 | Best Fitness: 1035 | avg: 1078.9
# Generasi 1423 | Best Fitness: 1035 | avg: 1068.6
# Generasi 1424 | Best Fitness: 1035 | avg: 1080.2
# Generasi 1425 | Best Fitness: 1035 | avg: 1085.2
# Generasi 1426 | Best Fitness: 1035 | avg: 1083.3
# Generasi 1427 | Best Fitness: 1035 | avg: 1070.0
# Generasi 1428 | Best Fitness: 1035 | avg: 1079.9
# Generasi 1429 | Best Fitness: 1035 | avg: 1098.8
# Generasi 1430 | Best Fitness: 1035 | avg: 1107.9
# Generasi 1431 | Best Fitness: 1035 | avg: 1084.8
# Generasi 1432 | Best Fitness: 1035 | avg: 1088.2
# Generasi 1433 | Best Fitness: 1035 | avg: 1086.2
# Generasi 1434 | Best Fitness: 1035 | avg: 1089.4
# Generasi 1435 | Best Fitness: 1035 | avg: 1095.1
# Generasi 1436 | Best Fitness: 1035 | avg: 1100.3
# Generasi 1437 | Best Fitness: 1035 | avg: 1076.8
# Generasi 1438 | Best Fitness: 1035 | avg: 1087.2
# Generasi 1439 | Best Fitness: 1035 | avg: 1092.7
# ----- GWO PHASE -----
# GWO Iter 0 Best: 1035 Avg: 1086
# GWO Iter 1 Best: 1035 Avg: 1084
# GWO Iter 2 Best: 1035 Avg: 1083
# GWO Iter 3 Best: 1035 Avg: 1083
# GWO Iter 4 Best: 1035 Avg: 1083
# GWO Iter 5 Best: 1035 Avg: 1082
# GWO Iter 6 Best: 1035 Avg: 1082
# GWO Iter 7 Best: 1035 Avg: 1082
# GWO Iter 8 Best: 1035 Avg: 1082
# GWO Iter 9 Best: 1035 Avg: 1080
# GWO Iter 10 Best: 1020 Avg: 1079
# GWO Iter 11 Best: 1020 Avg: 1079
# GWO Iter 12 Best: 1020 Avg: 1077
# GWO Iter 13 Best: 1020 Avg: 1077
# GWO Iter 14 Best: 1020 Avg: 1077
# GWO Iter 15 Best: 1020 Avg: 1077
# GWO Iter 16 Best: 1020 Avg: 1077
# GWO Iter 17 Best: 1020 Avg: 1077
# GWO Iter 18 Best: 1020 Avg: 1077
# GWO Iter 19 Best: 1020 Avg: 1077
# Generasi 1440 | Best Fitness: 1020 | avg: 1077.2
# Generasi 1441 | Best Fitness: 1020 | avg: 1081.1
# Generasi 1442 | Best Fitness: 1020 | avg: 1087.4
# Generasi 1443 | Best Fitness: 1020 | avg: 1069.6
# Generasi 1444 | Best Fitness: 1020 | avg: 1080.5
# Generasi 1445 | Best Fitness: 1020 | avg: 1076.8
# Generasi 1446 | Best Fitness: 1020 | avg: 1058.4
# Generasi 1447 | Best Fitness: 1020 | avg: 1070.5
# Generasi 1448 | Best Fitness: 1020 | avg: 1074.0
# Generasi 1449 | Best Fitness: 1020 | avg: 1076.9
# Generasi 1450 | Best Fitness: 1020 | avg: 1086.0
# Generasi 1451 | Best Fitness: 1020 | avg: 1089.9
# Generasi 1452 | Best Fitness: 1020 | avg: 1077.0
# Generasi 1453 | Best Fitness: 1020 | avg: 1079.8
# Generasi 1454 | Best Fitness: 1020 | avg: 1060.0
# Generasi 1455 | Best Fitness: 1020 | avg: 1063.6
# Generasi 1456 | Best Fitness: 1020 | avg: 1060.4
# Generasi 1457 | Best Fitness: 1020 | avg: 1060.4
# Generasi 1458 | Best Fitness: 1020 | avg: 1078.5
# Generasi 1459 | Best Fitness: 1020 | avg: 1061.6
# ----- GWO PHASE -----
# GWO Iter 0 Best: 1020 Avg: 1056
# GWO Iter 1 Best: 1020 Avg: 1054
# GWO Iter 2 Best: 1020 Avg: 1051
# GWO Iter 3 Best: 1020 Avg: 1050
# GWO Iter 4 Best: 1020 Avg: 1050
# GWO Iter 5 Best: 1020 Avg: 1050
# GWO Iter 6 Best: 1020 Avg: 1046
# GWO Iter 7 Best: 1020 Avg: 1046
# GWO Iter 8 Best: 1020 Avg: 1046
# GWO Iter 9 Best: 1020 Avg: 1044
# GWO Iter 10 Best: 1020 Avg: 1044
# GWO Iter 11 Best: 1020 Avg: 1044
# GWO Iter 12 Best: 1020 Avg: 1044
# GWO Iter 13 Best: 1020 Avg: 1044
# GWO Iter 14 Best: 1020 Avg: 1044
# GWO Iter 15 Best: 1020 Avg: 1044
# GWO Iter 16 Best: 1020 Avg: 1044
# GWO Iter 17 Best: 1020 Avg: 1044
# GWO Iter 18 Best: 1020 Avg: 1044
# GWO Iter 19 Best: 1020 Avg: 1044
# Generasi 1460 | Best Fitness: 1020 | avg: 1044.1
# Generasi 1461 | Best Fitness: 1020 | avg: 1091.5
# Generasi 1462 | Best Fitness: 1020 | avg: 1077.4
# Generasi 1463 | Best Fitness: 1020 | avg: 1082.0
# Generasi 1464 | Best Fitness: 1020 | avg: 1071.5
# Generasi 1465 | Best Fitness: 1020 | avg: 1061.8
# Generasi 1466 | Best Fitness: 1020 | avg: 1084.3
# Generasi 1467 | Best Fitness: 1020 | avg: 1075.7
# Generasi 1468 | Best Fitness: 1020 | avg: 1077.9
# Generasi 1469 | Best Fitness: 1020 | avg: 1067.8
# Generasi 1470 | Best Fitness: 1020 | avg: 1065.0
# Generasi 1471 | Best Fitness: 1020 | avg: 1072.4
# Generasi 1472 | Best Fitness: 1020 | avg: 1100.1
# Generasi 1473 | Best Fitness: 1020 | avg: 1068.0
# Generasi 1474 | Best Fitness: 1020 | avg: 1084.7
# Generasi 1475 | Best Fitness: 1020 | avg: 1075.4
# Generasi 1476 | Best Fitness: 1020 | avg: 1069.0
# Generasi 1477 | Best Fitness: 1020 | avg: 1082.2
# Generasi 1478 | Best Fitness: 1020 | avg: 1063.4
# Generasi 1479 | Best Fitness: 1020 | avg: 1089.7
# ----- GWO PHASE -----
# GWO Iter 0 Best: 1020 Avg: 1064
# GWO Iter 1 Best: 1020 Avg: 1062
# GWO Iter 2 Best: 1020 Avg: 1061
# GWO Iter 3 Best: 1020 Avg: 1057
# GWO Iter 4 Best: 1020 Avg: 1053
# GWO Iter 5 Best: 1020 Avg: 1052
# GWO Iter 6 Best: 1020 Avg: 1052
# GWO Iter 7 Best: 1020 Avg: 1050
# GWO Iter 8 Best: 1020 Avg: 1050
# GWO Iter 9 Best: 1020 Avg: 1050
# GWO Iter 10 Best: 1020 Avg: 1048
# GWO Iter 11 Best: 1020 Avg: 1048
# GWO Iter 12 Best: 1020 Avg: 1048
# GWO Iter 13 Best: 1020 Avg: 1046
# GWO Iter 14 Best: 1020 Avg: 1044
# GWO Iter 15 Best: 1020 Avg: 1044
# GWO Iter 16 Best: 1020 Avg: 1044
# GWO Iter 17 Best: 1020 Avg: 1044
# GWO Iter 18 Best: 1020 Avg: 1043
# GWO Iter 19 Best: 1020 Avg: 1043
# Generasi 1480 | Best Fitness: 1020 | avg: 1043.3
# Generasi 1481 | Best Fitness: 1020 | avg: 1057.5
# Generasi 1482 | Best Fitness: 1020 | avg: 1062.2
# Generasi 1483 | Best Fitness: 1020 | avg: 1075.5
# Generasi 1484 | Best Fitness: 1020 | avg: 1072.2
# Generasi 1485 | Best Fitness: 1020 | avg: 1055.0
# Generasi 1486 | Best Fitness: 1020 | avg: 1061.3
# Generasi 1487 | Best Fitness: 1020 | avg: 1054.5
# Generasi 1488 | Best Fitness: 1020 | avg: 1076.5
# Generasi 1489 | Best Fitness: 1020 | avg: 1062.7
# Generasi 1490 | Best Fitness: 1020 | avg: 1098.4
# Generasi 1491 | Best Fitness: 1020 | avg: 1066.5
# Generasi 1492 | Best Fitness: 1020 | avg: 1091.2
# Generasi 1493 | Best Fitness: 1020 | avg: 1078.2
# Generasi 1494 | Best Fitness: 1020 | avg: 1067.2
# Generasi 1495 | Best Fitness: 1020 | avg: 1058.4
# Generasi 1496 | Best Fitness: 1020 | avg: 1083.1
# Generasi 1497 | Best Fitness: 1020 | avg: 1077.0
# Generasi 1498 | Best Fitness: 1020 | avg: 1051.1
# Generasi 1499 | Best Fitness: 1020 | avg: 1079.3
# Best Fitness: 1020
# Detail Evaluasi:
# {'guruBentrok': 0, 'distribusiMapel': 31, 'mapelSiang': 0, 'durasiGuru': 1, 'waktuMGMP': 2, 'cekWaliKelas': 8, 'konsistensiGuruMapel': 17}

# %%
kelas = 0
ind = 0

print("Mapel kelas", kelas+1)
print(pop_mapel[ind, kelas])

print("Guru kelas", kelas+1)
print(pop_guru[ind, kelas])
# Out:
# Mapel kelas 1
# [ 4  4  6  6  6  5  5  4  4  7  7  7 12 12 12  1  1  3  3  3  3  3 10 10
#  13 13  5  5  2  2  8  8  9  9 11 11]
# Guru kelas 1
# [19 19  2  2  2 27 27 19 19 37 37 37 51 51 51 31 31 36 36 36 36 36 15 15
#  53 53 27 27 39 39 17 17 38 38 43 43]

# %%
best_index = best["index"]

best_mapel = pop_mapel[best_index]
best_guru  = pop_guru[best_index]

# %%
# print(best_mapel[0])
# print(type(best_mapel[0]))

# %% [markdown]
# ---
# # EXPORT FITNESS (OUTPUT)

# %%
path_file = os.path.join("../hasil/bestFitness", FITNESS_EXPORT)

with open(path_file, mode="w", newline="") as file:

    writer = csv.writer(file)

    writer.writerow(["kelas","slot","mapel","guru"])

    for kelas in range(len(best_mapel)):

        for slot in range(len(best_mapel[kelas])):

            mapel = best_mapel[kelas][slot]
            guru  = best_guru[kelas][slot]

            writer.writerow([
                kelas + 1,
                slot+ 1,
                mapel,
                guru
            ])

# %% [markdown]
# ---
# # Example

# %%
kelas_idx = 1

data = []

for slot in range(SLOT_PER_KELAS):

    mapel_id = best_mapel[kelas_idx, slot]
    guru_id  = best_guru[kelas_idx, slot]
    hari     = slotHari[slot]

    data.append({
        "Slot": slot + 1,
        "Hari": hari,
        "Mapel": mapel_id,
        "Guru": guru_id
    })

df = pd.DataFrame(data)

print(df)
# Out:
#     Slot  Hari  Mapel  Guru
# 0      1     1     11    37
# 1      2     1     11    37
# 2      3     1     12    51
# 3      4     1     12    51
# 4      5     1     12    51
# 5      6     1      8    23
# 6      7     1      8    23
# 7      8     1      7    21
# 8      9     2      7    21
# 9     10     2      7    21
# 10    11     2      1    31
# 11    12     2      1    31
# 12    13     2      4    19
# 13    14     2      4    19
# 14    15     2      2    45
# 15    16     2      2    45
# 16    17     3      9    42
# 17    18     3      9    42
# 18    19     3      5    18
# 19    20     3      5    18
# 20    21     3     13    53
# 21    22     3     13    53
# 22    23     3      5    18
# 23    24     3      5    18
# 24    25     4      6     2
# 25    26     4      6     2
# 26    27     4      6     2
# 27    28     4      3    36
# 28    29     4      3    36
# 29    30     4     10    47
# 30    31     4     10    47
# 31    32     5      3    36
# 32    33     5      3    36
# 33    34     5      3    36
# 34    35     5      4    19
# 35    36     5      4    19

# %% [markdown]
# ---
#
# # Bimbingan 12/03/2026

# %% [markdown]
# mulai pengerjaan jurnal (UI opsional)
# buku TA
# apakah boleh fitness != 0
# UI nya hanya crud via spreadsheet, yang penting page generate jadwal
# dokumentasikan iterasi untuk diagram garis
# mutasi dan crossover
# minus GWO
# bikin template excell UI untuk CRUD
#
# ===================================================
# before (sistem akbar)
# 21680 awal data masuk
#
# after (sistem akbar)
# 2480 akhir stelah optimasi
#
# hal manual vs digitalize = apakah jadwal lebih oke atau tidak?
# perbandingan runtime GA single vs GA-GWO
#
# SK keluar tgl nya februari
#
# kemudian bisa ngisi bimgingna online

# %% [markdown]
# ---
# # catatan saya
# Generate Population
#
# FOR generation
#
#     Evaluasi Fitness
#
#     GA Operator
#         Selection
#         Crossover
#         Mutation
#
#     GWO Local Search
#         update solusi menuju alpha beta delta
#
#     Repair Operator
#
# END

# %% [markdown]
# # CRUD
# # halaman generate jadwal ()

# %% [markdown]
# # /master

# %% [markdown]
# # Bimbingan 17/03
#
# tampilkan ebfore after evaluasi
#
# pertanyaan yang masih ada = optimasi bisa jadi ke oke an jadwal, parameter keberhasilan (detail evaluasi)
#
# introduction = tambahkan urgensi objek
#
# parameter dikasih tau di methodology
#
# introduction = kasih spill jadwal
#
# metolodogi = tambahkan flowchart dari data masuk hingga settigan GA dan GWO hingga output
#
# hasil pertama = jadwal seperti apa | tabel detail evaluasi | runtime
#
# hasil = grafik ditambahkan di akhir
#
# convergence analysis = convergence handle
#
# membandingkan GA biasa | Guided GA | guided GA GWO = skenario 2
